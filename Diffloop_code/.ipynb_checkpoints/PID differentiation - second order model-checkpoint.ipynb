# %%
import numpy as np
import scipy
import torch
from matplotlib import pyplot as plt
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable 
import control
from control import matlab
from matplotlib import cm

np.random.seed(0)
dev = "cpu"  
device = torch.device(dev)

# %%
sysA = np.array([[1.001,0],[0.0013,1.0]])
#sysA = 0.99
sysB = np.array([[0.04],[0.0]])
sysC = np.array([0,2])
sysD = 0
print(np.linalg.eig(sysA))
kp = 20.0
ki = 2.0
kd = 5.0
Tf = 0.01
# Out:
# (array([1.   , 1.001]), array([[0.        , 0.60971076],
#        [1.        , 0.79262399]]))

# %%
T = 2000
refs = np.zeros((30,T))
np.random.seed(2)

randval = 0

for i in range(30):
  refs[i,0:300] = 0
  randval = 5.8*np.random.rand()-2.9
  print(randval)  
  if randval>0 and randval<1:
    randval = 1
  if randval<0 and randval>-1:
    randval = -1
  refs[i,300:] = randval
# Out:
# -0.37122956757637837
# -2.7496278553982303
# 0.28804237169651303
# -0.37513012281399405
# -0.46186674789256355
# -0.9840580381775301
# -1.7130379225805135
# 0.6917716048338494
# -1.1620028926877657
# -1.3524018044033734
# 0.7025762300619105
# 0.16902414680682654
# -2.1194363169993853
# 0.07875310334132912
# -1.8302487792478914
# 1.6549438573367063
# 2.0530566973090347
# -0.03342634318481874
# 2.010056615073314
# -2.4380562333474463
# 0.030427322705882887
# -2.521338274556107
# -0.41689049993514127
# -2.340120689168447
# -2.162472164132591
# 0.5611227920758557
# -1.589130396495432
# -2.2797150310020986
# -1.6222239989907536
# -0.8710075469808642

# %%
ref = refs[1,:]
ysat = np.zeros((T,))
uvalssat = np.zeros((T,))
xcont = 0
u = 0
D = 0
ad = Tf/(Tf+0.01)
bd = kd/(Tf+0.01)
noise = 0.01*np.random.randn(T,1)

x0 = np.zeros((2,1))
x = x0
for i in range(T):
   ysat[i] = np.dot(sysC,x)+np.dot(sysD,u)+noise[i]
   xcont = xcont+(ref[i]-ysat[i])
   if(i>0):
     D = ad*D-bd*(ysat[i]-ysat[i-1])  
     u = 0.01*ki*xcont+kp*(ref[i]-ysat[i])+D
   if(u>3.0):
     u=3.0
   elif(u<-3.0):
     u=-3.0
   uvalssat[i] = u;
   x = np.dot(sysA,x)+np.dot(sysB,u);

ynosat = np.zeros((T,))
uvalsnosat = np.zeros((T,))
xcont = 0;
u = 0;
x = x0
D = 0

for i in range(T):
   ynosat[i] = np.dot(sysC,x)+np.dot(sysD,u)+noise[i]
   xcont = xcont+(ref[i]-ynosat[i])
   if(i>0):
     D = ad*D-bd*(ynosat[i]-ynosat[i-1])  
     u = 0.01*ki*xcont+kp*(ref[i]-ynosat[i])+D 
   uvalsnosat[i] = u;
   x = np.dot(sysA,x)+np.dot(sysB,u);

# %%
plt.figure
plt.plot(0.01*np.arange(T),ynosat)
plt.plot(0.01*np.arange(T),ysat)
plt.plot(0.01*np.arange(T),ref)
plt.xlabel("Time (s)")
plt.ylabel("Output")
plt.legend(["No saturation","Saturation","Reference"])
plt.show()

plt.figure
plt.plot(0.01*np.arange(T),uvalsnosat)
plt.plot(0.01*np.arange(T),uvalssat)
plt.xlabel("Time (s)")
plt.ylabel("Input")
plt.legend(["No saturation","Saturation"])
plt.show()

# %%
class neuralPID(torch.nn.Module):
   def __init__(self):
    super(neuralPID, self).__init__()
    torch.manual_seed(2)
    self.kplayer1 = torch.nn.Linear(2,2)
    self.kplayer2 = torch.nn.Linear(2,1)
    self.kilayer1 = torch.nn.Linear(2,2)
    self.kilayer2 = torch.nn.Linear(2,1)
    self.kdlayer1 = torch.nn.Linear(2,2)
    self.kdlayer2 = torch.nn.Linear(2,1)
    self.backlayer1 = torch.nn.Linear(2,2)
    self.backlayer2 = torch.nn.Linear(2,1)
  
   def forward(self,x):
    sigmoid = torch.nn.Tanh()
    kp = self.kplayer2(sigmoid(self.kplayer1(x)))
    ki = self.kilayer2(sigmoid(self.kilayer1(x)))
    kd = self.kdlayer2(sigmoid(self.kdlayer1(x)))
    back = self.backlayer2(sigmoid(self.backlayer1(x)))
    #kd = torch.clamp(kd,0,400)
    #kp = torch.clamp(kp,0,400)
    #ki = torch.clamp(ki,0,400)
    return kp,ki,kd,back

# %%
Tft = torch.tensor(Tf,requires_grad=True)
kpit = torch.tensor(kp,requires_grad=False)
kiit = torch.tensor(ki,requires_grad=False)
kdit = torch.tensor(kd,requires_grad=False)
backit = torch.tensor(0.1,requires_grad=False)

systA = torch.tensor(sysA,requires_grad=False)
systB = torch.tensor(sysB,requires_grad=False)
systC = torch.tensor(sysC,requires_grad=False)
systD = torch.tensor(sysD,requires_grad=False)

# %%
costinit = np.zeros((30,))

yinit = np.zeros((30,T))
uinit = np.zeros((30,T))
Tft = torch.tensor(Tf,requires_grad=True)
kpit = torch.tensor(kp,requires_grad=False)
kiit = torch.tensor(ki,requires_grad=False)
kdit = torch.tensor(kd,requires_grad=False)

systA = torch.tensor(sysA,requires_grad=False)
systB = torch.tensor(sysB,requires_grad=False)
systC = torch.tensor(sysC,requires_grad=False)
systD = torch.tensor(sysD,requires_grad=False)

for iters in range(0,30):
  ref = refs[iters,:]
  reft = torch.tensor(ref)
  noise = 0.01*torch.randn(T,1)

  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0],[0.0]],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  D  = torch.tensor([0.0],requires_grad=False)
  #torch.clamp(Tft,0.1,0.1)
  ad = torch.div(Tft,(Tft+0.01))
  
  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t];
    yinit[iters,t] = yt.clone().detach().numpy()
    #print(yt)
    #error = torch.tensor(reft[t]-yt,requires_grad=False)
    err = ref[t]-yt
    xcont = xcont+err
    if(t>0):
       #print(t,kpt,kit,kdt)
       #break;
       bd = torch.div(kdit,(Tft+0.01))
       D = ad*D-bd*(yt-yold);  
       u = (0.01*kiit*xcont+kpit*(ref[t]-yt)+D)
       u = torch.clamp(u,-3.0,3.0)
    uinit[iters,t] = u.clone().detach().numpy()
    x = torch.matmul(systA.float(),x)+systB.float()*u;
    cost = cost+(reft[t]-yt)**2
  costinit[iters] = cost.detach().numpy()

# %%
print(costinit)
plt.figure()
plt.plot(refs[1,:])
plt.plot(yinit[1,:])
# Out:
# [  47.01304626 1016.48278809   50.11792755   54.2663269    46.9082222
#    53.19108582  220.42596436   53.51212311   77.34220123  115.39278412
#    51.04141998   53.1942215   438.03295898   51.50717163  276.22961426
#   196.55462646  386.084198     52.52241135  375.5010376   671.57568359
#    52.12036133  802.00561523   54.08621597  593.55383301  483.34362793
#    51.3580246   188.71440125  565.21588135  200.6414032    50.77825546]

# %%
# Initialize network
Tft = torch.tensor(Tf,requires_grad=True)
kpit = torch.tensor(kp,requires_grad=False)
kiit = torch.tensor(ki,requires_grad=False)
kdit = torch.tensor(kd,requires_grad=False)
backit = torch.tensor(0.1,requires_grad=False)

kpt = torch.tensor(kp,requires_grad=True)
kit = torch.tensor(ki,requires_grad=True)
kdt = torch.tensor(kd,requires_grad=True)
backt = torch.tensor(0.1,requires_grad=True)

systA = torch.tensor(sysA,requires_grad=False)
systB = torch.tensor(sysB,requires_grad=False)
systC = torch.tensor(sysC,requires_grad=False)
systD = torch.tensor(sysD,requires_grad=False)

PIDparams = neuralPID()
#optimizer = torch.optim.Adam((PIDparams.parameters()), lr=0.1)
#for iters in range(1000):
#   kpt,kit,kdt = PIDparams(torch.randn(3,))
#   print(kpt,kit,kdt)
#   loss = (kpt-kpit)**2+(kit-kiit)**2+(kdt-kdit)**2
#   optimizer.zero_grad()
#   loss.backward()
#   optimizer.step()    
   #print(iters,loss)

# %%
ysat = np.zeros((T,))
uvalssat = np.zeros((T,))

optimizer = torch.optim.Adam((PIDparams.parameters()), lr=0.1, weight_decay=0.1)

smooth = 0.9
closs = 0
dtlossvals = []

for episodes in range(401):
  cepisode = episodes%20  
  if(cepisode==0):  
    episodeorder = np.random.choice(20, 20, replace=False)
  ref = refs[episodeorder[cepisode],:]
  reft = torch.tensor(ref)  
  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0],[0.0]],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  ucmd = torch.tensor([0.0],requires_grad=True)
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  D  = torch.tensor([0.0],requires_grad=False)
  ad = torch.div(Tft,(Tft+0.01))
  noise = 0.01*torch.randn(T,1)
  kpt = kpt.clone().detach()
  kit = kit.clone().detach()
  kdt = kdt.clone().detach()
  backt = backt.clone().detach()

  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t]
    saterr = u-ucmd
    err = reft[t]-yt
    ninput = torch.cat((err.detach(),saterr.detach()),0)
    kpdt,kidt,kddt,backdt = PIDparams(ninput)
    kpt = smooth*kpt+(1-smooth)*(kpit+kpdt)
    kit = smooth*kit+(1-smooth)*(kiit+kidt)
    kdt = smooth*kdt+(1-smooth)*(kdit+kddt)
    backt = smooth*backt+(1-smooth)*(backit+backdt)
    xcont = xcont+kit*err+backt*saterr.detach()
    if(t>0):
      bd = torch.div(kdt,(Tft+0.01))
      D = ad*D-bd*(yt-yold);  
      ucmd = (0.01*xcont+kpt*(reft[t]-yt)+D)
      u = torch.clamp(ucmd,-3.0,3.0)
    x = torch.matmul(systA.float(),x)+systB.float()*u;
    cost = cost+(reft[t]-yt)**2
  closs = closs+cost   
  if(episodes%120<20):
    print(episodes,cost)
  if(episodes%20==19):    
    dtlossvals.append(closs.clone().detach().numpy()[0]/20)
    closs = 0  
  optimizer.zero_grad()
  cost.backward()
  optimizer.step()
# Out:
# 0 tensor([116.3846], grad_fn=<AddBackward0>)
# 1 tensor([50.4741], grad_fn=<AddBackward0>)
# 2 tensor([574.9426], grad_fn=<AddBackward0>)
# 3 tensor([47.5495], grad_fn=<AddBackward0>)
# 4 tensor([481.2198], grad_fn=<AddBackward0>)
# 5 tensor([220.8424], grad_fn=<AddBackward0>)
# 6 tensor([50.1554], grad_fn=<AddBackward0>)
# 7 tensor([50.1604], grad_fn=<AddBackward0>)
# 8 tensor([695.3746], grad_fn=<AddBackward0>)
# 9 tensor([59.4879], grad_fn=<AddBackward0>)
# 10 tensor([56.6034], grad_fn=<AddBackward0>)
# 11 tensor([212.3681], grad_fn=<AddBackward0>)
# 12 tensor([51.2925], grad_fn=<AddBackward0>)
# 13 tensor([111.6787], grad_fn=<AddBackward0>)
# 14 tensor([73.8493], grad_fn=<AddBackward0>)
# 15 tensor([303.1103], grad_fn=<AddBackward0>)
# 16 tensor([262.5109], grad_fn=<AddBackward0>)
# 17 tensor([46.8761], grad_fn=<AddBackward0>)
# 18 tensor([51.9542], grad_fn=<AddBackward0>)
# 19 tensor([174.8457], grad_fn=<AddBackward0>)
# 120 tensor([48.0732], grad_fn=<AddBackward0>)
# 121 tensor([49.5632], grad_fn=<AddBackward0>)
# 122 tensor([44.8091], grad_fn=<AddBackward0>)
# 123 tensor([278.8116], grad_fn=<AddBackward0>)
# 124 tensor([45.5177], grad_fn=<AddBackward0>)
# 125 tensor([150.3281], grad_fn=<AddBackward0>)
# 126 tensor([553.1075], grad_fn=<AddBackward0>)
# 127 tensor([204.1502], grad_fn=<AddBackward0>)
# 128 tensor([45.0271], grad_fn=<AddBackward0>)
# 129 tensor([42.4728], grad_fn=<AddBackward0>)
# 130 tensor([253.7474], grad_fn=<AddBackward0>)
# 131 tensor([92.9657], grad_fn=<AddBackward0>)
# 132 tensor([46.9195], grad_fn=<AddBackward0>)
# 133 tensor([49.8274], grad_fn=<AddBackward0>)
# 134 tensor([285.5222], grad_fn=<AddBackward0>)
# 135 tensor([46.5603], grad_fn=<AddBackward0>)
# 136 tensor([64.6305], grad_fn=<AddBackward0>)
# 137 tensor([395.6647], grad_fn=<AddBackward0>)
# 138 tensor([51.7367], grad_fn=<AddBackward0>)
# 139 tensor([167.1555], grad_fn=<AddBackward0>)
# 240 tensor([163.4097], grad_fn=<AddBackward0>)
# 241 tensor([100.8116], grad_fn=<AddBackward0>)
# 242 tensor([259.7517], grad_fn=<AddBackward0>)
# 243 tensor([46.1844], grad_fn=<AddBackward0>)
# 244 tensor([44.9422], grad_fn=<AddBackward0>)
# 245 tensor([407.5550], grad_fn=<AddBackward0>)
# 246 tensor([45.3425], grad_fn=<AddBackward0>)
# 247 tensor([42.3283], grad_fn=<AddBackward0>)
# 248 tensor([545.7026], grad_fn=<AddBackward0>)
# 249 tensor([205.8593], grad_fn=<AddBackward0>)
# 250 tensor([48.2457], grad_fn=<AddBackward0>)
# 251 tensor([48.0831], grad_fn=<AddBackward0>)
# 252 tensor([45.2737], grad_fn=<AddBackward0>)
# 253 tensor([49.8259], grad_fn=<AddBackward0>)
# 254 tensor([159.1756], grad_fn=<AddBackward0>)
# 255 tensor([45.0535], grad_fn=<AddBackward0>)
# 256 tensor([69.8501], grad_fn=<AddBackward0>)
# 257 tensor([288.1328], grad_fn=<AddBackward0>)
# 258 tensor([268.9425], grad_fn=<AddBackward0>)
# 259 tensor([43.8751], grad_fn=<AddBackward0>)
# 360 tensor([92.5782], grad_fn=<AddBackward0>)
# 361 tensor([61.6548], grad_fn=<AddBackward0>)
# 362 tensor([176.3117], grad_fn=<AddBackward0>)
# 363 tensor([45.7410], grad_fn=<AddBackward0>)
# 364 tensor([45.8504], grad_fn=<AddBackward0>)
# 365 tensor([43.4006], grad_fn=<AddBackward0>)
# 366 tensor([275.8169], grad_fn=<AddBackward0>)
# 367 tensor([47.4390], grad_fn=<AddBackward0>)
# 368 tensor([45.0440], grad_fn=<AddBackward0>)
# 369 tensor([49.2077], grad_fn=<AddBackward0>)
# 370 tensor([149.8941], grad_fn=<AddBackward0>)
# 371 tensor([277.5876], grad_fn=<AddBackward0>)
# 372 tensor([578.4822], grad_fn=<AddBackward0>)
# 373 tensor([47.2965], grad_fn=<AddBackward0>)
# 374 tensor([417.1936], grad_fn=<AddBackward0>)
# 375 tensor([193.6510], grad_fn=<AddBackward0>)
# 376 tensor([48.0097], grad_fn=<AddBackward0>)
# 377 tensor([271.8123], grad_fn=<AddBackward0>)
# 378 tensor([47.0501], grad_fn=<AddBackward0>)
# 379 tensor([42.9768], grad_fn=<AddBackward0>)

# %%
plt.figure()
plt.plot(dtlossvals)

torch.save(PIDparams.state_dict(), "sodgradientparams")

# %%
kpst = torch.tensor(kp,requires_grad=True)
kist = torch.tensor(ki,requires_grad=True)
kdst = torch.tensor(kd,requires_grad=True)
backst = torch.tensor(0.0,requires_grad=True)
Tft = torch.tensor(Tf,requires_grad=True)
optimizer = torch.optim.Adam((kpst,kist,kdst,backst), lr=0.1, weight_decay=0.1)

stlossvals = []
closs = 0
kptrain = []
kitrain = []
kdtrain = []
backtrain = []
for episodes in range(401):
  cepisode = episodes%20  
  if(cepisode==0):  
    episodeorder = np.random.choice(20, 20, replace=False)
  ref = refs[episodeorder[cepisode],:]
  reft = torch.tensor(ref)  
  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0],[0.0]],requires_grad=True)  
  ucmd = torch.tensor([0.0],requires_grad=True)
  u = torch.tensor([0.0],requires_grad=True)  
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  D  = torch.tensor([0.0],requires_grad=False)
  #torch.clamp(Tft,0.1,0.1)
  ad = torch.div(Tft,(Tft+0.01))
  bd = torch.div(kdst,(Tft+0.01))
  noise = 0.01*torch.randn(T,1)
  
  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t];
    #error = torch.tensor(reft[t]-yt,requires_grad=False)
    saterr = u-ucmd
    xcont = xcont+kist*(reft[t]-yt)+backst*saterr
    if(t>0):
       #deriv = torch.tensor(yt-yold,requires_grad=False) 
       D = ad*D-bd*(yt-yold);  
       ucmd = (0.01*xcont+kpst*(reft[t]-yt)+D)
    u = torch.clamp(ucmd,-3.0,3.0)
    uvalssat[i] = u;
    x = torch.matmul(systA.float(),x)+systB.float()*u;
    cost = cost+(reft[t]-yt)**2
  closs = closs+cost 
  if(episodes%20==19):
    stlossvals.append(closs.clone().detach().numpy()[0]/20)
    closs = 0
  kptrain.append(kpst.clone().detach().numpy())
  kitrain.append(kist.clone().detach().numpy())
  kdtrain.append(kdst.clone().detach().numpy())
  backtrain.append(backst.clone().detach().numpy())  
  if(episodes%60<20):
    #print(kpt,kdt,kit,Tft)
    print(episodes,cost,backst) 
  optimizer.zero_grad()
  cost.backward()
  optimizer.step()
print(kpst,kist,kdst,backst)
# Out:
# 0 tensor([448.5357], grad_fn=<AddBackward0>) tensor(0., requires_grad=True)
# 1 tensor([51.3486], grad_fn=<AddBackward0>) tensor(0.1000, requires_grad=True)
# 2 tensor([46.2009], grad_fn=<AddBackward0>) tensor(0.1684, requires_grad=True)
# 3 tensor([186.3327], grad_fn=<AddBackward0>) tensor(0.2222, requires_grad=True)
# 4 tensor([98.3672], grad_fn=<AddBackward0>) tensor(0.2706, requires_grad=True)
# 5 tensor([50.3389], grad_fn=<AddBackward0>) tensor(0.3126, requires_grad=True)
# 6 tensor([47.1358], grad_fn=<AddBackward0>) tensor(0.3489, requires_grad=True)
# 7 tensor([44.5906], grad_fn=<AddBackward0>) tensor(0.3808, requires_grad=True)
# 8 tensor([48.8374], grad_fn=<AddBackward0>) tensor(0.4088, requires_grad=True)
# 9 tensor([48.6859], grad_fn=<AddBackward0>) tensor(0.4337, requires_grad=True)
# 10 tensor([158.6426], grad_fn=<AddBackward0>) tensor(0.4558, requires_grad=True)
# 11 tensor([266.9157], grad_fn=<AddBackward0>) tensor(0.4747, requires_grad=True)
# 12 tensor([47.7026], grad_fn=<AddBackward0>) tensor(0.4896, requires_grad=True)
# 13 tensor([431.6475], grad_fn=<AddBackward0>) tensor(0.5026, requires_grad=True)
# 14 tensor([45.7956], grad_fn=<AddBackward0>) tensor(0.5056, requires_grad=True)
# 15 tensor([564.5903], grad_fn=<AddBackward0>) tensor(0.5080, requires_grad=True)
# 16 tensor([46.4981], grad_fn=<AddBackward0>) tensor(0.5072, requires_grad=True)
# 17 tensor([64.7768], grad_fn=<AddBackward0>) tensor(0.5061, requires_grad=True)
# 18 tensor([208.7295], grad_fn=<AddBackward0>) tensor(0.5047, requires_grad=True)
# 19 tensor([282.9930], grad_fn=<AddBackward0>) tensor(0.5015, requires_grad=True)
# 60 tensor([47.1064], grad_fn=<AddBackward0>) tensor(0.5019, requires_grad=True)
# 61 tensor([563.9094], grad_fn=<AddBackward0>) tensor(0.5036, requires_grad=True)
# 62 tensor([48.3374], grad_fn=<AddBackward0>) tensor(0.5045, requires_grad=True)
# 63 tensor([97.2342], grad_fn=<AddBackward0>) tensor(0.5055, requires_grad=True)
# 64 tensor([256.8962], grad_fn=<AddBackward0>) tensor(0.5060, requires_grad=True)
# 65 tensor([49.3211], grad_fn=<AddBackward0>) tensor(0.5045, requires_grad=True)
# 66 tensor([49.3943], grad_fn=<AddBackward0>) tensor(0.5030, requires_grad=True)
# 67 tensor([44.7514], grad_fn=<AddBackward0>) tensor(0.5016, requires_grad=True)
# 68 tensor([46.6114], grad_fn=<AddBackward0>) tensor(0.5005, requires_grad=True)
# 69 tensor([46.2846], grad_fn=<AddBackward0>) tensor(0.4995, requires_grad=True)
# 70 tensor([405.8194], grad_fn=<AddBackward0>) tensor(0.4988, requires_grad=True)
# 71 tensor([265.0977], grad_fn=<AddBackward0>) tensor(0.4980, requires_grad=True)
# 72 tensor([68.1345], grad_fn=<AddBackward0>) tensor(0.4968, requires_grad=True)
# 73 tensor([44.1373], grad_fn=<AddBackward0>) tensor(0.4959, requires_grad=True)
# 74 tensor([166.2270], grad_fn=<AddBackward0>) tensor(0.4954, requires_grad=True)
# 75 tensor([44.5127], grad_fn=<AddBackward0>) tensor(0.4958, requires_grad=True)
# 76 tensor([290.1543], grad_fn=<AddBackward0>) tensor(0.4961, requires_grad=True)
# 77 tensor([42.4069], grad_fn=<AddBackward0>) tensor(0.4957, requires_grad=True)
# 78 tensor([160.6851], grad_fn=<AddBackward0>) tensor(0.4955, requires_grad=True)
# 79 tensor([202.5676], grad_fn=<AddBackward0>) tensor(0.4960, requires_grad=True)
# 120 tensor([250.3586], grad_fn=<AddBackward0>) tensor(0.5373, requires_grad=True)
# 121 tensor([49.9727], grad_fn=<AddBackward0>) tensor(0.5397, requires_grad=True)
# 122 tensor([47.1043], grad_fn=<AddBackward0>) tensor(0.5417, requires_grad=True)
# 123 tensor([47.2392], grad_fn=<AddBackward0>) tensor(0.5439, requires_grad=True)
# 124 tensor([284.7649], grad_fn=<AddBackward0>) tensor(0.5455, requires_grad=True)
# 125 tensor([268.8622], grad_fn=<AddBackward0>) tensor(0.5456, requires_grad=True)
# 126 tensor([45.6601], grad_fn=<AddBackward0>) tensor(0.5446, requires_grad=True)
# 127 tensor([47.3417], grad_fn=<AddBackward0>) tensor(0.5432, requires_grad=True)
# 128 tensor([571.0394], grad_fn=<AddBackward0>) tensor(0.5418, requires_grad=True)
# 129 tensor([68.0390], grad_fn=<AddBackward0>) tensor(0.5344, requires_grad=True)
# 130 tensor([157.2291], grad_fn=<AddBackward0>) tensor(0.5278, requires_grad=True)
# 131 tensor([208.8449], grad_fn=<AddBackward0>) tensor(0.5215, requires_grad=True)
# 132 tensor([48.0526], grad_fn=<AddBackward0>) tensor(0.5157, requires_grad=True)
# 133 tensor([406.8621], grad_fn=<AddBackward0>) tensor(0.5104, requires_grad=True)
# 134 tensor([45.0749], grad_fn=<AddBackward0>) tensor(0.5059, requires_grad=True)
# 135 tensor([46.1895], grad_fn=<AddBackward0>) tensor(0.5022, requires_grad=True)
# 136 tensor([166.8597], grad_fn=<AddBackward0>) tensor(0.4994, requires_grad=True)
# 137 tensor([102.5992], grad_fn=<AddBackward0>) tensor(0.4985, requires_grad=True)
# 138 tensor([45.3554], grad_fn=<AddBackward0>) tensor(0.4978, requires_grad=True)
# 139 tensor([47.0701], grad_fn=<AddBackward0>) tensor(0.4971, requires_grad=True)
# 180 tensor([44.9099], grad_fn=<AddBackward0>) tensor(0.5261, requires_grad=True)
# 181 tensor([47.7486], grad_fn=<AddBackward0>) tensor(0.5233, requires_grad=True)
# 182 tensor([89.3342], grad_fn=<AddBackward0>) tensor(0.5211, requires_grad=True)
# 183 tensor([257.9991], grad_fn=<AddBackward0>) tensor(0.5199, requires_grad=True)
# 184 tensor([47.6183], grad_fn=<AddBackward0>) tensor(0.5170, requires_grad=True)
# 185 tensor([47.0576], grad_fn=<AddBackward0>) tensor(0.5145, requires_grad=True)
# 186 tensor([203.3876], grad_fn=<AddBackward0>) tensor(0.5129, requires_grad=True)
# 187 tensor([265.9082], grad_fn=<AddBackward0>) tensor(0.5123, requires_grad=True)
# 188 tensor([542.5504], grad_fn=<AddBackward0>) tensor(0.5139, requires_grad=True)
# 189 tensor([420.7724], grad_fn=<AddBackward0>) tensor(0.5159, requires_grad=True)
# 190 tensor([152.5415], grad_fn=<AddBackward0>) tensor(0.5152, requires_grad=True)
# 191 tensor([48.8574], grad_fn=<AddBackward0>) tensor(0.5151, requires_grad=True)
# 192 tensor([279.0639], grad_fn=<AddBackward0>) tensor(0.5154, requires_grad=True)
# 193 tensor([47.6018], grad_fn=<AddBackward0>) tensor(0.5170, requires_grad=True)
# 194 tensor([47.3948], grad_fn=<AddBackward0>) tensor(0.5184, requires_grad=True)
# 195 tensor([50.0791], grad_fn=<AddBackward0>) tensor(0.5199, requires_grad=True)
# 196 tensor([68.5956], grad_fn=<AddBackward0>) tensor(0.5216, requires_grad=True)
# 197 tensor([47.6209], grad_fn=<AddBackward0>) tensor(0.5232, requires_grad=True)
# 198 tensor([171.1528], grad_fn=<AddBackward0>) tensor(0.5247, requires_grad=True)
# 199 tensor([49.0023], grad_fn=<AddBackward0>) tensor(0.5268, requires_grad=True)
# 240 tensor([48.1078], grad_fn=<AddBackward0>) tensor(0.5520, requires_grad=True)
# 241 tensor([50.2673], grad_fn=<AddBackward0>) tensor(0.5522, requires_grad=True)
# 242 tensor([176.6230], grad_fn=<AddBackward0>) tensor(0.5523, requires_grad=True)
# 243 tensor([46.3068], grad_fn=<AddBackward0>) tensor(0.5519, requires_grad=True)
# 244 tensor([47.7608], grad_fn=<AddBackward0>) tensor(0.5519, requires_grad=True)
# 245 tensor([266.6251], grad_fn=<AddBackward0>) tensor(0.5522, requires_grad=True)
# 246 tensor([551.4765], grad_fn=<AddBackward0>) tensor(0.5525, requires_grad=True)
# 247 tensor([402.1294], grad_fn=<AddBackward0>) tensor(0.5535, requires_grad=True)
# 248 tensor([266.8098], grad_fn=<AddBackward0>) tensor(0.5542, requires_grad=True)
# 249 tensor([46.3993], grad_fn=<AddBackward0>) tensor(0.5519, requires_grad=True)
# 250 tensor([48.7705], grad_fn=<AddBackward0>) tensor(0.5503, requires_grad=True)
# 251 tensor([101.5988], grad_fn=<AddBackward0>) tensor(0.5495, requires_grad=True)
# 252 tensor([165.9495], grad_fn=<AddBackward0>) tensor(0.5487, requires_grad=True)
# 253 tensor([67.8187], grad_fn=<AddBackward0>) tensor(0.5472, requires_grad=True)
# 254 tensor([284.6111], grad_fn=<AddBackward0>) tensor(0.5467, requires_grad=True)
# 255 tensor([203.9222], grad_fn=<AddBackward0>) tensor(0.5462, requires_grad=True)
# 256 tensor([48.5337], grad_fn=<AddBackward0>) tensor(0.5490, requires_grad=True)
# 257 tensor([48.3970], grad_fn=<AddBackward0>) tensor(0.5518, requires_grad=True)
# 258 tensor([47.8932], grad_fn=<AddBackward0>) tensor(0.5551, requires_grad=True)
# 259 tensor([46.6932], grad_fn=<AddBackward0>) tensor(0.5585, requires_grad=True)
# 300 tensor([410.0310], grad_fn=<AddBackward0>) tensor(0.5820, requires_grad=True)
# 301 tensor([545.5227], grad_fn=<AddBackward0>) tensor(0.5853, requires_grad=True)
# 302 tensor([68.0453], grad_fn=<AddBackward0>) tensor(0.5869, requires_grad=True)
# 303 tensor([48.1040], grad_fn=<AddBackward0>) tensor(0.5890, requires_grad=True)
# 304 tensor([97.9361], grad_fn=<AddBackward0>) tensor(0.5914, requires_grad=True)
# 305 tensor([48.2546], grad_fn=<AddBackward0>) tensor(0.5938, requires_grad=True)
# 306 tensor([49.7228], grad_fn=<AddBackward0>) tensor(0.5962, requires_grad=True)
# 307 tensor([50.0298], grad_fn=<AddBackward0>) tensor(0.5984, requires_grad=True)
# 308 tensor([174.5074], grad_fn=<AddBackward0>) tensor(0.6005, requires_grad=True)
# 309 tensor([47.8406], grad_fn=<AddBackward0>) tensor(0.6016, requires_grad=True)
# 310 tensor([47.5545], grad_fn=<AddBackward0>) tensor(0.6028, requires_grad=True)
# 311 tensor([48.0902], grad_fn=<AddBackward0>) tensor(0.6043, requires_grad=True)
# 312 tensor([200.4257], grad_fn=<AddBackward0>) tensor(0.6060, requires_grad=True)
# 313 tensor([47.1293], grad_fn=<AddBackward0>) tensor(0.6081, requires_grad=True)
# 314 tensor([47.9303], grad_fn=<AddBackward0>) tensor(0.6105, requires_grad=True)
# 315 tensor([286.9100], grad_fn=<AddBackward0>) tensor(0.6128, requires_grad=True)
# 316 tensor([49.4731], grad_fn=<AddBackward0>) tensor(0.6113, requires_grad=True)
# 317 tensor([265.1236], grad_fn=<AddBackward0>) tensor(0.6100, requires_grad=True)
# 318 tensor([256.8021], grad_fn=<AddBackward0>) tensor(0.6074, requires_grad=True)
# 319 tensor([158.7199], grad_fn=<AddBackward0>) tensor(0.6025, requires_grad=True)
# 360 tensor([48.2883], grad_fn=<AddBackward0>) tensor(0.5425, requires_grad=True)
# 361 tensor([46.2606], grad_fn=<AddBackward0>) tensor(0.5583, requires_grad=True)
# 362 tensor([97.8755], grad_fn=<AddBackward0>) tensor(0.5734, requires_grad=True)
# 363 tensor([49.8003], grad_fn=<AddBackward0>) tensor(0.5877, requires_grad=True)
# 364 tensor([50.1811], grad_fn=<AddBackward0>) tensor(0.6006, requires_grad=True)
# 365 tensor([543.5401], grad_fn=<AddBackward0>) tensor(0.6126, requires_grad=True)
# 366 tensor([421.3066], grad_fn=<AddBackward0>) tensor(0.6146, requires_grad=True)
# 367 tensor([276.7825], grad_fn=<AddBackward0>) tensor(0.6089, requires_grad=True)
# 368 tensor([207.2813], grad_fn=<AddBackward0>) tensor(0.6003, requires_grad=True)
# 369 tensor([159.5060], grad_fn=<AddBackward0>) tensor(0.5929, requires_grad=True)
# 370 tensor([48.7490], grad_fn=<AddBackward0>) tensor(0.5872, requires_grad=True)
# 371 tensor([293.4142], grad_fn=<AddBackward0>) tensor(0.5824, requires_grad=True)
# 372 tensor([69.7458], grad_fn=<AddBackward0>) tensor(0.5796, requires_grad=True)
# 373 tensor([49.3300], grad_fn=<AddBackward0>) tensor(0.5777, requires_grad=True)
# 374 tensor([46.5081], grad_fn=<AddBackward0>) tensor(0.5763, requires_grad=True)
# 375 tensor([176.4460], grad_fn=<AddBackward0>) tensor(0.5755, requires_grad=True)
# 376 tensor([261.7953], grad_fn=<AddBackward0>) tensor(0.5772, requires_grad=True)
# 377 tensor([48.4189], grad_fn=<AddBackward0>) tensor(0.5806, requires_grad=True)
# 378 tensor([48.9932], grad_fn=<AddBackward0>) tensor(0.5843, requires_grad=True)
# 379 tensor([48.7530], grad_fn=<AddBackward0>) tensor(0.5883, requires_grad=True)
# tensor(7.6653, requires_grad=True) tensor(1.2599, requires_grad=True) tensor(3.1773, requires_grad=True) tensor(0.5707, requires_grad=True)

# %%
kpdft = torch.tensor(kp,requires_grad=True)
kidft = torch.tensor(ki,requires_grad=True)
kddft = torch.tensor(kd,requires_grad=True)

#backdft = torch.tensor(0.1,requires_grad=True)

backdft = torch.zeros(500,requires_grad=True)

optimizer = torch.optim.Adam([backdft], lr=0.1, weight_decay=0.1)

dftlossvals = []
closs = 0
for episodes in range(501):
  cepisode = episodes%20  
  if(cepisode==0):  
    episodeorder = np.random.choice(20, 20, replace=False)
    
  ref = refs[episodeorder[cepisode],:]
  reft = torch.tensor(ref)  
  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0],[0.0]],requires_grad=True)  
  ucmd = torch.tensor([0.0],requires_grad=True)
  u2 = torch.tensor([0.0],requires_grad=True)
  u1 = torch.tensor([0.0],requires_grad=True)    
  u = torch.tensor([0.0],requires_grad=True)  
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  D  = torch.tensor([0.0],requires_grad=False)
  ad = torch.div(Tft,(Tft+0.01))
  bd = torch.div(kddft,(Tft+0.01))

  noise = 0.01*torch.randn(T,1)
  satest = torch.zeros(500,requires_grad=False)
  #satestsum = torch.sum(satest)
  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t];
    #error = torch.tensor(reft[t]-yt,requires_grad=False)
    #satestc = satest.clone().detach()
    #satest[1:500] = satestc[0:499] 
    satest = torch.roll(satest,1)
    satest[0] = u-ucmd
    #print(satest)
    #satestsum = satestsum+satest[0]
    xcont = xcont+kidft*(reft[t]-yt)
    if(t>0):
       #deriv = torch.tensor(yt-yold,requires_grad=False) 
       D = ad*D-bd*(yt-yold);  
       ucmd = (0.01*xcont+kpdft*(reft[t]-yt)+D+0.01*torch.dot(backdft,satest.detach()))
    u = torch.clamp(ucmd,-3.0,3.0)
    x = torch.matmul(systA.float(),x)+systB.float()*u2
    u2 = u1
    u1 = u
    cost = cost+torch.clamp((reft[t]-yt)**2,0,50)
  closs = closs+cost  
  if(episodes%20==19):    
    dftlossvals.append(closs.clone().detach().numpy()[0]/20)
    closs = 0 
  if(episodes%100==0):
    print(episodes,cost)
    
  optimizer.zero_grad()
  cost.backward()
  optimizer.step()
# Out:
# 0 tensor([797.8118], grad_fn=<AddBackward0>)
# 100 tensor([214.0266], grad_fn=<AddBackward0>)
# 200 tensor([51.5739], grad_fn=<AddBackward0>)
# 300 tensor([71.8223], grad_fn=<AddBackward0>)
# 400 tensor([48.9378], grad_fn=<AddBackward0>)
# 500 tensor([265.4771], grad_fn=<AddBackward0>)

# %%
kps = kpst.detach().numpy()
kis = kist.detach().numpy()
kds = kdst.detach().numpy()
backs = backst.detach().numpy()
print(kps,kis,kds,backs)

plt.figure()
plt.plot(np.arange(len(dtlossvals))*20,dtlossvals)
plt.xlabel("No. of episodes")
plt.ylabel("Loss")

plt.figure()
plt.plot(np.arange(len(dftlossvals))*20,dftlossvals)
plt.xlabel("No. of episodes")
plt.ylabel("Loss")

plt.figure()
plt.plot(np.arange(len(stlossvals))*20,stlossvals)
plt.xlabel("No. of episodes")
plt.ylabel("Loss")

plt.figure()
plt.plot(np.arange(len(kptrain)),kptrain)
plt.xlabel("No. of episodes")
plt.ylabel("kp")

plt.figure()
plt.plot(np.arange(len(kdtrain)),kdtrain)
plt.xlabel("No. of episodes")
plt.ylabel("kd")

plt.figure()
plt.plot(np.arange(len(kitrain)),kitrain)
plt.xlabel("No. of episodes")
plt.ylabel("ki")

plt.figure()
plt.plot(np.arange(len(backtrain)),backtrain)
plt.xlabel("No. of episodes")
plt.ylabel("Back-calculation constant")
# Out:
# 7.6653366 1.2598736 3.1772885 0.57069033
# Text(0, 0.5, 'Back-calculation constant')

# %%
costdgradient = np.zeros((10,))
costinit = np.zeros((10,))
costsgradient = np.zeros((10,))
costdfgradient = np.zeros((10,))

ydgradient = np.zeros((10,T))
udgradient = np.zeros((10,T))

ysgradient = np.zeros((10,T))
usgradient = np.zeros((10,T))


ydfgradient = np.zeros((10,T))
udfgradient = np.zeros((10,T))

kpdgradient = np.zeros((10,T))
kidgradient = np.zeros((10,T))
kddgradient = np.zeros((10,T))
backdgradient = np.zeros((10,T))
#PIDparams = neuralPID()
#PIDparams.load_state_dict(torch.load("dgradientparams"))

yinit = np.zeros((10,T))
uinit = np.zeros((10,T))
smooth = 0.9

for iters in range(0,10):
  ref = refs[20+iters,:]
  reft = torch.tensor(ref)
  noise = 0.01*torch.randn(T,1)  
  
  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0],[0.0]],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  ucmd = torch.tensor([0.0],requires_grad=True)
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  D  = torch.tensor([0.0],requires_grad=False)
  #torch.clamp(Tft,0.1,0.1)
  ad = torch.div(Tft,(Tft+0.01))
  
  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t];
    ydgradient[iters,t] = yt.clone().detach().numpy()
    #print(yt)
    #error = torch.tensor(reft[t]-yt,requires_grad=False)
    saterr = u-ucmd
    err = reft[t]-yt
    ninput = torch.cat((err.detach(),saterr.detach()),0)
    kpdt,kidt,kddt,backdt = PIDparams(ninput)
    kpt = smooth*kpt+(1-smooth)*(kpit+kpdt)
    kit = smooth*kit+(1-smooth)*(kiit+kidt)
    kdt = smooth*kdt+(1-smooth)*(kdit+kddt)
    backt = smooth*backt+(1-smooth)*(backit+backdt)
    xcont = xcont+kit*err+backt*saterr.detach()
    if(t>0):
      bd = torch.div(kdt,(Tft+0.01))
      D = ad*D-bd*(yt-yold);  
      ucmd = (0.01*xcont+kpt*(reft[t]-yt)+D)
      u = torch.clamp(ucmd,-3.0,3.0)
      udgradient[iters,t] = u.clone().detach().numpy()
      kpdgradient[iters,t] = kpt.clone().detach().numpy()
      kidgradient[iters,t] = kit.clone().detach().numpy()
      kddgradient[iters,t] = kdt.clone().detach().numpy()
      backdgradient[iters,t] = backt.clone().detach().numpy()  
    x = torch.matmul(systA.float(),x)+systB.float()*u;
    cost = cost+(reft[t]-yt)**2
    
  costdgradient[iters] = cost.detach().numpy()

  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0],[0.0]],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  D  = torch.tensor([0.0],requires_grad=False)
  #torch.clamp(Tft,0.1,0.1)
  ad = torch.div(Tft,(Tft+0.01))
  
  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t];
    yinit[iters,t] = yt.clone().detach().numpy()
    #print(yt)
    #error = torch.tensor(reft[t]-yt,requires_grad=False)
    err = ref[t]-yt
    xcont = xcont+err
    if(t>0):
       #print(t,kpt,kit,kdt)
       #break;
       bd = torch.div(kdit,(Tft+0.01))
       D = ad*D-bd*(yt-yold);  
       u = (0.01*kiit*xcont+kpit*(ref[t]-yt)+D)
       u = torch.clamp(u,-3.0,3.0)
    uinit[iters,t] = u.clone().detach().numpy()
    x = torch.matmul(systA.float(),x)+systB.float()*u;
    cost = cost+(reft[t]-yt)**2
  costinit[iters] = cost.detach().numpy()

  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0],[0.0]],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  D  = torch.tensor([0.0],requires_grad=False)
  #torch.clamp(Tft,0.1,0.1)
  ad = torch.div(Tft,(Tft+0.01))
  bd = torch.div(kdst,(Tft+0.01))

  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t];
    ysgradient[iters,t] = yt.clone().detach().numpy()
    #print(yt)
    #error = torch.tensor(reft[t]-yt,requires_grad=False)
    saterr = u-ucmd
    xcont = xcont+kist*(reft[t]-yt)+backst*saterr.detach()
    if(t>0):
       #deriv = torch.tensor(yt-yold,requires_grad=False) 
       D = ad*D-bd*(yt-yold);  
       ucmd = (0.01*xcont+kpst*(reft[t]-yt)+D)
    u = torch.clamp(ucmd,-3.0,3.0)
    usgradient[iters,t] = u.clone().detach().numpy()
    x = torch.matmul(systA.float(),x)+systB.float()*u;
    cost = cost+(reft[t]-yt)**2
  costsgradient[iters] = cost.detach().numpy() 

  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0],[0.0]],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  u2 = torch.tensor([0.0],requires_grad=True)
  u1 = torch.tensor([0.0],requires_grad=True)     
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  D  = torch.tensor([0.0],requires_grad=False)
  satest = torch.zeros(500,requires_grad=False)
  ad = torch.div(Tft,(Tft+0.01))
  bd = torch.div(kddft,(Tft+0.01))
    
  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t]
    ydfgradient[iters,t] = yt.clone().detach().numpy()
    satest = torch.roll(satest,1)
    satest[0] = u-ucmd
    xcont = xcont+kidft*(reft[t]-yt)
    if(t>0):
       D = ad*D-bd*(yt-yold);  
       ucmd = (0.01*xcont+kpdft*(reft[t]-yt)+D+0.01*torch.dot(backdft,satest.detach()))
    u = torch.clamp(ucmd,-3.3,3.3)
    x = torch.matmul(systA.float(),x)+systB.float()*u2
    u2 = u1
    u1 = u
    cost = cost+torch.clamp((reft[t]-yt)**2,0,50)
  costdfgradient[iters] = cost.detach().numpy()

# %%
print("Dgradient-dynamic",costdgradient)
print("DF-CVX",costdfgradient)
print("Dgradient-static",costsgradient)
print("Initial",costinit)
# Out:
# Dgradient-dynamic [ 46.36700439 439.12634277  46.80646896 356.11282349 299.9458313
#   50.01728821 150.92156982 339.37258911 144.3709259   47.23662186]
# DF-CVX [ 45.74169159 446.04702759  47.08726501 364.36193848 302.62091064
#   48.6558876  147.79182434 337.89816284 146.55889893  46.77275848]
# Dgradient-static [ 48.46509933 439.90350342  48.42402649 361.30557251 303.93948364
#   50.2986145  148.2350769  342.65988159 148.96032715  49.04382706]
# Initial [ 51.88573456 717.84973145  52.33599091 598.60333252 471.58618164
#   54.13243103 181.68795776 503.44174194 181.3969574   51.76860809]

# %%
plt.figure()
plt.plot(0.01*np.arange(0,T),refs[21,:])
plt.plot(0.01*np.arange(0,T),ydgradient[1,:])
plt.plot(0.01*np.arange(0,T),ysgradient[1,:])
plt.plot(0.01*np.arange(0,T),ydfgradient[1,:])
plt.plot(0.01*np.arange(0,T),yinit[1,:])
plt.xlabel("Time(s)")
plt.ylabel("Output")
plt.legend(["Reference","D-gradient (dynamic)","D-gradient (static)","DFC-CVX","Initial"])

plt.figure()
plt.plot(0.01*np.arange(0,T),uinit[1,:])
plt.plot(0.01*np.arange(0,T),udgradient[1,:])
plt.plot(0.01*np.arange(0,T),usgradient[1,:])
plt.plot(0.01*np.arange(0,T),udfgradient[1,:])
plt.xlabel("Time(s)")
plt.ylabel("Input")
plt.legend(["Initial","D-gradient (dynamic)","D-gradient (static)","DFC-CVX"])

plt.figure()
plt.plot(0.01*np.arange(1,T),kpdgradient[1,1:])
plt.xlabel("Time(s)")
plt.ylabel("Proportional gain")

plt.figure()
plt.plot(0.01*np.arange(1,T),kidgradient[1,1:])
plt.xlabel("Time(s)")
plt.ylabel("Integral gain")

plt.figure()
plt.plot(0.01*np.arange(1,T),kddgradient[1,1:])
plt.xlabel("Time(s)")
plt.ylabel("Derivative gain")

plt.figure()
plt.plot(0.01*np.arange(1,T),backdgradient[1,1:])
plt.xlabel("Time(s)")
plt.ylabel("Back-calculation gain")
# Out:
# Text(0, 0.5, 'Back-calculation gain')

# %%
# Save everything
np.save("sodddtlossvals",dtlossvals)
np.save("soddstlossvals",stlossvals)
np.save("sodddftlossvals",dftlossvals)
np.save("soddydgradient",ydgradient)
np.save("soddydfgradient",ydfgradient)
np.save("soddysgradient",ysgradient)
np.save("soddyinit",yinit)
np.save("soddudgradient",udgradient)
np.save("soddudfgradient",udfgradient)
np.save("soddusgradient",usgradient)
np.save("sodduinit",uinit)
np.save("soddkpdgradient",kpdgradient)
np.save("soddkidgradient",kidgradient)
np.save("soddkddgradient",kddgradient)
np.save("soddbackdgradient",backdgradient)
np.save("soddkptrain",kptrain)
np.save("soddkitrain",kitrain)
np.save("soddkdtrain",kdtrain)
np.save("soddbacktrain",backtrain)
np.save("soddrefs",refs)
np.save("soddcostdgradient",costdgradient)
np.save("soddcostdfgradient",costdfgradient)
np.save("soddcostsgradient",costsgradient)
np.save("soddcostinit",costinit)

torch.save(backdft,"soddbackdft")
torch.save(PIDparams.state_dict(), "soddgradientparams")

# %%
kpit = torch.tensor(kp,requires_grad=False)
kiit = torch.tensor(ki,requires_grad=False)
kdit = torch.tensor(kd,requires_grad=False)
PIDpg = neuralPID()
#optimizer = torch.optim.Adam((PIDpg.parameters()), lr=0.1)
#for iters in range(1000):
#   kpt,kit,kdt = PIDpg(torch.randn(3,))
#   print(kpt,kit,kdt)
#   loss = (kpt-kpit)**2+(kit-kiit)**2+(kdt-kdit)**2
#   optimizer.zero_grad()
#   loss.backward()
#   optimizer.step()

# %%
ysat = np.zeros((T,))
uvalssat = np.zeros((T,))

optimizer = torch.optim.Adam((PIDpg.parameters()), lr=0.1)

nupdates = 100
nepisodes = 120
for updates in range(nupdates):
  cost = np.zeros((nepisodes,T))
  ref = refs[updates%20,:]
  rcostsepisode = np.zeros((nepisodes*T,1))
  totalcost = np.zeros((nepisodes,))
  uvalsepisode = np.zeros((nepisodes*T,1))
  PIDinputsepisode = np.zeros((nepisodes*T,3))
  PIDstatesepisode = np.zeros((nepisodes*T,4))
  for episodes in range(nepisodes):
    xcont = 0
    x =[[0.0],[0.0]]  
    u = 0.0
    ucmd = 0.0
    
    ucmdvals = np.zeros((T,1))
    uvals =  np.zeros((T,1))
    PIDinputs = np.zeros((T,3))
    PIDstates = np.zeros((T,4))
    yt = 0.0
    D  = 0.0
    
    ad = Tf/(Tf+0.01)
    adt = torch.tensor(ad,requires_grad=False)
    adt = adt.float()
    noise = 0.01*np.random.randn(T,1)
    sigma = 0.5
    for t in range(T):
      yold = yt
      yt = np.clip(np.dot(sysC,x)+noise[t],-30.0,30.0)
      err = ref[t]-yt[0]
      xcont = xcont+err
      if(t>0):
         inp = np.array([err,u,ucmd])
         ninput = torch.tensor(inp,requires_grad=False)
         PIDinputs[t,:] = inp   
         kpdt,kidt,kddt = PIDpg(ninput.float())
         kpt = kpit+kpdt
         kit = kiit+kidt
         kdt = kdit+kddt
         kpn = kpt.detach().numpy()
         kin = kit.detach().numpy()
         kdn = kdt.detach().numpy()
         #print(kpn,kin,kdn)   
         bd = kdn[0]/(Tf+0.01)
         PIDstates[t,:] = [err,xcont,D,yt[0]-yold[0]] 
         D = ad*D-bd*(yt[0]-yold[0])
         ucmd = (0.01*kin[0]*xcont+kpn[0]*err+D)
      if(episodes==0):
        u = ucmd
      else:  
        u = ucmd+sigma*np.random.randn()
      uvals[t] = u
      u = np.clip(u,-35.0,35.0)
      x = np.dot(sysA,x)+sysB*u;
      cost[episodes,t] = (ref[t]-yt)**2
    #rcosts = np.flip(np.cumsum(np.flip(cost[episodes,:],[0]),0),[0])
    totalcost[episodes] = np.sum(cost[episodes,:])
    rcosts = np.repeat(totalcost[episodes],T,0)
    #if(episodes==0):
    #  print(updates,episodes,rcosts[0])
    rcostsepisode[episodes*T:(episodes+1)*T,0] = rcosts
    uvalsepisode[episodes*T:(episodes+1)*T,:] = uvals
    PIDinputsepisode[episodes*T:(episodes+1)*T,:] = PIDinputs
    PIDstatesepisode[episodes*T:(episodes+1)*T,:] = PIDstates
  print(updates,episodes,np.min(totalcost))
  PIDinputstorch = torch.tensor(PIDinputsepisode).float()
  PIDstatestorch = torch.tensor(PIDstatesepisode).float()
  uvalstorch = torch.tensor(uvalsepisode).float()
  rcoststorch = torch.tensor(rcostsepisode).float()
  costmean = torch.tensor(np.mean(totalcost)).float()
    
  kptvals,kitvals,kdtvals = PIDpg(PIDinputstorch)
  bdtvals = (kd+kdtvals)/(Tft+0.01)  
  Dvals = adt*PIDstatestorch[:,2]-bdtvals*PIDstatestorch[:,3]  
  ucmdvals = 0.01*torch.mul((ki+kitvals),PIDstatestorch[:,1])+torch.mul((kp+kptvals),PIDstatestorch[:,0])+Dvals
  
  updatecost = torch.mean(torch.mul((uvalstorch-ucmdvals)**2,rcoststorch-costmean))/(2*sigma)
  optimizer.zero_grad()
  updatecost.backward()
  optimizer.step()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-20-2b00b39fa3d9> in <module>
#      41          ninput = torch.tensor(inp,requires_grad=False)
#      42          PIDinputs[t,:] = inp
# ---> 43          kpdt,kidt,kddt = PIDpg(ninput.float())
#      44          kpt = kpit+kpdt
#      45          kit = kiit+kidt
#
# ~/anaconda3/envs/pytogpu/lib/python3.8/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# <ipython-input-6-d32cbaf6ed8a> in forward(self, x)
#      14    def forward(self,x):
#      15     sigmoid = torch.nn.Tanh()
# ---> 16     kp = self.kplayer2(sigmoid(self.kplayer1(x)))
#      17     ki = self.kilayer2(sigmoid(self.kilayer1(x)))
#      18     kd = self.kdlayer2(sigmoid(self.kdlayer1(x)))
#
# ~/anaconda3/envs/pytogpu/lib/python3.8/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/pytogpu/lib/python3.8/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      85
#      86     def forward(self, input):
# ---> 87         return F.linear(input, self.weight, self.bias)
#      88
#      89     def extra_repr(self):
#
# ~/anaconda3/envs/pytogpu/lib/python3.8/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1370         ret = torch.addmm(bias, input, weight.t())
#    1371     else:
# -> 1372         output = input.matmul(weight.t())
#    1373         if bias is not None:
#    1374             output += bias
#
# RuntimeError: size mismatch, m1: [1 x 3], m2: [2 x 2] at /opt/conda/conda-bld/pytorch_1579022027550/work/aten/src/TH/generic/THTensorMath.cpp:136
