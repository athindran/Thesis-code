# %%
import numpy as np
import scipy
import torch
from matplotlib import pyplot as plt
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable 
import control
from control import matlab
from matplotlib import cm

np.random.seed(0)
dev = "cpu"  
device = torch.device(dev)

# %%
sysA = np.array([[0.9852,0.0099,0,0],[0.0099,1.00,0.0,0.0],[0.00,0.01,1.0,0.0],[0.00,0.0001,0.01,1.00]])
#sysA = 0.99
sysB = np.array([[0.0099],[0.0],[0.0],[0.0]])
sysC = np.array([0,1.0,0.8,0.15])
sysD = 0
print(np.linalg.eig(sysA))
kp = 10.0
ki = 5.0
kd = 8.0
Tf = 0.01
# Out:
# (array([1.        , 1.        , 1.00496002, 0.98023998]), array([[ 0.00000000e+00,  0.00000000e+00,  1.06810574e-01,
#          8.66745215e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  2.13189765e-01,
#         -4.34249524e-01],
#        [ 0.00000000e+00,  2.22044605e-14,  4.29816673e-01,
#          2.19761725e-01],
#        [ 1.00000000e+00, -1.00000000e+00,  8.70861213e-01,
#         -1.09017740e-01]]))

# %%
T = 4500
np.random.seed(0)
refs = np.zeros((30,T))

randval = 0

for i in range(30):
  refs[i,0:300] = 0
  randval = 8.0*np.random.rand()-4.0
  print(i,randval)  
  if randval>0 and randval<1:
    randval = 1
  if randval<0 and randval>-1:
    randval = -1
  refs[i,300:] = randval
# Out:
# 0 0.390508031418598
# 1 1.7215149309793558
# 2 0.822107008573151
# 3 0.3590654639751749
# 4 -0.6107616052887623
# 5 1.167152904533249
# 6 -0.4993023098984599
# 7 3.134184006256638
# 8 3.7093020840082342
# 9 -0.9324678493937784
# 10 2.3338003046613167
# 11 0.23115935802323584
# 12 0.5443564887514585
# 13 3.4047731063412883
# 14 -3.4317115344169045
# 15 -3.3029656023876743
# 16 -3.8382528204773942
# 17 2.660958764383504
# 18 2.225254007598804
# 19 2.9600971859745533
# 20 3.828946737862112
# 21 2.393268513733789
# 22 -0.30816510197654523
# 23 2.2442334102916437
# 24 -3.0538045930485342
# 25 1.1193681706201906
# 26 -2.8531737007276288
# 27 3.557351336396671
# 28 0.1747865740005734
# 29 -0.6827044800758113

# %%
ref = refs[8,:]
ysat = np.zeros((T,))
uvalssat = np.zeros((T,))
xcont = 0
u = 0
D = 0
ad = Tf/(Tf+0.01)
bd = kd/(Tf+0.01)
noise = 0.01*np.random.randn(T,1)

x0 = np.zeros((4,1))
x = x0
for i in range(T):
   ysat[i] = np.dot(sysC,x)+np.dot(sysD,u)+noise[i]
   xcont = xcont+(ref[i]-ysat[i])
   if(i>0):
     D = ad*D-bd*(ysat[i]-ysat[i-1])  
     u = 0.01*ki*xcont+kp*(ref[i]-ysat[i])+D
   if(u>5):
     u=5
   elif(u<-5):
     u=-5
   uvalssat[i] = u;
   x = np.dot(sysA,x)+np.dot(sysB,u);

ynosat = np.zeros((T,))
uvalsnosat = np.zeros((T,))
xcont = 0;
u = 0;
x = x0
D = 0

for i in range(T):
   ynosat[i] = np.dot(sysC,x)+np.dot(sysD,u)+noise[i]
   xcont = xcont+(ref[i]-ynosat[i])
   if(i>0):
     D = ad*D-bd*(ynosat[i]-ynosat[i-1])  
     u = 0.01*ki*xcont+kp*(ref[i]-ynosat[i])+D 
   uvalsnosat[i] = u;
   x = np.dot(sysA,x)+np.dot(sysB,u);

# %%
plt.figure
plt.plot(0.01*np.arange(T),ynosat)
plt.plot(0.01*np.arange(T),ysat)
plt.plot(0.01*np.arange(T),ref)
plt.xlabel("Time (s)")
plt.ylabel("Output")
plt.legend(["No saturation","Saturation","Reference"])
plt.show()

plt.figure
plt.plot(0.01*np.arange(T),uvalsnosat)
plt.plot(0.01*np.arange(T),uvalssat)
plt.xlabel("Time (s)")
plt.ylabel("Input")
plt.legend(["No saturation","Saturation"])
plt.show()

# %%
class neuralPID(torch.nn.Module):
   def __init__(self):
    super(neuralPID, self).__init__()
    torch.manual_seed(2)
    self.kplayer1 = torch.nn.Linear(2,2)
    self.kplayer2 = torch.nn.Linear(2,1)
    self.kilayer1 = torch.nn.Linear(2,2)
    self.kilayer2 = torch.nn.Linear(2,1)
    self.kdlayer1 = torch.nn.Linear(2,2)
    self.kdlayer2 = torch.nn.Linear(2,1)
    self.backlayer1 = torch.nn.Linear(2,2)
    self.backlayer2 = torch.nn.Linear(2,1)
  
   def forward(self,x):
    sigmoid = torch.nn.Tanh()
    kp = self.kplayer2(sigmoid(self.kplayer1(x)))
    ki = self.kilayer2(sigmoid(self.kilayer1(x)))
    kd = self.kdlayer2(sigmoid(self.kdlayer1(x)))
    back = self.backlayer2(sigmoid(self.backlayer1(x)))
    #kd = torch.clamp(kd,0,400)
    #kp = torch.clamp(kp,0,400)
    #ki = torch.clamp(ki,0,400)
    return kp,ki,kd,back

# %%
Tft = torch.tensor(Tf,requires_grad=True)
kpit = torch.tensor(kp,requires_grad=False)
kiit = torch.tensor(ki,requires_grad=False)
kdit = torch.tensor(kd,requires_grad=False)
backit = torch.tensor(0.1,requires_grad=False)

systA = torch.tensor(sysA,requires_grad=False)
systB = torch.tensor(sysB,requires_grad=False)
systC = torch.tensor(sysC,requires_grad=False)
systD = torch.tensor(sysD,requires_grad=False)

# %%
costinit = np.zeros((30,))

yinit = np.zeros((30,T))
uinit = np.zeros((30,T))
Tft = torch.tensor(Tf,requires_grad=True)
kpit = torch.tensor(kp,requires_grad=False)
kiit = torch.tensor(ki,requires_grad=False)
kdit = torch.tensor(kd,requires_grad=False)

systA = torch.tensor(sysA,requires_grad=False)
systB = torch.tensor(sysB,requires_grad=False)
systC = torch.tensor(sysC,requires_grad=False)
systD = torch.tensor(sysD,requires_grad=False)

for iters in range(0,30):
  ref = refs[iters,:]
  reft = torch.tensor(ref)
  noise = 0.01*torch.randn(T,1)

  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0],[0.0],[0.0],[0.0]],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  D  = torch.tensor([0.0],requires_grad=False)
  #torch.clamp(Tft,0.1,0.1)
  ad = torch.div(Tft,(Tft+0.01))
  
  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t];
    yinit[iters,t] = yt.clone().detach().numpy()
    #print(yt)
    #error = torch.tensor(reft[t]-yt,requires_grad=False)
    err = ref[t]-yt
    xcont = xcont+err
    if(t>0):
       #print(t,kpt,kit,kdt)
       #break;
       bd = torch.div(kdit,(Tft+0.01))
       D = ad*D-bd*(yt-yold);  
       u = (0.01*kiit*xcont+kpit*(ref[t]-yt)+D)
       u = torch.clamp(u,-5.0,5.0)
    uinit[iters,t] = u.clone().detach().numpy()
    x = torch.matmul(systA.float(),x)+systB.float()*u;
    cost = cost+(reft[t]-yt)**2
  costinit[iters] = cost.detach().numpy()

# %%
print(costinit)
plt.figure()
plt.plot(refs[16,:])
plt.plot(yinit[16,:])
# Out:
# [  65.43836212  217.57182312   63.14740753   73.03501892   68.63970184
#    88.46726227   67.02814484  999.54284668 2112.4765625    64.33181
#   455.12585449   68.89270782   65.02403259 1361.13378906 1527.06237793
#  1159.36816406 3344.82910156  672.24560547  413.15478516  858.03686523
#  2504.13305664  488.00149536   62.16889572  418.87216187  930.29394531
#    82.89407349  783.62969971 1960.72216797   62.94996643   65.46639252]

# %%
# Initialize network
Tft = torch.tensor(Tf,requires_grad=True)
kpit = torch.tensor(kp,requires_grad=False)
kiit = torch.tensor(ki,requires_grad=False)
kdit = torch.tensor(kd,requires_grad=False)
backit = torch.tensor(0.1,requires_grad=False)

kpt = torch.tensor(kp,requires_grad=True)
kit = torch.tensor(ki,requires_grad=True)
kdt = torch.tensor(kd,requires_grad=True)
backt = torch.tensor(0.1,requires_grad=True)

systA = torch.tensor(sysA,requires_grad=False)
systB = torch.tensor(sysB,requires_grad=False)
systC = torch.tensor(sysC,requires_grad=False)
systD = torch.tensor(sysD,requires_grad=False)

PIDparams = neuralPID()
#optimizer = torch.optim.Adam((PIDparams.parameters()), lr=0.1)
#for iters in range(1000):
#   kpt,kit,kdt = PIDparams(torch.randn(3,))
#   print(kpt,kit,kdt)
#   loss = (kpt-kpit)**2+(kit-kiit)**2+(kdt-kdit)**2
#   optimizer.zero_grad()
#   loss.backward()
#   optimizer.step()    
   #print(iters,loss)

# %%
ysat = np.zeros((T,))
uvalssat = np.zeros((T,))

optimizer = torch.optim.Adam((PIDparams.parameters()), lr=0.1, weight_decay=0.1)

smooth = 0.9
closs = 0
dtlossvals = []

for episodes in range(701):
  #cepisode = np.random.randint(20)  
  cepisode = episodes%20  
  if(cepisode==0):  
    episodeorder = np.random.choice(20, 20, replace=False)
  ref = refs[episodeorder[cepisode],:]
  reft = torch.tensor(ref)  
  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0],[0.0],[0.0],[0.0]],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  ucmd = torch.tensor([0.0],requires_grad=True)
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  D  = torch.tensor([0.0],requires_grad=False)
  ad = torch.div(Tft,(Tft+0.01))
  noise = 0.01*torch.randn(T,1)
  kpt = kpt.clone().detach()
  kit = kit.clone().detach()
  kdt = kdt.clone().detach()
  backt = backt.clone().detach()

  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t]
    saterr = u-ucmd
    err = reft[t]-yt
    ninput = torch.cat((err.detach(),saterr.detach()),0)
    kpdt,kidt,kddt,backdt = PIDparams(ninput)
    kpt = smooth*kpt+(1-smooth)*(kpit+kpdt)
    kit = smooth*kit+(1-smooth)*(kiit+kidt)
    kdt = smooth*kdt+(1-smooth)*(kdit+kddt)
    backt = smooth*backt+(1-smooth)*(backit+backdt)
    xcont = xcont+kit*err+backt*saterr.detach()
    if(t>0):
      bd = torch.div(kdt,(Tft+0.01))
      D = ad*D-bd*(yt-yold);  
      ucmd = (0.01*xcont+kpt*(reft[t]-yt)+D)
      u = torch.clamp(ucmd,-5.0,5.0)
    x = torch.matmul(systA.float(),x)+systB.float()*u;
    cost = cost+(reft[t]-yt)**2
  closs = closs+cost   
  if(episodes%120<20):
    print(episodes,cost)
    
  if(episodes%20==19):    
    dtlossvals.append(closs.clone().detach().numpy()[0]/20)
    closs = 0  
    
  optimizer.zero_grad()
  cost.backward()
  optimizer.step()
# Out:
# 0 tensor([817.8785], grad_fn=<AddBackward0>)
# 1 tensor([41.5752], grad_fn=<AddBackward0>)
# 2 tensor([305.4337], grad_fn=<AddBackward0>)
# 3 tensor([42.8265], grad_fn=<AddBackward0>)
# 4 tensor([39.5036], grad_fn=<AddBackward0>)
# 5 tensor([669.5242], grad_fn=<AddBackward0>)
# 6 tensor([287.2788], grad_fn=<AddBackward0>)
# 7 tensor([453.6417], grad_fn=<AddBackward0>)
# 8 tensor([162.3904], grad_fn=<AddBackward0>)
# 9 tensor([37.7037], grad_fn=<AddBackward0>)
# 10 tensor([57.0919], grad_fn=<AddBackward0>)
# 11 tensor([1022.5782], grad_fn=<AddBackward0>)
# 12 tensor([39.1050], grad_fn=<AddBackward0>)
# 13 tensor([41.6347], grad_fn=<AddBackward0>)
# 14 tensor([838.4410], grad_fn=<AddBackward0>)
# 15 tensor([1119.3621], grad_fn=<AddBackward0>)
# 16 tensor([566.8499], grad_fn=<AddBackward0>)
# 17 tensor([39.4821], grad_fn=<AddBackward0>)
# 18 tensor([40.0078], grad_fn=<AddBackward0>)
# 19 tensor([1005.5490], grad_fn=<AddBackward0>)
# 120 tensor([36.4579], grad_fn=<AddBackward0>)
# 121 tensor([856.9872], grad_fn=<AddBackward0>)
# 122 tensor([40.3660], grad_fn=<AddBackward0>)
# 123 tensor([145.0933], grad_fn=<AddBackward0>)
# 124 tensor([279.9294], grad_fn=<AddBackward0>)
# 125 tensor([555.4328], grad_fn=<AddBackward0>)
# 126 tensor([39.6434], grad_fn=<AddBackward0>)
# 127 tensor([39.1871], grad_fn=<AddBackward0>)
# 128 tensor([39.8708], grad_fn=<AddBackward0>)
# 129 tensor([435.4095], grad_fn=<AddBackward0>)
# 130 tensor([997.3137], grad_fn=<AddBackward0>)
# 131 tensor([41.3839], grad_fn=<AddBackward0>)
# 132 tensor([800.4321], grad_fn=<AddBackward0>)
# 133 tensor([769.1316], grad_fn=<AddBackward0>)
# 134 tensor([40.8787], grad_fn=<AddBackward0>)
# 135 tensor([654.4604], grad_fn=<AddBackward0>)
# 136 tensor([40.1576], grad_fn=<AddBackward0>)
# 137 tensor([320.2589], grad_fn=<AddBackward0>)
# 138 tensor([55.6489], grad_fn=<AddBackward0>)
# 139 tensor([1130.5044], grad_fn=<AddBackward0>)
# 240 tensor([1000.6979], grad_fn=<AddBackward0>)
# 241 tensor([281.2764], grad_fn=<AddBackward0>)
# 242 tensor([38.3983], grad_fn=<AddBackward0>)
# 243 tensor([658.9393], grad_fn=<AddBackward0>)
# 244 tensor([38.7500], grad_fn=<AddBackward0>)
# 245 tensor([38.3399], grad_fn=<AddBackward0>)
# 246 tensor([39.9560], grad_fn=<AddBackward0>)
# 247 tensor([38.6073], grad_fn=<AddBackward0>)
# 248 tensor([313.5627], grad_fn=<AddBackward0>)
# 249 tensor([38.2497], grad_fn=<AddBackward0>)
# 250 tensor([434.2153], grad_fn=<AddBackward0>)
# 251 tensor([149.0647], grad_fn=<AddBackward0>)
# 252 tensor([823.2736], grad_fn=<AddBackward0>)
# 253 tensor([753.0613], grad_fn=<AddBackward0>)
# 254 tensor([55.6435], grad_fn=<AddBackward0>)
# 255 tensor([40.0213], grad_fn=<AddBackward0>)
# 256 tensor([1070.9121], grad_fn=<AddBackward0>)
# 257 tensor([559.0621], grad_fn=<AddBackward0>)
# 258 tensor([39.0121], grad_fn=<AddBackward0>)
# 259 tensor([802.4250], grad_fn=<AddBackward0>)
# 360 tensor([38.4134], grad_fn=<AddBackward0>)
# 361 tensor([283.0967], grad_fn=<AddBackward0>)
# 362 tensor([551.6984], grad_fn=<AddBackward0>)
# 363 tensor([37.3971], grad_fn=<AddBackward0>)
# 364 tensor([56.6655], grad_fn=<AddBackward0>)
# 365 tensor([39.7948], grad_fn=<AddBackward0>)
# 366 tensor([1097.0031], grad_fn=<AddBackward0>)
# 367 tensor([39.0460], grad_fn=<AddBackward0>)
# 368 tensor([846.6466], grad_fn=<AddBackward0>)
# 369 tensor([647.7664], grad_fn=<AddBackward0>)
# 370 tensor([145.8972], grad_fn=<AddBackward0>)
# 371 tensor([995.3781], grad_fn=<AddBackward0>)
# 372 tensor([40.2867], grad_fn=<AddBackward0>)
# 373 tensor([309.5514], grad_fn=<AddBackward0>)
# 374 tensor([38.5371], grad_fn=<AddBackward0>)
# 375 tensor([39.2137], grad_fn=<AddBackward0>)
# 376 tensor([39.4052], grad_fn=<AddBackward0>)
# 377 tensor([437.0038], grad_fn=<AddBackward0>)
# 378 tensor([800.4060], grad_fn=<AddBackward0>)
# 379 tensor([753.4442], grad_fn=<AddBackward0>)
# 480 tensor([40.7568], grad_fn=<AddBackward0>)
# 481 tensor([744.0668], grad_fn=<AddBackward0>)
# 482 tensor([38.9549], grad_fn=<AddBackward0>)
# 483 tensor([1083.9296], grad_fn=<AddBackward0>)
# 484 tensor([38.6123], grad_fn=<AddBackward0>)
# 485 tensor([661.1782], grad_fn=<AddBackward0>)
# 486 tensor([148.2173], grad_fn=<AddBackward0>)
# 487 tensor([812.8657], grad_fn=<AddBackward0>)
# 488 tensor([58.8001], grad_fn=<AddBackward0>)
# 489 tensor([311.3620], grad_fn=<AddBackward0>)
# 490 tensor([842.8968], grad_fn=<AddBackward0>)
# 491 tensor([40.7740], grad_fn=<AddBackward0>)
# 492 tensor([40.0557], grad_fn=<AddBackward0>)
# 493 tensor([425.1969], grad_fn=<AddBackward0>)
# 494 tensor([993.3485], grad_fn=<AddBackward0>)
# 495 tensor([560.4517], grad_fn=<AddBackward0>)
# 496 tensor([41.0258], grad_fn=<AddBackward0>)
# 497 tensor([38.7122], grad_fn=<AddBackward0>)
# 498 tensor([276.5799], grad_fn=<AddBackward0>)
# 499 tensor([39.4715], grad_fn=<AddBackward0>)
# 600 tensor([752.8165], grad_fn=<AddBackward0>)
# 601 tensor([818.2210], grad_fn=<AddBackward0>)
# 602 tensor([39.5548], grad_fn=<AddBackward0>)
# 603 tensor([308.3406], grad_fn=<AddBackward0>)
# 604 tensor([570.5806], grad_fn=<AddBackward0>)
# 605 tensor([40.8580], grad_fn=<AddBackward0>)
# 606 tensor([438.2376], grad_fn=<AddBackward0>)
# 607 tensor([671.3547], grad_fn=<AddBackward0>)
# 608 tensor([1095.8041], grad_fn=<AddBackward0>)
# 609 tensor([39.6157], grad_fn=<AddBackward0>)
# 610 tensor([57.7093], grad_fn=<AddBackward0>)
# 611 tensor([1019.2253], grad_fn=<AddBackward0>)
# 612 tensor([41.6889], grad_fn=<AddBackward0>)
# 613 tensor([40.1763], grad_fn=<AddBackward0>)
# 614 tensor([794.0520], grad_fn=<AddBackward0>)
# 615 tensor([151.5778], grad_fn=<AddBackward0>)
# 616 tensor([39.3660], grad_fn=<AddBackward0>)
# 617 tensor([275.1584], grad_fn=<AddBackward0>)
# 618 tensor([39.9460], grad_fn=<AddBackward0>)
# 619 tensor([39.0182], grad_fn=<AddBackward0>)

# %%
plt.figure()
plt.plot(dtlossvals)
torch.save(PIDparams.state_dict(), "4odgradientparams")

# %%
kpst = torch.tensor(kp,requires_grad=True)
kist = torch.tensor(ki,requires_grad=True)
kdst = torch.tensor(kd,requires_grad=True)
backst = torch.tensor(0.1,requires_grad=True)
Tft = torch.tensor(Tf,requires_grad=True)
optimizer = torch.optim.Adam((kpst,kist,kdst,backst), lr=0.1, weight_decay=0.5)

stlossvals = []
closs = 0
kptrain = []
kitrain = []
kdtrain = []
backtrain = []
for episodes in range(701):
  cepisode = episodes%20  
  if(cepisode==0):  
    episodeorder = np.random.choice(20, 20, replace=False)
  ref = refs[episodeorder[cepisode],:]
  reft = torch.tensor(ref)  
  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0],[0.0],[0.0],[0.0]],requires_grad=True)  
  ucmd = torch.tensor([0.0],requires_grad=True)
  u = torch.tensor([0.0],requires_grad=True)  
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  D  = torch.tensor([0.0],requires_grad=False)
  #torch.clamp(Tft,0.1,0.1)
  ad = torch.div(Tft,(Tft+0.01))
  bd = torch.div(kdst,(Tft+0.01))
  noise = 0.01*torch.randn(T,1)
  
  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t];
    #error = torch.tensor(reft[t]-yt,requires_grad=False)
    saterr = u-ucmd
    xcont = xcont+kist*(reft[t]-yt)+backst*saterr
    if(t>0):
       #deriv = torch.tensor(yt-yold,requires_grad=False) 
       D = ad*D-bd*(yt-yold);  
       ucmd = (0.01*xcont+kpst*(reft[t]-yt)+D)
    u = torch.clamp(ucmd,-5.0,5.0)
    uvalssat[i] = u;
    x = torch.matmul(systA.float(),x)+systB.float()*u;
    cost = cost+torch.clamp((reft[t]-yt)**2,0,50)
  closs = closs+cost  
  if(episodes%20==19):    
    stlossvals.append(closs.clone().detach().numpy()/20)
    closs = 0
  kptrain.append(kpst.clone().detach().numpy())
  kitrain.append(kist.clone().detach().numpy())
  kdtrain.append(kdst.clone().detach().numpy())
  backtrain.append(backst.clone().detach().numpy())  
  if(episodes%120<20):
    #print(kpt,kdt,kit,Tft)
    print(episodes,cost,backst) 
  optimizer.zero_grad()
  cost.backward()
  optimizer.step()

print(kpst,kist,kdst,backst)
# Out:
# 0 tensor([967.4679], grad_fn=<AddBackward0>) tensor(0.1000, requires_grad=True)
# 1 tensor([815.7602], grad_fn=<AddBackward0>) tensor(0.2000, requires_grad=True)
# 2 tensor([209.6090], grad_fn=<AddBackward0>) tensor(0.2925, requires_grad=True)
# 3 tensor([66.5706], grad_fn=<AddBackward0>) tensor(0.3639, requires_grad=True)
# 4 tensor([65.8445], grad_fn=<AddBackward0>) tensor(0.4218, requires_grad=True)
# 5 tensor([61.0830], grad_fn=<AddBackward0>) tensor(0.4706, requires_grad=True)
# 6 tensor([1421.7875], grad_fn=<AddBackward0>) tensor(0.5123, requires_grad=True)
# 7 tensor([63.0640], grad_fn=<AddBackward0>) tensor(0.5743, requires_grad=True)
# 8 tensor([898.8417], grad_fn=<AddBackward0>) tensor(0.6283, requires_grad=True)
# 9 tensor([342.0255], grad_fn=<AddBackward0>) tensor(0.6859, requires_grad=True)
# 10 tensor([520.8344], grad_fn=<AddBackward0>) tensor(0.7387, requires_grad=True)
# 11 tensor([59.4581], grad_fn=<AddBackward0>) tensor(0.7887, requires_grad=True)
# 12 tensor([943.4623], grad_fn=<AddBackward0>) tensor(0.8334, requires_grad=True)
# 13 tensor([80.2374], grad_fn=<AddBackward0>) tensor(0.8807, requires_grad=True)
# 14 tensor([58.4516], grad_fn=<AddBackward0>) tensor(0.9231, requires_grad=True)
# 15 tensor([875.3661], grad_fn=<AddBackward0>) tensor(0.9611, requires_grad=True)
# 16 tensor([370.3813], grad_fn=<AddBackward0>) tensor(1.0003, requires_grad=True)
# 17 tensor([56.7297], grad_fn=<AddBackward0>) tensor(1.0360, requires_grad=True)
# 18 tensor([1085.6160], grad_fn=<AddBackward0>) tensor(1.0683, requires_grad=True)
# 19 tensor([55.0731], grad_fn=<AddBackward0>) tensor(1.0996, requires_grad=True)
# 120 tensor([831.6750], grad_fn=<AddBackward0>) tensor(1.4398, requires_grad=True)
# 121 tensor([441.1504], grad_fn=<AddBackward0>) tensor(1.4322, requires_grad=True)
# 122 tensor([64.1105], grad_fn=<AddBackward0>) tensor(1.4244, requires_grad=True)
# 123 tensor([672.4586], grad_fn=<AddBackward0>) tensor(1.4177, requires_grad=True)
# 124 tensor([45.5793], grad_fn=<AddBackward0>) tensor(1.4121, requires_grad=True)
# 125 tensor([763.0828], grad_fn=<AddBackward0>) tensor(1.4072, requires_grad=True)
# 126 tensor([289.4287], grad_fn=<AddBackward0>) tensor(1.4093, requires_grad=True)
# 127 tensor([45.2229], grad_fn=<AddBackward0>) tensor(1.4120, requires_grad=True)
# 128 tensor([586.0188], grad_fn=<AddBackward0>) tensor(1.4147, requires_grad=True)
# 129 tensor([44.5329], grad_fn=<AddBackward0>) tensor(1.4174, requires_grad=True)
# 130 tensor([44.7647], grad_fn=<AddBackward0>) tensor(1.4201, requires_grad=True)
# 131 tensor([45.9523], grad_fn=<AddBackward0>) tensor(1.4228, requires_grad=True)
# 132 tensor([1108.3777], grad_fn=<AddBackward0>) tensor(1.4254, requires_grad=True)
# 133 tensor([1015.9711], grad_fn=<AddBackward0>) tensor(1.4337, requires_grad=True)
# 134 tensor([815.0649], grad_fn=<AddBackward0>) tensor(1.4548, requires_grad=True)
# 135 tensor([45.0045], grad_fn=<AddBackward0>) tensor(1.4767, requires_grad=True)
# 136 tensor([325.3096], grad_fn=<AddBackward0>) tensor(1.4966, requires_grad=True)
# 137 tensor([45.7519], grad_fn=<AddBackward0>) tensor(1.5144, requires_grad=True)
# 138 tensor([44.7448], grad_fn=<AddBackward0>) tensor(1.5306, requires_grad=True)
# 139 tensor([154.3911], grad_fn=<AddBackward0>) tensor(1.5454, requires_grad=True)
# 240 tensor([673.2443], grad_fn=<AddBackward0>) tensor(1.5836, requires_grad=True)
# 241 tensor([834.9776], grad_fn=<AddBackward0>) tensor(1.5796, requires_grad=True)
# 242 tensor([585.2808], grad_fn=<AddBackward0>) tensor(1.5735, requires_grad=True)
# 243 tensor([48.0345], grad_fn=<AddBackward0>) tensor(1.5676, requires_grad=True)
# 244 tensor([48.3512], grad_fn=<AddBackward0>) tensor(1.5626, requires_grad=True)
# 245 tensor([47.8571], grad_fn=<AddBackward0>) tensor(1.5585, requires_grad=True)
# 246 tensor([47.2550], grad_fn=<AddBackward0>) tensor(1.5551, requires_grad=True)
# 247 tensor([67.1849], grad_fn=<AddBackward0>) tensor(1.5523, requires_grad=True)
# 248 tensor([48.0018], grad_fn=<AddBackward0>) tensor(1.5504, requires_grad=True)
# 249 tensor([289.9898], grad_fn=<AddBackward0>) tensor(1.5490, requires_grad=True)
# 250 tensor([1024.2433], grad_fn=<AddBackward0>) tensor(1.5502, requires_grad=True)
# 251 tensor([48.2163], grad_fn=<AddBackward0>) tensor(1.5577, requires_grad=True)
# 252 tensor([1122.0090], grad_fn=<AddBackward0>) tensor(1.5647, requires_grad=True)
# 253 tensor([161.0836], grad_fn=<AddBackward0>) tensor(1.5786, requires_grad=True)
# 254 tensor([773.0023], grad_fn=<AddBackward0>) tensor(1.5925, requires_grad=True)
# 255 tensor([845.0959], grad_fn=<AddBackward0>) tensor(1.6004, requires_grad=True)
# 256 tensor([329.4786], grad_fn=<AddBackward0>) tensor(1.6029, requires_grad=True)
# 257 tensor([47.6742], grad_fn=<AddBackward0>) tensor(1.6053, requires_grad=True)
# 258 tensor([47.3576], grad_fn=<AddBackward0>) tensor(1.6077, requires_grad=True)
# 259 tensor([451.8648], grad_fn=<AddBackward0>) tensor(1.6102, requires_grad=True)
# 360 tensor([47.2825], grad_fn=<AddBackward0>) tensor(1.5949, requires_grad=True)
# 361 tensor([845.9928], grad_fn=<AddBackward0>) tensor(1.5947, requires_grad=True)
# 362 tensor([47.5519], grad_fn=<AddBackward0>) tensor(1.5875, requires_grad=True)
# 363 tensor([1119.9413], grad_fn=<AddBackward0>) tensor(1.5814, requires_grad=True)
# 364 tensor([47.1607], grad_fn=<AddBackward0>) tensor(1.5765, requires_grad=True)
# 365 tensor([158.7374], grad_fn=<AddBackward0>) tensor(1.5725, requires_grad=True)
# 366 tensor([454.7850], grad_fn=<AddBackward0>) tensor(1.5697, requires_grad=True)
# 367 tensor([1021.1873], grad_fn=<AddBackward0>) tensor(1.5667, requires_grad=True)
# 368 tensor([292.9923], grad_fn=<AddBackward0>) tensor(1.5642, requires_grad=True)
# 369 tensor([330.8793], grad_fn=<AddBackward0>) tensor(1.5633, requires_grad=True)
# 370 tensor([586.2869], grad_fn=<AddBackward0>) tensor(1.5624, requires_grad=True)
# 371 tensor([676.5950], grad_fn=<AddBackward0>) tensor(1.5588, requires_grad=True)
# 372 tensor([774.9969], grad_fn=<AddBackward0>) tensor(1.5531, requires_grad=True)
# 373 tensor([48.8004], grad_fn=<AddBackward0>) tensor(1.5458, requires_grad=True)
# 374 tensor([48.2694], grad_fn=<AddBackward0>) tensor(1.5396, requires_grad=True)
# 375 tensor([48.5974], grad_fn=<AddBackward0>) tensor(1.5344, requires_grad=True)
# 376 tensor([817.4965], grad_fn=<AddBackward0>) tensor(1.5301, requires_grad=True)
# 377 tensor([48.3115], grad_fn=<AddBackward0>) tensor(1.5316, requires_grad=True)
# 378 tensor([48.1255], grad_fn=<AddBackward0>) tensor(1.5334, requires_grad=True)
# 379 tensor([66.6016], grad_fn=<AddBackward0>) tensor(1.5353, requires_grad=True)
# 480 tensor([328.8076], grad_fn=<AddBackward0>) tensor(1.5227, requires_grad=True)
# 481 tensor([162.0599], grad_fn=<AddBackward0>) tensor(1.5294, requires_grad=True)
# 482 tensor([48.1437], grad_fn=<AddBackward0>) tensor(1.5371, requires_grad=True)
# 483 tensor([49.2809], grad_fn=<AddBackward0>) tensor(1.5444, requires_grad=True)
# 484 tensor([1111.1655], grad_fn=<AddBackward0>) tensor(1.5514, requires_grad=True)
# 485 tensor([65.7596], grad_fn=<AddBackward0>) tensor(1.5467, requires_grad=True)
# 486 tensor([667.2726], grad_fn=<AddBackward0>) tensor(1.5431, requires_grad=True)
# 487 tensor([47.3029], grad_fn=<AddBackward0>) tensor(1.5391, requires_grad=True)
# 488 tensor([590.7863], grad_fn=<AddBackward0>) tensor(1.5359, requires_grad=True)
# 489 tensor([47.7435], grad_fn=<AddBackward0>) tensor(1.5270, requires_grad=True)
# 490 tensor([48.1454], grad_fn=<AddBackward0>) tensor(1.5193, requires_grad=True)
# 491 tensor([47.5806], grad_fn=<AddBackward0>) tensor(1.5127, requires_grad=True)
# 492 tensor([837.0803], grad_fn=<AddBackward0>) tensor(1.5073, requires_grad=True)
# 493 tensor([1033.2350], grad_fn=<AddBackward0>) tensor(1.4996, requires_grad=True)
# 494 tensor([295.9315], grad_fn=<AddBackward0>) tensor(1.5073, requires_grad=True)
# 495 tensor([764.1976], grad_fn=<AddBackward0>) tensor(1.5144, requires_grad=True)
# 496 tensor([47.3232], grad_fn=<AddBackward0>) tensor(1.5218, requires_grad=True)
# 497 tensor([456.7663], grad_fn=<AddBackward0>) tensor(1.5288, requires_grad=True)
# 498 tensor([47.5425], grad_fn=<AddBackward0>) tensor(1.5322, requires_grad=True)
# 499 tensor([846.4643], grad_fn=<AddBackward0>) tensor(1.5356, requires_grad=True)
# 600 tensor([767.8726], grad_fn=<AddBackward0>) tensor(1.4991, requires_grad=True)
# 601 tensor([1028.9752], grad_fn=<AddBackward0>) tensor(1.4879, requires_grad=True)
# 602 tensor([48.0978], grad_fn=<AddBackward0>) tensor(1.4874, requires_grad=True)
# 603 tensor([48.0096], grad_fn=<AddBackward0>) tensor(1.4874, requires_grad=True)
# 604 tensor([47.9211], grad_fn=<AddBackward0>) tensor(1.4879, requires_grad=True)
# 605 tensor([840.6881], grad_fn=<AddBackward0>) tensor(1.4889, requires_grad=True)
# 606 tensor([48.2966], grad_fn=<AddBackward0>) tensor(1.4973, requires_grad=True)
# 607 tensor([67.8944], grad_fn=<AddBackward0>) tensor(1.5055, requires_grad=True)
# 608 tensor([675.6862], grad_fn=<AddBackward0>) tensor(1.5138, requires_grad=True)
# 609 tensor([327.0698], grad_fn=<AddBackward0>) tensor(1.5236, requires_grad=True)
# 610 tensor([290.1894], grad_fn=<AddBackward0>) tensor(1.5329, requires_grad=True)
# 611 tensor([448.9496], grad_fn=<AddBackward0>) tensor(1.5425, requires_grad=True)
# 612 tensor([48.0354], grad_fn=<AddBackward0>) tensor(1.5483, requires_grad=True)
# 613 tensor([159.6433], grad_fn=<AddBackward0>) tensor(1.5539, requires_grad=True)
# 614 tensor([47.7426], grad_fn=<AddBackward0>) tensor(1.5605, requires_grad=True)
# 615 tensor([583.5904], grad_fn=<AddBackward0>) tensor(1.5669, requires_grad=True)
# 616 tensor([852.3396], grad_fn=<AddBackward0>) tensor(1.5656, requires_grad=True)
# 617 tensor([1121.5520], grad_fn=<AddBackward0>) tensor(1.5443, requires_grad=True)
# 618 tensor([48.0788], grad_fn=<AddBackward0>) tensor(1.5090, requires_grad=True)
# 619 tensor([47.3005], grad_fn=<AddBackward0>) tensor(1.4776, requires_grad=True)
# tensor(8.3605, requires_grad=True) tensor(2.4192, requires_grad=True) tensor(3.4338, requires_grad=True) tensor(1.5188, requires_grad=True)

# %%
kpdft = torch.tensor(kp,requires_grad=True)
kidft = torch.tensor(ki,requires_grad=True)
kddft = torch.tensor(kd,requires_grad=True)

#backdft = torch.tensor(0.1,requires_grad=True)

backdft = torch.zeros(500,requires_grad=True)

optimizer = torch.optim.Adam([backdft], lr=0.1, weight_decay=0.1)

dftlossvals = []
closs = 0
for episodes in range(501):
  cepisode = episodes%20  
  if(cepisode==0):  
    episodeorder = np.random.choice(20, 20, replace=False)
    
  ref = refs[episodeorder[cepisode],:]
  reft = torch.tensor(ref)  
  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0],[0.0],[0.0],[0.0]],requires_grad=True)  
  ucmd = torch.tensor([0.0],requires_grad=True)   
  u = torch.tensor([0.0],requires_grad=True)  
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  D  = torch.tensor([0.0],requires_grad=False)
  ad = torch.div(Tft,(Tft+0.01))
  bd = torch.div(kddft,(Tft+0.01))

  noise = 0.01*torch.randn(T,1)
  satest = torch.zeros(500,requires_grad=False)
  #satestsum = torch.sum(satest)
  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t];
    #error = torch.tensor(reft[t]-yt,requires_grad=False)
    #satestc = satest.clone().detach()
    #satest[1:500] = satestc[0:499] 
    satest = torch.roll(satest,1)
    satest[0] = u-ucmd
    #print(satest)
    #satestsum = satestsum+satest[0]
    xcont = xcont+kidft*(reft[t]-yt)
    if(t>0):
       #deriv = torch.tensor(yt-yold,requires_grad=False) 
       D = ad*D-bd*(yt-yold);  
       ucmd = (0.01*xcont+kpdft*(reft[t]-yt)+D+0.01*torch.dot(backdft,satest.detach()))
    u = torch.clamp(ucmd,-5.0,5.0)
    x = torch.matmul(systA.float(),x)+systB.float()*u
    #u2 = u1
    #u1 = u
    cost = cost+torch.clamp((reft[t]-yt)**2,0,50)
  closs = closs+cost  
  if(episodes%20==19):    
    dftlossvals.append(closs.clone().detach().numpy()[0]/20)
    closs = 0 
  if(episodes%120<20):
    print(episodes,cost)
    
  optimizer.zero_grad()
  cost.backward()
  optimizer.step()
# Out:
# 0 tensor([412.3443], grad_fn=<AddBackward0>)
# 1 tensor([2676.9907], grad_fn=<AddBackward0>)
# 2 tensor([603.1097], grad_fn=<AddBackward0>)
# 3 tensor([1567.6588], grad_fn=<AddBackward0>)
# 4 tensor([1100.6946], grad_fn=<AddBackward0>)
# 5 tensor([415.9274], grad_fn=<AddBackward0>)
# 6 tensor([62.7521], grad_fn=<AddBackward0>)
# 7 tensor([62.9645], grad_fn=<AddBackward0>)
# 8 tensor([1001.8336], grad_fn=<AddBackward0>)
# 9 tensor([928.6640], grad_fn=<AddBackward0>)
# 10 tensor([709.3781], grad_fn=<AddBackward0>)
# 11 tensor([60.9068], grad_fn=<AddBackward0>)
# 12 tensor([88.0063], grad_fn=<AddBackward0>)
# 13 tensor([208.2553], grad_fn=<AddBackward0>)
# 14 tensor([61.9011], grad_fn=<AddBackward0>)
# 15 tensor([64.1799], grad_fn=<AddBackward0>)
# 16 tensor([63.7865], grad_fn=<AddBackward0>)
# 17 tensor([63.7893], grad_fn=<AddBackward0>)
# 18 tensor([790.9501], grad_fn=<AddBackward0>)
# 19 tensor([63.5838], grad_fn=<AddBackward0>)
# 120 tensor([387.8973], grad_fn=<AddBackward0>)
# 121 tensor([666.4882], grad_fn=<AddBackward0>)
# 122 tensor([62.4587], grad_fn=<AddBackward0>)
# 123 tensor([60.6792], grad_fn=<AddBackward0>)
# 124 tensor([750.4283], grad_fn=<AddBackward0>)
# 125 tensor([58.9845], grad_fn=<AddBackward0>)
# 126 tensor([958.1885], grad_fn=<AddBackward0>)
# 127 tensor([61.3869], grad_fn=<AddBackward0>)
# 128 tensor([59.9781], grad_fn=<AddBackward0>)
# 129 tensor([81.2473], grad_fn=<AddBackward0>)
# 130 tensor([59.9042], grad_fn=<AddBackward0>)
# 131 tensor([185.6622], grad_fn=<AddBackward0>)
# 132 tensor([503.4432], grad_fn=<AddBackward0>)
# 133 tensor([335.6425], grad_fn=<AddBackward0>)
# 134 tensor([61.2622], grad_fn=<AddBackward0>)
# 135 tensor([61.0066], grad_fn=<AddBackward0>)
# 136 tensor([1775.8801], grad_fn=<AddBackward0>)
# 137 tensor([1349.6174], grad_fn=<AddBackward0>)
# 138 tensor([966.5444], grad_fn=<AddBackward0>)
# 139 tensor([880.8909], grad_fn=<AddBackward0>)
# 240 tensor([188.4154], grad_fn=<AddBackward0>)
# 241 tensor([82.4679], grad_fn=<AddBackward0>)
# 242 tensor([966.6091], grad_fn=<AddBackward0>)
# 243 tensor([367.3076], grad_fn=<AddBackward0>)
# 244 tensor([63.7393], grad_fn=<AddBackward0>)
# 245 tensor([60.8727], grad_fn=<AddBackward0>)
# 246 tensor([1451.7867], grad_fn=<AddBackward0>)
# 247 tensor([650.6008], grad_fn=<AddBackward0>)
# 248 tensor([1434.5972], grad_fn=<AddBackward0>)
# 249 tensor([62.6031], grad_fn=<AddBackward0>)
# 250 tensor([333.2199], grad_fn=<AddBackward0>)
# 251 tensor([58.7876], grad_fn=<AddBackward0>)
# 252 tensor([60.7955], grad_fn=<AddBackward0>)
# 253 tensor([63.6368], grad_fn=<AddBackward0>)
# 254 tensor([522.0067], grad_fn=<AddBackward0>)
# 255 tensor([789.1773], grad_fn=<AddBackward0>)
# 256 tensor([61.6685], grad_fn=<AddBackward0>)
# 257 tensor([989.9065], grad_fn=<AddBackward0>)
# 258 tensor([869.7285], grad_fn=<AddBackward0>)
# 259 tensor([59.2060], grad_fn=<AddBackward0>)
# 360 tensor([340.7470], grad_fn=<AddBackward0>)
# 361 tensor([370.9491], grad_fn=<AddBackward0>)
# 362 tensor([60.1284], grad_fn=<AddBackward0>)
# 363 tensor([931.3834], grad_fn=<AddBackward0>)
# 364 tensor([945.6682], grad_fn=<AddBackward0>)
# 365 tensor([61.5474], grad_fn=<AddBackward0>)
# 366 tensor([511.8014], grad_fn=<AddBackward0>)
# 367 tensor([189.9048], grad_fn=<AddBackward0>)
# 368 tensor([1312.2498], grad_fn=<AddBackward0>)
# 369 tensor([846.9464], grad_fn=<AddBackward0>)
# 370 tensor([62.9360], grad_fn=<AddBackward0>)
# 371 tensor([762.8194], grad_fn=<AddBackward0>)
# 372 tensor([60.7507], grad_fn=<AddBackward0>)
# 373 tensor([82.0383], grad_fn=<AddBackward0>)
# 374 tensor([1232.2719], grad_fn=<AddBackward0>)
# 375 tensor([59.9129], grad_fn=<AddBackward0>)
# 376 tensor([647.3597], grad_fn=<AddBackward0>)
# 377 tensor([58.3542], grad_fn=<AddBackward0>)
# 378 tensor([59.4538], grad_fn=<AddBackward0>)
# 379 tensor([61.5498], grad_fn=<AddBackward0>)
# 480 tensor([61.5511], grad_fn=<AddBackward0>)
# 481 tensor([63.1542], grad_fn=<AddBackward0>)
# 482 tensor([978.8174], grad_fn=<AddBackward0>)
# 483 tensor([1229.5676], grad_fn=<AddBackward0>)
# 484 tensor([87.9472], grad_fn=<AddBackward0>)
# 485 tensor([510.3770], grad_fn=<AddBackward0>)
# 486 tensor([378.3991], grad_fn=<AddBackward0>)
# 487 tensor([60.8987], grad_fn=<AddBackward0>)
# 488 tensor([190.7781], grad_fn=<AddBackward0>)
# 489 tensor([772.7247], grad_fn=<AddBackward0>)
# 490 tensor([60.5951], grad_fn=<AddBackward0>)
# 491 tensor([1366.5474], grad_fn=<AddBackward0>)
# 492 tensor([993.8614], grad_fn=<AddBackward0>)
# 493 tensor([329.2871], grad_fn=<AddBackward0>)
# 494 tensor([661.8158], grad_fn=<AddBackward0>)
# 495 tensor([59.1585], grad_fn=<AddBackward0>)
# 496 tensor([59.1047], grad_fn=<AddBackward0>)
# 497 tensor([57.8513], grad_fn=<AddBackward0>)
# 498 tensor([61.3510], grad_fn=<AddBackward0>)
# 499 tensor([896.0703], grad_fn=<AddBackward0>)

# %%
kps = kpst.detach().numpy()
kis = kist.detach().numpy()
kds = kdst.detach().numpy()
backs = backst.detach().numpy()
print(kps,kis,kds,backs)

plt.figure()
plt.plot(np.arange(len(dtlossvals))*20,dtlossvals)
plt.xlabel("No. of episodes")
plt.ylabel("Loss")

plt.figure()
plt.plot(np.arange(len(dftlossvals))*20,dftlossvals)
plt.xlabel("No. of episodes")
plt.ylabel("Loss")

plt.figure()
plt.plot(np.arange(len(stlossvals))*20,stlossvals)
plt.xlabel("No. of episodes")
plt.ylabel("Loss")

plt.figure()
plt.plot(np.arange(len(kptrain)),kptrain)
plt.xlabel("No. of episodes")
plt.ylabel("kp")

plt.figure()
plt.plot(np.arange(len(kdtrain)),kdtrain)
plt.xlabel("No. of episodes")
plt.ylabel("kd")

plt.figure()
plt.plot(np.arange(len(kitrain)),kitrain)
plt.xlabel("No. of episodes")
plt.ylabel("ki")

plt.figure()
plt.plot(np.arange(len(backtrain)),backtrain)
plt.xlabel("No. of episodes")
plt.ylabel("Back-calculation constant")
# Out:
# 8.360497 2.419234 3.4337916 1.5188301
# Text(0, 0.5, 'Back-calculation constant')

# %%
costdgradient = np.zeros((10,))
costinit = np.zeros((10,))
costsgradient = np.zeros((10,))
costdfgradient = np.zeros((10,))

ydgradient = np.zeros((10,T))
udgradient = np.zeros((10,T))

ysgradient = np.zeros((10,T))
usgradient = np.zeros((10,T))

ydfgradient = np.zeros((10,T))
udfgradient = np.zeros((10,T))

kpdgradient = np.zeros((10,T))
kidgradient = np.zeros((10,T))
kddgradient = np.zeros((10,T))
backdgradient = np.zeros((10,T))
#PIDparams = neuralPID()
#PIDparams.load_state_dict(torch.load("dgradientparams"))

yinit = np.zeros((10,T))
uinit = np.zeros((10,T))
smooth = 0.9

for iters in range(0,10):
  ref = refs[20+iters,:]
  reft = torch.tensor(ref)
  noise = 0.01*torch.randn(T,1)  
  
  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0],[0.0],[0.0],[0.0]],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  ucmd = torch.tensor([0.0],requires_grad=True)
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  D  = torch.tensor([0.0],requires_grad=False)
  #torch.clamp(Tft,0.1,0.1)
  ad = torch.div(Tft,(Tft+0.01))
  
  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t];
    ydgradient[iters,t] = yt.clone().detach().numpy()
    #print(yt)
    #error = torch.tensor(reft[t]-yt,requires_grad=False)
    saterr = u-ucmd
    err = reft[t]-yt
    ninput = torch.cat((err.detach(),saterr.detach()),0)
    kpdt,kidt,kddt,backdt = PIDparams(ninput)
    kpt = smooth*kpt+(1-smooth)*(kpit+kpdt)
    kit = smooth*kit+(1-smooth)*(kiit+kidt)
    kdt = smooth*kdt+(1-smooth)*(kdit+kddt)
    backt = smooth*backt+(1-smooth)*(backit+backdt)
    xcont = xcont+kit*err+backt*saterr.detach()
    if(t>0):
      bd = torch.div(kdt,(Tft+0.01))
      D = ad*D-bd*(yt-yold);  
      ucmd = (0.01*xcont+kpt*(reft[t]-yt)+D)
      u = torch.clamp(ucmd,-5.0,5.0)
      udgradient[iters,t] = u.clone().detach().numpy()
      kpdgradient[iters,t] = kpt.clone().detach().numpy()
      kidgradient[iters,t] = kit.clone().detach().numpy()
      kddgradient[iters,t] = kdt.clone().detach().numpy()
      backdgradient[iters,t] = backt.clone().detach().numpy()  
    x = torch.matmul(systA.float(),x)+systB.float()*u;
    cost = cost+(reft[t]-yt)**2
    
  costdgradient[iters] = cost.detach().numpy()

  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0],[0.0],[0.0],[0.0]],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  D  = torch.tensor([0.0],requires_grad=False)
  #torch.clamp(Tft,0.1,0.1)
  ad = torch.div(Tft,(Tft+0.01))
  
  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t];
    yinit[iters,t] = yt.clone().detach().numpy()
    #print(yt)
    #error = torch.tensor(reft[t]-yt,requires_grad=False)
    err = ref[t]-yt
    xcont = xcont+err
    if(t>0):
       #print(t,kpt,kit,kdt)
       #break;
       bd = torch.div(kdit,(Tft+0.01))
       D = ad*D-bd*(yt-yold);  
       u = (0.01*kiit*xcont+kpit*(ref[t]-yt)+D)
       u = torch.clamp(u,-5.0,5.0)
    uinit[iters,t] = u.clone().detach().numpy()
    x = torch.matmul(systA.float(),x)+systB.float()*u;
    cost = cost+(reft[t]-yt)**2
  costinit[iters] = cost.detach().numpy()

  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0],[0.0],[0.0],[0.0]],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  D  = torch.tensor([0.0],requires_grad=False)
  #torch.clamp(Tft,0.1,0.1)
  ad = torch.div(Tft,(Tft+0.01))
  bd = torch.div(kdst,(Tft+0.01))

  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t];
    ysgradient[iters,t] = yt.clone().detach().numpy()
    #print(yt)
    #error = torch.tensor(reft[t]-yt,requires_grad=False)
    saterr = u-ucmd
    xcont = xcont+kist*(reft[t]-yt)+backst*saterr.detach()
    if(t>0):
       #deriv = torch.tensor(yt-yold,requires_grad=False) 
       D = ad*D-bd*(yt-yold);  
       ucmd = (0.01*xcont+kpst*(reft[t]-yt)+D)
    u = torch.clamp(ucmd,-5.0,5.0)
    usgradient[iters,t] = u.clone().detach().numpy()
    x = torch.matmul(systA.float(),x)+systB.float()*u;
    cost = cost+(reft[t]-yt)**2
  costsgradient[iters] = cost.detach().numpy() 

  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0],[0.0],[0.0],[0.0]],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  u2 = torch.tensor([0.0],requires_grad=True)
  u1 = torch.tensor([0.0],requires_grad=True)     
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  D  = torch.tensor([0.0],requires_grad=False)
  satest = torch.zeros(500,requires_grad=False)
  ad = torch.div(Tft,(Tft+0.01))
  bd = torch.div(kddft,(Tft+0.01))
    
  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t]
    ydfgradient[iters,t] = yt.clone().detach().numpy()
    satest = torch.roll(satest,1)
    satest[0] = u-ucmd
    xcont = xcont+kidft*(reft[t]-yt)
    if(t>0):
       D = ad*D-bd*(yt-yold);  
       ucmd = (0.01*xcont+kpdft*(reft[t]-yt)+D+0.01*torch.dot(backdft,satest.detach()))
    u = torch.clamp(ucmd,-5.0,5.0)
    x = torch.matmul(systA.float(),x)+systB.float()*u
    cost = cost+torch.clamp((reft[t]-yt)**2,0,50)
  costdfgradient[iters] = cost.detach().numpy()

# %%
print("Dgradient-dynamic",costdgradient)
print("Dgradient-static",costsgradient)
print("DF-CVX",costdfgradient)
print("Initial",costinit)

print("Dgradient-dynamic",np.mean(costdgradient),np.std(costdgradient))
print("DF-CVX",np.mean(costdfgradient),np.std(costdfgradient))
print("Dgradient-static",np.mean(costsgradient),np.std(costsgradient))
print("Initial",np.mean(costinit),np.std(costinit))
# Out:
# Dgradient-dynamic [1087.77929688  330.97546387   39.64624786  276.9659729   618.75360107
#    51.34118271  525.7364502   909.90753174   39.66312027   40.20561218]
# Dgradient-static [1112.45715332  346.19436646   46.96563721  294.29833984  633.49688721
#    60.53785324  537.55474854  927.16455078   47.26424408   48.29164505]
# DF-CVX [1767.87927246  392.21481323   60.91462326  329.78250122  733.47290039
#    74.65512848  586.72924805 1259.03515625   59.43793869   60.26228714]
# Initial [3575.97729492  494.1378479    63.52055359  409.37307739  952.28503418
#    81.89087677  740.16827393 1834.60754395   62.46505356   65.36712646]
# Dgradient-dynamic 392.0974479675293 364.23873573558734
# DF-CVX 532.4383869171143 551.0836001311558
# Dgradient-static 405.4225425720215 368.8770394617101
# Initial 827.9792682647706 1057.5098995834635

# %%
plt.figure()
plt.plot(0.01*np.arange(0,T),refs[20,:])
plt.plot(0.01*np.arange(0,T),ydgradient[0,:])
plt.plot(0.01*np.arange(0,T),ysgradient[0,:])
plt.plot(0.01*np.arange(0,T),ydfgradient[0,:])
plt.plot(0.01*np.arange(0,T),yinit[0,:])
plt.xlabel("Time(s)")
plt.ylabel("Output")
plt.legend(["Reference","D-gradient (dynamic)","D-gradient (static)","DF-CVX","Initial"])

plt.figure()
plt.plot(0.01*np.arange(0,T),uinit[0,:])
plt.plot(0.01*np.arange(0,T),udgradient[0,:])
plt.plot(0.01*np.arange(0,T),usgradient[0,:])
plt.plot(0.01*np.arange(0,T),udfgradient[0,:])
plt.xlabel("Time(s)")
plt.ylabel("Input")
plt.legend(["Initial","D-gradient (dynamic)","D-gradient (static)","DF-CVX"])

plt.figure()
plt.plot(0.01*np.arange(1,T),kpdgradient[0,1:])
plt.xlabel("Time(s)")
plt.ylabel("Proportional gain")

plt.figure()
plt.plot(0.01*np.arange(1,T),kidgradient[0,1:])
plt.xlabel("Time(s)")
plt.ylabel("Integral gain")

plt.figure()
plt.plot(0.01*np.arange(1,T),kddgradient[0,1:])
plt.xlabel("Time(s)")
plt.ylabel("Derivative gain")

plt.figure()
plt.plot(0.01*np.arange(1,T),backdgradient[0,1:])
plt.xlabel("Time(s)")
plt.ylabel("Back-calculation gain")
# Out:
# Text(0, 0.5, 'Back-calculation gain')

# %%
# Save everything
np.save("4odddtlossvals",dtlossvals)
np.save("4oddstlossvals",stlossvals)
np.save("4odddftlossvals",dftlossvals)
np.save("4oddydgradient",ydgradient)
np.save("4oddydfgradient",ydfgradient)
np.save("4oddysgradient",ysgradient)
np.save("4oddyinit",yinit)
np.save("4oddudgradient",udgradient)
np.save("4oddudfgradient",udfgradient)
np.save("4oddusgradient",usgradient)
np.save("4odduinit",uinit)
np.save("4oddkpdgradient",kpdgradient)
np.save("4oddkidgradient",kidgradient)
np.save("4oddkddgradient",kddgradient)
np.save("4oddbackdgradient",backdgradient)
np.save("4oddkptrain",kptrain)
np.save("4oddkitrain",kitrain)
np.save("4oddkdtrain",kdtrain)
np.save("4oddbacktrain",backtrain)
np.save("4oddrefs",refs)
np.save("4oddcostdgradient",costdgradient)
np.save("4oddcostdfgradient",costdfgradient)
np.save("4oddcostsgradient",costsgradient)
np.save("4oddcostinit",costinit)

torch.save(backdft,"4oddbackdft")
torch.save(PIDparams.state_dict(), "4oddgradientparams")

# %%
kpit = torch.tensor(kp,requires_grad=False)
kiit = torch.tensor(ki,requires_grad=False)
kdit = torch.tensor(kd,requires_grad=False)
PIDpg = neuralPID()
#optimizer = torch.optim.Adam((PIDpg.parameters()), lr=0.1)
#for iters in range(1000):
#   kpt,kit,kdt = PIDpg(torch.randn(3,))
#   print(kpt,kit,kdt)
#   loss = (kpt-kpit)**2+(kit-kiit)**2+(kdt-kdit)**2
#   optimizer.zero_grad()
#   loss.backward()
#   optimizer.step()

# %%
ysat = np.zeros((T,))
uvalssat = np.zeros((T,))

optimizer = torch.optim.Adam((PIDpg.parameters()), lr=0.1)

nupdates = 100
nepisodes = 120
for updates in range(nupdates):
  cost = np.zeros((nepisodes,T))
  ref = refs[updates%20,:]
  rcostsepisode = np.zeros((nepisodes*T,1))
  totalcost = np.zeros((nepisodes,))
  uvalsepisode = np.zeros((nepisodes*T,1))
  PIDinputsepisode = np.zeros((nepisodes*T,3))
  PIDstatesepisode = np.zeros((nepisodes*T,4))
  for episodes in range(nepisodes):
    xcont = 0
    x =[[0.0],[0.0]]  
    u = 0.0
    ucmd = 0.0
    
    ucmdvals = np.zeros((T,1))
    uvals =  np.zeros((T,1))
    PIDinputs = np.zeros((T,3))
    PIDstates = np.zeros((T,4))
    yt = 0.0
    D  = 0.0
    
    ad = Tf/(Tf+0.01)
    adt = torch.tensor(ad,requires_grad=False)
    adt = adt.float()
    noise = 0.01*np.random.randn(T,1)
    sigma = 0.5
    for t in range(T):
      yold = yt
      yt = np.clip(np.dot(sysC,x)+noise[t],-30.0,30.0)
      err = ref[t]-yt[0]
      xcont = xcont+err
      if(t>0):
         inp = np.array([err,u,ucmd])
         ninput = torch.tensor(inp,requires_grad=False)
         PIDinputs[t,:] = inp   
         kpdt,kidt,kddt = PIDpg(ninput.float())
         kpt = kpit+kpdt
         kit = kiit+kidt
         kdt = kdit+kddt
         kpn = kpt.detach().numpy()
         kin = kit.detach().numpy()
         kdn = kdt.detach().numpy()
         #print(kpn,kin,kdn)   
         bd = kdn[0]/(Tf+0.01)
         PIDstates[t,:] = [err,xcont,D,yt[0]-yold[0]] 
         D = ad*D-bd*(yt[0]-yold[0])
         ucmd = (0.01*kin[0]*xcont+kpn[0]*err+D)
      if(episodes==0):
        u = ucmd
      else:  
        u = ucmd+sigma*np.random.randn()
      uvals[t] = u
      u = np.clip(u,-35.0,35.0)
      x = np.dot(sysA,x)+sysB*u;
      cost[episodes,t] = (ref[t]-yt)**2
    #rcosts = np.flip(np.cumsum(np.flip(cost[episodes,:],[0]),0),[0])
    totalcost[episodes] = np.sum(cost[episodes,:])
    rcosts = np.repeat(totalcost[episodes],T,0)
    #if(episodes==0):
    #  print(updates,episodes,rcosts[0])
    rcostsepisode[episodes*T:(episodes+1)*T,0] = rcosts
    uvalsepisode[episodes*T:(episodes+1)*T,:] = uvals
    PIDinputsepisode[episodes*T:(episodes+1)*T,:] = PIDinputs
    PIDstatesepisode[episodes*T:(episodes+1)*T,:] = PIDstates
  print(updates,episodes,np.min(totalcost))
  PIDinputstorch = torch.tensor(PIDinputsepisode).float()
  PIDstatestorch = torch.tensor(PIDstatesepisode).float()
  uvalstorch = torch.tensor(uvalsepisode).float()
  rcoststorch = torch.tensor(rcostsepisode).float()
  costmean = torch.tensor(np.mean(totalcost)).float()
    
  kptvals,kitvals,kdtvals = PIDpg(PIDinputstorch)
  bdtvals = (kd+kdtvals)/(Tft+0.01)  
  Dvals = adt*PIDstatestorch[:,2]-bdtvals*PIDstatestorch[:,3]  
  ucmdvals = 0.01*torch.mul((ki+kitvals),PIDstatestorch[:,1])+torch.mul((kp+kptvals),PIDstatestorch[:,0])+Dvals
  
  updatecost = torch.mean(torch.mul((uvalstorch-ucmdvals)**2,rcoststorch-costmean))/(2*sigma)
  optimizer.zero_grad()
  updatecost.backward()
  optimizer.step()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-20-2b00b39fa3d9> in <module>
#      41          ninput = torch.tensor(inp,requires_grad=False)
#      42          PIDinputs[t,:] = inp
# ---> 43          kpdt,kidt,kddt = PIDpg(ninput.float())
#      44          kpt = kpit+kpdt
#      45          kit = kiit+kidt
#
# ~/anaconda3/envs/pytogpu/lib/python3.8/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# <ipython-input-6-d32cbaf6ed8a> in forward(self, x)
#      14    def forward(self,x):
#      15     sigmoid = torch.nn.Tanh()
# ---> 16     kp = self.kplayer2(sigmoid(self.kplayer1(x)))
#      17     ki = self.kilayer2(sigmoid(self.kilayer1(x)))
#      18     kd = self.kdlayer2(sigmoid(self.kdlayer1(x)))
#
# ~/anaconda3/envs/pytogpu/lib/python3.8/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/pytogpu/lib/python3.8/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      85
#      86     def forward(self, input):
# ---> 87         return F.linear(input, self.weight, self.bias)
#      88
#      89     def extra_repr(self):
#
# ~/anaconda3/envs/pytogpu/lib/python3.8/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1370         ret = torch.addmm(bias, input, weight.t())
#    1371     else:
# -> 1372         output = input.matmul(weight.t())
#    1373         if bias is not None:
#    1374             output += bias
#
# RuntimeError: size mismatch, m1: [1 x 3], m2: [2 x 2] at /opt/conda/conda-bld/pytorch_1579022027550/work/aten/src/TH/generic/THTensorMath.cpp:136
