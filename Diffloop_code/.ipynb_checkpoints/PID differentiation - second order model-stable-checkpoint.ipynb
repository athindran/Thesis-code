# %%
import numpy as np
import scipy
import torch
from matplotlib import pyplot as plt
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable 
import control
from control import matlab
from matplotlib import cm

np.random.seed(0)
dev = "cpu"  
device = torch.device(dev)

# %%
sysA = np.array([[1.000,0.0008],[0.0013,1.0]])
#sysA = 0.99
sysB = np.array([[0.04],[0.0]])
sysC = np.array([0,2])
sysD = 0
print(np.linalg.eig(sysA))
kp = 20.0
ki = 2.0
kd = 5.0
Tf = 0.01
# Out:
# (array([1.0010198, 0.9989802]), array([[ 0.6172134 , -0.6172134 ],
#        [ 0.78679579,  0.78679579]]))

# %%
T = 2000
refs = np.zeros((30,T))
np.random.seed(2)

randval = 0

for i in range(30):
  refs[i,0:300] = 0
  randval = 5.8*np.random.rand()-2.9
  print(randval)  
  if randval>0 and randval<1:
    randval = 1
  if randval<0 and randval>-1:
    randval = -1
  refs[i,300:] = randval
# Out:
# -0.37122956757637837
# -2.7496278553982303
# 0.28804237169651303
# -0.37513012281399405
# -0.46186674789256355
# -0.9840580381775301
# -1.7130379225805135
# 0.6917716048338494
# -1.1620028926877657
# -1.3524018044033734
# 0.7025762300619105
# 0.16902414680682654
# -2.1194363169993853
# 0.07875310334132912
# -1.8302487792478914
# 1.6549438573367063
# 2.0530566973090347
# -0.03342634318481874
# 2.010056615073314
# -2.4380562333474463
# 0.030427322705882887
# -2.521338274556107
# -0.41689049993514127
# -2.340120689168447
# -2.162472164132591
# 0.5611227920758557
# -1.589130396495432
# -2.2797150310020986
# -1.6222239989907536
# -0.8710075469808642

# %%
ref = refs[1,:]
ysat = np.zeros((T,))
uvalssat = np.zeros((T,))
xcont = 0
u = 0
D = 0
ad = Tf/(Tf+0.01)
bd = kd/(Tf+0.01)
noise = 0.01*np.random.randn(T,1)

x0 = np.zeros((2,1))
x = x0
for i in range(T):
   ysat[i] = np.dot(sysC,x)+np.dot(sysD,u)+noise[i]
   xcont = xcont+(ref[i]-ysat[i])
   if(i>0):
     D = ad*D-bd*(ysat[i]-ysat[i-1])  
     u = 0.01*ki*xcont+kp*(ref[i]-ysat[i])+D
   if(u>3.0):
     u=3.0
   elif(u<-3.0):
     u=-3.0
   uvalssat[i] = u;
   x = np.dot(sysA,x)+np.dot(sysB,u);

ynosat = np.zeros((T,))
uvalsnosat = np.zeros((T,))
xcont = 0;
u = 0;
x = x0
D = 0

for i in range(T):
   ynosat[i] = np.dot(sysC,x)+np.dot(sysD,u)+noise[i]
   xcont = xcont+(ref[i]-ynosat[i])
   if(i>0):
     D = ad*D-bd*(ynosat[i]-ynosat[i-1])  
     u = 0.01*ki*xcont+kp*(ref[i]-ynosat[i])+D 
   uvalsnosat[i] = u;
   x = np.dot(sysA,x)+np.dot(sysB,u);

# %%
plt.figure
plt.plot(0.01*np.arange(T),ynosat)
plt.plot(0.01*np.arange(T),ysat)
plt.plot(0.01*np.arange(T),ref)
plt.xlabel("Time (s)")
plt.ylabel("Output")
plt.legend(["No saturation","Saturation","Reference"])
plt.show()

plt.figure
plt.plot(0.01*np.arange(T),uvalsnosat)
plt.plot(0.01*np.arange(T),uvalssat)
plt.xlabel("Time (s)")
plt.ylabel("Input")
plt.legend(["No saturation","Saturation"])
plt.show()

# %%
class neuralPID(torch.nn.Module):
   def __init__(self):
    super(neuralPID, self).__init__()
    torch.manual_seed(2)
    self.kplayer1 = torch.nn.Linear(2,2)
    self.kplayer2 = torch.nn.Linear(2,1)
    self.kilayer1 = torch.nn.Linear(2,2)
    self.kilayer2 = torch.nn.Linear(2,1)
    self.kdlayer1 = torch.nn.Linear(2,2)
    self.kdlayer2 = torch.nn.Linear(2,1)
    self.backlayer1 = torch.nn.Linear(2,2)
    self.backlayer2 = torch.nn.Linear(2,1)
  
   def forward(self,x):
    sigmoid = torch.nn.Tanh()
    kp = self.kplayer2(sigmoid(self.kplayer1(x)))
    ki = self.kilayer2(sigmoid(self.kilayer1(x)))
    kd = self.kdlayer2(sigmoid(self.kdlayer1(x)))
    back = self.backlayer2(sigmoid(self.backlayer1(x)))
    #kd = torch.clamp(kd,0,400)
    #kp = torch.clamp(kp,0,400)
    #ki = torch.clamp(ki,0,400)
    return kp,ki,kd,back

# %%
Tft = torch.tensor(Tf,requires_grad=True)
kpit = torch.tensor(kp,requires_grad=False)
kiit = torch.tensor(ki,requires_grad=False)
kdit = torch.tensor(kd,requires_grad=False)
backit = torch.tensor(0.1,requires_grad=False)

systA = torch.tensor(sysA,requires_grad=False)
systB = torch.tensor(sysB,requires_grad=False)
systC = torch.tensor(sysC,requires_grad=False)
systD = torch.tensor(sysD,requires_grad=False)

# %%
costinit = np.zeros((30,))

yinit = np.zeros((30,T))
uinit = np.zeros((30,T))
Tft = torch.tensor(Tf,requires_grad=True)
kpit = torch.tensor(kp,requires_grad=False)
kiit = torch.tensor(ki,requires_grad=False)
kdit = torch.tensor(kd,requires_grad=False)

systA = torch.tensor(sysA,requires_grad=False)
systB = torch.tensor(sysB,requires_grad=False)
systC = torch.tensor(sysC,requires_grad=False)
systD = torch.tensor(sysD,requires_grad=False)

for iters in range(0,30):
  ref = refs[iters,:]
  reft = torch.tensor(ref)
  noise = 0.01*torch.randn(T,1)

  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0],[0.0]],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  D  = torch.tensor([0.0],requires_grad=False)
  #torch.clamp(Tft,0.1,0.1)
  ad = torch.div(Tft,(Tft+0.01))
  
  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t];
    yinit[iters,t] = yt.clone().detach().numpy()
    #print(yt)
    #error = torch.tensor(reft[t]-yt,requires_grad=False)
    err = ref[t]-yt
    xcont = xcont+err
    if(t>0):
       #print(t,kpt,kit,kdt)
       #break;
       bd = torch.div(kdit,(Tft+0.01))
       D = ad*D-bd*(yt-yold);  
       u = (0.01*kiit*xcont+kpit*(ref[t]-yt)+D)
       u = torch.clamp(u,-3.0,3.0)
    uinit[iters,t] = u.clone().detach().numpy()
    x = torch.matmul(systA.float(),x)+systB.float()*u;
    cost = cost+(reft[t]-yt)**2
  costinit[iters] = cost.detach().numpy()

# %%
print(costinit)
plt.figure()
plt.plot(refs[1,:])
plt.plot(yinit[1,:])
# Out:
# [ 50.69254303 825.52130127  48.44729614  54.57674789  48.68120575
#   51.95583344 206.96261597  48.56554413  72.9740448  110.84013367
#   51.42602539  50.38070297 396.82785034  48.68688583 251.25860596
#  191.59469604 351.3470459   51.44469452 326.97348022 574.84185791
#   46.89762115 614.28710938  51.20515442 534.10925293 421.58126831
#   48.18386459 168.06173706 493.96170044 181.73857117  51.88479996]

# %%
# Initialize network
Tft = torch.tensor(Tf,requires_grad=True)
kpit = torch.tensor(kp,requires_grad=False)
kiit = torch.tensor(ki,requires_grad=False)
kdit = torch.tensor(kd,requires_grad=False)
backit = torch.tensor(0.1,requires_grad=False)

kpt = torch.tensor(kp,requires_grad=True)
kit = torch.tensor(ki,requires_grad=True)
kdt = torch.tensor(kd,requires_grad=True)
backt = torch.tensor(0.1,requires_grad=True)

systA = torch.tensor(sysA,requires_grad=False)
systB = torch.tensor(sysB,requires_grad=False)
systC = torch.tensor(sysC,requires_grad=False)
systD = torch.tensor(sysD,requires_grad=False)

PIDparams = neuralPID()
#optimizer = torch.optim.Adam((PIDparams.parameters()), lr=0.1)
#for iters in range(1000):
#   kpt,kit,kdt = PIDparams(torch.randn(3,))
#   print(kpt,kit,kdt)
#   loss = (kpt-kpit)**2+(kit-kiit)**2+(kdt-kdit)**2
#   optimizer.zero_grad()
#   loss.backward()
#   optimizer.step()    
   #print(iters,loss)

# %%
ysat = np.zeros((T,))
uvalssat = np.zeros((T,))

optimizer = torch.optim.Adam((PIDparams.parameters()), lr=0.1, weight_decay=0.1)

smooth = 0.9
closs = 0
dtlossvals = []

for episodes in range(401):
  cepisode = episodes%20  
  if(cepisode==0):  
    episodeorder = np.random.choice(20, 20, replace=False)
  ref = refs[episodeorder[cepisode],:]
  reft = torch.tensor(ref)  
  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0],[0.0]],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  ucmd = torch.tensor([0.0],requires_grad=True)
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  D  = torch.tensor([0.0],requires_grad=False)
  ad = torch.div(Tft,(Tft+0.01))
  noise = 0.01*torch.randn(T,1)
  kpt = kpt.clone().detach()
  kit = kit.clone().detach()
  kdt = kdt.clone().detach()
  backt = backt.clone().detach()

  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t]
    saterr = u-ucmd
    err = reft[t]-yt
    ninput = torch.cat((err.detach(),saterr.detach()),0)
    kpdt,kidt,kddt,backdt = PIDparams(ninput)
    kpt = smooth*kpt+(1-smooth)*(kpit+kpdt)
    kit = smooth*kit+(1-smooth)*(kiit+kidt)
    kdt = smooth*kdt+(1-smooth)*(kdit+kddt)
    backt = smooth*backt+(1-smooth)*(backit+backdt)
    xcont = xcont+kit*err+backt*saterr.detach()
    if(t>0):
      bd = torch.div(kdt,(Tft+0.01))
      D = ad*D-bd*(yt-yold);  
      ucmd = (0.01*xcont+kpt*(reft[t]-yt)+D)
      u = torch.clamp(ucmd,-3.0,3.0)
    x = torch.matmul(systA.float(),x)+systB.float()*u;
    cost = cost+(reft[t]-yt)**2
  closs = closs+cost   
  if(episodes%120<20):
    print(episodes,cost)
  if(episodes%20==19):    
    dtlossvals.append(closs.clone().detach().numpy()[0]/20)
    closs = 0  
  optimizer.zero_grad()
  cost.backward()
  optimizer.step()
# Out:
# 0 tensor([110.4125], grad_fn=<AddBackward0>)
# 1 tensor([49.4961], grad_fn=<AddBackward0>)
# 2 tensor([521.9916], grad_fn=<AddBackward0>)
# 3 tensor([46.7232], grad_fn=<AddBackward0>)
# 4 tensor([450.4420], grad_fn=<AddBackward0>)
# 5 tensor([216.9114], grad_fn=<AddBackward0>)
# 6 tensor([49.8595], grad_fn=<AddBackward0>)
# 7 tensor([49.9943], grad_fn=<AddBackward0>)
# 8 tensor([673.8317], grad_fn=<AddBackward0>)
# 9 tensor([60.8316], grad_fn=<AddBackward0>)
# 10 tensor([58.2017], grad_fn=<AddBackward0>)
# 11 tensor([217.7284], grad_fn=<AddBackward0>)
# 12 tensor([52.2785], grad_fn=<AddBackward0>)
# 13 tensor([107.6384], grad_fn=<AddBackward0>)
# 14 tensor([72.7016], grad_fn=<AddBackward0>)
# 15 tensor([292.1501], grad_fn=<AddBackward0>)
# 16 tensor([256.1243], grad_fn=<AddBackward0>)
# 17 tensor([47.8878], grad_fn=<AddBackward0>)
# 18 tensor([53.5058], grad_fn=<AddBackward0>)
# 19 tensor([179.9744], grad_fn=<AddBackward0>)
# 120 tensor([48.0873], grad_fn=<AddBackward0>)
# 121 tensor([50.1895], grad_fn=<AddBackward0>)
# 122 tensor([45.2198], grad_fn=<AddBackward0>)
# 123 tensor([279.3335], grad_fn=<AddBackward0>)
# 124 tensor([45.5619], grad_fn=<AddBackward0>)
# 125 tensor([151.5242], grad_fn=<AddBackward0>)
# 126 tensor([556.6727], grad_fn=<AddBackward0>)
# 127 tensor([205.7344], grad_fn=<AddBackward0>)
# 128 tensor([45.3218], grad_fn=<AddBackward0>)
# 129 tensor([42.8450], grad_fn=<AddBackward0>)
# 130 tensor([254.7937], grad_fn=<AddBackward0>)
# 131 tensor([93.8395], grad_fn=<AddBackward0>)
# 132 tensor([47.1215], grad_fn=<AddBackward0>)
# 133 tensor([49.3602], grad_fn=<AddBackward0>)
# 134 tensor([287.6205], grad_fn=<AddBackward0>)
# 135 tensor([46.4445], grad_fn=<AddBackward0>)
# 136 tensor([64.8003], grad_fn=<AddBackward0>)
# 137 tensor([399.5035], grad_fn=<AddBackward0>)
# 138 tensor([51.4998], grad_fn=<AddBackward0>)
# 139 tensor([168.8976], grad_fn=<AddBackward0>)
# 240 tensor([163.0724], grad_fn=<AddBackward0>)
# 241 tensor([100.1546], grad_fn=<AddBackward0>)
# 242 tensor([260.6901], grad_fn=<AddBackward0>)
# 243 tensor([46.3678], grad_fn=<AddBackward0>)
# 244 tensor([45.2581], grad_fn=<AddBackward0>)
# 245 tensor([403.5706], grad_fn=<AddBackward0>)
# 246 tensor([45.3166], grad_fn=<AddBackward0>)
# 247 tensor([42.7505], grad_fn=<AddBackward0>)
# 248 tensor([551.3071], grad_fn=<AddBackward0>)
# 249 tensor([207.5179], grad_fn=<AddBackward0>)
# 250 tensor([48.4624], grad_fn=<AddBackward0>)
# 251 tensor([48.2523], grad_fn=<AddBackward0>)
# 252 tensor([45.5215], grad_fn=<AddBackward0>)
# 253 tensor([49.8335], grad_fn=<AddBackward0>)
# 254 tensor([160.0955], grad_fn=<AddBackward0>)
# 255 tensor([45.3537], grad_fn=<AddBackward0>)
# 256 tensor([69.6487], grad_fn=<AddBackward0>)
# 257 tensor([289.5243], grad_fn=<AddBackward0>)
# 258 tensor([272.1818], grad_fn=<AddBackward0>)
# 259 tensor([44.2289], grad_fn=<AddBackward0>)
# 360 tensor([93.1571], grad_fn=<AddBackward0>)
# 361 tensor([62.1965], grad_fn=<AddBackward0>)
# 362 tensor([177.2099], grad_fn=<AddBackward0>)
# 363 tensor([45.9518], grad_fn=<AddBackward0>)
# 364 tensor([45.9606], grad_fn=<AddBackward0>)
# 365 tensor([43.8539], grad_fn=<AddBackward0>)
# 366 tensor([279.0048], grad_fn=<AddBackward0>)
# 367 tensor([47.4545], grad_fn=<AddBackward0>)
# 368 tensor([45.2762], grad_fn=<AddBackward0>)
# 369 tensor([49.0502], grad_fn=<AddBackward0>)
# 370 tensor([150.6034], grad_fn=<AddBackward0>)
# 371 tensor([280.5215], grad_fn=<AddBackward0>)
# 372 tensor([580.8406], grad_fn=<AddBackward0>)
# 373 tensor([47.3697], grad_fn=<AddBackward0>)
# 374 tensor([421.4485], grad_fn=<AddBackward0>)
# 375 tensor([197.0317], grad_fn=<AddBackward0>)
# 376 tensor([48.2450], grad_fn=<AddBackward0>)
# 377 tensor([274.1933], grad_fn=<AddBackward0>)
# 378 tensor([47.2331], grad_fn=<AddBackward0>)
# 379 tensor([43.1552], grad_fn=<AddBackward0>)

# %%
plt.figure()
plt.plot(dtlossvals)

torch.save(PIDparams.state_dict(), "sodgradientparams")

# %%
kpst = torch.tensor(kp,requires_grad=True)
kist = torch.tensor(ki,requires_grad=True)
kdst = torch.tensor(kd,requires_grad=True)
backst = torch.tensor(0.0,requires_grad=True)
Tft = torch.tensor(Tf,requires_grad=True)
optimizer = torch.optim.Adam((kpst,kist,kdst,backst), lr=0.1, weight_decay=0.1)

stlossvals = []
closs = 0
kptrain = []
kitrain = []
kdtrain = []
backtrain = []
for episodes in range(401):
  cepisode = episodes%20  
  if(cepisode==0):  
    episodeorder = np.random.choice(20, 20, replace=False)
  ref = refs[episodeorder[cepisode],:]
  reft = torch.tensor(ref)  
  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0],[0.0]],requires_grad=True)  
  ucmd = torch.tensor([0.0],requires_grad=True)
  u = torch.tensor([0.0],requires_grad=True)  
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  D  = torch.tensor([0.0],requires_grad=False)
  #torch.clamp(Tft,0.1,0.1)
  ad = torch.div(Tft,(Tft+0.01))
  bd = torch.div(kdst,(Tft+0.01))
  noise = 0.01*torch.randn(T,1)
  
  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t];
    #error = torch.tensor(reft[t]-yt,requires_grad=False)
    saterr = u-ucmd
    xcont = xcont+kist*(reft[t]-yt)+backst*saterr
    if(t>0):
       #deriv = torch.tensor(yt-yold,requires_grad=False) 
       D = ad*D-bd*(yt-yold);  
       ucmd = (0.01*xcont+kpst*(reft[t]-yt)+D)
    u = torch.clamp(ucmd,-3.0,3.0)
    uvalssat[i] = u;
    x = torch.matmul(systA.float(),x)+systB.float()*u;
    cost = cost+(reft[t]-yt)**2
  closs = closs+cost 
  if(episodes%20==19):
    stlossvals.append(closs.clone().detach().numpy()[0]/20)
    closs = 0
  kptrain.append(kpst.clone().detach().numpy())
  kitrain.append(kist.clone().detach().numpy())
  kdtrain.append(kdst.clone().detach().numpy())
  backtrain.append(backst.clone().detach().numpy())  
  if(episodes%60<20):
    #print(kpt,kdt,kit,Tft)
    print(episodes,cost,backst) 
  optimizer.zero_grad()
  cost.backward()
  optimizer.step()
print(kpst,kist,kdst,backst)
# Out:
# 0 tensor([398.7210], grad_fn=<AddBackward0>) tensor(0., requires_grad=True)
# 1 tensor([50.4631], grad_fn=<AddBackward0>) tensor(0.1000, requires_grad=True)
# 2 tensor([45.8495], grad_fn=<AddBackward0>) tensor(0.1691, requires_grad=True)
# 3 tensor([179.5431], grad_fn=<AddBackward0>) tensor(0.2237, requires_grad=True)
# 4 tensor([97.1212], grad_fn=<AddBackward0>) tensor(0.2736, requires_grad=True)
# 5 tensor([50.2306], grad_fn=<AddBackward0>) tensor(0.3164, requires_grad=True)
# 6 tensor([46.9611], grad_fn=<AddBackward0>) tensor(0.3534, requires_grad=True)
# 7 tensor([44.6986], grad_fn=<AddBackward0>) tensor(0.3858, requires_grad=True)
# 8 tensor([48.8146], grad_fn=<AddBackward0>) tensor(0.4141, requires_grad=True)
# 9 tensor([48.7990], grad_fn=<AddBackward0>) tensor(0.4391, requires_grad=True)
# 10 tensor([160.4657], grad_fn=<AddBackward0>) tensor(0.4609, requires_grad=True)
# 11 tensor([270.4004], grad_fn=<AddBackward0>) tensor(0.4774, requires_grad=True)
# 12 tensor([47.7707], grad_fn=<AddBackward0>) tensor(0.4862, requires_grad=True)
# 13 tensor([437.8022], grad_fn=<AddBackward0>) tensor(0.4934, requires_grad=True)
# 14 tensor([45.7873], grad_fn=<AddBackward0>) tensor(0.4843, requires_grad=True)
# 15 tensor([571.8762], grad_fn=<AddBackward0>) tensor(0.4754, requires_grad=True)
# 16 tensor([46.1404], grad_fn=<AddBackward0>) tensor(0.4569, requires_grad=True)
# 17 tensor([64.5781], grad_fn=<AddBackward0>) tensor(0.4395, requires_grad=True)
# 18 tensor([207.2651], grad_fn=<AddBackward0>) tensor(0.4233, requires_grad=True)
# 19 tensor([280.9088], grad_fn=<AddBackward0>) tensor(0.4072, requires_grad=True)
# 60 tensor([47.8196], grad_fn=<AddBackward0>) tensor(0.4008, requires_grad=True)
# 61 tensor([565.8246], grad_fn=<AddBackward0>) tensor(0.4031, requires_grad=True)
# 62 tensor([48.8834], grad_fn=<AddBackward0>) tensor(0.4088, requires_grad=True)
# 63 tensor([97.8824], grad_fn=<AddBackward0>) tensor(0.4144, requires_grad=True)
# 64 tensor([257.0295], grad_fn=<AddBackward0>) tensor(0.4195, requires_grad=True)
# 65 tensor([49.6416], grad_fn=<AddBackward0>) tensor(0.4221, requires_grad=True)
# 66 tensor([49.9442], grad_fn=<AddBackward0>) tensor(0.4244, requires_grad=True)
# 67 tensor([45.1635], grad_fn=<AddBackward0>) tensor(0.4267, requires_grad=True)
# 68 tensor([46.9412], grad_fn=<AddBackward0>) tensor(0.4290, requires_grad=True)
# 69 tensor([46.8916], grad_fn=<AddBackward0>) tensor(0.4312, requires_grad=True)
# 70 tensor([408.6140], grad_fn=<AddBackward0>) tensor(0.4337, requires_grad=True)
# 71 tensor([266.4819], grad_fn=<AddBackward0>) tensor(0.4353, requires_grad=True)
# 72 tensor([68.8812], grad_fn=<AddBackward0>) tensor(0.4363, requires_grad=True)
# 73 tensor([44.7509], grad_fn=<AddBackward0>) tensor(0.4378, requires_grad=True)
# 74 tensor([167.2022], grad_fn=<AddBackward0>) tensor(0.4394, requires_grad=True)
# 75 tensor([45.0296], grad_fn=<AddBackward0>) tensor(0.4420, requires_grad=True)
# 76 tensor([292.1932], grad_fn=<AddBackward0>) tensor(0.4444, requires_grad=True)
# 77 tensor([42.8756], grad_fn=<AddBackward0>) tensor(0.4450, requires_grad=True)
# 78 tensor([161.5147], grad_fn=<AddBackward0>) tensor(0.4459, requires_grad=True)
# 79 tensor([204.0809], grad_fn=<AddBackward0>) tensor(0.4475, requires_grad=True)
# 120 tensor([253.8458], grad_fn=<AddBackward0>) tensor(0.4847, requires_grad=True)
# 121 tensor([49.8030], grad_fn=<AddBackward0>) tensor(0.4858, requires_grad=True)
# 122 tensor([47.5931], grad_fn=<AddBackward0>) tensor(0.4869, requires_grad=True)
# 123 tensor([47.5435], grad_fn=<AddBackward0>) tensor(0.4883, requires_grad=True)
# 124 tensor([288.8716], grad_fn=<AddBackward0>) tensor(0.4892, requires_grad=True)
# 125 tensor([270.4125], grad_fn=<AddBackward0>) tensor(0.4872, requires_grad=True)
# 126 tensor([45.6011], grad_fn=<AddBackward0>) tensor(0.4835, requires_grad=True)
# 127 tensor([47.2918], grad_fn=<AddBackward0>) tensor(0.4797, requires_grad=True)
# 128 tensor([574.2847], grad_fn=<AddBackward0>) tensor(0.4764, requires_grad=True)
# 129 tensor([68.0370], grad_fn=<AddBackward0>) tensor(0.4636, requires_grad=True)
# 130 tensor([157.8558], grad_fn=<AddBackward0>) tensor(0.4524, requires_grad=True)
# 131 tensor([209.8242], grad_fn=<AddBackward0>) tensor(0.4426, requires_grad=True)
# 132 tensor([48.0684], grad_fn=<AddBackward0>) tensor(0.4344, requires_grad=True)
# 133 tensor([409.5265], grad_fn=<AddBackward0>) tensor(0.4271, requires_grad=True)
# 134 tensor([45.4478], grad_fn=<AddBackward0>) tensor(0.4229, requires_grad=True)
# 135 tensor([46.4502], grad_fn=<AddBackward0>) tensor(0.4199, requires_grad=True)
# 136 tensor([168.5714], grad_fn=<AddBackward0>) tensor(0.4181, requires_grad=True)
# 137 tensor([102.0750], grad_fn=<AddBackward0>) tensor(0.4198, requires_grad=True)
# 138 tensor([45.2039], grad_fn=<AddBackward0>) tensor(0.4225, requires_grad=True)
# 139 tensor([46.9661], grad_fn=<AddBackward0>) tensor(0.4251, requires_grad=True)
# 180 tensor([45.9014], grad_fn=<AddBackward0>) tensor(0.4882, requires_grad=True)
# 181 tensor([48.4403], grad_fn=<AddBackward0>) tensor(0.4861, requires_grad=True)
# 182 tensor([91.1531], grad_fn=<AddBackward0>) tensor(0.4849, requires_grad=True)
# 183 tensor([257.8144], grad_fn=<AddBackward0>) tensor(0.4851, requires_grad=True)
# 184 tensor([48.1853], grad_fn=<AddBackward0>) tensor(0.4838, requires_grad=True)
# 185 tensor([46.9964], grad_fn=<AddBackward0>) tensor(0.4830, requires_grad=True)
# 186 tensor([204.7052], grad_fn=<AddBackward0>) tensor(0.4831, requires_grad=True)
# 187 tensor([267.1629], grad_fn=<AddBackward0>) tensor(0.4844, requires_grad=True)
# 188 tensor([550.2284], grad_fn=<AddBackward0>) tensor(0.4882, requires_grad=True)
# 189 tensor([424.2664], grad_fn=<AddBackward0>) tensor(0.4882, requires_grad=True)
# 190 tensor([155.3633], grad_fn=<AddBackward0>) tensor(0.4833, requires_grad=True)
# 191 tensor([49.2629], grad_fn=<AddBackward0>) tensor(0.4799, requires_grad=True)
# 192 tensor([283.1395], grad_fn=<AddBackward0>) tensor(0.4775, requires_grad=True)
# 193 tensor([48.0359], grad_fn=<AddBackward0>) tensor(0.4774, requires_grad=True)
# 194 tensor([47.8901], grad_fn=<AddBackward0>) tensor(0.4775, requires_grad=True)
# 195 tensor([50.5674], grad_fn=<AddBackward0>) tensor(0.4782, requires_grad=True)
# 196 tensor([68.7735], grad_fn=<AddBackward0>) tensor(0.4794, requires_grad=True)
# 197 tensor([47.8380], grad_fn=<AddBackward0>) tensor(0.4810, requires_grad=True)
# 198 tensor([171.8242], grad_fn=<AddBackward0>) tensor(0.4828, requires_grad=True)
# 199 tensor([49.4717], grad_fn=<AddBackward0>) tensor(0.4863, requires_grad=True)
# 240 tensor([49.0043], grad_fn=<AddBackward0>) tensor(0.5230, requires_grad=True)
# 241 tensor([50.2315], grad_fn=<AddBackward0>) tensor(0.5178, requires_grad=True)
# 242 tensor([175.6638], grad_fn=<AddBackward0>) tensor(0.5134, requires_grad=True)
# 243 tensor([46.7312], grad_fn=<AddBackward0>) tensor(0.5095, requires_grad=True)
# 244 tensor([48.3285], grad_fn=<AddBackward0>) tensor(0.5068, requires_grad=True)
# 245 tensor([270.3505], grad_fn=<AddBackward0>) tensor(0.5050, requires_grad=True)
# 246 tensor([556.7715], grad_fn=<AddBackward0>) tensor(0.5047, requires_grad=True)
# 247 tensor([406.3044], grad_fn=<AddBackward0>) tensor(0.5046, requires_grad=True)
# 248 tensor([266.8755], grad_fn=<AddBackward0>) tensor(0.5052, requires_grad=True)
# 249 tensor([47.5076], grad_fn=<AddBackward0>) tensor(0.5041, requires_grad=True)
# 250 tensor([48.9920], grad_fn=<AddBackward0>) tensor(0.5041, requires_grad=True)
# 251 tensor([102.1262], grad_fn=<AddBackward0>) tensor(0.5050, requires_grad=True)
# 252 tensor([165.8491], grad_fn=<AddBackward0>) tensor(0.5068, requires_grad=True)
# 253 tensor([68.7852], grad_fn=<AddBackward0>) tensor(0.5087, requires_grad=True)
# 254 tensor([288.6531], grad_fn=<AddBackward0>) tensor(0.5118, requires_grad=True)
# 255 tensor([206.1278], grad_fn=<AddBackward0>) tensor(0.5142, requires_grad=True)
# 256 tensor([48.7587], grad_fn=<AddBackward0>) tensor(0.5207, requires_grad=True)
# 257 tensor([48.7161], grad_fn=<AddBackward0>) tensor(0.5272, requires_grad=True)
# 258 tensor([48.1931], grad_fn=<AddBackward0>) tensor(0.5342, requires_grad=True)
# 259 tensor([47.5085], grad_fn=<AddBackward0>) tensor(0.5411, requires_grad=True)
# 300 tensor([414.5183], grad_fn=<AddBackward0>) tensor(0.5430, requires_grad=True)
# 301 tensor([553.5067], grad_fn=<AddBackward0>) tensor(0.5356, requires_grad=True)
# 302 tensor([69.3962], grad_fn=<AddBackward0>) tensor(0.5250, requires_grad=True)
# 303 tensor([48.8892], grad_fn=<AddBackward0>) tensor(0.5168, requires_grad=True)
# 304 tensor([99.4233], grad_fn=<AddBackward0>) tensor(0.5104, requires_grad=True)
# 305 tensor([49.3400], grad_fn=<AddBackward0>) tensor(0.5062, requires_grad=True)
# 306 tensor([50.5235], grad_fn=<AddBackward0>) tensor(0.5033, requires_grad=True)
# 307 tensor([50.0694], grad_fn=<AddBackward0>) tensor(0.5014, requires_grad=True)
# 308 tensor([175.9064], grad_fn=<AddBackward0>) tensor(0.5004, requires_grad=True)
# 309 tensor([48.9991], grad_fn=<AddBackward0>) tensor(0.5023, requires_grad=True)
# 310 tensor([48.7994], grad_fn=<AddBackward0>) tensor(0.5049, requires_grad=True)
# 311 tensor([48.6074], grad_fn=<AddBackward0>) tensor(0.5080, requires_grad=True)
# 312 tensor([203.5731], grad_fn=<AddBackward0>) tensor(0.5117, requires_grad=True)
# 313 tensor([48.1343], grad_fn=<AddBackward0>) tensor(0.5197, requires_grad=True)
# 314 tensor([48.5788], grad_fn=<AddBackward0>) tensor(0.5277, requires_grad=True)
# 315 tensor([289.2546], grad_fn=<AddBackward0>) tensor(0.5356, requires_grad=True)
# 316 tensor([50.0373], grad_fn=<AddBackward0>) tensor(0.5404, requires_grad=True)
# 317 tensor([268.3045], grad_fn=<AddBackward0>) tensor(0.5452, requires_grad=True)
# 318 tensor([259.9717], grad_fn=<AddBackward0>) tensor(0.5488, requires_grad=True)
# 319 tensor([159.7477], grad_fn=<AddBackward0>) tensor(0.5480, requires_grad=True)
# 360 tensor([48.9487], grad_fn=<AddBackward0>) tensor(0.4757, requires_grad=True)
# 361 tensor([46.9206], grad_fn=<AddBackward0>) tensor(0.5066, requires_grad=True)
# 362 tensor([98.5510], grad_fn=<AddBackward0>) tensor(0.5355, requires_grad=True)
# 363 tensor([50.1408], grad_fn=<AddBackward0>) tensor(0.5626, requires_grad=True)
# 364 tensor([50.2641], grad_fn=<AddBackward0>) tensor(0.5870, requires_grad=True)
# 365 tensor([554.3397], grad_fn=<AddBackward0>) tensor(0.6095, requires_grad=True)
# 366 tensor([426.9965], grad_fn=<AddBackward0>) tensor(0.6038, requires_grad=True)
# 367 tensor([278.7402], grad_fn=<AddBackward0>) tensor(0.5821, requires_grad=True)
# 368 tensor([208.7208], grad_fn=<AddBackward0>) tensor(0.5560, requires_grad=True)
# 369 tensor([160.5557], grad_fn=<AddBackward0>) tensor(0.5331, requires_grad=True)
# 370 tensor([49.5375], grad_fn=<AddBackward0>) tensor(0.5144, requires_grad=True)
# 371 tensor([296.8557], grad_fn=<AddBackward0>) tensor(0.4983, requires_grad=True)
# 372 tensor([70.7329], grad_fn=<AddBackward0>) tensor(0.4903, requires_grad=True)
# 373 tensor([50.1526], grad_fn=<AddBackward0>) tensor(0.4844, requires_grad=True)
# 374 tensor([47.4197], grad_fn=<AddBackward0>) tensor(0.4798, requires_grad=True)
# 375 tensor([178.5613], grad_fn=<AddBackward0>) tensor(0.4766, requires_grad=True)
# 376 tensor([264.6733], grad_fn=<AddBackward0>) tensor(0.4796, requires_grad=True)
# 377 tensor([49.3158], grad_fn=<AddBackward0>) tensor(0.4899, requires_grad=True)
# 378 tensor([49.7509], grad_fn=<AddBackward0>) tensor(0.5005, requires_grad=True)
# 379 tensor([49.4354], grad_fn=<AddBackward0>) tensor(0.5111, requires_grad=True)
# tensor(7.6047, requires_grad=True) tensor(1.2633, requires_grad=True) tensor(3.0588, requires_grad=True) tensor(0.5163, requires_grad=True)

# %%
kpdft = torch.tensor(kp,requires_grad=True)
kidft = torch.tensor(ki,requires_grad=True)
kddft = torch.tensor(kd,requires_grad=True)

#backdft = torch.tensor(0.1,requires_grad=True)

backdft = torch.zeros(500,requires_grad=True)

optimizer = torch.optim.Adam([backdft], lr=0.1, weight_decay=0.5)

dftlossvals = []
closs = 0
for episodes in range(501):
  cepisode = episodes%20  
  if(cepisode==0):  
    episodeorder = np.random.choice(20, 20, replace=False)
    
  ref = refs[episodeorder[cepisode],:]
  reft = torch.tensor(ref)  
  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0],[0.0]],requires_grad=True)  
  ucmd = torch.tensor([0.0],requires_grad=True)
  #u2 = torch.tensor([0.0],requires_grad=True)
  #u1 = torch.tensor([0.0],requires_grad=True)    
  u = torch.tensor([0.0],requires_grad=True)  
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  D  = torch.tensor([0.0],requires_grad=False)
  ad = torch.div(Tft,(Tft+0.01))
  bd = torch.div(kddft,(Tft+0.01))

  noise = 0.01*torch.randn(T,1)
  satest = torch.zeros(500,requires_grad=False)
  #satestsum = torch.sum(satest)
  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t];
    #error = torch.tensor(reft[t]-yt,requires_grad=False)
    #satestc = satest.clone().detach()
    #satest[1:500] = satestc[0:499] 
    satest = torch.roll(satest,1)
    satest[0] = u-ucmd
    #print(satest)
    #satestsum = satestsum+satest[0]
    xcont = xcont+kidft*(reft[t]-yt)
    if(t>0):
       #deriv = torch.tensor(yt-yold,requires_grad=False) 
       D = ad*D-bd*(yt-yold);  
       ucmd = (0.01*xcont+kpdft*(reft[t]-yt)+D+0.01*torch.dot(backdft,satest.detach()))
    u = torch.clamp(ucmd,-3.0,3.0)
    x = torch.matmul(systA.float(),x)+systB.float()*u
    #u2 = u1
    #u1 = u
    cost = cost+torch.clamp((reft[t]-yt)**2,0,50)
  closs = closs+cost  
  if(episodes%20==19):    
    dftlossvals.append(closs.clone().detach().numpy()[0]/20)
    closs = 0 
  if(episodes%100==0):
    print(episodes,cost)
    
  optimizer.zero_grad()
  cost.backward()
  optimizer.step()
# Out:
# 0 tensor([344.2863], grad_fn=<AddBackward0>)
# 100 tensor([47.6984], grad_fn=<AddBackward0>)
# 200 tensor([49.8106], grad_fn=<AddBackward0>)
# 300 tensor([48.5203], grad_fn=<AddBackward0>)
# 400 tensor([44.4211], grad_fn=<AddBackward0>)
# 500 tensor([68.6415], grad_fn=<AddBackward0>)

# %%
kps = kpst.detach().numpy()
kis = kist.detach().numpy()
kds = kdst.detach().numpy()
backs = backst.detach().numpy()
print(kps,kis,kds,backs)

plt.figure()
plt.plot(np.arange(len(dtlossvals))*20,dtlossvals)
plt.xlabel("No. of episodes")
plt.ylabel("Loss")

plt.figure()
plt.plot(np.arange(len(dftlossvals))*20,dftlossvals)
plt.xlabel("No. of episodes")
plt.ylabel("Loss")

plt.figure()
plt.plot(np.arange(len(stlossvals))*20,stlossvals)
plt.xlabel("No. of episodes")
plt.ylabel("Loss")

plt.figure()
plt.plot(np.arange(len(kptrain)),kptrain)
plt.xlabel("No. of episodes")
plt.ylabel("kp")

plt.figure()
plt.plot(np.arange(len(kdtrain)),kdtrain)
plt.xlabel("No. of episodes")
plt.ylabel("kd")

plt.figure()
plt.plot(np.arange(len(kitrain)),kitrain)
plt.xlabel("No. of episodes")
plt.ylabel("ki")

plt.figure()
plt.plot(np.arange(len(backtrain)),backtrain)
plt.xlabel("No. of episodes")
plt.ylabel("Back-calculation constant")
# Out:
# 7.6046677 1.2632843 3.0587678 0.51628304
# Text(0, 0.5, 'Back-calculation constant')

# %%
costdgradient = np.zeros((10,))
costinit = np.zeros((10,))
costsgradient = np.zeros((10,))
costdfgradient = np.zeros((10,))

ydgradient = np.zeros((10,T))
udgradient = np.zeros((10,T))

ysgradient = np.zeros((10,T))
usgradient = np.zeros((10,T))


ydfgradient = np.zeros((10,T))
udfgradient = np.zeros((10,T))

kpdgradient = np.zeros((10,T))
kidgradient = np.zeros((10,T))
kddgradient = np.zeros((10,T))
backdgradient = np.zeros((10,T))
#PIDparams = neuralPID()
#PIDparams.load_state_dict(torch.load("dgradientparams"))

yinit = np.zeros((10,T))
uinit = np.zeros((10,T))
smooth = 0.9

for iters in range(0,10):
  ref = refs[20+iters,:]
  reft = torch.tensor(ref)
  noise = 0.01*torch.randn(T,1)  
  
  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0],[0.0]],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  ucmd = torch.tensor([0.0],requires_grad=True)
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  D  = torch.tensor([0.0],requires_grad=False)
  #torch.clamp(Tft,0.1,0.1)
  ad = torch.div(Tft,(Tft+0.01))
  
  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t];
    ydgradient[iters,t] = yt.clone().detach().numpy()
    #print(yt)
    #error = torch.tensor(reft[t]-yt,requires_grad=False)
    saterr = u-ucmd
    err = reft[t]-yt
    ninput = torch.cat((err.detach(),saterr.detach()),0)
    kpdt,kidt,kddt,backdt = PIDparams(ninput)
    kpt = smooth*kpt+(1-smooth)*(kpit+kpdt)
    kit = smooth*kit+(1-smooth)*(kiit+kidt)
    kdt = smooth*kdt+(1-smooth)*(kdit+kddt)
    backt = smooth*backt+(1-smooth)*(backit+backdt)
    xcont = xcont+kit*err+backt*saterr.detach()
    if(t>0):
      bd = torch.div(kdt,(Tft+0.01))
      D = ad*D-bd*(yt-yold);  
      ucmd = (0.01*xcont+kpt*(reft[t]-yt)+D)
      u = torch.clamp(ucmd,-3.0,3.0)
      udgradient[iters,t] = u.clone().detach().numpy()
      kpdgradient[iters,t] = kpt.clone().detach().numpy()
      kidgradient[iters,t] = kit.clone().detach().numpy()
      kddgradient[iters,t] = kdt.clone().detach().numpy()
      backdgradient[iters,t] = backt.clone().detach().numpy()  
    x = torch.matmul(systA.float(),x)+systB.float()*u;
    cost = cost+(reft[t]-yt)**2
    
  costdgradient[iters] = cost.detach().numpy()

  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0],[0.0]],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  D  = torch.tensor([0.0],requires_grad=False)
  #torch.clamp(Tft,0.1,0.1)
  ad = torch.div(Tft,(Tft+0.01))
  
  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t];
    yinit[iters,t] = yt.clone().detach().numpy()
    #print(yt)
    #error = torch.tensor(reft[t]-yt,requires_grad=False)
    err = ref[t]-yt
    xcont = xcont+err
    if(t>0):
       #print(t,kpt,kit,kdt)
       #break;
       bd = torch.div(kdit,(Tft+0.01))
       D = ad*D-bd*(yt-yold);  
       u = (0.01*kiit*xcont+kpit*(ref[t]-yt)+D)
       u = torch.clamp(u,-3.0,3.0)
    uinit[iters,t] = u.clone().detach().numpy()
    x = torch.matmul(systA.float(),x)+systB.float()*u;
    cost = cost+(reft[t]-yt)**2
  costinit[iters] = cost.detach().numpy()

  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0],[0.0]],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  D  = torch.tensor([0.0],requires_grad=False)
  #torch.clamp(Tft,0.1,0.1)
  ad = torch.div(Tft,(Tft+0.01))
  bd = torch.div(kdst,(Tft+0.01))

  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t];
    ysgradient[iters,t] = yt.clone().detach().numpy()
    #print(yt)
    #error = torch.tensor(reft[t]-yt,requires_grad=False)
    saterr = u-ucmd
    xcont = xcont+kist*(reft[t]-yt)+backst*saterr.detach()
    if(t>0):
       #deriv = torch.tensor(yt-yold,requires_grad=False) 
       D = ad*D-bd*(yt-yold);  
       ucmd = (0.01*xcont+kpst*(reft[t]-yt)+D)
    u = torch.clamp(ucmd,-3.0,3.0)
    usgradient[iters,t] = u.clone().detach().numpy()
    x = torch.matmul(systA.float(),x)+systB.float()*u;
    cost = cost+(reft[t]-yt)**2
  costsgradient[iters] = cost.detach().numpy() 

  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0],[0.0]],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  u2 = torch.tensor([0.0],requires_grad=True)
  u1 = torch.tensor([0.0],requires_grad=True)     
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  D  = torch.tensor([0.0],requires_grad=False)
  satest = torch.zeros(500,requires_grad=False)
  ad = torch.div(Tft,(Tft+0.01))
  bd = torch.div(kddft,(Tft+0.01))
    
  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t]
    ydfgradient[iters,t] = yt.clone().detach().numpy()
    satest = torch.roll(satest,1)
    satest[0] = u-ucmd
    xcont = xcont+kidft*(reft[t]-yt)
    if(t>0):
       D = ad*D-bd*(yt-yold);  
       ucmd = (0.01*xcont+kpdft*(reft[t]-yt)+D+0.01*torch.dot(backdft,satest.detach()))
    u = torch.clamp(ucmd,-3.0,3.0)
    x = torch.matmul(systA.float(),x)+systB.float()*u
    cost = cost+(reft[t]-yt)**2
  costdfgradient[iters] = cost.detach().numpy()

# %%
print("Dgradient-dynamic",costdgradient)
print("DF-CVX",costdfgradient)
print("Dgradient-static",costsgradient)
print("Initial",costinit)

print("Dgradient-dynamic",np.mean(costdgradient),np.std(costdgradient))
print("DF-CVX",np.mean(costdfgradient),np.std(costdfgradient))
print("Dgradient-static",np.mean(costsgradient),np.std(costsgradient))
print("Initial",np.mean(costinit),np.std(costinit))
# Out:
# Dgradient-dynamic [ 44.49452591 449.76425171  42.88938522 398.20019531 315.18130493
#   47.32265091 140.7257843  323.65313721 148.04634094  45.70437622]
# DF-CVX [ 44.71372986 471.8248291   44.21720886 414.68795776 328.5229187
#   47.33802414 145.72814941 341.58477783 154.61152649  45.59770584]
# Dgradient-static [ 46.9842186  449.07717896  47.74881363 384.7442627  312.92883301
#   49.0325737  143.86036682 343.12271118 152.66609192  47.99926376]
# Initial [ 48.18648148 644.15625     49.57361984 550.3572998  408.40182495
#   52.129673   171.46643066 452.34393311 181.9329834   48.52125168]
# Dgradient-dynamic 195.59819526672362 152.38910619790514
# DF-CVX 203.88268280029297 160.2893299414434
# Dgradient-static 197.81643142700196 150.74516036535863
# Initial 260.7069747924805 219.52400597540077

# %%
plt.figure()
plt.plot(0.01*np.arange(0,T),refs[21,:])
plt.plot(0.01*np.arange(0,T),ydgradient[1,:])
plt.plot(0.01*np.arange(0,T),ysgradient[1,:])
plt.plot(0.01*np.arange(0,T),ydfgradient[1,:])
plt.plot(0.01*np.arange(0,T),yinit[1,:])
plt.xlabel("Time(s)")
plt.ylabel("Output")
plt.legend(["Reference","D-gradient (dynamic)","D-gradient (static)","DFC-CVX","Initial"])

plt.figure()
plt.plot(0.01*np.arange(0,T),uinit[1,:])
plt.plot(0.01*np.arange(0,T),udgradient[1,:])
plt.plot(0.01*np.arange(0,T),usgradient[1,:])
plt.plot(0.01*np.arange(0,T),udfgradient[1,:])
plt.xlabel("Time(s)")
plt.ylabel("Input")
plt.legend(["Initial","D-gradient (dynamic)","D-gradient (static)","DFC-CVX"])

plt.figure()
plt.plot(0.01*np.arange(1,T),kpdgradient[1,1:])
plt.xlabel("Time(s)")
plt.ylabel("Proportional gain")

plt.figure()
plt.plot(0.01*np.arange(1,T),kidgradient[1,1:])
plt.xlabel("Time(s)")
plt.ylabel("Integral gain")

plt.figure()
plt.plot(0.01*np.arange(1,T),kddgradient[1,1:])
plt.xlabel("Time(s)")
plt.ylabel("Derivative gain")

plt.figure()
plt.plot(0.01*np.arange(1,T),backdgradient[1,1:])
plt.xlabel("Time(s)")
plt.ylabel("Back-calculation gain")
# Out:
# Text(0, 0.5, 'Back-calculation gain')

# %%
# Save everything
np.save("sodddtlossvals",dtlossvals)
np.save("soddstlossvals",stlossvals)
np.save("sodddftlossvals",dftlossvals)
np.save("soddydgradient",ydgradient)
np.save("soddydfgradient",ydfgradient)
np.save("soddysgradient",ysgradient)
np.save("soddyinit",yinit)
np.save("soddudgradient",udgradient)
np.save("soddudfgradient",udfgradient)
np.save("soddusgradient",usgradient)
np.save("sodduinit",uinit)
np.save("soddkpdgradient",kpdgradient)
np.save("soddkidgradient",kidgradient)
np.save("soddkddgradient",kddgradient)
np.save("soddbackdgradient",backdgradient)
np.save("soddkptrain",kptrain)
np.save("soddkitrain",kitrain)
np.save("soddkdtrain",kdtrain)
np.save("soddbacktrain",backtrain)
np.save("soddrefs",refs)
np.save("soddcostdgradient",costdgradient)
np.save("soddcostdfgradient",costdfgradient)
np.save("soddcostsgradient",costsgradient)
np.save("soddcostinit",costinit)

torch.save(backdft,"soddbackdft")
torch.save(PIDparams.state_dict(), "soddgradientparams")

# %%
kpit = torch.tensor(kp,requires_grad=False)
kiit = torch.tensor(ki,requires_grad=False)
kdit = torch.tensor(kd,requires_grad=False)
PIDpg = neuralPID()
#optimizer = torch.optim.Adam((PIDpg.parameters()), lr=0.1)
#for iters in range(1000):
#   kpt,kit,kdt = PIDpg(torch.randn(3,))
#   print(kpt,kit,kdt)
#   loss = (kpt-kpit)**2+(kit-kiit)**2+(kdt-kdit)**2
#   optimizer.zero_grad()
#   loss.backward()
#   optimizer.step()

# %%
ysat = np.zeros((T,))
uvalssat = np.zeros((T,))

optimizer = torch.optim.Adam((PIDpg.parameters()), lr=0.1)

nupdates = 100
nepisodes = 120
for updates in range(nupdates):
  cost = np.zeros((nepisodes,T))
  ref = refs[updates%20,:]
  rcostsepisode = np.zeros((nepisodes*T,1))
  totalcost = np.zeros((nepisodes,))
  uvalsepisode = np.zeros((nepisodes*T,1))
  PIDinputsepisode = np.zeros((nepisodes*T,3))
  PIDstatesepisode = np.zeros((nepisodes*T,4))
  for episodes in range(nepisodes):
    xcont = 0
    x =[[0.0],[0.0]]  
    u = 0.0
    ucmd = 0.0
    
    ucmdvals = np.zeros((T,1))
    uvals =  np.zeros((T,1))
    PIDinputs = np.zeros((T,3))
    PIDstates = np.zeros((T,4))
    yt = 0.0
    D  = 0.0
    
    ad = Tf/(Tf+0.01)
    adt = torch.tensor(ad,requires_grad=False)
    adt = adt.float()
    noise = 0.01*np.random.randn(T,1)
    sigma = 0.5
    for t in range(T):
      yold = yt
      yt = np.clip(np.dot(sysC,x)+noise[t],-30.0,30.0)
      err = ref[t]-yt[0]
      xcont = xcont+err
      if(t>0):
         inp = np.array([err,u,ucmd])
         ninput = torch.tensor(inp,requires_grad=False)
         PIDinputs[t,:] = inp   
         kpdt,kidt,kddt = PIDpg(ninput.float())
         kpt = kpit+kpdt
         kit = kiit+kidt
         kdt = kdit+kddt
         kpn = kpt.detach().numpy()
         kin = kit.detach().numpy()
         kdn = kdt.detach().numpy()
         #print(kpn,kin,kdn)   
         bd = kdn[0]/(Tf+0.01)
         PIDstates[t,:] = [err,xcont,D,yt[0]-yold[0]] 
         D = ad*D-bd*(yt[0]-yold[0])
         ucmd = (0.01*kin[0]*xcont+kpn[0]*err+D)
      if(episodes==0):
        u = ucmd
      else:  
        u = ucmd+sigma*np.random.randn()
      uvals[t] = u
      u = np.clip(u,-35.0,35.0)
      x = np.dot(sysA,x)+sysB*u;
      cost[episodes,t] = (ref[t]-yt)**2
    #rcosts = np.flip(np.cumsum(np.flip(cost[episodes,:],[0]),0),[0])
    totalcost[episodes] = np.sum(cost[episodes,:])
    rcosts = np.repeat(totalcost[episodes],T,0)
    #if(episodes==0):
    #  print(updates,episodes,rcosts[0])
    rcostsepisode[episodes*T:(episodes+1)*T,0] = rcosts
    uvalsepisode[episodes*T:(episodes+1)*T,:] = uvals
    PIDinputsepisode[episodes*T:(episodes+1)*T,:] = PIDinputs
    PIDstatesepisode[episodes*T:(episodes+1)*T,:] = PIDstates
  print(updates,episodes,np.min(totalcost))
  PIDinputstorch = torch.tensor(PIDinputsepisode).float()
  PIDstatestorch = torch.tensor(PIDstatesepisode).float()
  uvalstorch = torch.tensor(uvalsepisode).float()
  rcoststorch = torch.tensor(rcostsepisode).float()
  costmean = torch.tensor(np.mean(totalcost)).float()
    
  kptvals,kitvals,kdtvals = PIDpg(PIDinputstorch)
  bdtvals = (kd+kdtvals)/(Tft+0.01)  
  Dvals = adt*PIDstatestorch[:,2]-bdtvals*PIDstatestorch[:,3]  
  ucmdvals = 0.01*torch.mul((ki+kitvals),PIDstatestorch[:,1])+torch.mul((kp+kptvals),PIDstatestorch[:,0])+Dvals
  
  updatecost = torch.mean(torch.mul((uvalstorch-ucmdvals)**2,rcoststorch-costmean))/(2*sigma)
  optimizer.zero_grad()
  updatecost.backward()
  optimizer.step()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-20-2b00b39fa3d9> in <module>
#      41          ninput = torch.tensor(inp,requires_grad=False)
#      42          PIDinputs[t,:] = inp
# ---> 43          kpdt,kidt,kddt = PIDpg(ninput.float())
#      44          kpt = kpit+kpdt
#      45          kit = kiit+kidt
#
# ~/anaconda3/envs/pytogpu/lib/python3.8/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# <ipython-input-6-d32cbaf6ed8a> in forward(self, x)
#      14    def forward(self,x):
#      15     sigmoid = torch.nn.Tanh()
# ---> 16     kp = self.kplayer2(sigmoid(self.kplayer1(x)))
#      17     ki = self.kilayer2(sigmoid(self.kilayer1(x)))
#      18     kd = self.kdlayer2(sigmoid(self.kdlayer1(x)))
#
# ~/anaconda3/envs/pytogpu/lib/python3.8/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/pytogpu/lib/python3.8/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      85
#      86     def forward(self, input):
# ---> 87         return F.linear(input, self.weight, self.bias)
#      88
#      89     def extra_repr(self):
#
# ~/anaconda3/envs/pytogpu/lib/python3.8/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1370         ret = torch.addmm(bias, input, weight.t())
#    1371     else:
# -> 1372         output = input.matmul(weight.t())
#    1373         if bias is not None:
#    1374             output += bias
#
# RuntimeError: size mismatch, m1: [1 x 3], m2: [2 x 2] at /opt/conda/conda-bld/pytorch_1579022027550/work/aten/src/TH/generic/THTensorMath.cpp:136
