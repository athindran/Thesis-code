# %%
import numpy as np
import scipy
import torch
from matplotlib import pyplot as plt
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable 
import control
from control import matlab
from matplotlib import cm

np.random.seed(0)
dev = "cpu"  
device = torch.device(dev)

# %%
sysA = 1.010
#sysA = 0.99
sysB = 0.125
sysC = 0.1608
sysD = 0

kp = 4.0
ki = 16.0

# %%
x = 0

ref = np.ones((1500,))
ref[200:400] = 2;
ref[400:600] = 0;
ref[600:1000] = -2.1;
ref[1000:1400] = 2.0;
ref[1400:1500] = 3.0;

noise = 0.1*np.random.randn(1500,1)
ysat = np.zeros((1500,))
uvalssat = np.zeros((1500,))
xcont = 0;
u = 0;
for i in range(1500):
   ysat[i] = sysC*x+sysD*u+noise[i];
   xcont = xcont+(ref[i]-ysat[i]);
   u = 0.01*ki*xcont+kp*(ref[i]-ysat[i]);
   if(u>4):
     u=4;
   elif(u<-4):
     u=-4;  
   uvalssat[i] = u;
   x = sysA*x+sysB*u;

ynosat = np.zeros((1500,))
uvalsnosat = np.zeros((1500,))
xcont = 0;
u = 0;
noise = 0.1*np.random.randn(1500,1)

for i in range(1500):
   ynosat[i] = sysC*x+sysD*u+noise[i];
   xcont = xcont+(ref[i]-ynosat[i]);
   u = 0.01*ki*xcont+kp*(ref[i]-ynosat[i]); 
   uvalsnosat[i] = u;
   x = sysA*x+sysB*u;

# %%
plt.figure
plt.plot(0.01*np.arange(1500),ynosat)
plt.plot(0.01*np.arange(1500),ysat)
plt.xlabel("Time (s)")
plt.ylabel("Output")
plt.show()

plt.figure
plt.plot(0.01*np.arange(1500),uvalsnosat)
plt.plot(0.01*np.arange(1500),uvalssat)
plt.xlabel("Time (s)")
plt.ylabel("Input")
plt.show()

# %%
# Use policy gradient to tune kp,ki
ysat = np.zeros((1500,))
uvalssat = np.zeros((1500,))

systA = torch.tensor(sysA,requires_grad=False)
systB = torch.tensor(sysB,requires_grad=False)
systC = torch.tensor(sysC,requires_grad=False)
systD = torch.tensor(sysD,requires_grad=False)

kpt = torch.tensor(kp,requires_grad=True)
kit = torch.tensor(ki,requires_grad=True)
optimizer = torch.optim.Adam((kpt,kit), lr=1)
ref = np.ones((1500,))
ref[200:400] = 2
ref[400:600] = 0
ref[600:1000] = -2.1
ref[1000:1400] = 2.0
ref[1400:1500] = 3.0 
for episodes in range(1000):
  #kpt = F.relu(kpt)
  #kit = F.relu(kit)
  noise = 0.1*torch.randn(1500,1)  
  reft = torch.tensor(ref)  
  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([0.0],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  cost = torch.tensor([0.0],requires_grad=True) 
  for t in range(1500):
    yt = systC*x+systD*u+noise[i];
    xcont = xcont+(reft[t]-yt);
    u = 0.01*kit*xcont+kpt*(reft[t]-yt);
    if(u>4):
      u=4
    elif(u<-4):
      u=-4
    uvalssat[i] = u;
    x = systA*x+systB*u;
    cost = cost+(reft[t]-yt)**2
  if(episodes%100==0):
    print(episodes,cost)  
  optimizer.zero_grad()
  cost.backward()
  optimizer.step()
  #print(kpt,kit)
# Out:
# 0 tensor([1136.4916], grad_fn=<AddBackward0>)
# 100 tensor([411.3775], grad_fn=<AddBackward0>)
# 200 tensor([402.0481], grad_fn=<AddBackward0>)
# 300 tensor([397.6577], grad_fn=<AddBackward0>)
# 400 tensor([391.6048], grad_fn=<AddBackward0>)
# 500 tensor([393.9562], grad_fn=<AddBackward0>)
# 600 tensor([383.2543], grad_fn=<AddBackward0>)
# 700 tensor([384.2054], grad_fn=<AddBackward0>)
# 800 tensor([383.4229], grad_fn=<AddBackward0>)
# 900 tensor([378.2364], grad_fn=<AddBackward0>)

# %%
print(kpt.detach().numpy())
print(kit.detach().numpy())
# Out:
# 54.862823
# -15.970625

# %%
x = 0
kppg = 54.86
kipg = -15.97
ref = np.ones((1500,))
ref[200:400] = 2;
ref[400:600] = 0;
ref[600:1000] = -2.1;
ref[1000:1400] = 2.0;
ref[1400:1500] = 3.0;

ypg = np.zeros((1500,))
uvalspg = np.zeros((1500,))
xcont = 0;
u = 0;
costpg = 0;
noise = 0.1*torch.randn(1500,1)
for i in range(1500):
   ypg[i] = sysC*x+sysD*u+noise[i];
   xcont = xcont+(ref[i]-ypg[i]);
   costpg = costpg+(ref[i]-ypg[i])**2;
   u = 0.01*kipg*xcont+kppg*(ref[i]-ypg[i]);
   if(u>4):
     u=4;
   elif(u<-4):
     u=-4;  
   uvalspg[i] = u;
   x = sysA*x+sysB*u;

x = 0

ref = np.ones((1500,))
ref[200:400] = 2;
ref[400:600] = 0;
ref[600:1000] = -2.1;
ref[1000:1400] = 2.0;
ref[1400:1500] = 3.0;

ysat = np.zeros((1500,))
uvalssat = np.zeros((1500,))
xcont = 0;
u = 0;
costsat = 0;
noise = 0.1*torch.randn(1500,1)

for i in range(1500):
   ysat[i] = sysC*x+sysD*u+noise[i];
   xcont = xcont+(ref[i]-ysat[i]);
   u = 0.01*ki*xcont+kp*(ref[i]-ysat[i]);
   costsat = costsat+(ref[i]-ysat[i])**2;
   if(u>4):
     u=4;
   elif(u<-4):
     u=-4;  
   uvalssat[i] = u;
   x = sysA*x+sysB*u;

print(costsat,costpg)
# Out:
# 1115.75636892062 448.46091855144505

# %%
plt.figure
plt.plot(0.01*np.arange(1500),ynosat)
plt.plot(0.01*np.arange(1500),ysat)
plt.plot(0.01*np.arange(1500),ypg)
plt.xlabel("Time (s)")
plt.ylabel("Output")
plt.legend(["No saturation","Initial design with saturation","DG with saturation"])
plt.show()

plt.figure
plt.plot(0.01*np.arange(1500),uvalsnosat)
plt.plot(0.01*np.arange(1500),uvalssat)
plt.plot(0.01*np.arange(1500),uvalspg)
plt.xlabel("Time (s)")
plt.ylabel("Input")
plt.legend(["No saturation","Initial design with saturation","DG with saturation"])
plt.show()

# %%
x = 0

ref = np.sin(np.arange(0,500)*0.1)+np.sin(np.arange(0,500)*0.01)

ysat = np.zeros((500,))
uvalssat = np.zeros((500,))
xcont = 0;
u = 0;
noise = 0.1*torch.randn(500,1)

for i in range(500):
   ysat[i] = sysC*x+sysD*u+noise[i];
   xcont = xcont+(ref[i]-ysat[i]);
   u = 0.01*ki*xcont+kp*(ref[i]-ysat[i]);
   if(u>3):
     u=3;
   elif(u<-3):
     u=-3;  
   uvalssat[i] = u;
   x = sysA*x+sysB*u;
    
ynosat = np.zeros((500,))
uvalsnosat = np.zeros((500,))
noise = 0.1*torch.randn(500,1)
xcont = 0;
x = 0
u = 0;
for i in range(500):
   ynosat[i] = sysC*x+sysD*u+noise[i];
   xcont = xcont+(ref[i]-ynosat[i]);
   u = 0.01*ki*xcont+kp*(ref[i]-ynosat[i]); 
   uvalsnosat[i] = u;
   x = sysA*x+sysB*u;

plt.figure
plt.plot(0.01*np.arange(500),ynosat)
plt.plot(0.01*np.arange(500),ysat)
plt.xlabel("Time (s)")
plt.ylabel("Output")
plt.legend(["Without saturation","With saturation"])
plt.show()

plt.figure
plt.plot(0.01*np.arange(500),uvalsnosat)
plt.plot(0.01*np.arange(500),uvalssat)
plt.xlabel("Time (s)")
plt.ylabel("Input")
plt.legend(["Without saturation","With saturation"])
plt.show()

# %%
# Use policy gradient to tune kp,ki
ysat = np.zeros((500,))
uvalssat = np.zeros((500,))

systA = torch.tensor(sysA,requires_grad=False)
systB = torch.tensor(sysB,requires_grad=False)
systC = torch.tensor(sysC,requires_grad=False)
systD = torch.tensor(sysD,requires_grad=False)

kpt = torch.tensor(kp,requires_grad=True)
kit = torch.tensor(ki,requires_grad=True)
optimizer = torch.optim.Adam((kpt,kit), lr=1)
ref = np.sin(np.arange(0,500)*0.1)+np.sin(np.arange(0,500)*0.01)

for episodes in range(1000):
  reft = torch.tensor(ref)  
  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([0.0],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  cost = torch.tensor([0.0],requires_grad=True)
  noise = 0.1*torch.randn(1000,1)
  for t in range(500):
    yt = systC*x+systD*u+noise[t];
    xcont = xcont+(reft[t]-yt);
    u = 0.01*kit*xcont+kpt*(reft[t]-yt);
    u = torch.clamp(u,-3.0,3.0)
    uvalssat[i] = u;
    x = systA*x+systB*u;
    cost = cost+(reft[t]-yt)**2
  if(episodes%100==0):
    print(episodes,cost)  
  optimizer.zero_grad()
  cost.backward()
  optimizer.step()
  #print(kpt,kit)
# Out:
# 0 tensor([319.3459], grad_fn=<AddBackward0>)
# 100 tensor([137.8885], grad_fn=<AddBackward0>)
# 200 tensor([138.4304], grad_fn=<AddBackward0>)
# 300 tensor([129.9008], grad_fn=<AddBackward0>)
# 400 tensor([138.2343], grad_fn=<AddBackward0>)
# 500 tensor([136.4814], grad_fn=<AddBackward0>)
# 600 tensor([132.3898], grad_fn=<AddBackward0>)
# 700 tensor([138.7481], grad_fn=<AddBackward0>)
# 800 tensor([148.7477], grad_fn=<AddBackward0>)
# 900 tensor([130.1733], grad_fn=<AddBackward0>)

# %%
print(kpt.detach().numpy())
print(kit.detach().numpy())
# Out:
# 50.743195
# 0.511895

# %%
x = 0
kppg = 50.74
kipg = 0.511
ref = np.sin(np.arange(0,500)*0.1)+np.sin(np.arange(0,500)*0.01)

ypg = np.zeros((500,))
uvalspg = np.zeros((500,))
xcont = 0
u = 0
noise = 0.1*torch.randn(1000,1)
costpg = 0
for i in range(500):
   ypg[i] = sysC*x+sysD*u+noise[i];
   xcont = xcont+(ref[i]-ypg[i]);
   costpg = costpg+(ref[i]-ypg[i])**2;
   u = 0.01*kipg*xcont+kppg*(ref[i]-ypg[i]);
   if(u>3):
     u=3;
   elif(u<-3):
     u=-3;  
   uvalspg[i] = u;
   x = sysA*x+sysB*u;

x = 0
ysat = np.zeros((500,))
uvalssat = np.zeros((500,))
xcont = 0;
u = 0;
costsat = 0;
noise = 0.1*torch.randn(1000,1)

for i in range(500):
   ysat[i] = sysC*x+sysD*u+noise[i];
   xcont = xcont+(ref[i]-ysat[i]);
   u = 0.01*ki*xcont+kp*(ref[i]-ysat[i]);
   costsat = costsat+(ref[i]-ysat[i])**2;
   if(u>3):
     u=3
   elif(u<-3):
     u=-3
   uvalssat[i] = u;
   x = sysA*x+sysB*u;
    
x = 0
ynosat = np.zeros((500,))
uvalsnosat = np.zeros((500,))
xcont = 0
u = 0
costnosat = 0
noise = 0.1*torch.randn(1000,1)

for i in range(500):
   ynosat[i] = sysC*x+sysD*u+noise[i]
   xcont = xcont+(ref[i]-ynosat[i])
   u = 0.01*ki*xcont+kp*(ref[i]-ynosat[i])
   costnosat = costnosat+(ref[i]-ynosat[i])**2
   uvalsnosat[i] = u
   x = sysA*x+sysB*u
    
print(costnosat,costsat,costpg)
# Out:
# 275.9593252097808 314.23556863718875 130.14042592955954

# %%
print(kppg,kipg)
plt.figure
plt.plot(0.01*np.arange(500),ynosat)
plt.plot(0.01*np.arange(500),ysat)
plt.plot(0.01*np.arange(500),ypg)
plt.plot(0.01*np.arange(500),ref)
plt.xlabel("Time (s)")
plt.ylabel("Output")
plt.legend(["No saturation","Initial design with saturation","PG with saturation","Reference"])
plt.show()

plt.figure
plt.plot(0.01*np.arange(500),uvalsnosat)
plt.plot(0.01*np.arange(500),uvalssat)
plt.plot(0.01*np.arange(500),uvalspg)
plt.xlabel("Time (s)")
plt.ylabel("Input")
plt.legend(["No saturation","Initial design with saturation","PG with saturation"])
plt.show()
# Out:
# 50.74 0.511

# %%
# Create a dictionary of inputs

refs = np.zeros((20,1000))

#refs[0,0:200] = 1
#refs[0,200:400] = 3
#refs[0,400:600] = 1
#refs[0,600:800] = -1

#refs[1,0:200] = -1
#refs[1,200:600] = -3
#refs[1,400:600] = -1
#refs[1,600:800] = 1

refs[0,0:1000] = 2*(0.1*np.sin(0.1*np.arange(0,1000))+0.3*np.sin(0.01*np.arange(0,1000)))
refs[0,0:1000] = 2*(0.4*np.sin(0.1*np.arange(0,1000))+0.5*np.sin(0.01*np.arange(0,1000)))
refs[2,0:1000] = 2*(0.4*np.sin(0.1*np.arange(0,1000))+0.7*np.sin(0.01*np.arange(0,1000)))
refs[3,0:1000] = 2*(0.8*np.sin(0.1*np.arange(0,1000))+0.4*np.sin(0.01*np.arange(0,1000)))
refs[4,0:1000] = 0.6*refs[0,:]+0.4*refs[2,:]

refs[5,0:200] = 2
refs[5,200:400] = 4
refs[5,400:600] = 3
refs[5,600:800] = 1

refs[6,0:200] = 2
refs[6,200:600] = -2
refs[6,400:600] = -3
refs[6,600:800] = 1

refs[7,0:200] = 1
refs[7,200:400] = 3
refs[7,400:600] = 1
refs[7,600:800] = -1

refs[8,0:200] = -1
refs[8,200:600] = -3
refs[8,400:600] = -1
refs[8,600:800] = 1

refs[9,:] = 0.5*refs[5,:]+0.5*refs[8,:]

refs[10,0:200] = 1
refs[10,200:400] = -3
refs[10,400:600] = 2
refs[10,600:800] = 0

refs[11,0:200] = 2
refs[11,200:600] = 0
refs[11,400:600] = -1
refs[11,600:800] = 1

refs[12,0:1000] = 0.9*np.sin(0.1*np.arange(0,1000))+0.1*np.sin(0.01*np.arange(0,1000))
refs[13,0:1000] = 0.2*np.sin(0.1*np.arange(0,1000))+0.1*np.sin(0.01*np.arange(0,1000))
refs[14,0:1000] = refs[10,:]+refs[12,:]

refs[15,0:200] = -1
refs[15,200:400] = -3
refs[15,400:600] = -2
refs[15,600:800] = 0

refs[16,0:200] = -2
refs[16,200:600] = 0
refs[16,400:600] = 1
refs[16,600:800] = -1

refs[17,0:1000] = 0.4*np.sin(0.1*np.arange(0,1000))+0.6*np.sin(0.01*np.arange(0,1000))
refs[18,0:1000] = 0.3*np.sin(0.1*np.arange(0,1000))+0.7*np.sin(0.01*np.arange(0,1000))
refs[19,0:1000] = refs[17,:]+refs[15,:]

# %%
nepisodes = 1000
systA = torch.tensor(sysA,requires_grad=False)
systB = torch.tensor(sysB,requires_grad=False)
systC = torch.tensor(sysC,requires_grad=False)
systD = torch.tensor(sysD,requires_grad=False)

kpt = torch.tensor(kp,requires_grad=True)
kit = torch.tensor(ki,requires_grad=True)
optimizer = torch.optim.Adam((kpt,kit), lr=1)

for episode in range(nepisodes):
  ref = refs[episode%5,:]
  reft = torch.tensor(ref)  
  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([0.0],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  cost = torch.tensor([0.0],requires_grad=True)
  noise = 0.1*torch.randn(1000,1)

  for t in range(1000):
    yt = systC*x+systD*u+noise[t];
    xcont = xcont+(reft[t]-yt);
    u = 0.01*kit*xcont+kpt*(reft[t]-yt);
    u = torch.clamp(u,-3.0,3.0)
    uvalssat[i] = u;
    x = systA*x+systB*u;
    cost = cost+(reft[t]-yt)**2
  if(episode%100==0):
    print(episode,cost)  
  optimizer.zero_grad()
  cost.backward()
  optimizer.step()
  #print(kppg,kipg)
# Out:
# 0 tensor([391.0618], grad_fn=<AddBackward0>)
# 100 tensor([123.9889], grad_fn=<AddBackward0>)
# 200 tensor([121.2354], grad_fn=<AddBackward0>)
# 300 tensor([122.5075], grad_fn=<AddBackward0>)
# 400 tensor([120.7541], grad_fn=<AddBackward0>)
# 500 tensor([120.0398], grad_fn=<AddBackward0>)
# 600 tensor([105.5273], grad_fn=<AddBackward0>)
# 700 tensor([116.7644], grad_fn=<AddBackward0>)
# 800 tensor([115.6604], grad_fn=<AddBackward0>)
# 900 tensor([129.0343], grad_fn=<AddBackward0>)

# %%
print(kpt.detach().numpy())
print(kit.detach().numpy())
# Out:
# 52.262165
# -1.9148664

# %%
x = 0
kppg = 52.26
kipg = -1.91

ref = 0.5*np.sin(np.arange(0,1000)*0.2)+1.8*np.sin(np.arange(0,1000)*0.02)

ysat = np.zeros((1000,))
uvalssat = np.zeros((1000,))
xcont = 0;
u = 0;
costsat = 0
for i in range(1000):
   ysat[i] = sysC*x+sysD*u;
   xcont = xcont+(ref[i]-ysat[i]);
   costsat += (ref[i]-ysat[i])**2 
   u = 0.01*ki*xcont+kp*(ref[i]-ysat[i]);
   if(u>3):
     u=3;
   elif(u<-3):
     u=-3;  
   uvalssat[i] = u;
   x = sysA*x+sysB*u;
    
ynosat = np.zeros((1000,))
uvalsnosat = np.zeros((1000,))
xcont = 0;
x = 0
u = 0;
costnosat = 0
for i in range(1000):
   ynosat[i] = sysC*x+sysD*u;
   xcont = xcont+(ref[i]-ynosat[i]);
   costnosat += (ref[i]-ynosat[i])**2 
   u = 0.01*ki*xcont+kp*(ref[i]-ynosat[i]); 
   uvalsnosat[i] = u;
   x = sysA*x+sysB*u;

ypg = np.zeros((1000,))
uvalspg = np.zeros((1000,))
xcont = 0;
x = 0
u = 0;
costpg = 0
for i in range(1000):
   ypg[i] = sysC*x+sysD*u;
   xcont = xcont+(ref[i]-ypg[i]);
   u = 0.01*kipg*xcont+kppg*(ref[i]-ypg[i]);
   if(u>3):
     u=3
   elif(u<-3):
     u=-3
   costpg += (ref[i]-ypg[i])**2    
   uvalspg[i] = u;
   x = sysA*x+sysB*u;

print(costsat,costnosat,costpg)
plt.figure
plt.plot(0.01*np.arange(1000),ynosat)
plt.plot(0.01*np.arange(1000),ysat)
plt.plot(0.01*np.arange(1000),ypg)
plt.plot(0.01*np.arange(1000),ref)
plt.xlabel("Time (s)")
plt.ylabel("Output")
plt.legend(["Without saturation","With saturation","D gradient","Reference"])
plt.show()

plt.figure
plt.plot(0.01*np.arange(1000),uvalsnosat)
plt.plot(0.01*np.arange(1000),uvalssat)
plt.plot(0.01*np.arange(1000),uvalspg)
plt.xlabel("Time (s)")
plt.ylabel("Input")
plt.legend(["Without saturation","With saturation","D gradient"])
plt.show()
# Out:
# 192.2571667989136 172.0527850506516 129.65084020893073

# %%
# Use policy gradient to tune kp,ki
nepisodes = 1000
systA = torch.tensor(sysA,requires_grad=False)
systB = torch.tensor(sysB,requires_grad=False)
systC = torch.tensor(sysC,requires_grad=False)
systD = torch.tensor(sysD,requires_grad=False)

kpt = torch.tensor(kp,requires_grad=True)
kit = torch.tensor(ki,requires_grad=True)
optimizer = torch.optim.Adam((kpt,kit), lr=1)

for episode in range(nepisodes):
  #ref = refs[5+episode%5,:]
  ref = refs[episode%10,:]
  reft = torch.tensor(ref)  
  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([0.0],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  cost = torch.tensor([0.0],requires_grad=True) 
  noise = 0.1*torch.randn(1000,1)

  for t in range(1000):
    yt = systC*x+systD*u+noise[t];
    xcont = xcont+(reft[t]-yt);
    u = 0.01*kit*xcont+kpt*(reft[t]-yt);
    u = torch.clamp(u,-3.0,3.0)
    x = systA*x+systB*u;
    cost = cost+torch.abs((reft[t]-yt))
  if(episode%100==0):
    print(episode,cost)  
    print(kpt,kit)
  optimizer.zero_grad()
  cost.backward()
  optimizer.step()
  #print(kppg,kipg)
# Out:
# 0 tensor([561.8070], grad_fn=<AddBackward0>)
# tensor(4., requires_grad=True) tensor(16., requires_grad=True)
# 100 tensor([288.4174], grad_fn=<AddBackward0>)
# tensor(25.4871, requires_grad=True) tensor(-1.2115, requires_grad=True)
# 200 tensor([301.4008], grad_fn=<AddBackward0>)
# tensor(30.0295, requires_grad=True) tensor(-1.2663, requires_grad=True)
# 300 tensor([286.3824], grad_fn=<AddBackward0>)
# tensor(33.8956, requires_grad=True) tensor(-1.3665, requires_grad=True)
# 400 tensor([285.2194], grad_fn=<AddBackward0>)
# tensor(36.6201, requires_grad=True) tensor(-1.9722, requires_grad=True)
# 500 tensor([283.6826], grad_fn=<AddBackward0>)
# tensor(38.8411, requires_grad=True) tensor(-1.9132, requires_grad=True)
# 600 tensor([276.7335], grad_fn=<AddBackward0>)
# tensor(40.3587, requires_grad=True) tensor(-2.0869, requires_grad=True)
# 700 tensor([281.0133], grad_fn=<AddBackward0>)
# tensor(41.6754, requires_grad=True) tensor(-1.5807, requires_grad=True)
# 800 tensor([283.6940], grad_fn=<AddBackward0>)
# tensor(42.9729, requires_grad=True) tensor(-2.3455, requires_grad=True)
# 900 tensor([292.5479], grad_fn=<AddBackward0>)
# tensor(44.2974, requires_grad=True) tensor(-1.9854, requires_grad=True)

# %%
print(kpt.detach().numpy())
print(kit.detach().numpy())
# Out:
# 45.673622
# -3.0147614

# %%
x = 0
kppg = 76.82
kipg = 12.96
print(kppg,kipg)
ref = np.zeros((1000,))
ref[0:250] = -2.5
ref[250:400] = 1.5
ref[400:700] = 4.5
ref[700:900] = 1.5

ysat = np.zeros((1000,))
uvalssat = np.zeros((1000,))
xcont = 0;
u = 0;
costsat = 0
noise = 0.1*torch.randn(1000,1)

for i in range(1000):
   ysat[i] = sysC*x+sysD*u+noise[i];
   xcont = xcont+(ref[i]-ysat[i]);
   costsat += np.abs((ref[i]-ysat[i]))+np.abs(ysat[i]-ysat[i-1])
   u = 0.01*ki*xcont+kp*(ref[i]-ysat[i]);
   if(u>3):
     u=3;
   elif(u<-3):
     u=-3;  
   uvalssat[i] = u;
   x = sysA*x+sysB*u;
    
ynosat = np.zeros((1000,))
uvalsnosat = np.zeros((1000,))
xcont = 0;
x = 0
u = 0;
costnosat = 0
noise = 0.1*torch.randn(1000,1)

for i in range(1000):
   ynosat[i] = sysC*x+sysD*u+noise[i];
   xcont = xcont+(ref[i]-ynosat[i]);
   costnosat += np.abs((ref[i]-ynosat[i]))+np.abs(ynosat[i]-ynosat[i-1])
   u = 0.01*ki*xcont+kp*(ref[i]-ynosat[i]); 
   uvalsnosat[i] = u;
   x = sysA*x+sysB*u;

ypg = np.zeros((1000,))
uvalspg = np.zeros((1000,))
xcont = 0;
x = 0
u = 0;
costpg = 0
noise = 0.1*torch.randn(1000,1)

for i in range(1000):
   ypg[i] = sysC*x+sysD*u+noise[i];
   xcont = xcont+(ref[i]-ypg[i]);
   u = 0.01*kipg*xcont+kppg*(ref[i]-ypg[i]);
   if(u>3):
     u=3
   elif(u<-3):
     u=-3
   costpg += np.abs((ref[i]-ypg[i]))+np.abs(ypg[i]-ypg[i-1])    
   uvalspg[i] = u;
   x = sysA*x+sysB*u;

print(costsat,costnosat,costpg)
plt.figure
plt.plot(0.01*np.arange(1000),ynosat)
plt.plot(0.01*np.arange(1000),ysat)
plt.plot(0.01*np.arange(1000),ypg)
plt.xlabel("Time (s)")
plt.ylabel("Output")
plt.legend(["Without saturation","With saturation","Policy gradient"])
plt.show()

plt.figure
plt.plot(0.01*np.arange(1000),uvalsnosat)
plt.plot(0.01*np.arange(1000),uvalssat)
plt.plot(0.01*np.arange(1000),uvalspg)
plt.xlabel("Time (s)")
plt.ylabel("Input")
plt.legend(["Without saturation","With saturation","Policy gradient"])
plt.show()
# Out:
# 76.82 12.96
# 1216.2208476474043 444.9932265644893 879.0209619663656
