# %%
import numpy as np
import scipy
import torch
from matplotlib import pyplot as plt
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable 
import control
from control import matlab
from matplotlib import cm

np.random.seed(0)
dev = "cpu"  
device = torch.device(dev)

# %%
sysA = np.array([1.01])
#sysA = 0.99
sysB = np.array([[0.125]])
sysC = np.array([0.1608])
sysD = 0
#print(np.linalg.eig(sysA))
kp = 4.0
ki = 10.0
kd = 0.0
Tf = 0.01

# %%
T = 1500
refs = np.zeros((30,T))

randval = 0

for i in range(30):
  refs[i,0:300] = 0
  randval = 8*np.random.rand()-4.0
  if randval>0 and randval<2:
    randval = 2
  if randval<0 and randval>-2:
    randval = -2
  refs[i,300:] = randval

# %%
ref = refs[8,:]
ysat = np.zeros((T,))
uvalssat = np.zeros((T,))
xcont = 0
u = 0
D = 0
ad = Tf/(Tf+0.01)
bd = kd/(Tf+0.01)
noise = 0.05*np.random.randn(T,1)

x0 = np.zeros((1,1))
x = x0
for i in range(T):
   ysat[i] = np.dot(sysC,x)+np.dot(sysD,u)+noise[i]
   xcont = xcont+(ref[i]-ysat[i])
   uprev = u 
   if(i>0):
     D = ad*D-bd*(ysat[i]-ysat[i-1])  
     u = 0.01*ki*xcont+kp*(ref[i]-ysat[i])+D
   if(u>3.3):
     u=3.3
   elif(u<-3.3):
     u=-3.3
   uvalssat[i] = u;
   if(i>2):
     x = np.dot(sysA,x)+np.dot(sysB,uvalssat[i-2]);
   else:
     x = np.dot(sysA,x)
ynosat = np.zeros((T,))
uvalsnosat = np.zeros((T,))
xcont = 0;
u = 0;
x = x0
D = 0

for i in range(T):
   ynosat[i] = np.dot(sysC,x)+np.dot(sysD,u)+noise[i]
   xcont = xcont+(ref[i]-ynosat[i])
   if(i>0):
     D = ad*D-bd*(ynosat[i]-ynosat[i-1])  
     u = 0.01*ki*xcont+kp*(ref[i]-ynosat[i])+D 
   uvalsnosat[i] = u;
   if(i>2):
     x = np.dot(sysA,x)+np.dot(sysB,uvalsnosat[i-2]);
   else:
     x = np.dot(sysA,x)

# %%
plt.figure
plt.plot(0.01*np.arange(T),ynosat)
plt.plot(0.01*np.arange(T),ysat)
plt.plot(0.01*np.arange(T),ref)
plt.xlabel("Time (s)")
plt.ylabel("Output")
plt.legend(["No saturation","Saturation","Reference"])
plt.show()

plt.figure
plt.plot(0.01*np.arange(T),uvalsnosat)
plt.plot(0.01*np.arange(T),uvalssat)
plt.xlabel("Time (s)")
plt.ylabel("Input")
plt.legend(["No saturation","Saturation"])
plt.show()

# %%
class neuralPID(torch.nn.Module):
   def __init__(self):
    super(neuralPID, self).__init__()
    torch.manual_seed(2)
    self.kplayer1 = torch.nn.Linear(2,2)
    self.kplayer2 = torch.nn.Linear(2,1)
    self.kilayer1 = torch.nn.Linear(2,2)
    self.kilayer2 = torch.nn.Linear(2,1)
    self.backlayer1 = torch.nn.Linear(2,2)
    self.backlayer2 = torch.nn.Linear(2,1)
  
   def forward(self,x):
    sigmoid = torch.nn.Tanh()
    kp = self.kplayer2(sigmoid(self.kplayer1(x)))
    ki = self.kilayer2(sigmoid(self.kilayer1(x)))
    back = self.backlayer2(sigmoid(self.backlayer1(x)))
    #kd = torch.clamp(kd,0,400)
    #kp = torch.clamp(kp,0,400)
    #ki = torch.clamp(ki,0,400)
    return kp,ki,back

# %%
Tft = torch.tensor(Tf,requires_grad=True)
kpit = torch.tensor(kp,requires_grad=False)
kiit = torch.tensor(ki,requires_grad=False)
#kdit = torch.tensor(kd,requires_grad=False)
backit = torch.tensor(0.1,requires_grad=False)

systA = torch.tensor(sysA,requires_grad=False)
systB = torch.tensor(sysB,requires_grad=False)
systC = torch.tensor(sysC,requires_grad=False)
systD = torch.tensor(sysD,requires_grad=False)

# %%
costinit = np.zeros((30,))

yinit = np.zeros((30,T))
uinit = np.zeros((30,T))
Tft = torch.tensor(Tf,requires_grad=True)
kpit = torch.tensor(kp,requires_grad=False)
kiit = torch.tensor(ki,requires_grad=False)
kdit = torch.tensor(kd,requires_grad=False)

systA = torch.tensor(sysA,requires_grad=False)
systB = torch.tensor(sysB,requires_grad=False)
systC = torch.tensor([sysC],requires_grad=False)
systD = torch.tensor(sysD,requires_grad=False)

for iters in range(0,30):
  ref = refs[iters,:]
  reft = torch.tensor(ref)
  noise = 0.05*torch.randn(T,1)

  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([0.0],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  D  = torch.tensor([0.0],requires_grad=False)
  #torch.clamp(Tft,0.1,0.1)
  ad = torch.div(Tft,(Tft+0.01))
  
  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t];
    yinit[iters,t] = yt.clone().detach().numpy()
    #print(yt)
    #error = torch.tensor(reft[t]-yt,requires_grad=False)
    err = ref[t]-yt
    xcont = xcont+err
    if(t>0):
       #print(t,kpt,kit,kdt)
       #break;
       bd = torch.div(kdit,(Tft+0.01))
       D = ad*D-bd*(yt-yold);  
       u = (0.01*kiit*xcont+kpit*(ref[t]-yt)+D)
       u = torch.clamp(u,-3.3,3.3)
    uinit[iters,t] = u.clone()
    if(t>2):
      x = torch.matmul(systA.float(),x)+systB.float()*uinit[iters,t-2];
    else:
      x = torch.matmul(systA.float(),x)+systB.float()*uinit[iters,0]
    cost = cost+(reft[t]-yt)**2
  costinit[iters] = cost.detach().numpy()

# %%
print(costinit)
plt.figure()
plt.plot(refs[8,:])
plt.plot(yinit[8,:])
plt.plot(uinit[8,:])
# Out:
# [  81.86898804   80.21835327   80.57714844   81.75465393   81.70522308
#    78.52483368   77.4082489   315.0151062  1137.44067383   78.09312439
#   119.35923004   78.61172485   80.94367981  509.80490112  525.07128906
#   412.33334351 1869.26489258  178.25340271  105.75371552  252.7787323
#  2061.27636719  133.13223267   81.85321808  108.31612396  278.07473755
#    80.1631546   225.04899597  695.90911865   77.83867645   76.60951233]

# %%
# Initialize network
Tft = torch.tensor(Tf,requires_grad=True)
kpit = torch.tensor(kp,requires_grad=False)
kiit = torch.tensor(ki,requires_grad=False)
#kdit = torch.tensor(kd,requires_grad=False)
backit = torch.tensor(0.1,requires_grad=False)

kpt = torch.tensor(kp,requires_grad=True)
kit = torch.tensor(ki,requires_grad=True)
#kdit = torch.tensor(kd,requires_grad=False)
backt = torch.tensor(0.1,requires_grad=True)

systA = torch.tensor(sysA,requires_grad=False)
systB = torch.tensor(sysB,requires_grad=False)
systC = torch.tensor(sysC,requires_grad=False)
systD = torch.tensor(sysD,requires_grad=False)

PIDparams = neuralPID()
#optimizer = torch.optim.Adam((PIDparams.parameters()), lr=0.1)
#for iters in range(1000):
#   kpt,kit,kdt = PIDparams(torch.randn(3,))
#   print(kpt,kit,kdt)
#   loss = (kpt-kpit)**2+(kit-kiit)**2+(kdt-kdit)**2
#   optimizer.zero_grad()
#   loss.backward()
#   optimizer.step()    
   #print(iters,loss)

# %%
ysat = np.zeros((T,))
uvalssat = np.zeros((T,))

optimizer = torch.optim.Adam((PIDparams.parameters()), lr=0.1, weight_decay=0.1)
smooth = 0.9
for episodes in range(1001):
  #cepisode = np.random.randint(20)  
  cepisode = episodes%20
  ref = refs[cepisode,:]
  reft = torch.tensor(ref)  
  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0]],requires_grad=True)  
  u2 = torch.tensor([0.0],requires_grad=True)
  u1 = torch.tensor([0.0],requires_grad=True)
  u = torch.tensor([0.0],requires_grad=True)
  ucmd = torch.tensor([0.0],requires_grad=True)
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  #D  = torch.tensor([0.0],requires_grad=False)
  #ad = torch.div(Tft,(Tft+0.01))
  noise = 0.01*torch.randn(T,1)
  kpt = kpt.clone().detach()
  kit = kit.clone().detach()
  backt = backt.clone().detach()
  #uvals = torch.zeros(T,1,requires_grad=True)  
  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t]
    saterr = u-ucmd
    err = reft[t]-yt
    ninput = torch.cat((err,saterr),0)
    kpdt,kidt,backdt = PIDparams(ninput)
    kpt = smooth*kpt+(1-smooth)*(kpit+kpdt)
    kit = smooth*kit+(1-smooth)*(kiit+kidt)
    backt = smooth*backt+(1-smooth)*(backit+backdt)
    xcont = xcont+kit*err+backt*saterr.detach()
    if(t>0):
      #bd = torch.div(kdt,(Tft+0.01))
      #D = ad*D-bd*(yt-yold);  
      ucmd = (0.01*xcont+kpt*(reft[t]-yt))
      u = torch.clamp(ucmd,-3.3,3.3)
        
    x = torch.matmul(systA.float(),x)+systB.float()*u2
    u2 = u1
    u1 = u
    cost = cost+(reft[t]-yt)**2  
  if(episodes%120<20):
    print(episodes,cost)
  optimizer.zero_grad()
  cost.backward()
  optimizer.step()
# Out:
# 0 tensor([72.2979], grad_fn=<AddBackward0>)
# 1 tensor([68.4153], grad_fn=<AddBackward0>)
# 2 tensor([64.4644], grad_fn=<AddBackward0>)
# 3 tensor([60.1787], grad_fn=<AddBackward0>)
# 4 tensor([69.7175], grad_fn=<AddBackward0>)
# 5 tensor([55.4860], grad_fn=<AddBackward0>)
# 6 tensor([64.7320], grad_fn=<AddBackward0>)
# 7 tensor([170.9634], grad_fn=<AddBackward0>)
# 8 tensor([264.7753], grad_fn=<AddBackward0>)
# 9 tensor([56.9374], grad_fn=<AddBackward0>)
# 10 tensor([73.5210], grad_fn=<AddBackward0>)
# 11 tensor([48.3697], grad_fn=<AddBackward0>)
# 12 tensor([47.6867], grad_fn=<AddBackward0>)
# 13 tensor([213.2156], grad_fn=<AddBackward0>)
# 14 tensor([216.4156], grad_fn=<AddBackward0>)
# 15 tensor([192.4575], grad_fn=<AddBackward0>)
# 16 tensor([291.7148], grad_fn=<AddBackward0>)
# 17 tensor([108.4345], grad_fn=<AddBackward0>)
# 18 tensor([64.7631], grad_fn=<AddBackward0>)
# 19 tensor([141.1940], grad_fn=<AddBackward0>)
# 120 tensor([48.1006], grad_fn=<AddBackward0>)
# 121 tensor([48.2454], grad_fn=<AddBackward0>)
# 122 tensor([47.8861], grad_fn=<AddBackward0>)
# 123 tensor([48.1653], grad_fn=<AddBackward0>)
# 124 tensor([48.4873], grad_fn=<AddBackward0>)
# 125 tensor([48.5673], grad_fn=<AddBackward0>)
# 126 tensor([49.6851], grad_fn=<AddBackward0>)
# 127 tensor([166.7714], grad_fn=<AddBackward0>)
# 128 tensor([273.8854], grad_fn=<AddBackward0>)
# 129 tensor([50.8975], grad_fn=<AddBackward0>)
# 130 tensor([74.8982], grad_fn=<AddBackward0>)
# 131 tensor([48.3632], grad_fn=<AddBackward0>)
# 132 tensor([48.7726], grad_fn=<AddBackward0>)
# 133 tensor([214.1256], grad_fn=<AddBackward0>)
# 134 tensor([237.1378], grad_fn=<AddBackward0>)
# 135 tensor([212.2043], grad_fn=<AddBackward0>)
# 136 tensor([320.7818], grad_fn=<AddBackward0>)
# 137 tensor([105.6024], grad_fn=<AddBackward0>)
# 138 tensor([64.7012], grad_fn=<AddBackward0>)
# 139 tensor([145.4675], grad_fn=<AddBackward0>)
# 240 tensor([47.8517], grad_fn=<AddBackward0>)
# 241 tensor([47.9064], grad_fn=<AddBackward0>)
# 242 tensor([48.0112], grad_fn=<AddBackward0>)
# 243 tensor([48.3828], grad_fn=<AddBackward0>)
# 244 tensor([48.1848], grad_fn=<AddBackward0>)
# 245 tensor([48.1217], grad_fn=<AddBackward0>)
# 246 tensor([48.0664], grad_fn=<AddBackward0>)
# 247 tensor([164.9081], grad_fn=<AddBackward0>)
# 248 tensor([263.6711], grad_fn=<AddBackward0>)
# 249 tensor([48.0310], grad_fn=<AddBackward0>)
# 250 tensor([73.3880], grad_fn=<AddBackward0>)
# 251 tensor([48.1494], grad_fn=<AddBackward0>)
# 252 tensor([48.9005], grad_fn=<AddBackward0>)
# 253 tensor([207.5166], grad_fn=<AddBackward0>)
# 254 tensor([211.4140], grad_fn=<AddBackward0>)
# 255 tensor([191.7638], grad_fn=<AddBackward0>)
# 256 tensor([288.9545], grad_fn=<AddBackward0>)
# 257 tensor([104.7101], grad_fn=<AddBackward0>)
# 258 tensor([64.4357], grad_fn=<AddBackward0>)
# 259 tensor([140.3544], grad_fn=<AddBackward0>)
# 360 tensor([48.5446], grad_fn=<AddBackward0>)
# 361 tensor([48.4165], grad_fn=<AddBackward0>)
# 362 tensor([48.9665], grad_fn=<AddBackward0>)
# 363 tensor([47.8943], grad_fn=<AddBackward0>)
# 364 tensor([47.4304], grad_fn=<AddBackward0>)
# 365 tensor([48.6329], grad_fn=<AddBackward0>)
# 366 tensor([47.7947], grad_fn=<AddBackward0>)
# 367 tensor([168.5616], grad_fn=<AddBackward0>)
# 368 tensor([270.9702], grad_fn=<AddBackward0>)
# 369 tensor([48.3342], grad_fn=<AddBackward0>)
# 370 tensor([73.5795], grad_fn=<AddBackward0>)
# 371 tensor([47.9520], grad_fn=<AddBackward0>)
# 372 tensor([48.6675], grad_fn=<AddBackward0>)
# 373 tensor([208.0527], grad_fn=<AddBackward0>)
# 374 tensor([212.4512], grad_fn=<AddBackward0>)
# 375 tensor([190.3083], grad_fn=<AddBackward0>)
# 376 tensor([290.7932], grad_fn=<AddBackward0>)
# 377 tensor([104.9680], grad_fn=<AddBackward0>)
# 378 tensor([65.1297], grad_fn=<AddBackward0>)
# 379 tensor([140.5762], grad_fn=<AddBackward0>)
# 480 tensor([48.2136], grad_fn=<AddBackward0>)
# 481 tensor([48.1753], grad_fn=<AddBackward0>)
# 482 tensor([48.1361], grad_fn=<AddBackward0>)
# 483 tensor([47.7215], grad_fn=<AddBackward0>)
# 484 tensor([48.6931], grad_fn=<AddBackward0>)
# 485 tensor([47.8675], grad_fn=<AddBackward0>)
# 486 tensor([48.8846], grad_fn=<AddBackward0>)
# 487 tensor([165.7697], grad_fn=<AddBackward0>)
# 488 tensor([263.7803], grad_fn=<AddBackward0>)
# 489 tensor([48.8208], grad_fn=<AddBackward0>)
# 490 tensor([73.1344], grad_fn=<AddBackward0>)
# 491 tensor([47.9346], grad_fn=<AddBackward0>)
# 492 tensor([48.3550], grad_fn=<AddBackward0>)
# 493 tensor([208.1262], grad_fn=<AddBackward0>)
# 494 tensor([215.6318], grad_fn=<AddBackward0>)
# 495 tensor([192.7664], grad_fn=<AddBackward0>)
# 496 tensor([292.8708], grad_fn=<AddBackward0>)
# 497 tensor([104.9343], grad_fn=<AddBackward0>)
# 498 tensor([65.8399], grad_fn=<AddBackward0>)
# 499 tensor([142.9347], grad_fn=<AddBackward0>)
# 600 tensor([48.0838], grad_fn=<AddBackward0>)
# 601 tensor([47.7521], grad_fn=<AddBackward0>)
# 602 tensor([47.4916], grad_fn=<AddBackward0>)
# 603 tensor([47.8825], grad_fn=<AddBackward0>)
# 604 tensor([47.6884], grad_fn=<AddBackward0>)
# 605 tensor([47.7900], grad_fn=<AddBackward0>)
# 606 tensor([48.0072], grad_fn=<AddBackward0>)
# 607 tensor([166.0175], grad_fn=<AddBackward0>)
# 608 tensor([263.2193], grad_fn=<AddBackward0>)
# 609 tensor([47.9567], grad_fn=<AddBackward0>)
# 610 tensor([73.4442], grad_fn=<AddBackward0>)
# 611 tensor([48.2415], grad_fn=<AddBackward0>)
# 612 tensor([48.6469], grad_fn=<AddBackward0>)
# 613 tensor([207.5021], grad_fn=<AddBackward0>)
# 614 tensor([212.1581], grad_fn=<AddBackward0>)
# 615 tensor([190.0653], grad_fn=<AddBackward0>)
# 616 tensor([290.5310], grad_fn=<AddBackward0>)
# 617 tensor([106.8841], grad_fn=<AddBackward0>)
# 618 tensor([66.5391], grad_fn=<AddBackward0>)
# 619 tensor([144.6703], grad_fn=<AddBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-3ecd34e13bb3> in <module>
#      32     kpdt,kidt,backdt = PIDparams(ninput)
#      33     kpt = smooth*kpt+(1-smooth)*(kpit+kpdt)
# ---> 34     kit = smooth*kit+(1-smooth)*(kiit+kidt)
#      35     backt = smooth*backt+(1-smooth)*(backit+backdt)
#      36     xcont = xcont+kit*err+backt*saterr.detach()
#
# KeyboardInterrupt:

# %%
#plt.figure()
#plt.plot(ref)
torch.save(PIDparams.state_dict(), "foddgradientparams")

# %%
kpst = torch.tensor(kp,requires_grad=True)
kist = torch.tensor(ki,requires_grad=True)
#kdst = torch.tensor(kd,requires_grad=True)
backst = torch.tensor(0.1,requires_grad=True)
#Tft = torch.tensor(Tf,requires_grad=True)
optimizer = torch.optim.Adam((kpst,kist,backst), lr=0.1, weight_decay=0.1)

stlossvals = []
closs = 0
kptrain = []
kitrain = []
kdtrain = []
backtrain = []
for episodes in range(501):
  cepisode = episodes%20
  ref = refs[cepisode,:]
  reft = torch.tensor(ref)  
  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0]],requires_grad=True)  
  ucmd = torch.tensor([0.0],requires_grad=True)
  u2 = torch.tensor([0.0],requires_grad=True)
  u1 = torch.tensor([0.0],requires_grad=True)    
  u = torch.tensor([0.0],requires_grad=True)  
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  D  = torch.tensor([0.0],requires_grad=False)
  #torch.clamp(Tft,0.1,0.1)
  #ad = torch.div(Tft,(Tft+0.01))
  #bd = torch.div(kdst,(Tft+0.01))
  noise = 0.01*torch.randn(T,1)
  
  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t];
    #error = torch.tensor(reft[t]-yt,requires_grad=False)
    saterr = u-ucmd
    xcont = xcont+kist*(reft[t]-yt)+backst*saterr
    if(t>0):
       #deriv = torch.tensor(yt-yold,requires_grad=False) 
       #D = ad*D-bd*(yt-yold);  
       ucmd = (0.01*xcont+kpst*(reft[t]-yt))
    u = torch.clamp(ucmd,-3.3,3.3)
    uvalssat[i] = u;
    x = torch.matmul(systA.float(),x)+systB.float()*u2
    u2 = u1
    u1 = u
    cost = cost+torch.clamp((reft[t]-yt)**2,0,50)
  closs = closs+cost  
  if(episodes%20==19):    
    stlossvals.append(closs.clone().detach().numpy()/20)
    closs = 0
  kptrain.append(kpst.clone().detach().numpy())
  kitrain.append(kist.clone().detach().numpy())
  #kdtrain.append(kdst.clone().detach().numpy())
  backtrain.append(backst.clone().detach().numpy())  
  if(episodes%120<20):
    #print(kpt,kdt,kit,Tft)
    print(episodes,cost,backst) 
  optimizer.zero_grad()
  cost.backward()
  optimizer.step()

print(kpst,kist,backst)
# Out:
# 0 tensor([74.4365], grad_fn=<AddBackward0>) tensor(0.1000, requires_grad=True)
# 1 tensor([72.1574], grad_fn=<AddBackward0>) tensor(0.2000, requires_grad=True)
# 2 tensor([70.2377], grad_fn=<AddBackward0>) tensor(0.2998, requires_grad=True)
# 3 tensor([68.3081], grad_fn=<AddBackward0>) tensor(0.3993, requires_grad=True)
# 4 tensor([66.0866], grad_fn=<AddBackward0>) tensor(0.4982, requires_grad=True)
# 5 tensor([64.7405], grad_fn=<AddBackward0>) tensor(0.5966, requires_grad=True)
# 6 tensor([63.4961], grad_fn=<AddBackward0>) tensor(0.6941, requires_grad=True)
# 7 tensor([208.5879], grad_fn=<AddBackward0>) tensor(0.7908, requires_grad=True)
# 8 tensor([321.9722], grad_fn=<AddBackward0>) tensor(0.8793, requires_grad=True)
# 9 tensor([59.7136], grad_fn=<AddBackward0>) tensor(0.9636, requires_grad=True)
# 10 tensor([87.7381], grad_fn=<AddBackward0>) tensor(1.0423, requires_grad=True)
# 11 tensor([57.6126], grad_fn=<AddBackward0>) tensor(1.1185, requires_grad=True)
# 12 tensor([56.8638], grad_fn=<AddBackward0>) tensor(1.1902, requires_grad=True)
# 13 tensor([231.4846], grad_fn=<AddBackward0>) tensor(1.2578, requires_grad=True)
# 14 tensor([232.3388], grad_fn=<AddBackward0>) tensor(1.3311, requires_grad=True)
# 15 tensor([207.2812], grad_fn=<AddBackward0>) tensor(1.4083, requires_grad=True)
# 16 tensor([304.7305], grad_fn=<AddBackward0>) tensor(1.4873, requires_grad=True)
# 17 tensor([113.0117], grad_fn=<AddBackward0>) tensor(1.5698, requires_grad=True)
# 18 tensor([69.3994], grad_fn=<AddBackward0>) tensor(1.6490, requires_grad=True)
# 19 tensor([147.0401], grad_fn=<AddBackward0>) tensor(1.7234, requires_grad=True)
# 120 tensor([48.3402], grad_fn=<AddBackward0>) tensor(2.1356, requires_grad=True)
# 121 tensor([48.7885], grad_fn=<AddBackward0>) tensor(2.1279, requires_grad=True)
# 122 tensor([48.8944], grad_fn=<AddBackward0>) tensor(2.1223, requires_grad=True)
# 123 tensor([48.8165], grad_fn=<AddBackward0>) tensor(2.1187, requires_grad=True)
# 124 tensor([48.8188], grad_fn=<AddBackward0>) tensor(2.1169, requires_grad=True)
# 125 tensor([49.1809], grad_fn=<AddBackward0>) tensor(2.1168, requires_grad=True)
# 126 tensor([48.6319], grad_fn=<AddBackward0>) tensor(2.1181, requires_grad=True)
# 127 tensor([165.0540], grad_fn=<AddBackward0>) tensor(2.1207, requires_grad=True)
# 128 tensor([262.9622], grad_fn=<AddBackward0>) tensor(2.1218, requires_grad=True)
# 129 tensor([48.8627], grad_fn=<AddBackward0>) tensor(2.1165, requires_grad=True)
# 130 tensor([73.6867], grad_fn=<AddBackward0>) tensor(2.1131, requires_grad=True)
# 131 tensor([48.4948], grad_fn=<AddBackward0>) tensor(2.1113, requires_grad=True)
# 132 tensor([48.4355], grad_fn=<AddBackward0>) tensor(2.1112, requires_grad=True)
# 133 tensor([208.4296], grad_fn=<AddBackward0>) tensor(2.1125, requires_grad=True)
# 134 tensor([212.3230], grad_fn=<AddBackward0>) tensor(2.1097, requires_grad=True)
# 135 tensor([191.1273], grad_fn=<AddBackward0>) tensor(2.1029, requires_grad=True)
# 136 tensor([290.2278], grad_fn=<AddBackward0>) tensor(2.0938, requires_grad=True)
# 137 tensor([105.3940], grad_fn=<AddBackward0>) tensor(2.0768, requires_grad=True)
# 138 tensor([65.0782], grad_fn=<AddBackward0>) tensor(2.0622, requires_grad=True)
# 139 tensor([141.5920], grad_fn=<AddBackward0>) tensor(2.0506, requires_grad=True)
# 240 tensor([49.4483], grad_fn=<AddBackward0>) tensor(1.5956, requires_grad=True)
# 241 tensor([49.1239], grad_fn=<AddBackward0>) tensor(1.5860, requires_grad=True)
# 242 tensor([49.0289], grad_fn=<AddBackward0>) tensor(1.5812, requires_grad=True)
# 243 tensor([49.5560], grad_fn=<AddBackward0>) tensor(1.5806, requires_grad=True)
# 244 tensor([49.3509], grad_fn=<AddBackward0>) tensor(1.5838, requires_grad=True)
# 245 tensor([49.1540], grad_fn=<AddBackward0>) tensor(1.5905, requires_grad=True)
# 246 tensor([49.2983], grad_fn=<AddBackward0>) tensor(1.6002, requires_grad=True)
# 247 tensor([164.5738], grad_fn=<AddBackward0>) tensor(1.6124, requires_grad=True)
# 248 tensor([263.8996], grad_fn=<AddBackward0>) tensor(1.6227, requires_grad=True)
# 249 tensor([49.1811], grad_fn=<AddBackward0>) tensor(1.6196, requires_grad=True)
# 250 tensor([74.0221], grad_fn=<AddBackward0>) tensor(1.6202, requires_grad=True)
# 251 tensor([48.9260], grad_fn=<AddBackward0>) tensor(1.6240, requires_grad=True)
# 252 tensor([49.2115], grad_fn=<AddBackward0>) tensor(1.6308, requires_grad=True)
# 253 tensor([208.7317], grad_fn=<AddBackward0>) tensor(1.6399, requires_grad=True)
# 254 tensor([213.5815], grad_fn=<AddBackward0>) tensor(1.6398, requires_grad=True)
# 255 tensor([191.7365], grad_fn=<AddBackward0>) tensor(1.6302, requires_grad=True)
# 256 tensor([291.5828], grad_fn=<AddBackward0>) tensor(1.6152, requires_grad=True)
# 257 tensor([104.5283], grad_fn=<AddBackward0>) tensor(1.5835, requires_grad=True)
# 258 tensor([65.3853], grad_fn=<AddBackward0>) tensor(1.5577, requires_grad=True)
# 259 tensor([141.9426], grad_fn=<AddBackward0>) tensor(1.5385, requires_grad=True)
# 360 tensor([50.0126], grad_fn=<AddBackward0>) tensor(1.3157, requires_grad=True)
# 361 tensor([50.1078], grad_fn=<AddBackward0>) tensor(1.3068, requires_grad=True)
# 362 tensor([49.4336], grad_fn=<AddBackward0>) tensor(1.3044, requires_grad=True)
# 363 tensor([49.6409], grad_fn=<AddBackward0>) tensor(1.3078, requires_grad=True)
# 364 tensor([49.4598], grad_fn=<AddBackward0>) tensor(1.3164, requires_grad=True)
# 365 tensor([49.9635], grad_fn=<AddBackward0>) tensor(1.3296, requires_grad=True)
# 366 tensor([49.4407], grad_fn=<AddBackward0>) tensor(1.3468, requires_grad=True)
# 367 tensor([164.8344], grad_fn=<AddBackward0>) tensor(1.3673, requires_grad=True)
# 368 tensor([264.0582], grad_fn=<AddBackward0>) tensor(1.3860, requires_grad=True)
# 369 tensor([48.8341], grad_fn=<AddBackward0>) tensor(1.3881, requires_grad=True)
# 370 tensor([74.1681], grad_fn=<AddBackward0>) tensor(1.3946, requires_grad=True)
# 371 tensor([48.4909], grad_fn=<AddBackward0>) tensor(1.4051, requires_grad=True)
# 372 tensor([49.0258], grad_fn=<AddBackward0>) tensor(1.4189, requires_grad=True)
# 373 tensor([208.0288], grad_fn=<AddBackward0>) tensor(1.4355, requires_grad=True)
# 374 tensor([213.6063], grad_fn=<AddBackward0>) tensor(1.4387, requires_grad=True)
# 375 tensor([191.2054], grad_fn=<AddBackward0>) tensor(1.4283, requires_grad=True)
# 376 tensor([289.7623], grad_fn=<AddBackward0>) tensor(1.4101, requires_grad=True)
# 377 tensor([105.2077], grad_fn=<AddBackward0>) tensor(1.3711, requires_grad=True)
# 378 tensor([65.7294], grad_fn=<AddBackward0>) tensor(1.3401, requires_grad=True)
# 379 tensor([141.3857], grad_fn=<AddBackward0>) tensor(1.3178, requires_grad=True)
# 480 tensor([49.3644], grad_fn=<AddBackward0>) tensor(1.2492, requires_grad=True)
# 481 tensor([49.8803], grad_fn=<AddBackward0>) tensor(1.2408, requires_grad=True)
# 482 tensor([49.7046], grad_fn=<AddBackward0>) tensor(1.2393, requires_grad=True)
# 483 tensor([49.5489], grad_fn=<AddBackward0>) tensor(1.2441, requires_grad=True)
# 484 tensor([49.3416], grad_fn=<AddBackward0>) tensor(1.2544, requires_grad=True)
# 485 tensor([49.5883], grad_fn=<AddBackward0>) tensor(1.2696, requires_grad=True)
# 486 tensor([49.8983], grad_fn=<AddBackward0>) tensor(1.2891, requires_grad=True)
# 487 tensor([165.3758], grad_fn=<AddBackward0>) tensor(1.3120, requires_grad=True)
# 488 tensor([263.6119], grad_fn=<AddBackward0>) tensor(1.3329, requires_grad=True)
# 489 tensor([48.7288], grad_fn=<AddBackward0>) tensor(1.3363, requires_grad=True)
# 490 tensor([73.9445], grad_fn=<AddBackward0>) tensor(1.3442, requires_grad=True)
# 491 tensor([49.0925], grad_fn=<AddBackward0>) tensor(1.3562, requires_grad=True)
# 492 tensor([48.5668], grad_fn=<AddBackward0>) tensor(1.3716, requires_grad=True)
# 493 tensor([207.7033], grad_fn=<AddBackward0>) tensor(1.3900, requires_grad=True)
# 494 tensor([212.5310], grad_fn=<AddBackward0>) tensor(1.3934, requires_grad=True)
# 495 tensor([191.1901], grad_fn=<AddBackward0>) tensor(1.3820, requires_grad=True)
# 496 tensor([291.1081], grad_fn=<AddBackward0>) tensor(1.3621, requires_grad=True)
# 497 tensor([105.4021], grad_fn=<AddBackward0>) tensor(1.3191, requires_grad=True)
# 498 tensor([65.2340], grad_fn=<AddBackward0>) tensor(1.2850, requires_grad=True)
# 499 tensor([141.4127], grad_fn=<AddBackward0>) tensor(1.2605, requires_grad=True)
# tensor(5.6595, requires_grad=True) tensor(2.5509, requires_grad=True) tensor(1.2351, requires_grad=True)

# %%
kps = kpst.detach().numpy()
kis = kist.detach().numpy()
#kds = kdst.detach().numpy()
backs = backst.detach().numpy()
print(kps,kis,backs)

plt.figure()
plt.plot(np.arange(len(stlossvals))*20,stlossvals)
plt.xlabel("No. of episodes")
plt.ylabel("Loss")

plt.figure()
plt.plot(np.arange(len(kptrain)),kptrain)
plt.xlabel("No. of episodes")
plt.ylabel("kp")

#plt.figure()
#plt.plot(np.arange(len(kdtrain)),kdtrain)
#plt.xlabel("No. of episodes")
#plt.ylabel("kd")

plt.figure()
plt.plot(np.arange(len(kitrain)),kitrain)
plt.xlabel("No. of episodes")
plt.ylabel("ki")

plt.figure()
plt.plot(np.arange(len(backtrain)),backtrain)
plt.xlabel("No. of episodes")
plt.ylabel("Back-calculation constant")
# Out:
# 5.6594944 2.5509129 1.2351013
# Text(0, 0.5, 'Back-calculation constant')

# %%
costdgradient = np.zeros((10,))
costinit = np.zeros((10,))
costsgradient = np.zeros((10,))
kpt = torch.tensor(kp,requires_grad=True)
kit = torch.tensor(ki,requires_grad=True)
#kdit = torch.tensor(kd,requires_grad=False)
backt = torch.tensor(0.1,requires_grad=True)

ydgradient = np.zeros((10,T))
udgradient = np.zeros((10,T))

ysgradient = np.zeros((10,T))
usgradient = np.zeros((10,T))
smooth = 0.9

kpdgradient = np.zeros((10,T))
kidgradient = np.zeros((10,T))
#kddgradient = np.zeros((10,T))
backdgradient = np.zeros((10,T))
#PIDparams = neuralPID()
#PIDparams.load_state_dict(torch.load("dgradientparams"))

#yinit = np.zeros((10,T))
#uinit = np.zeros((10,T))

for iters in range(0,10):
  ref = refs[20+iters,:]
  reft = torch.tensor(ref)
  noise = 0.01*torch.randn(T,1)  
  
  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0]],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  u2 = torch.tensor([0.0],requires_grad=True)
  u1 = torch.tensor([0.0],requires_grad=True) 
  ucmd = torch.tensor([0.0],requires_grad=True)
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
#  D  = torch.tensor([0.0],requires_grad=False)
  #torch.clamp(Tft,0.1,0.1)
#  ad = torch.div(Tft,(Tft+0.01))
  
  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t];
    ydgradient[iters,t] = yt.clone().detach().numpy()
    #print(yt)
    #error = torch.tensor(reft[t]-yt,requires_grad=False)
    saterr = u-ucmd
    err = reft[t]-yt
    ninput = torch.cat((err.detach(),saterr.detach()),0)
    kpdt,kidt,backdt = PIDparams(ninput)
    kpt = smooth*kpt+(1-smooth)*(kpit+kpdt)
    kit = smooth*kit+(1-smooth)*(kiit+kidt)
    backt = smooth*backt+(1-smooth)*(backit+backdt)
    xcont = xcont+kit*err+backt*saterr.detach()
    if(t>0):
#      bd = torch.div(kdt,(Tft+0.01))
#      D = ad*D-bd*(yt-yold);  
      ucmd = (0.01*xcont+kpt*(reft[t]-yt))
      u = torch.clamp(ucmd,-3.3,3.3)
      udgradient[iters,t] = u.clone().detach().numpy()
      kpdgradient[iters,t] = kpt.clone().detach().numpy()
      kidgradient[iters,t] = kit.clone().detach().numpy()
#      kddgradient[iters,t] = kdt.clone().detach().numpy()
      backdgradient[iters,t] = backt.clone().detach().numpy()  
    x = torch.matmul(systA.float(),x)+systB.float()*u2
    u2 = u1
    u1 = u
    cost = cost+(reft[t]-yt)**2
    
  costdgradient[iters] = cost.detach().numpy()

  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0]],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  u2 = torch.tensor([0.0],requires_grad=True)
  u1 = torch.tensor([0.0],requires_grad=True)     
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  #D  = torch.tensor([0.0],requires_grad=False)
  #torch.clamp(Tft,0.1,0.1)
  #ad = torch.div(Tft,(Tft+0.01))
  
  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t];
    yinit[iters,t] = yt.clone().detach().numpy()
    #print(yt)
    #error = torch.tensor(reft[t]-yt,requires_grad=False)
    err = ref[t]-yt
    xcont = xcont+err
    if(t>0):
       #print(t,kpt,kit,kdt)
       #break;
       #bd = torch.div(kdit,(Tft+0.01))
       #D = ad*D-bd*(yt-yold);  
       u = (0.01*kiit*xcont+kpit*(ref[t]-yt))
       u = torch.clamp(u,-3.3,3.3)
    uinit[iters,t] = u.clone().detach().numpy()
    x = torch.matmul(systA.float(),x)+systB.float()*u2
    u2 = u1
    u1 = u
    cost = cost+(reft[t]-yt)**2
  costinit[iters] = cost.detach().numpy()

  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0]],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  u2 = torch.tensor([0.0],requires_grad=True)
  u1 = torch.tensor([0.0],requires_grad=True)     
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  D  = torch.tensor([0.0],requires_grad=False)
  #torch.clamp(Tft,0.1,0.1)
  #ad = torch.div(Tft,(Tft+0.01))
  #bd = torch.div(kdst,(Tft+0.01))

  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t];
    ysgradient[iters,t] = yt.clone().detach().numpy()
    #print(yt)
    #error = torch.tensor(reft[t]-yt,requires_grad=False)
    saterr = u-ucmd
    xcont = xcont+kist*(reft[t]-yt)+backst*saterr.detach()
    if(t>0):
       #deriv = torch.tensor(yt-yold,requires_grad=False) 
       #D = ad*D-bd*(yt-yold);  
       ucmd = (0.01*xcont+kpst*(reft[t]-yt))
    u = torch.clamp(ucmd,-3.3,3.3)
    usgradient[iters,t] = u.clone().detach().numpy()
    x = torch.matmul(systA.float(),x)+systB.float()*u2
    u2 = u1
    u1 = u
    cost = cost+(reft[t]-yt)**2
  costsgradient[iters] = cost.detach().numpy()

# %%
print("Dgradient-dynamic",costdgradient)
print("Dgradient-static",costsgradient)
print("Initial",costinit)
# Out:
# Dgradient-dynamic [292.58792114  79.45988464  47.97444153  67.63201141 152.40936279
#   49.27637482 127.28768921 238.39102173  49.37036514  48.04673004]
# Dgradient-static [287.75006104  79.05558777  49.62595749  67.46587372 152.82762146
#   49.61334229 128.13627625 234.22543335  49.64962387  49.60097885]
# Initial [1754.83459473  126.2881012    75.66311646  106.1338501   278.81030273
#    75.54531097  217.41040039  694.16851807   75.47618103   75.56257629]

# %%
plt.figure()
plt.plot(0.01*np.arange(0,T),refs[20,:])
plt.plot(0.01*np.arange(0,T),ydgradient[0,:])
plt.plot(0.01*np.arange(0,T),ysgradient[0,:])
plt.plot(0.01*np.arange(0,T),yinit[0,:])
plt.xlabel("Time(s)")
plt.ylabel("Output")
plt.legend(["Reference","D-gradient (dynamic)","D-gradient (static)","Initial"])

plt.figure()
plt.plot(0.01*np.arange(0,T),uinit[0,:])
plt.plot(0.01*np.arange(0,T),udgradient[0,:])
plt.plot(0.01*np.arange(0,T),usgradient[0,:])
plt.xlabel("Time(s)")
plt.ylabel("Input")
plt.legend(["Initial","D-gradient (dynamic)","D-gradient (static)"])

plt.figure()
plt.plot(0.01*np.arange(1,T),kpdgradient[0,1:])
plt.xlabel("Time(s)")
plt.ylabel("Proportional gain")

plt.figure()
plt.plot(0.01*np.arange(1,T),kidgradient[0,1:])
plt.xlabel("Time(s)")
plt.ylabel("Integral gain")

#plt.figure()
#plt.plot(0.01*np.arange(1,T),kddgradient[2,1:])
#plt.xlabel("Time(s)")
#plt.ylabel("Derivative gain")

plt.figure()
plt.plot(0.01*np.arange(1,T),backdgradient[0,1:])
plt.xlabel("Time(s)")
plt.ylabel("Back-calculation gain")
# Out:
# Text(0, 0.5, 'Back-calculation gain')

# %%
print(kpdgradient[6,0:300])
print(kidgradient[6,0:300])
# Out:
# [ 0.         22.03262711 23.01442719 23.01442719 22.0326252  22.0326252
#  22.0326252  22.03258896 22.0326252  22.03260803 23.01442719 23.01442719
#  23.01442719 23.01442719 22.0326252  23.01442719 22.0326252  23.01442719
#  23.0144062  22.0326252  23.01442719 23.01442719 23.00859451 22.68816376
#  22.0326252  22.03262329 22.03262329 22.0326252  22.0326252  22.0326252
#  21.79889297 23.01442719 23.01442719 23.01442719 22.0326252  22.0326252
#  22.0326252  23.01442719 23.01305008 22.0326252  22.0326252  23.01442719
#  23.01414108 22.0326252  21.03497314 23.01442719 23.01442719 23.01442719
#  22.0326252  22.03347969 23.01442719 22.0326252  22.58296967 22.0326252
#  22.0326252  23.01442719 22.0326252  23.01442719 22.04034042 22.04950333
#  22.0326252  22.00075912 23.01442719 23.01442719 23.01402092 22.0326252
#  23.01442719 23.01442719 22.03262138 23.01442719 22.0326252  22.0326252
#  22.0326786  23.01442719 23.01442719 22.0326252  23.01442719 23.01442719
#  22.0326252  22.03262329 20.96812057 23.01442719 23.01442719 22.0326252
#  22.0326252  23.01442719 22.0326252  22.0326252  23.01442719 23.01442719
#  23.01442719 22.03262329 23.01442719 23.01442719 22.0326252  22.03262329
#  22.0326252  22.0326252  23.01442719 22.0326252  23.01428223 22.03273392
#  22.0326252  23.01442719 23.01442719 23.01442719 22.0326252  23.01442719
#  22.0326252  22.0326252  23.01442719 22.0326252  22.0326252  23.01442719
#  23.01442719 22.04998398 23.01442719 22.98893929 22.0326252  23.01442719
#  22.0326252  22.98773575 22.0326252  21.33955383 22.0326252  22.0326252
#  23.01442719 23.01435089 23.01442719 23.01442719 23.0138588  22.0326252
#  22.0326252  23.01442719 22.0326252  23.01442719 23.01442719 22.51196289
#  22.0326252  22.03276062 23.01442719 22.0326252  22.0800209  22.0326252
#  22.0326252  23.01442719 23.01442719 22.03262329 23.01442719 22.0326252
#  23.01442719 22.0326252  22.0326252  22.03266525 23.01437569 22.0326252
#  22.03133583 23.01442719 22.0326252  22.0326252  23.01442719 23.01442719
#  23.01430702 22.0326252  22.0326252  23.01407242 23.01442719 23.00900841
#  23.01442719 22.03261948 22.0326252  22.0326252  23.01442719 23.01442719
#  22.03261948 23.01442719 23.01442719 22.03238297 23.01442719 23.01442719
#  23.01442719 22.0326252  23.01442719 22.0326252  23.01442719 22.0326252
#  22.0326252  22.0326252  22.0326252  22.03261948 22.0326252  20.96756554
#  22.0326252  22.0326252  23.01442719 23.01442719 22.0326252  23.01442719
#  22.0326252  22.95749664 22.03262711 22.03220367 23.01440048 22.03278732
#  22.0326252  22.0326252  23.01442719 23.01442719 22.0326252  22.0326252
#  22.0326252  23.01442719 22.0326252  23.01442719 23.01234436 23.01442719
#  23.01442719 22.0326252  23.01442719 23.01442719 22.0326252  22.0326252
#  23.01442719 22.0326252  23.01442719 23.01442719 22.0326252  23.01442719
#  22.0326252  23.01442719 22.0326252  22.58460617 22.0326252  22.0326252
#  22.90697861 22.0326252  23.01442719 22.0326252  22.0326252  23.01442719
#  22.0326252  23.01442719 22.0326252  22.03262329 23.01442719 22.0326252
#  23.01442719 22.0326252  23.01442719 23.01440048 23.01442719 22.03262329
#  22.0326252  22.03366852 22.0326252  20.96759987 22.0326252  22.03260422
#  22.0326252  22.0326252  23.01442719 22.03263474 23.01442719 22.0326252
#  23.01442719 22.03283691 22.0326252  23.01442719 22.13273621 22.0326252
#  23.01442719 22.0326252  23.01442719 22.0326252  22.03257751 23.01442719
#  23.01438332 22.03262329 23.01442719 22.0326252  22.0326252  22.0326252
#  23.01442719 22.0326252  23.01442719 23.01442719 22.0326252  22.0326252
#  22.00731659 23.01442719 23.01442719 22.0326252  22.0326252  22.0326252
#  22.0326252  22.0326252  23.01442719 23.01442719 22.0326252  21.99996185]
# [ 0.         10.57468987 12.07868385 12.07868385  6.95504332  6.96021605
#   6.95504332  6.95504332  7.18937874  6.95504332 12.07868385 12.07868385
#  12.07868385 12.07868385  6.95504332 12.07868385  6.95504379 12.07868385
#  12.07868385  6.95504332 12.07868385 12.07868385 12.0786829  12.07867146
#   6.97321367  6.95504332  6.95504332  6.95504332  6.95504332  6.95504332
#   6.95504332 12.07868385 12.07868385 12.07868385  6.95504332  6.95504332
#   6.97747993 12.07868385 12.0786829   6.95512438  6.95504332 12.07868385
#  12.07868385  6.95504332  6.95504332 12.07868385 12.07868385 12.07868385
#   6.95504332 12.07320881 12.07868385  7.44240856 12.07866764  6.95504332
#   6.95504332 12.07868385  6.95504332 12.07868385 12.07782745 12.07824135
#   6.95504332  6.95504332 12.07868385 12.07868385 12.07868385  6.95504332
#  12.07868385 12.07868385  6.95504332 12.07868385  8.09255981  6.95504332
#  12.01682281 12.07868385 12.07868385  6.95504332 12.07868385 12.07868385
#   6.95504332  6.95504332  6.95504332 12.07868385 12.07868385  6.95504332
#   6.95504332 12.07868385  6.95504332  6.95504332 12.07868385 12.07868385
#  12.07868385  6.95504332 12.07868385 12.07868385  6.95504332  6.95504332
#   6.95504332  6.95504379 12.07868385  6.95504332 12.07868385 12.05041122
#   6.95504332 12.07868385 12.07868385 12.07868385  6.95504379 12.07868385
#   6.95504379  6.95708179 12.07868385  6.95504332  6.95504332 12.07868385
#  12.07868385 12.07825184 12.07868385 12.07868195  6.95504332 12.07868385
#   6.97458267 12.07868195  6.95504379  6.95504332  6.95504332  6.95504332
#  12.07868385 12.07868385 12.07868385 12.07868385 12.0786829   6.95504332
#   6.95504332 12.07868385  6.95504332 12.07868385 12.07868385 12.07866383
#   6.95504332 12.05186939 12.07868385  6.95504379 12.07849503  6.95504332
#   6.95504332 12.07868385 12.07868385  6.95504332 12.07868385  6.95907116
#  12.07868385  6.95504332  6.95504332 12.00186729 12.07868385  6.95541143
#   6.95504332 12.07868385  6.95504332  6.95627117 12.07868385 12.07868385
#  12.07868385  6.95504332  6.95504332 12.07868385 12.07868385 12.0786829
#  12.07868385  6.95504332  6.95504332  6.9550457  12.07868385 12.07868385
#   6.95504332 12.07868385 12.07868385  6.95504332 12.07868385 12.07868385
#  12.07868385  6.95504332 12.07868385  6.9567194  12.07868385  6.95504332
#   6.95504332  6.95504332  8.49625111  6.95504332  6.95504332  6.95504332
#   6.95504332  6.95504332 12.07868385 12.07868385  6.95504332 12.07868385
#   7.54717922 12.07868099 11.09764099  6.95504332 12.07868385 12.05862617
#   6.95504332  6.95504332 12.07868385 12.07868385  6.97336197  6.95504332
#   6.95504332 12.07868385  6.95517826 12.07868385 12.0786829  12.07868385
#  12.07868385  6.95504332 12.07868385 12.07868385  6.95504332  6.95504856
#  12.07868385  6.95504332 12.07868385 12.07868385  6.95504332 12.07868385
#   6.95504332 12.07868385  6.95802021 12.07866859  6.95504332  6.95686769
#  12.07868004  6.95558643 12.07868385  6.95504332  6.95526028 12.07868385
#   6.95504332 12.07868385  6.95504332  6.95504332 12.07868385  6.95504332
#  12.07868385  6.95504332 12.07868385 12.07868385 12.07868385  6.95504332
#   6.95504332 12.07471085  6.95504332  6.95504332  6.95504332  6.95504332
#   6.95504332  6.95504332 12.07868385 11.77339935 12.07868385  7.00216818
#  12.07868385 12.06336403  6.95504332 12.07868385 12.07858658  6.95504332
#  12.07868385  6.95504332 12.07868385  8.83378792  6.95504332 12.07868385
#  12.07868385  6.95504332 12.07868385  6.95504332  6.95504951  6.95504332
#  12.07868385  6.95504379 12.07868385 12.07868385  6.95516682  6.95504332
#   6.95504332 12.07868385 12.07868385  6.95504332  6.95504332  6.95504332
#   6.98158979  6.95504761 12.07868385 12.07868385  6.95504332  6.95504332]

# %%
kpit = torch.tensor(kp,requires_grad=False)
kiit = torch.tensor(ki,requires_grad=False)
kdit = torch.tensor(kd,requires_grad=False)
PIDpg = neuralPID()
#optimizer = torch.optim.Adam((PIDpg.parameters()), lr=0.1)
#for iters in range(1000):
#   kpt,kit,kdt = PIDpg(torch.randn(3,))
#   print(kpt,kit,kdt)
#   loss = (kpt-kpit)**2+(kit-kiit)**2+(kdt-kdit)**2
#   optimizer.zero_grad()
#   loss.backward()
#   optimizer.step()

# %%
ysat = np.zeros((T,))
uvalssat = np.zeros((T,))

optimizer = torch.optim.Adam((PIDpg.parameters()), lr=0.1)

nupdates = 100
nepisodes = 120
for updates in range(nupdates):
  cost = np.zeros((nepisodes,T))
  ref = refs[updates%20,:]
  rcostsepisode = np.zeros((nepisodes*T,1))
  totalcost = np.zeros((nepisodes,))
  uvalsepisode = np.zeros((nepisodes*T,1))
  PIDinputsepisode = np.zeros((nepisodes*T,3))
  PIDstatesepisode = np.zeros((nepisodes*T,4))
  for episodes in range(nepisodes):
    xcont = 0
    x =[[0.0],[0.0]]  
    u = 0.0
    ucmd = 0.0
    
    ucmdvals = np.zeros((T,1))
    uvals =  np.zeros((T,1))
    PIDinputs = np.zeros((T,3))
    PIDstates = np.zeros((T,4))
    yt = 0.0
    D  = 0.0
    
    ad = Tf/(Tf+0.01)
    adt = torch.tensor(ad,requires_grad=False)
    adt = adt.float()
    noise = 0.01*np.random.randn(T,1)
    sigma = 0.5
    for t in range(T):
      yold = yt
      yt = np.clip(np.dot(sysC,x)+noise[t],-30.0,30.0)
      err = ref[t]-yt[0]
      xcont = xcont+err
      if(t>0):
         inp = np.array([err,u,ucmd])
         ninput = torch.tensor(inp,requires_grad=False)
         PIDinputs[t,:] = inp   
         kpdt,kidt,kddt = PIDpg(ninput.float())
         kpt = kpit+kpdt
         kit = kiit+kidt
         kdt = kdit+kddt
         kpn = kpt.detach().numpy()
         kin = kit.detach().numpy()
         kdn = kdt.detach().numpy()
         #print(kpn,kin,kdn)   
         bd = kdn[0]/(Tf+0.01)
         PIDstates[t,:] = [err,xcont,D,yt[0]-yold[0]] 
         D = ad*D-bd*(yt[0]-yold[0])
         ucmd = (0.01*kin[0]*xcont+kpn[0]*err+D)
      if(episodes==0):
        u = ucmd
      else:  
        u = ucmd+sigma*np.random.randn()
      uvals[t] = u
      u = np.clip(u,-35.0,35.0)
      x = np.dot(sysA,x)+sysB*u;
      cost[episodes,t] = (ref[t]-yt)**2
    #rcosts = np.flip(np.cumsum(np.flip(cost[episodes,:],[0]),0),[0])
    totalcost[episodes] = np.sum(cost[episodes,:])
    rcosts = np.repeat(totalcost[episodes],T,0)
    #if(episodes==0):
    #  print(updates,episodes,rcosts[0])
    rcostsepisode[episodes*T:(episodes+1)*T,0] = rcosts
    uvalsepisode[episodes*T:(episodes+1)*T,:] = uvals
    PIDinputsepisode[episodes*T:(episodes+1)*T,:] = PIDinputs
    PIDstatesepisode[episodes*T:(episodes+1)*T,:] = PIDstates
  print(updates,episodes,np.min(totalcost))
  PIDinputstorch = torch.tensor(PIDinputsepisode).float()
  PIDstatestorch = torch.tensor(PIDstatesepisode).float()
  uvalstorch = torch.tensor(uvalsepisode).float()
  rcoststorch = torch.tensor(rcostsepisode).float()
  costmean = torch.tensor(np.mean(totalcost)).float()
    
  kptvals,kitvals,kdtvals = PIDpg(PIDinputstorch)
  bdtvals = (kd+kdtvals)/(Tft+0.01)  
  Dvals = adt*PIDstatestorch[:,2]-bdtvals*PIDstatestorch[:,3]  
  ucmdvals = 0.01*torch.mul((ki+kitvals),PIDstatestorch[:,1])+torch.mul((kp+kptvals),PIDstatestorch[:,0])+Dvals
  
  updatecost = torch.mean(torch.mul((uvalstorch-ucmdvals)**2,rcoststorch-costmean))/(2*sigma)
  optimizer.zero_grad()
  updatecost.backward()
  optimizer.step()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-2b00b39fa3d9> in <module>
#      38       xcont = xcont+err
#      39       if(t>0):
# ---> 40          inp = np.array([err,u,ucmd])
#      41          ninput = torch.tensor(inp,requires_grad=False)
#      42          PIDinputs[t,:] = inp
#
# KeyboardInterrupt:
