# %%
import numpy as np
import scipy
import torch
from matplotlib import pyplot as plt
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable 
import control
from control import matlab
from matplotlib import cm

np.random.seed(0)
dev = "cpu"  
device = torch.device(dev)

# %%
sysA = np.array([1.01])
#sysA = 0.99
sysB = np.array([[0.125]])
sysC = np.array([0.1608])
sysD = 0
#print(np.linalg.eig(sysA))
kp = 4.0
ki = 10.0
kd = 0.0
Tf = 0.01

# %%
T = 1500
refs = np.zeros((30,T))

randval = 0

for i in range(30):
  refs[i,0:300] = 0
  randval = 8*np.random.rand()-4.0
  if randval>0 and randval<2:
    randval = 2
  if randval<0 and randval>-2:
    randval = -2
  refs[i,300:] = randval

# %%
ref = refs[8,:]
ysat = np.zeros((T,))
uvalssat = np.zeros((T,))
xcont = 0
u = 0
D = 0
ad = Tf/(Tf+0.01)
bd = kd/(Tf+0.01)
noise = 0.01*np.random.randn(T,1)

x0 = np.zeros((1,1))
x = x0
for i in range(T):
   ysat[i] = np.dot(sysC,x)+np.dot(sysD,u)+noise[i]
   xcont = xcont+(ref[i]-ysat[i])
   if(i>0):
     D = ad*D-bd*(ysat[i]-ysat[i-1])  
     u = 0.01*ki*xcont+kp*(ref[i]-ysat[i])+D
   if(u>3.3):
     u=3.3
   elif(u<-3.3):
     u=-3.3
   uvalssat[i] = u;
   x = np.dot(sysA,x)+np.dot(sysB,u);

ynosat = np.zeros((T,))
uvalsnosat = np.zeros((T,))
xcont = 0;
u = 0;
x = x0
D = 0

for i in range(T):
   ynosat[i] = np.dot(sysC,x)+np.dot(sysD,u)+noise[i]
   xcont = xcont+(ref[i]-ynosat[i])
   if(i>0):
     D = ad*D-bd*(ynosat[i]-ynosat[i-1])  
     u = 0.01*ki*xcont+kp*(ref[i]-ynosat[i])+D 
   uvalsnosat[i] = u;
   x = np.dot(sysA,x)+np.dot(sysB,u);

# %%
plt.figure
plt.plot(0.01*np.arange(T),ynosat)
plt.plot(0.01*np.arange(T),ysat)
plt.plot(0.01*np.arange(T),ref)
plt.xlabel("Time (s)")
plt.ylabel("Output")
plt.legend(["No saturation","Saturation","Reference"])
plt.show()

plt.figure
plt.plot(0.01*np.arange(T),uvalsnosat)
plt.plot(0.01*np.arange(T),uvalssat)
plt.xlabel("Time (s)")
plt.ylabel("Input")
plt.legend(["No saturation","Saturation"])
plt.show()

# %%
class neuralPID(torch.nn.Module):
   def __init__(self):
    super(neuralPID, self).__init__()
    torch.manual_seed(2)
    self.kplayer1 = torch.nn.Linear(2,2)
    self.kplayer2 = torch.nn.Linear(2,1)
    self.kilayer1 = torch.nn.Linear(2,2)
    self.kilayer2 = torch.nn.Linear(2,1)
    self.backlayer1 = torch.nn.Linear(2,2)
    self.backlayer2 = torch.nn.Linear(2,1)
  
   def forward(self,x):
    sigmoid = torch.nn.Tanh()
    kp = self.kplayer2(sigmoid(self.kplayer1(x)))
    ki = self.kilayer2(sigmoid(self.kilayer1(x)))
    back = self.backlayer2(sigmoid(self.backlayer1(x)))
    #kd = torch.clamp(kd,0,400)
    #kp = torch.clamp(kp,0,400)
    #ki = torch.clamp(ki,0,400)
    return kp,ki,back

# %%
Tft = torch.tensor(Tf,requires_grad=True)
kpit = torch.tensor(kp,requires_grad=False)
kiit = torch.tensor(ki,requires_grad=False)
#kdit = torch.tensor(kd,requires_grad=False)
backit = torch.tensor(-0.1,requires_grad=False)

systA = torch.tensor(sysA,requires_grad=False)
systB = torch.tensor(sysB,requires_grad=False)
systC = torch.tensor(sysC,requires_grad=False)
systD = torch.tensor(sysD,requires_grad=False)

# %%
costinit = np.zeros((30,))

yinit = np.zeros((30,T))
uinit = np.zeros((30,T))
Tft = torch.tensor(Tf,requires_grad=True)
kpit = torch.tensor(kp,requires_grad=False)
kiit = torch.tensor(ki,requires_grad=False)
kdit = torch.tensor(kd,requires_grad=False)

systA = torch.tensor(sysA,requires_grad=False)
systB = torch.tensor(sysB,requires_grad=False)
systC = torch.tensor(sysC,requires_grad=False)
systD = torch.tensor(sysD,requires_grad=False)

for iters in range(0,30):
  ref = refs[iters,:]
  reft = torch.tensor(ref)
  noise = 0.01*torch.randn(T,1)

  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0]],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  D  = torch.tensor([0.0],requires_grad=False)
  #torch.clamp(Tft,0.1,0.1)
  ad = torch.div(Tft,(Tft+0.01))
  
  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t];
    yinit[iters,t] = yt.clone().detach().numpy()
    #print(yt)
    #error = torch.tensor(reft[t]-yt,requires_grad=False)
    err = ref[t]-yt
    xcont = xcont+err
    if(t>0):
       #print(t,kpt,kit,kdt)
       #break;
       bd = torch.div(kdit,(Tft+0.01))
       D = ad*D-bd*(yt-yold);  
       u = (0.01*kiit*xcont+kpit*(ref[t]-yt)+D)
       u = torch.clamp(u,-3.3,3.3)
    uinit[iters,t] = u.clone().detach().numpy()
    x = torch.matmul(systA.float(),x)+systB.float()*u;
    cost = cost+(reft[t]-yt)**2
  costinit[iters] = cost.detach().numpy()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-764803ad2b7e> in <module>
#      29   for t in range(T):
#      30     yold = yt
# ---> 31     yt = torch.matmul(systC.float(),x)+noise[t];
#      32     yinit[iters,t] = yt.clone().detach().numpy()
#      33     #print(yt)
#
# KeyboardInterrupt:

# %%
###### print(costinit)
plt.figure()
plt.plot(refs[8,:])
plt.plot(yinit[8,:])
plt.plot(uinit[8,:])

# %%
# Initialize network
Tft = torch.tensor(Tf,requires_grad=True)
kpit = torch.tensor(kp,requires_grad=False)
kiit = torch.tensor(ki,requires_grad=False)
#kdit = torch.tensor(kd,requires_grad=False)
backit = torch.tensor(1.0,requires_grad=False)

kpt = torch.tensor(kp,requires_grad=True)
kit = torch.tensor(ki,requires_grad=True)
#kdit = torch.tensor(kd,requires_grad=False)
backt = torch.tensor(1.0,requires_grad=True)

systA = torch.tensor(sysA,requires_grad=False)
systB = torch.tensor(sysB,requires_grad=False)
systC = torch.tensor(sysC,requires_grad=False)
systD = torch.tensor(sysD,requires_grad=False)

PIDparams = neuralPID()
#optimizer = torch.optim.Adam((PIDparams.parameters()), lr=0.1)
#for iters in range(1000):
#   kpt,kit,kdt = PIDparams(torch.randn(3,))
#   print(kpt,kit,kdt)
#   loss = (kpt-kpit)**2+(kit-kiit)**2+(kdt-kdit)**2
#   optimizer.zero_grad()
#   loss.backward()
#   optimizer.step()    
   #print(iters,loss)

# %%
ysat = np.zeros((T,))
uvalssat = np.zeros((T,))

optimizer = torch.optim.Adam((PIDparams.parameters()), lr=0.1)
smooth = 0
for episodes in range(501):
  #cepisode = np.random.randint(20)  
  cepisode = episodes%20
  ref = refs[cepisode,:]
  reft = torch.tensor(ref)  
  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0]],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  ucmd = torch.tensor([0.0],requires_grad=True)
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  #D  = torch.tensor([0.0],requires_grad=False)
  #ad = torch.div(Tft,(Tft+0.01))
  noise = 0.01*torch.randn(T,1)
  kpt = kpt.clone().detach()
  kit = kit.clone().detach()
  backt = backt.clone().detach()
  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t]
    saterr = u-ucmd
    err = reft[t]-yt
    ninput = torch.cat((err,saterr),0)
    kpdt,kidt,backdt = PIDparams(ninput)
    kpt = smooth*kpt+(1-smooth)*(kpit+kpdt)
    kit = smooth*kit+(1-smooth)*(kiit+kidt)
    backt = smooth*backit+(1-smooth)*(backit+backdt)
    xcont = xcont+kit*err+backt*saterr.detach()
    if(t>0):
      #bd = torch.div(kdt,(Tft+0.01))
      #D = ad*D-bd*(yt-yold);  
      ucmd = (0.01*xcont+kpt*(reft[t]-yt))
      u = torch.clamp(ucmd,-3.3,3.3)
    x = torch.matmul(systA.float(),x)+systB.float()*u;
    cost = cost+(reft[t]-yt)**2  
  if(episodes%120<20):
    print(episodes,cost)
  optimizer.zero_grad()
  cost.backward()
  optimizer.step()
# Out:
# 0 tensor([53.5087], grad_fn=<AddBackward0>)
# 1 tensor([50.7509], grad_fn=<AddBackward0>)
# 2 tensor([48.3552], grad_fn=<AddBackward0>)
# 3 tensor([45.7308], grad_fn=<AddBackward0>)
# 4 tensor([53.6197], grad_fn=<AddBackward0>)
# 5 tensor([43.3320], grad_fn=<AddBackward0>)
# 6 tensor([51.2535], grad_fn=<AddBackward0>)
# 7 tensor([147.1508], grad_fn=<AddBackward0>)
# 8 tensor([237.0856], grad_fn=<AddBackward0>)
# 9 tensor([47.8319], grad_fn=<AddBackward0>)
# 10 tensor([62.7582], grad_fn=<AddBackward0>)
# 11 tensor([40.6171], grad_fn=<AddBackward0>)
# 12 tensor([40.0122], grad_fn=<AddBackward0>)
# 13 tensor([188.4175], grad_fn=<AddBackward0>)
# 14 tensor([206.9850], grad_fn=<AddBackward0>)
# 15 tensor([182.9790], grad_fn=<AddBackward0>)
# 16 tensor([277.1914], grad_fn=<AddBackward0>)
# 17 tensor([91.4524], grad_fn=<AddBackward0>)
# 18 tensor([54.7820], grad_fn=<AddBackward0>)
# 19 tensor([123.3600], grad_fn=<AddBackward0>)
# 120 tensor([40.0871], grad_fn=<AddBackward0>)
# 121 tensor([40.1678], grad_fn=<AddBackward0>)
# 122 tensor([39.9275], grad_fn=<AddBackward0>)
# 123 tensor([40.1663], grad_fn=<AddBackward0>)
# 124 tensor([40.4453], grad_fn=<AddBackward0>)
# 125 tensor([40.5425], grad_fn=<AddBackward0>)
# 126 tensor([40.0392], grad_fn=<AddBackward0>)
# 127 tensor([145.3950], grad_fn=<AddBackward0>)
# 128 tensor([235.5784], grad_fn=<AddBackward0>)
# 129 tensor([40.2236], grad_fn=<AddBackward0>)
# 130 tensor([62.2256], grad_fn=<AddBackward0>)
# 131 tensor([39.4899], grad_fn=<AddBackward0>)
# 132 tensor([40.0892], grad_fn=<AddBackward0>)
# 133 tensor([183.7631], grad_fn=<AddBackward0>)
# 134 tensor([188.8613], grad_fn=<AddBackward0>)
# 135 tensor([169.1848], grad_fn=<AddBackward0>)
# 136 tensor([260.1634], grad_fn=<AddBackward0>)
# 137 tensor([90.1226], grad_fn=<AddBackward0>)
# 138 tensor([54.1441], grad_fn=<AddBackward0>)
# 139 tensor([124.6396], grad_fn=<AddBackward0>)
# 240 tensor([39.6504], grad_fn=<AddBackward0>)
# 241 tensor([39.9585], grad_fn=<AddBackward0>)
# 242 tensor([39.6411], grad_fn=<AddBackward0>)
# 243 tensor([40.0321], grad_fn=<AddBackward0>)
# 244 tensor([40.1202], grad_fn=<AddBackward0>)
# 245 tensor([40.2092], grad_fn=<AddBackward0>)
# 246 tensor([39.9104], grad_fn=<AddBackward0>)
# 247 tensor([146.3717], grad_fn=<AddBackward0>)
# 248 tensor([237.9500], grad_fn=<AddBackward0>)
# 249 tensor([40.0035], grad_fn=<AddBackward0>)
# 250 tensor([62.1425], grad_fn=<AddBackward0>)
# 251 tensor([39.9583], grad_fn=<AddBackward0>)
# 252 tensor([40.7889], grad_fn=<AddBackward0>)
# 253 tensor([185.4618], grad_fn=<AddBackward0>)
# 254 tensor([187.6690], grad_fn=<AddBackward0>)
# 255 tensor([169.5942], grad_fn=<AddBackward0>)
# 256 tensor([258.9155], grad_fn=<AddBackward0>)
# 257 tensor([91.0159], grad_fn=<AddBackward0>)
# 258 tensor([54.5518], grad_fn=<AddBackward0>)
# 259 tensor([123.6579], grad_fn=<AddBackward0>)
# 360 tensor([40.1723], grad_fn=<AddBackward0>)
# 361 tensor([39.8848], grad_fn=<AddBackward0>)
# 362 tensor([40.3288], grad_fn=<AddBackward0>)
# 363 tensor([39.4936], grad_fn=<AddBackward0>)
# 364 tensor([39.8535], grad_fn=<AddBackward0>)
# 365 tensor([40.0788], grad_fn=<AddBackward0>)
# 366 tensor([40.1395], grad_fn=<AddBackward0>)
# 367 tensor([147.1643], grad_fn=<AddBackward0>)
# 368 tensor([238.4545], grad_fn=<AddBackward0>)
# 369 tensor([40.7042], grad_fn=<AddBackward0>)
# 370 tensor([62.4100], grad_fn=<AddBackward0>)
# 371 tensor([39.9844], grad_fn=<AddBackward0>)
# 372 tensor([40.4197], grad_fn=<AddBackward0>)
# 373 tensor([185.3235], grad_fn=<AddBackward0>)
# 374 tensor([188.9206], grad_fn=<AddBackward0>)
# 375 tensor([168.4811], grad_fn=<AddBackward0>)
# 376 tensor([260.7840], grad_fn=<AddBackward0>)
# 377 tensor([91.2201], grad_fn=<AddBackward0>)
# 378 tensor([55.1148], grad_fn=<AddBackward0>)
# 379 tensor([123.2794], grad_fn=<AddBackward0>)
# 480 tensor([39.9214], grad_fn=<AddBackward0>)
# 481 tensor([39.7905], grad_fn=<AddBackward0>)
# 482 tensor([39.7847], grad_fn=<AddBackward0>)
# 483 tensor([39.7176], grad_fn=<AddBackward0>)
# 484 tensor([39.8399], grad_fn=<AddBackward0>)
# 485 tensor([39.7937], grad_fn=<AddBackward0>)
# 486 tensor([40.3650], grad_fn=<AddBackward0>)
# 487 tensor([145.6432], grad_fn=<AddBackward0>)
# 488 tensor([236.7213], grad_fn=<AddBackward0>)
# 489 tensor([39.8501], grad_fn=<AddBackward0>)
# 490 tensor([62.0513], grad_fn=<AddBackward0>)
# 491 tensor([39.7293], grad_fn=<AddBackward0>)
# 492 tensor([40.3437], grad_fn=<AddBackward0>)
# 493 tensor([185.1846], grad_fn=<AddBackward0>)
# 494 tensor([189.0032], grad_fn=<AddBackward0>)
# 495 tensor([167.7959], grad_fn=<AddBackward0>)
# 496 tensor([260.5239], grad_fn=<AddBackward0>)
# 497 tensor([90.5472], grad_fn=<AddBackward0>)
# 498 tensor([55.4004], grad_fn=<AddBackward0>)
# 499 tensor([124.4142], grad_fn=<AddBackward0>)

# %%
#plt.figure()
#plt.plot(ref)
torch.save(PIDparams.state_dict(), "fodgradientparams")

# %%
kpst = torch.tensor(kp,requires_grad=True)
kist = torch.tensor(ki,requires_grad=True)
#kdst = torch.tensor(kd,requires_grad=True)
backst = torch.tensor(1.0,requires_grad=True)
#Tft = torch.tensor(Tf,requires_grad=True)
optimizer = torch.optim.Adam((kpst,kist,backst), lr=0.1)

stlossvals = []
closs = 0
kptrain = []
kitrain = []
kdtrain = []
backtrain = []
for episodes in range(701):
  cepisode = episodes%20
  ref = refs[cepisode,:]
  reft = torch.tensor(ref)  
  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0]],requires_grad=True)  
  ucmd = torch.tensor([0.0],requires_grad=True)
  u = torch.tensor([0.0],requires_grad=True)  
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  D  = torch.tensor([0.0],requires_grad=False)
  #torch.clamp(Tft,0.1,0.1)
  #ad = torch.div(Tft,(Tft+0.01))
  #bd = torch.div(kdst,(Tft+0.01))
  noise = 0.01*torch.randn(T,1)
  
  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t];
    #error = torch.tensor(reft[t]-yt,requires_grad=False)
    saterr = u-ucmd
    xcont = xcont+kist*(reft[t]-yt)+backst*saterr
    if(t>0):
       #deriv = torch.tensor(yt-yold,requires_grad=False) 
       #D = ad*D-bd*(yt-yold);  
       ucmd = (0.01*xcont+kpst*(reft[t]-yt))
    u = torch.clamp(ucmd,-3.3,3.3)
    uvalssat[i] = u;
    x = torch.matmul(systA.float(),x)+systB.float()*u;
    cost = cost+torch.clamp((reft[t]-yt)**2,0,50)
  closs = closs+cost  
  if(episodes%20==19):    
    stlossvals.append(closs.clone().detach().numpy()/20)
    closs = 0
  kptrain.append(kpst.clone().detach().numpy())
  kitrain.append(kist.clone().detach().numpy())
  #kdtrain.append(kdst.clone().detach().numpy())
  backtrain.append(backst.clone().detach().numpy())  
  if(episodes%120<20):
    #print(kpt,kdt,kit,Tft)
    print(episodes,cost,backst) 
  optimizer.zero_grad()
  cost.backward()
  optimizer.step()

print(kpst,kist,backst)
# Out:
# 0 tensor([54.1681], grad_fn=<AddBackward0>) tensor(1., requires_grad=True)
# 1 tensor([53.0726], grad_fn=<AddBackward0>) tensor(1.1000, requires_grad=True)
# 2 tensor([51.6226], grad_fn=<AddBackward0>) tensor(1.1999, requires_grad=True)
# 3 tensor([50.7846], grad_fn=<AddBackward0>) tensor(1.2994, requires_grad=True)
# 4 tensor([49.8314], grad_fn=<AddBackward0>) tensor(1.3985, requires_grad=True)
# 5 tensor([48.9513], grad_fn=<AddBackward0>) tensor(1.4971, requires_grad=True)
# 6 tensor([47.7538], grad_fn=<AddBackward0>) tensor(1.5951, requires_grad=True)
# 7 tensor([162.9296], grad_fn=<AddBackward0>) tensor(1.6922, requires_grad=True)
# 8 tensor([255.9544], grad_fn=<AddBackward0>) tensor(1.7838, requires_grad=True)
# 9 tensor([45.8340], grad_fn=<AddBackward0>) tensor(1.8744, requires_grad=True)
# 10 tensor([68.9744], grad_fn=<AddBackward0>) tensor(1.9600, requires_grad=True)
# 11 tensor([44.8260], grad_fn=<AddBackward0>) tensor(2.0433, requires_grad=True)
# 12 tensor([44.1356], grad_fn=<AddBackward0>) tensor(2.1224, requires_grad=True)
# 13 tensor([190.2410], grad_fn=<AddBackward0>) tensor(2.1975, requires_grad=True)
# 14 tensor([193.2049], grad_fn=<AddBackward0>) tensor(2.2763, requires_grad=True)
# 15 tensor([172.8997], grad_fn=<AddBackward0>) tensor(2.3571, requires_grad=True)
# 16 tensor([262.0031], grad_fn=<AddBackward0>) tensor(2.4381, requires_grad=True)
# 17 tensor([93.3148], grad_fn=<AddBackward0>) tensor(2.5188, requires_grad=True)
# 18 tensor([56.5250], grad_fn=<AddBackward0>) tensor(2.5961, requires_grad=True)
# 19 tensor([124.9216], grad_fn=<AddBackward0>) tensor(2.6690, requires_grad=True)
# 120 tensor([40.8880], grad_fn=<AddBackward0>) tensor(2.5928, requires_grad=True)
# 121 tensor([41.0612], grad_fn=<AddBackward0>) tensor(2.5851, requires_grad=True)
# 122 tensor([40.3272], grad_fn=<AddBackward0>) tensor(2.5808, requires_grad=True)
# 123 tensor([40.5941], grad_fn=<AddBackward0>) tensor(2.5793, requires_grad=True)
# 124 tensor([40.4836], grad_fn=<AddBackward0>) tensor(2.5804, requires_grad=True)
# 125 tensor([40.7522], grad_fn=<AddBackward0>) tensor(2.5841, requires_grad=True)
# 126 tensor([40.2971], grad_fn=<AddBackward0>) tensor(2.5898, requires_grad=True)
# 127 tensor([145.7881], grad_fn=<AddBackward0>) tensor(2.5975, requires_grad=True)
# 128 tensor([236.1576], grad_fn=<AddBackward0>) tensor(2.6024, requires_grad=True)
# 129 tensor([40.5590], grad_fn=<AddBackward0>) tensor(2.5975, requires_grad=True)
# 130 tensor([62.7211], grad_fn=<AddBackward0>) tensor(2.5955, requires_grad=True)
# 131 tensor([40.3777], grad_fn=<AddBackward0>) tensor(2.5958, requires_grad=True)
# 132 tensor([40.7600], grad_fn=<AddBackward0>) tensor(2.5983, requires_grad=True)
# 133 tensor([184.1282], grad_fn=<AddBackward0>) tensor(2.6029, requires_grad=True)
# 134 tensor([189.0976], grad_fn=<AddBackward0>) tensor(2.6018, requires_grad=True)
# 135 tensor([169.7220], grad_fn=<AddBackward0>) tensor(2.5948, requires_grad=True)
# 136 tensor([260.7891], grad_fn=<AddBackward0>) tensor(2.5842, requires_grad=True)
# 137 tensor([90.6643], grad_fn=<AddBackward0>) tensor(2.5634, requires_grad=True)
# 138 tensor([54.4821], grad_fn=<AddBackward0>) tensor(2.5459, requires_grad=True)
# 139 tensor([123.8317], grad_fn=<AddBackward0>) tensor(2.5326, requires_grad=True)
# 240 tensor([40.1372], grad_fn=<AddBackward0>) tensor(2.2261, requires_grad=True)
# 241 tensor([40.4748], grad_fn=<AddBackward0>) tensor(2.2195, requires_grad=True)
# 242 tensor([40.1388], grad_fn=<AddBackward0>) tensor(2.2171, requires_grad=True)
# 243 tensor([40.3702], grad_fn=<AddBackward0>) tensor(2.2186, requires_grad=True)
# 244 tensor([39.9479], grad_fn=<AddBackward0>) tensor(2.2235, requires_grad=True)
# 245 tensor([40.3892], grad_fn=<AddBackward0>) tensor(2.2314, requires_grad=True)
# 246 tensor([40.2186], grad_fn=<AddBackward0>) tensor(2.2419, requires_grad=True)
# 247 tensor([144.8129], grad_fn=<AddBackward0>) tensor(2.2547, requires_grad=True)
# 248 tensor([235.1119], grad_fn=<AddBackward0>) tensor(2.2639, requires_grad=True)
# 249 tensor([40.2841], grad_fn=<AddBackward0>) tensor(2.2612, requires_grad=True)
# 250 tensor([62.7776], grad_fn=<AddBackward0>) tensor(2.2618, requires_grad=True)
# 251 tensor([40.3560], grad_fn=<AddBackward0>) tensor(2.2652, requires_grad=True)
# 252 tensor([40.3223], grad_fn=<AddBackward0>) tensor(2.2713, requires_grad=True)
# 253 tensor([185.2991], grad_fn=<AddBackward0>) tensor(2.2796, requires_grad=True)
# 254 tensor([188.4525], grad_fn=<AddBackward0>) tensor(2.2797, requires_grad=True)
# 255 tensor([168.9988], grad_fn=<AddBackward0>) tensor(2.2725, requires_grad=True)
# 256 tensor([261.4479], grad_fn=<AddBackward0>) tensor(2.2602, requires_grad=True)
# 257 tensor([90.7308], grad_fn=<AddBackward0>) tensor(2.2337, requires_grad=True)
# 258 tensor([54.6071], grad_fn=<AddBackward0>) tensor(2.2117, requires_grad=True)
# 259 tensor([123.2290], grad_fn=<AddBackward0>) tensor(2.1953, requires_grad=True)
# 360 tensor([40.2705], grad_fn=<AddBackward0>) tensor(1.9791, requires_grad=True)
# 361 tensor([40.5724], grad_fn=<AddBackward0>) tensor(1.9715, requires_grad=True)
# 362 tensor([40.2918], grad_fn=<AddBackward0>) tensor(1.9691, requires_grad=True)
# 363 tensor([40.4774], grad_fn=<AddBackward0>) tensor(1.9714, requires_grad=True)
# 364 tensor([40.3138], grad_fn=<AddBackward0>) tensor(1.9778, requires_grad=True)
# 365 tensor([40.2001], grad_fn=<AddBackward0>) tensor(1.9879, requires_grad=True)
# 366 tensor([40.3155], grad_fn=<AddBackward0>) tensor(2.0012, requires_grad=True)
# 367 tensor([146.0334], grad_fn=<AddBackward0>) tensor(2.0172, requires_grad=True)
# 368 tensor([235.3244], grad_fn=<AddBackward0>) tensor(2.0296, requires_grad=True)
# 369 tensor([40.4517], grad_fn=<AddBackward0>) tensor(2.0274, requires_grad=True)
# 370 tensor([61.9956], grad_fn=<AddBackward0>) tensor(2.0292, requires_grad=True)
# 371 tensor([40.3970], grad_fn=<AddBackward0>) tensor(2.0341, requires_grad=True)
# 372 tensor([40.3290], grad_fn=<AddBackward0>) tensor(2.0422, requires_grad=True)
# 373 tensor([183.6890], grad_fn=<AddBackward0>) tensor(2.0529, requires_grad=True)
# 374 tensor([188.2025], grad_fn=<AddBackward0>) tensor(2.0533, requires_grad=True)
# 375 tensor([169.7183], grad_fn=<AddBackward0>) tensor(2.0445, requires_grad=True)
# 376 tensor([260.3523], grad_fn=<AddBackward0>) tensor(2.0303, requires_grad=True)
# 377 tensor([90.6712], grad_fn=<AddBackward0>) tensor(1.9990, requires_grad=True)
# 378 tensor([54.7054], grad_fn=<AddBackward0>) tensor(1.9737, requires_grad=True)
# 379 tensor([122.9697], grad_fn=<AddBackward0>) tensor(1.9554, requires_grad=True)
# 480 tensor([40.2992], grad_fn=<AddBackward0>) tensor(1.8139, requires_grad=True)
# 481 tensor([40.4076], grad_fn=<AddBackward0>) tensor(1.8049, requires_grad=True)
# 482 tensor([40.3410], grad_fn=<AddBackward0>) tensor(1.8017, requires_grad=True)
# 483 tensor([39.7253], grad_fn=<AddBackward0>) tensor(1.8041, requires_grad=True)
# 484 tensor([39.9944], grad_fn=<AddBackward0>) tensor(1.8113, requires_grad=True)
# 485 tensor([40.0928], grad_fn=<AddBackward0>) tensor(1.8227, requires_grad=True)
# 486 tensor([39.7508], grad_fn=<AddBackward0>) tensor(1.8378, requires_grad=True)
# 487 tensor([144.6027], grad_fn=<AddBackward0>) tensor(1.8559, requires_grad=True)
# 488 tensor([236.7300], grad_fn=<AddBackward0>) tensor(1.8717, requires_grad=True)
# 489 tensor([39.6558], grad_fn=<AddBackward0>) tensor(1.8726, requires_grad=True)
# 490 tensor([62.0815], grad_fn=<AddBackward0>) tensor(1.8775, requires_grad=True)
# 491 tensor([40.0160], grad_fn=<AddBackward0>) tensor(1.8859, requires_grad=True)
# 492 tensor([40.3293], grad_fn=<AddBackward0>) tensor(1.8973, requires_grad=True)
# 493 tensor([185.5321], grad_fn=<AddBackward0>) tensor(1.9112, requires_grad=True)
# 494 tensor([188.9675], grad_fn=<AddBackward0>) tensor(1.9134, requires_grad=True)
# 495 tensor([168.9560], grad_fn=<AddBackward0>) tensor(1.9052, requires_grad=True)
# 496 tensor([259.9428], grad_fn=<AddBackward0>) tensor(1.8903, requires_grad=True)
# 497 tensor([91.2500], grad_fn=<AddBackward0>) tensor(1.8572, requires_grad=True)
# 498 tensor([54.6256], grad_fn=<AddBackward0>) tensor(1.8307, requires_grad=True)
# 499 tensor([122.0278], grad_fn=<AddBackward0>) tensor(1.8117, requires_grad=True)
# 600 tensor([39.7123], grad_fn=<AddBackward0>) tensor(1.6958, requires_grad=True)
# 601 tensor([40.3140], grad_fn=<AddBackward0>) tensor(1.6874, requires_grad=True)
# 602 tensor([39.7199], grad_fn=<AddBackward0>) tensor(1.6854, requires_grad=True)
# 603 tensor([40.3955], grad_fn=<AddBackward0>) tensor(1.6891, requires_grad=True)
# 604 tensor([40.0235], grad_fn=<AddBackward0>) tensor(1.6979, requires_grad=True)
# 605 tensor([39.9529], grad_fn=<AddBackward0>) tensor(1.7114, requires_grad=True)
# 606 tensor([39.9316], grad_fn=<AddBackward0>) tensor(1.7287, requires_grad=True)
# 607 tensor([144.6914], grad_fn=<AddBackward0>) tensor(1.7492, requires_grad=True)
# 608 tensor([234.3262], grad_fn=<AddBackward0>) tensor(1.7669, requires_grad=True)
# 609 tensor([40.0266], grad_fn=<AddBackward0>) tensor(1.7686, requires_grad=True)
# 610 tensor([62.3845], grad_fn=<AddBackward0>) tensor(1.7745, requires_grad=True)
# 611 tensor([39.9185], grad_fn=<AddBackward0>) tensor(1.7836, requires_grad=True)
# 612 tensor([40.4589], grad_fn=<AddBackward0>) tensor(1.7959, requires_grad=True)
# 613 tensor([184.0606], grad_fn=<AddBackward0>) tensor(1.8108, requires_grad=True)
# 614 tensor([190.1907], grad_fn=<AddBackward0>) tensor(1.8126, requires_grad=True)
# 615 tensor([168.7614], grad_fn=<AddBackward0>) tensor(1.8019, requires_grad=True)
# 616 tensor([260.5852], grad_fn=<AddBackward0>) tensor(1.7845, requires_grad=True)
# 617 tensor([91.5676], grad_fn=<AddBackward0>) tensor(1.7472, requires_grad=True)
# 618 tensor([54.4603], grad_fn=<AddBackward0>) tensor(1.7169, requires_grad=True)
# 619 tensor([123.6039], grad_fn=<AddBackward0>) tensor(1.6948, requires_grad=True)
# tensor(10.4826, requires_grad=True) tensor(11.3440, requires_grad=True) tensor(1.6279, requires_grad=True)

# %%
kps = kpst.detach().numpy()
kis = kist.detach().numpy()
#kds = kdst.detach().numpy()
backs = backst.detach().numpy()
print(kps,kis,backs)

plt.figure()
plt.plot(np.arange(len(stlossvals))*20,stlossvals)
plt.xlabel("No. of episodes")
plt.ylabel("Loss")

plt.figure()
plt.plot(np.arange(len(kptrain)),kptrain)
plt.xlabel("No. of episodes")
plt.ylabel("kp")

#plt.figure()
#plt.plot(np.arange(len(kdtrain)),kdtrain)
#plt.xlabel("No. of episodes")
#plt.ylabel("kd")

plt.figure()
plt.plot(np.arange(len(kitrain)),kitrain)
plt.xlabel("No. of episodes")
plt.ylabel("ki")

plt.figure()
plt.plot(np.arange(len(backtrain)),backtrain)
plt.xlabel("No. of episodes")
plt.ylabel("Back-calculation constant")
# Out:
# 10.482562 11.343963 1.6278508
# Text(0, 0.5, 'Back-calculation constant')

# %%
costdgradient = np.zeros((10,))
costinit = np.zeros((10,))
costsgradient = np.zeros((10,))
kpt = torch.tensor(kp,requires_grad=True)
kit = torch.tensor(ki,requires_grad=True)
#kdit = torch.tensor(kd,requires_grad=False)
backt = torch.tensor(1.0,requires_grad=True)

ydgradient = np.zeros((10,T))
udgradient = np.zeros((10,T))

ysgradient = np.zeros((10,T))
usgradient = np.zeros((10,T))
smooth = 0.9

kpdgradient = np.zeros((10,T))
kidgradient = np.zeros((10,T))
#kddgradient = np.zeros((10,T))
backdgradient = np.zeros((10,T))
#PIDparams = neuralPID()
#PIDparams.load_state_dict(torch.load("dgradientparams"))

#yinit = np.zeros((10,T))
#uinit = np.zeros((10,T))

for iters in range(0,10):
  ref = refs[20+iters,:]
  reft = torch.tensor(ref)
  noise = 0.01*torch.randn(T,1)  
  
  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0]],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  ucmd = torch.tensor([0.0],requires_grad=True)
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
#  D  = torch.tensor([0.0],requires_grad=False)
  #torch.clamp(Tft,0.1,0.1)
#  ad = torch.div(Tft,(Tft+0.01))
  
  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t];
    ydgradient[iters,t] = yt.clone().detach().numpy()
    #print(yt)
    #error = torch.tensor(reft[t]-yt,requires_grad=False)
    saterr = u-ucmd
    err = reft[t]-yt
    ninput = torch.cat((err.detach(),saterr.detach()),0)
    kpdt,kidt,backdt = PIDparams(ninput)
    kpt = smooth*kpt+(1-smooth)*(kpit+kpdt)
    kit = smooth*kit+(1-smooth)*(kiit+kidt)
    backt = smooth*backit+(1-smooth)*(backit+backdt)
    xcont = xcont+kit*err+backt*saterr.detach()
    if(t>0):
#      bd = torch.div(kdt,(Tft+0.01))
#      D = ad*D-bd*(yt-yold);  
      ucmd = (0.01*xcont+kpt*(reft[t]-yt))
      u = torch.clamp(ucmd,-3.3,3.3)
      udgradient[iters,t] = u.clone().detach().numpy()
      kpdgradient[iters,t] = kpt.clone().detach().numpy()
      kidgradient[iters,t] = kit.clone().detach().numpy()
#      kddgradient[iters,t] = kdt.clone().detach().numpy()
      backdgradient[iters,t] = backt.clone().detach().numpy()  
    x = torch.matmul(systA.float(),x)+systB.float()*u;
    cost = cost+(reft[t]-yt)**2
    
  costdgradient[iters] = cost.detach().numpy()

  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0]],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  #D  = torch.tensor([0.0],requires_grad=False)
  #torch.clamp(Tft,0.1,0.1)
  #ad = torch.div(Tft,(Tft+0.01))
  
  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t];
    yinit[iters,t] = yt.clone().detach().numpy()
    #print(yt)
    #error = torch.tensor(reft[t]-yt,requires_grad=False)
    err = ref[t]-yt
    xcont = xcont+err
    if(t>0):
       #print(t,kpt,kit,kdt)
       #break;
       #bd = torch.div(kdit,(Tft+0.01))
       #D = ad*D-bd*(yt-yold);  
       u = (0.01*kiit*xcont+kpit*(ref[t]-yt))
       u = torch.clamp(u,-3.3,3.3)
    uinit[iters,t] = u.clone().detach().numpy()
    x = torch.matmul(systA.float(),x)+systB.float()*u;
    cost = cost+(reft[t]-yt)**2
  costinit[iters] = cost.detach().numpy()

  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0]],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  D  = torch.tensor([0.0],requires_grad=False)
  #torch.clamp(Tft,0.1,0.1)
  #ad = torch.div(Tft,(Tft+0.01))
  #bd = torch.div(kdst,(Tft+0.01))

  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t];
    ysgradient[iters,t] = yt.clone().detach().numpy()
    #print(yt)
    #error = torch.tensor(reft[t]-yt,requires_grad=False)
    saterr = u-ucmd
    xcont = xcont+kist*(reft[t]-yt)+backst*saterr.detach()
    if(t>0):
       #deriv = torch.tensor(yt-yold,requires_grad=False) 
       #D = ad*D-bd*(yt-yold);  
       ucmd = (0.01*xcont+kpst*(reft[t]-yt))
    u = torch.clamp(ucmd,-3.3,3.3)
    usgradient[iters,t] = u.clone().detach().numpy()
    x = torch.matmul(systA.float(),x)+systB.float()*u;
    cost = cost+(reft[t]-yt)**2
  costsgradient[iters] = cost.detach().numpy()

# %%
print("Dgradient-dynamic",costdgradient)
print("Dgradient-static",costsgradient)
print("Initial",costinit)
# Out:
# Dgradient-dynamic [258.18948364  66.61434937  40.29442596  55.15759659 134.73562622
#   39.63996124 110.29890442 209.74151611  39.61578369  39.23443222]
# Dgradient-static [257.56878662  66.99555206  40.40116119  55.61064529 134.81140137
#   39.84031296 110.81016541 209.40699768  39.99654388  39.66372681]
# Initial [854.32415771 105.38550568  61.30298615  86.42558289 224.30368042
#   60.63348389 180.70606995 458.47650146  61.09593964  60.63313293]

# %%
plt.figure()
plt.plot(0.01*np.arange(0,T),refs[20,:])
    xcont = 0
    x =[[0.0],[0.0]]  
    u = 0.0
    ucmd = 0.0
    
    ucmdvals = np.zeros((T,1))
    uvals =  np.zeros((T,1))
    PIDinputs = np.zeros((T,3))
    PIDstates = np.zeros((T,4))
    yt = 0.0
    D  = 0.0
    
    ad = Tf/(Tf+0.01)
    adt = torch.tensor(ad,requires_grad=False)
    adt = adt.float()
    noise = 0.01*np.random.randn(T,1)
    sigma = 0.5
    for t in range(T):
      yold = yt
      yt = np.clip(np.dot(sysC,x)+noise[t],-30.0,30.0)
      err = ref[t]-yt[0]
      xcont = xcont+err
      if(t>0):
         inp = np.array([err,u,ucmd])
         ninput = torch.tensor(inp,requires_grad=False)
         PIDinputs[t,:] = inp   
         kpdt,kidt,kddt = PIDpg(ninput.float())
         kpt = kpit+kpdt
         kit = kiit+kidt
         kdt = kdit+kddt
         kpn = kpt.detach().numpy()
         kin = kit.detach().numpy()
         kdn = kdt.detach().numpy()
         #print(kpn,kin,kdn)   
         bd = kdn[0]/(Tf+0.01)
         PIDstates[t,:] = [err,xcont,D,yt[0]-yold[0]] 
         D = ad*D-bd*(yt[0]-yold[0])
         ucmd = (0.01*kin[0]*xcont+kpn[0]*err+D)
      if(episodes==0):
        u = ucmd
      else:  
        u = ucmd+sigma*np.random.randn()
      uvals[t] = u
      u = np.clip(u,-35.0,35.0)
      x = np.dot(sysA,x)+sysB*u;
      cost[episodes,t] = (ref[t]-yt)**2
    #rcosts = np.flip(np.cumsum(np.flip(cost[episodes,:],[0]),0),[0])
    totalcost[episodes] = np.sum(cost[episodes,:])
    rcosts = np.repeat(totalcost[episodes],T,0)
    #if(episodes==0):
    #  print(updates,episodes,rcosts[0])
    rcostsepisode[episodes*T:(episodes+1)*T,0] = rcosts
    uvalsepisode[episodes*T:(episodes+1)*T,:] = uvals
    PIDinputsepisode[episodes*T:(episodes+1)*T,:] = PIDinputs
    PIDstatesepisode[episodes*T:(episodes+1)*T,:] = PIDstates
  print(updates,episodes,np.min(totalcost))
  PIDinputstorch = torch.tensor(PIDinputsepisode).float()
  PIDstatestorch = torch.tensor(PIDstatesepisode).float()
  uvalstorch = torch.tensor(uvalsepisode).float()
  rcoststorch = torch.tensor(rcostsepisode).float()
  costmean = torch.tensor(np.mean(totalcost)).float()
    
  kptvals,kitvals,kdtvals = PIDpg(PIDinputstorch)
  bdtvals = (kd+kdtvals)/(Tft+0.01)  
  Dvals = adt*PIDstatestorch[:,2]-bdtvals*PIDstatestorch[:,3]  
  ucmdvals = 0.01*torch.mul((ki+kitvals),PIDstatestorch[:,1])+torch.mul((kp+kptvals),PIDstatestorch[:,0])+Dvals
  
  updatecost = torch.mean(torch.mul((uvalstorch-ucmdvals)**2,rcoststorch-costmean))/(2*sigma)
  optimizer.zero_grad()
  updatecost.backward()
  optimizer.step()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-2b00b39fa3d9> in <module>
#      38       xcont = xcont+err
#      39       if(t>0):
# ---> 40          inp = np.array([err,u,ucmd])
#      41          ninput = torch.tensor(inp,requires_grad=False)
#      42          PIDinputs[t,:] = inp
#
# KeyboardInterrupt:
