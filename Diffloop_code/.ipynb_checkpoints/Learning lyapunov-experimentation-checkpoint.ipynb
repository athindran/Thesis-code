# %%
import numpy as np
import scipy
import torch
from matplotlib import pyplot as plt
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable 
import control
from control import matlab
from matplotlib import cm

np.random.seed(0)
if torch.cuda.is_available():  
  dev = "cuda:0" 
else:  
  dev = "cpu"  
device = torch.device(dev)

# %%
# Define the true system model
mtrue = 0.15
btrue = 0.1
ltrue = 0.5
g = 9.81

def pendulumt(x,u):
  noise = 0
  f = []
  for r in range(0,len(x)):
    f.append([x[r][1], -(btrue/(mtrue*ltrue**2))*x[r][1]+(g/ltrue)*torch.sin(x[r][0])])
  ft = torch.tensor(f,requires_grad=False)
  return ft

def pendulum(x,u):
  if u[0]>0.8:
    u[0]=0.8
  elif u[0]<-0.8:
    u[0]=-0.8
    
  return np.array([x[1], -(btrue/(mtrue*ltrue**2))*x[1]+(g/ltrue)*np.sin(x[0])+u[0]/(mtrue*ltrue**2)])

# %%
A = np.array([[0,1],[(g/ltrue),-1*(btrue/(mtrue*ltrue**2))]])
B = np.array([[0],[1/(mtrue*ltrue**2)]])
C = np.eye(2)
D = 0

Q = np.diag([1,0.1])
R = 0.1
Dlqr = control.lqr(A,B,Q,R)
Klqr = np.array(Dlqr[0])
Slqr = np.array(Dlqr[1])
print(Klqr)
print(Slqr)
# Out:
# [[3.98249114 1.04397851]]
# [[0.37877771 0.01493434]
#  [0.01493434 0.00391492]]

# %%
nx = 100
ny = 100
x = np.linspace(-3.14, 3.14, nx)
y = np.linspace(-6, 6, ny)
xv, yv = np.meshgrid(x, y)
xvnext = np.array(xv)
yvnext = np.array(yv)
verifies = np.zeros((nx,ny),dtype=np.bool)
V = np.zeros((nx,ny))
Vdot = np.zeros((nx,ny))

#plt.figure()
for i in range(nx):
    for j in range(ny):
      xvec = np.array([[xv[i,j]],[yv[i,j]]])
      xvecdot = np.array(pendulum(xvec,-np.dot(Klqr,xvec)))
      xvnext[i,j] = xvecdot[0]
      yvnext[i,j] = xvecdot[1]
      V[i,j] = np.dot(np.dot(xvec.T,Slqr),xvec)
      Vdot[i,j] = np.dot(np.dot(xvecdot.T,Slqr),xvec)  
      if V[i,j]>=0 and Vdot[i,j]<0:
        verifies[i,j] = True
fig = plt.figure()
plt.scatter(xv[verifies],yv[verifies],color='w')
plt.scatter(xv[np.logical_not(verifies)],yv[np.logical_not(verifies)],color='k')
contours = plt.contour(xv,yv,V,[0.3,1,5,10,20,100])
plt.clabel(contours, inline=1, fontsize=10)
plt.streamplot(xv,yv,xvnext,yvnext, color=('gray'), linewidth=0.5,
                  density=0.5, arrowstyle='-|>', arrowsize=1.5)
plt.xlabel('Angle (rad)')
plt.ylabel('Angular velocity (rad/s)')
plt.show()

# %%
T = 1000
sols = np.zeros((T,3))
x = np.array([2,5]);


for t in np.arange(0,T):
    sols[t,0:2] = x;
    u = -np.dot(Klqr,x)
    #print(u)
    xdot = pendulum(x,u)
    
    lyaph = np.dot(Slqr,x)
    sols[t,2] = np.dot(x,lyaph.ravel())
    x = x+0.01*xdot;
    
plt.figure()
plt.plot(0.01*np.arange(0,T),sols[:,0])
plt.title("LQR State 0")

plt.figure()
plt.plot(0.01*np.arange(0,T),sols[:,1])
plt.title("LQR State 1")
print(sols[-1,0])
plt.figure()
plt.plot(0.01*np.arange(0,T),sols[:,2])
plt.title("lyapunov function")
print(sols[-1,2])
# Out:
# 1.4468515790420604e-12
# 6.77104552787792e-25

# %%
class lyapNetquad(torch.nn.Module):
  def __init__(self):
    super(lyapNetquad, self).__init__()
    torch.manual_seed(2)
    self.lyaphalf1 = torch.nn.Linear(2,10,bias=False)
  
  def forward(self,x):
    sigmoid = torch.nn.Tanh()    
    lyaph = self.lyaphalf1(x)
    return lyaph

class lyapNetmed(torch.nn.Module):
  def __init__(self):
    super(lyapNetmed, self).__init__()
    torch.manual_seed(2)
    self.lyaphalf1 = torch.nn.Linear(2,5,bias=False)
    self.lyaphalf2 = torch.nn.Linear(5,10,bias=False)
    #self.ls = torch.tensor([1000.0], requires_grad=True)
  
  def forward(self,x):
    sigmoid = torch.nn.Tanh()    
    lyaph1 = sigmoid(self.lyaphalf1(x))
    lyaph = self.lyaphalf2(lyaph1)
    return lyaph

class lyapNetlarge(torch.nn.Module):
  def __init__(self):
    super(lyapNetlarge, self).__init__()
    torch.manual_seed(2)
    self.lyaphalf1 = torch.nn.Linear(2,32,bias=False)
    self.lyaphalf2 = torch.nn.Linear(32,64,bias=False)
    self.lyaphalf3 = torch.nn.Linear(64,10,bias=False)
  
  def forward(self,x):
    sigmoid = torch.nn.Tanh()    
    lyaph1 = sigmoid(self.lyaphalf1(x))
    lyaph2 = sigmoid(self.lyaphalf2(lyaph1))
    lyaph = self.lyaphalf3(lyaph2)
    return lyaph

# %%
    ## takes in a module and applies the specified weight initialization
    def weights_init_normal(m):
        '''Takes in a module and initializes all linear layers with weight
           values taken from a normal distribution.'''

        classname = m.__class__.__name__
        # for every Linear layer in a model
        if classname.find('Linear') != -1:
            y = m.in_features
        # m.weight.data shoud be taken from a normal distribution
            m.weight.data.normal_(0.0,1/np.sqrt(y))

# %%
def lyaptraining(dataset,Kcontrol,ls,lyaph_net,max_iters,Q,R,batch_size,learning_rate):
  iters = 0
  costs = []
  torch.manual_seed(2)
  
  optimizer = torch.optim.Adam((lyaph_net.parameters()), lr=learning_rate, weight_decay=0.3)
  roalearn = torch.optim.Adam([ls],lr=learning_rate)
  while iters<max_iters:
    indices = np.random.randint(low=0, high=dataset.shape[0], size=batch_size)
    x = dataset[indices,:].clone().detach().requires_grad_(False)
    x.to(device)
    lyaph = lyaph_net(x.cuda())
    u = Kcontrol(x.cuda())
    u = torch.clamp(u,-0.8,0.8)
    xdot = pendulumt(x,u)
    xdotu = torch.zeros((batch_size,2))
    xdotu[:,1] = u[:,0]/(mtrue*ltrue**2)
    xdot = xdot+xdotu;
    xnext = x+0.01*xdot;
    xnext.to(device)
    lyaphnext = lyaph_net(xnext.cuda())
    #print(lyaph.shape)
    lyaph = torch.reshape(lyaph,(100,2,5))
    xs = torch.unsqueeze(x.cuda(),1)
    lyapfunch = torch.squeeze(torch.matmul(xs,lyaph),1)
    lyapfunc = torch.sum(lyapfunch**2,dim=1)+0.1*torch.sum(x.cuda()**2,dim=1)
    
    xsnext = torch.unsqueeze(xnext.cuda(),1)
    #print(xsnext.shape)
    lyaphnext = torch.reshape(lyaphnext,(100,2,5))
    lyapfuncnh = torch.squeeze(torch.matmul(xsnext,lyaphnext),1)
    lyapfuncnext = torch.sum(lyapfuncnh**2,dim=1)+0.1*torch.sum(xnext.cuda()**2,dim=1)
    lyapder = lyapfuncnext-lyapfunc
    lqrcost = torch.sum(torch.mul(torch.mm(x.cuda(),Q.cuda()),x.cuda()),dim=1)+torch.sum(R.cuda()*torch.mul(u,u),dim=1)
    
    cost =  (torch.div(0.5*(torch.sign(ls.cuda()-lyapfunc)+1)*(F.relu(lyapder+0.9*lqrcost+1)),0.001*(lyapfunc+0.1))).mean()\
            +0.1*(torch.sign(lyapder)*(ls.cuda()-lyapfunc)).mean()

    if iters%1000==0:
      print(iters,"Loss=",cost.item(),"Lyapunovfunc",lyapfunc.mean().data,"Lyapunov deriv",lyapder.mean().data,"LQR cost",lqrcost.mean().data,"ls",ls)
    costs.append(cost.item())
    optimizer.zero_grad()
    roalearn.zero_grad()
    cost.backward()
    optimizer.step()
    roalearn.step()
    iters = iters+1
  return costs,Kcontrol,lyaph_net,ls

def controltraining(dataset,Kcontrol,ls,lyaph_net,max_iters,Q,R,batch_size,learning_rate):
  iters = 0
  costs = []
  torch.manual_seed(2)
  
  optimizer = torch.optim.Adam((Kcontrol.parameters()), lr=learning_rate)
  roalearn = torch.optim.Adam([ls],lr=learning_rate)
  while iters<max_iters:
    indices = np.random.randint(low=0, high=dataset.shape[0], size=batch_size)
    x = dataset[indices,:].clone().detach().requires_grad_(False)
    x.to(device)
    lyaph = lyaph_net(x.cuda())
    u = Kcontrol(x.cuda())
    u = torch.clamp(u,-0.8,0.8)
    xdot = pendulumt(x,u)
    xdotu = torch.zeros((batch_size,2))
    xdotu[:,1] = u[:,0]/(mtrue*ltrue**2)
    xdot = xdot+xdotu;
    xnext = x+0.01*xdot;
    xnext.to(device)
    lyaphnext = lyaph_net(xnext.cuda())
    
    lyaph = torch.reshape(lyaph,(100,2,5))
    xs = torch.unsqueeze(x.cuda(),1)
    lyapfunch = torch.squeeze(torch.matmul(xs,lyaph),1)
    lyapfunc = torch.sum(lyapfunch**2,dim=1)+0.1*torch.sum(x.cuda()**2,dim=1)
    
    xsnext = torch.unsqueeze(xnext.cuda(),1)
    lyaphnext = torch.reshape(lyaphnext,(100,2,5))
    lyapfuncnh = torch.squeeze(torch.matmul(xsnext,lyaphnext),1)
    lyapfuncnext = torch.sum(lyapfuncnh**2,dim=1)+0.1*torch.sum(xnext.cuda()**2,dim=1)
    lyapder = lyapfuncnext-lyapfunc
    lqrcost = torch.sum(torch.mul(torch.mm(x.cuda(),Q.cuda()),x.cuda()),dim=1)+torch.sum(R.cuda()*torch.mul(u,u),dim=1)
    
    cost =  (torch.div(0.5*(torch.sign(ls.cuda()-lyapfunc)+1)*(F.relu(lyapder+0.9*lqrcost+1)),0.001*(lyapfunc+0.1))).mean()\
            +0.1*(torch.sign(lyapder)*(ls.cuda()-lyapfunc)).mean()

    if iters%1000==0:
      print(iters,"Loss=",cost.item(),"Lyapunovfunc",lyapfunc.mean().data,"Lyapunov deriv",lyapder.mean().data,"LQR cost",lqrcost.mean().data,"ls",ls)
    costs.append(cost.item())
    optimizer.zero_grad()
    roalearn.zero_grad()
    cost.backward()
    optimizer.step()
    roalearn.step()
    iters = iters+1
  return costs,Kcontrol,lyaph_net,ls

# %%
max_iters = 10000
learning_rate = 0.01

torch.manual_seed(2)


#print(dataset)
batch_size = 100
#lyapnetq = lyapNetquad()
Q = torch.tensor([[1,0],[0,0.1]], dtype=torch.float64)
R = torch.tensor([0.1], dtype=torch.float64)

lyaph_net = lyapNetlarge()
#lyaph_net.apply(weights_init_normal)
Kcontrol = torch.nn.Linear(2,1,bias=False)
Kcontrol.weight = torch.nn.Parameter(torch.tensor(([[-3.98, -1.04]])))
#lyaph = torch.randn(2,7,requires_grad=True)
ls = torch.tensor([10.0], requires_grad=True)
lyaph_net.to(device)
Kcontrol.to(device)
Q.to(device)
R.to(device)
ls.to(device)
dataset = torch.rand([10000,2],requires_grad=False)
dataset[:,0] = 6.3*dataset[:,0]-3.15;
dataset[:,1] = 6.3*dataset[:,1]-3.15;
dataset.to(device)
iters = 0
while iters<2:
  costs,Kcontrol,lyaph_net,ls = lyaptraining(dataset,Kcontrol,ls,lyaph_net,max_iters,Q.float(),R.float(),batch_size,learning_rate)
  costs,Kcontrol,lyaph_net,ls = controltraining(dataset,Kcontrol,ls,lyaph_net,max_iters,Q.float(),R.float(),batch_size,learning_rate)
  iters = iters+1

#costs,Kcontrol,lyaph_net,ls = lyaptraining(dataset,Kcontrol,ls,lyaph_net,max_iters,Q.float(),R.float(),batch_size,learning_rate)
# Out:
# 0 Loss= 4593.1142578125 Lyapunovfunc tensor(1.2359, device='cuda:0') Lyapunov deriv tensor(-0.0815, device='cuda:0') LQR cost tensor(4.0483, device='cuda:0') ls tensor([10.], requires_grad=True)
# 1000 Loss= 5.898148536682129 Lyapunovfunc tensor(111.8277, device='cuda:0') Lyapunov deriv tensor(-3.4745, device='cuda:0') LQR cost tensor(3.4063, device='cuda:0') ls tensor([19.7643], requires_grad=True)
# 2000 Loss= 5.091241359710693 Lyapunovfunc tensor(73.7646, device='cuda:0') Lyapunov deriv tensor(-1.8338, device='cuda:0') LQR cost tensor(3.7804, device='cuda:0') ls tensor([26.0933], requires_grad=True)
# 3000 Loss= 19.589637756347656 Lyapunovfunc tensor(76.1174, device='cuda:0') Lyapunov deriv tensor(-1.4309, device='cuda:0') LQR cost tensor(3.1253, device='cuda:0') ls tensor([33.6225], requires_grad=True)
# 4000 Loss= 6.5070109367370605 Lyapunovfunc tensor(69.2720, device='cuda:0') Lyapunov deriv tensor(-0.3385, device='cuda:0') LQR cost tensor(3.5743, device='cuda:0') ls tensor([42.0401], requires_grad=True)
# 5000 Loss= 14.96078109741211 Lyapunovfunc tensor(82.0684, device='cuda:0') Lyapunov deriv tensor(-1.9697, device='cuda:0') LQR cost tensor(3.7548, device='cuda:0') ls tensor([50.4664], requires_grad=True)
# 6000 Loss= 4.977093696594238 Lyapunovfunc tensor(99.9133, device='cuda:0') Lyapunov deriv tensor(-1.5716, device='cuda:0') LQR cost tensor(3.7946, device='cuda:0') ls tensor([59.5965], requires_grad=True)
# 7000 Loss= 14.399852752685547 Lyapunovfunc tensor(267.2067, device='cuda:0') Lyapunov deriv tensor(-4.3841, device='cuda:0') LQR cost tensor(3.4222, device='cuda:0') ls tensor([69.0512], requires_grad=True)
# 8000 Loss= 13.796276092529297 Lyapunovfunc tensor(292.2773, device='cuda:0') Lyapunov deriv tensor(-4.4612, device='cuda:0') LQR cost tensor(3.5836, device='cuda:0') ls tensor([78.5692], requires_grad=True)
# 9000 Loss= 2.605041980743408 Lyapunovfunc tensor(95.4252, device='cuda:0') Lyapunov deriv tensor(-2.6466, device='cuda:0') LQR cost tensor(4.0543, device='cuda:0') ls tensor([87.8182], requires_grad=True)
# 0 Loss= 2.056628704071045 Lyapunovfunc tensor(132.5633, device='cuda:0') Lyapunov deriv tensor(-1.5408, device='cuda:0') LQR cost tensor(3.7633, device='cuda:0') ls tensor([96.8971], requires_grad=True)
# 1000 Loss= 2.1371963024139404 Lyapunovfunc tensor(123.7311, device='cuda:0') Lyapunov deriv tensor(-2.5324, device='cuda:0') LQR cost tensor(3.2720, device='cuda:0') ls tensor([106.9133], requires_grad=True)
# 2000 Loss= 5.332258224487305 Lyapunovfunc tensor(139.9138, device='cuda:0') Lyapunov deriv tensor(-1.7543, device='cuda:0') LQR cost tensor(3.8590, device='cuda:0') ls tensor([116.8558], requires_grad=True)
# 3000 Loss= 2.2143380641937256 Lyapunovfunc tensor(134.3625, device='cuda:0') Lyapunov deriv tensor(-2.1826, device='cuda:0') LQR cost tensor(3.8287, device='cuda:0') ls tensor([126.8240], requires_grad=True)
# 4000 Loss= 14.486082077026367 Lyapunovfunc tensor(122.7985, device='cuda:0') Lyapunov deriv tensor(-2.4542, device='cuda:0') LQR cost tensor(3.0136, device='cuda:0') ls tensor([136.7829], requires_grad=True)
# 5000 Loss= 31.236127853393555 Lyapunovfunc tensor(120.6681, device='cuda:0') Lyapunov deriv tensor(-2.9188, device='cuda:0') LQR cost tensor(3.0216, device='cuda:0') ls tensor([146.6972], requires_grad=True)
# 6000 Loss= 11.684743881225586 Lyapunovfunc tensor(136.8406, device='cuda:0') Lyapunov deriv tensor(-2.0258, device='cuda:0') LQR cost tensor(3.8142, device='cuda:0') ls tensor([156.6929], requires_grad=True)
# 7000 Loss= 4.887950897216797 Lyapunovfunc tensor(143.6411, device='cuda:0') Lyapunov deriv tensor(-2.1606, device='cuda:0') LQR cost tensor(3.9402, device='cuda:0') ls tensor([166.6488], requires_grad=True)
# 8000 Loss= 18.70498275756836 Lyapunovfunc tensor(140.7760, device='cuda:0') Lyapunov deriv tensor(-1.9648, device='cuda:0') LQR cost tensor(3.9702, device='cuda:0') ls tensor([176.6123], requires_grad=True)
# 9000 Loss= 21.83603858947754 Lyapunovfunc tensor(130.1615, device='cuda:0') Lyapunov deriv tensor(-2.3256, device='cuda:0') LQR cost tensor(3.6176, device='cuda:0') ls tensor([186.5660], requires_grad=True)
# 0 Loss= 7.106201648712158 Lyapunovfunc tensor(128.7258, device='cuda:0') Lyapunov deriv tensor(-2.5388, device='cuda:0') LQR cost tensor(3.3810, device='cuda:0') ls tensor([196.4868], requires_grad=True)
# 1000 Loss= 101.7557373046875 Lyapunovfunc tensor(164.1645, device='cuda:0') Lyapunov deriv tensor(-3.2046, device='cuda:0') LQR cost tensor(4.0175, device='cuda:0') ls tensor([206.3332], requires_grad=True)
# 2000 Loss= 15.962778091430664 Lyapunovfunc tensor(162.8750, device='cuda:0') Lyapunov deriv tensor(-3.3980, device='cuda:0') LQR cost tensor(3.2735, device='cuda:0') ls tensor([216.2484], requires_grad=True)
# 3000 Loss= -0.17809009552001953 Lyapunovfunc tensor(156.3604, device='cuda:0') Lyapunov deriv tensor(-3.8354, device='cuda:0') LQR cost tensor(3.0738, device='cuda:0') ls tensor([226.4434], requires_grad=True)
# 4000 Loss= -2.507375717163086 Lyapunovfunc tensor(150.1698, device='cuda:0') Lyapunov deriv tensor(-2.9680, device='cuda:0') LQR cost tensor(3.3835, device='cuda:0') ls tensor([236.5871], requires_grad=True)
# 5000 Loss= 100.58655548095703 Lyapunovfunc tensor(151.9676, device='cuda:0') Lyapunov deriv tensor(-2.6233, device='cuda:0') LQR cost tensor(3.8011, device='cuda:0') ls tensor([246.8069], requires_grad=True)
# 6000 Loss= -0.5010261535644531 Lyapunovfunc tensor(167.3809, device='cuda:0') Lyapunov deriv tensor(-4.8790, device='cuda:0') LQR cost tensor(3.6377, device='cuda:0') ls tensor([257.1495], requires_grad=True)
# 7000 Loss= -2.498715400695801 Lyapunovfunc tensor(149.7387, device='cuda:0') Lyapunov deriv tensor(-4.3790, device='cuda:0') LQR cost tensor(3.3214, device='cuda:0') ls tensor([267.5007], requires_grad=True)
# 8000 Loss= 14.90066909790039 Lyapunovfunc tensor(159.3058, device='cuda:0') Lyapunov deriv tensor(-3.6178, device='cuda:0') LQR cost tensor(3.5438, device='cuda:0') ls tensor([277.7511], requires_grad=True)
# 9000 Loss= -4.566654205322266 Lyapunovfunc tensor(158.9288, device='cuda:0') Lyapunov deriv tensor(-4.1444, device='cuda:0') LQR cost tensor(3.7547, device='cuda:0') ls tensor([287.8818], requires_grad=True)
# 0 Loss= -3.370579719543457 Lyapunovfunc tensor(149.8512, device='cuda:0') Lyapunov deriv tensor(-5.5056, device='cuda:0') LQR cost tensor(3.4243, device='cuda:0') ls tensor([297.9418], requires_grad=True)
# 1000 Loss= -6.1748199462890625 Lyapunovfunc tensor(152.9978, device='cuda:0') Lyapunov deriv tensor(-5.4869, device='cuda:0') LQR cost tensor(3.3268, device='cuda:0') ls tensor([307.9359], requires_grad=True)
# 2000 Loss= -4.370260238647461 Lyapunovfunc tensor(173.2325, device='cuda:0') Lyapunov deriv tensor(-3.7408, device='cuda:0') LQR cost tensor(3.7790, device='cuda:0') ls tensor([317.9365], requires_grad=True)
# 3000 Loss= -3.349349021911621 Lyapunovfunc tensor(156.4035, device='cuda:0') Lyapunov deriv tensor(-3.9249, device='cuda:0') LQR cost tensor(3.3707, device='cuda:0') ls tensor([327.9204], requires_grad=True)
# 4000 Loss= -9.776329040527344 Lyapunovfunc tensor(169.5672, device='cuda:0') Lyapunov deriv tensor(-5.1345, device='cuda:0') LQR cost tensor(3.5565, device='cuda:0') ls tensor([337.9175], requires_grad=True)
# 5000 Loss= -6.945528030395508 Lyapunovfunc tensor(177.0748, device='cuda:0') Lyapunov deriv tensor(-5.5586, device='cuda:0') LQR cost tensor(4.0953, device='cuda:0') ls tensor([347.9168], requires_grad=True)
# 6000 Loss= 4.963981628417969 Lyapunovfunc tensor(145.1008, device='cuda:0') Lyapunov deriv tensor(-5.3426, device='cuda:0') LQR cost tensor(3.0238, device='cuda:0') ls tensor([357.9264], requires_grad=True)
# 7000 Loss= -5.965390205383301 Lyapunovfunc tensor(162.3093, device='cuda:0') Lyapunov deriv tensor(-3.5925, device='cuda:0') LQR cost tensor(3.8794, device='cuda:0') ls tensor([367.9267], requires_grad=True)
# 8000 Loss= -13.438820838928223 Lyapunovfunc tensor(148.0832, device='cuda:0') Lyapunov deriv tensor(-5.4898, device='cuda:0') LQR cost tensor(3.3749, device='cuda:0') ls tensor([377.9229], requires_grad=True)
# 9000 Loss= -10.711624145507812 Lyapunovfunc tensor(174.4656, device='cuda:0') Lyapunov deriv tensor(-5.2881, device='cuda:0') LQR cost tensor(4.1345, device='cuda:0') ls tensor([387.9194], requires_grad=True)

# %%
print(lyaph_net)
print(ls)
print(Kcontrol.weight)
#lyapnp = lyaph.detach().numpy()
#Slearn = np.dot(lyapnp,lyapnp.T)
Klearn = Kcontrol.cpu().weight.detach().numpy().ravel()
print(Klearn)
# Out:
# lyapNetlarge(
#   (lyaphalf1): Linear(in_features=2, out_features=32, bias=False)
#   (lyaphalf2): Linear(in_features=32, out_features=64, bias=False)
#   (lyaphalf3): Linear(in_features=64, out_features=10, bias=False)
# )
# tensor([397.9197], requires_grad=True)
# Parameter containing:
# tensor([[-4.1544, -3.0214]], device='cuda:0', requires_grad=True)
# [-4.154416 -3.02143 ]

# %%
T = 1500
sols = np.zeros((T,3))
x = np.array([2,5]);
print(x)

for t in np.arange(0,T):
    sols[t,0:2] = x;
    u = [np.dot(Klearn,x)]
    xdot = pendulum(x,u)
    
    xt = torch.tensor(x).float()
    xt.to(device)
    lyah = lyaph_net(xt.cuda())
    lyah = torch.reshape(lyah,(2,5))
    lya = torch.sum(torch.matmul(xt.cuda(),lyah)**2)+0.1*torch.sum(xt.cuda()**2)
    sols[t,2] = lya.cpu().detach().numpy()
    x = x+0.01*xdot;
    
plt.figure()
plt.plot(0.01*np.arange(0,T),sols[:,0])
plt.title("LL State 0")

plt.figure()
plt.plot(0.01*np.arange(0,T),sols[:,1])
plt.title("LL State 1")
print(sols[-1,0])
plt.figure()
plt.plot(0.01*np.arange(0,T),sols[:,2])
plt.title("lyapunov function")
print(sols[-1,2])
# Out:
# [2 5]
# 2.6021499389790265e-07
# 1.5114369513445115e-14

# %%
nx = 500
ny = 500
x = np.linspace(-3.14, 3.14, nx)
y = np.linspace(-6, 6, ny)
xv, yv = np.meshgrid(x, y)
xvnext = np.array(xv)
yvnext = np.array(yv)
verifies = np.zeros((nx,ny),dtype=np.bool)
V = np.zeros((nx,ny))
Vdot = np.zeros((nx,ny))

#plt.figure()
for i in range(nx):
    for j in range(ny):
      xvec = np.array([[xv[i,j]],[yv[i,j]]])
      xvecdot = np.array(pendulum(xvec,[np.dot(Klearn,xvec)]))
      xvnext[i,j] = xvecdot[0]
      yvnext[i,j] = xvecdot[1]
        
      xt = torch.tensor([xv[i,j],yv[i,j]]).float()
      xt.to(device)
      lyah = lyaph_net(xt.cuda())
      lyah = torch.reshape(lyah,(2,5))
      lya = torch.sum(torch.matmul(xt.cuda(),lyah)**2)+0.1*torch.sum(xt.cuda()**2)
    
      xt = torch.tensor([xv[i,j]+0.01*xvnext[i,j],yv[i,j]+0.01*yvnext[i,j]]).float()
      xt.to(device)
      lyah = lyaph_net(xt.cuda())
      lyah = torch.reshape(lyah,(2,5))
      lyan = torch.sum(torch.matmul(xt.cuda(),lyah)**2)+0.1*torch.sum(xt.cuda()**2)
      
      V[i,j] = lya.cpu().detach().numpy()
      Vnext = lyan.cpu().detach().numpy()
      Vdot[i,j] = Vnext-V[i,j]
      if V[i,j]>=0 and Vdot[i,j]<0:
        verifies[i,j] = True
fig = plt.figure()
plt.scatter(xv[verifies],yv[verifies],color='w')
plt.scatter(xv[np.logical_not(verifies)],yv[np.logical_not(verifies)],color='k')
contours = plt.contour(xv,yv,V,[10,100,300,1000])
plt.clabel(contours, inline=1, fontsize=10)
plt.streamplot(xv,yv,xvnext,yvnext, color=('gray'), linewidth=0.5,
                  density=0.5, arrowstyle='-|>', arrowsize=1.5)
plt.xlabel('Angle (rad)')
plt.ylabel('Angular velocity (rad/s)')
plt.show()
