# %%
import numpy as np
import scipy
import torch
from matplotlib import pyplot as plt
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable 
import control
from control import matlab
from matplotlib import cm

np.random.seed(0)
dev = "cpu"  
device = torch.device(dev)

# %%
sysA = np.array([[0.9871,-0.0056,-0.0037,-0.0015],[0.0099,1.0000,-0.00,-0.00],[0.00,0.0025,1.0,0.0],[0.00,0.00,0.0012,1.00]])
#sysA = 0.99
sysB = np.array([[0.0397],[0.0002],[0.0],[0.0]])
sysC = np.array([0,0.25,0.8,1.2])
sysD = 0
print(np.linalg.eig(sysA))
kp = 20.0
ki = 8.0
kd = 10.0
Tf = 0.01
# Out:
# (array([0.99401227, 0.99647552, 0.99743533, 0.99917689]), array([[-0.48625422,  0.27399793,  0.17365955, -0.01522059],
#        [ 0.80396299, -0.76963891, -0.67035056,  0.18306646],
#        [-0.33567078,  0.54592321,  0.65344659, -0.55602072],
#        [ 0.06727168, -0.18587344, -0.30574506,  0.81061456]]))

# %%
T = 4000
np.random.seed(0)
refs = np.zeros((30,T))

randval = 0

for i in range(30):
  refs[i,0:300] = 0
  randval = 8.0*np.random.rand()-4.0
  print(i,randval)  
  if randval>0 and randval<1:
    randval = 1
  if randval<0 and randval>-1:
    randval = -1
  refs[i,300:] = randval
# Out:
# 0 0.390508031418598
# 1 1.7215149309793558
# 2 0.822107008573151
# 3 0.3590654639751749
# 4 -0.6107616052887623
# 5 1.167152904533249
# 6 -0.4993023098984599
# 7 3.134184006256638
# 8 3.7093020840082342
# 9 -0.9324678493937784
# 10 2.3338003046613167
# 11 0.23115935802323584
# 12 0.5443564887514585
# 13 3.4047731063412883
# 14 -3.4317115344169045
# 15 -3.3029656023876743
# 16 -3.8382528204773942
# 17 2.660958764383504
# 18 2.225254007598804
# 19 2.9600971859745533
# 20 3.828946737862112
# 21 2.393268513733789
# 22 -0.30816510197654523
# 23 2.2442334102916437
# 24 -3.0538045930485342
# 25 1.1193681706201906
# 26 -2.8531737007276288
# 27 3.557351336396671
# 28 0.1747865740005734
# 29 -0.6827044800758113

# %%
ref = refs[8,:]
ysat = np.zeros((T,))
uvalssat = np.zeros((T,))
xcont = 0
u = 0
D = 0
ad = Tf/(Tf+0.01)
bd = kd/(Tf+0.01)
noise = 0.01*np.random.randn(T,1)

x0 = np.zeros((4,1))
x = x0
for i in range(T):
   ysat[i] = np.dot(sysC,x)+np.dot(sysD,u)+noise[i]
   xcont = xcont+(ref[i]-ysat[i])
   if(i>0):
     D = ad*D-bd*(ysat[i]-ysat[i-1])  
     u = 0.01*ki*xcont+kp*(ref[i]-ysat[i])+D
   if(u>1):
     u=1
   elif(u<-1):
     u=-1
   uvalssat[i] = u;
   x = np.dot(sysA,x)+np.dot(sysB,u);

ynosat = np.zeros((T,))
uvalsnosat = np.zeros((T,))
xcont = 0;
u = 0;
x = x0
D = 0

for i in range(T):
   ynosat[i] = np.dot(sysC,x)+np.dot(sysD,u)+noise[i]
   xcont = xcont+(ref[i]-ynosat[i])
   if(i>0):
     D = ad*D-bd*(ynosat[i]-ynosat[i-1])  
     u = 0.01*ki*xcont+kp*(ref[i]-ynosat[i])+D 
   uvalsnosat[i] = u;
   x = np.dot(sysA,x)+np.dot(sysB,u);

# %%
plt.figure
plt.plot(0.01*np.arange(T),ynosat)
plt.plot(0.01*np.arange(T),ysat)
plt.plot(0.01*np.arange(T),ref)
plt.xlabel("Time (s)")
plt.ylabel("Output")
plt.legend(["No saturation","Saturation","Reference"])
plt.show()

plt.figure
plt.plot(0.01*np.arange(T),uvalsnosat)
plt.plot(0.01*np.arange(T),uvalssat)
plt.xlabel("Time (s)")
plt.ylabel("Input")
plt.legend(["No saturation","Saturation"])
plt.show()

# %%
class neuralPID(torch.nn.Module):
   def __init__(self):
    super(neuralPID, self).__init__()
    torch.manual_seed(2)
    self.kplayer1 = torch.nn.Linear(2,2)
    self.kplayer2 = torch.nn.Linear(2,1)
    self.kilayer1 = torch.nn.Linear(2,2)
    self.kilayer2 = torch.nn.Linear(2,1)
    self.kdlayer1 = torch.nn.Linear(2,2)
    self.kdlayer2 = torch.nn.Linear(2,1)
    self.backlayer1 = torch.nn.Linear(2,2)
    self.backlayer2 = torch.nn.Linear(2,1)
  
   def forward(self,x):
    sigmoid = torch.nn.Tanh()
    kp = self.kplayer2(sigmoid(self.kplayer1(x)))
    ki = self.kilayer2(sigmoid(self.kilayer1(x)))
    kd = self.kdlayer2(sigmoid(self.kdlayer1(x)))
    back = self.backlayer2(sigmoid(self.backlayer1(x)))
    #kd = torch.clamp(kd,0,400)
    #kp = torch.clamp(kp,0,400)
    #ki = torch.clamp(ki,0,400)
    return kp,ki,kd,back

# %%
Tft = torch.tensor(Tf,requires_grad=True)
kpit = torch.tensor(kp,requires_grad=False)
kiit = torch.tensor(ki,requires_grad=False)
kdit = torch.tensor(kd,requires_grad=False)
backit = torch.tensor(0.1,requires_grad=False)

systA = torch.tensor(sysA,requires_grad=False)
systB = torch.tensor(sysB,requires_grad=False)
systC = torch.tensor(sysC,requires_grad=False)
systD = torch.tensor(sysD,requires_grad=False)

# %%
costinit = np.zeros((30,))

yinit = np.zeros((30,T))
uinit = np.zeros((30,T))
Tft = torch.tensor(Tf,requires_grad=True)
kpit = torch.tensor(kp,requires_grad=False)
kiit = torch.tensor(ki,requires_grad=False)
kdit = torch.tensor(kd,requires_grad=False)

systA = torch.tensor(sysA,requires_grad=False)
systB = torch.tensor(sysB,requires_grad=False)
systC = torch.tensor(sysC,requires_grad=False)
systD = torch.tensor(sysD,requires_grad=False)

for iters in range(0,30):
  ref = refs[iters,:]
  reft = torch.tensor(ref)
  noise = 0.01*torch.randn(T,1)

  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0],[0.0],[0.0],[0.0]],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  D  = torch.tensor([0.0],requires_grad=False)
  #torch.clamp(Tft,0.1,0.1)
  ad = torch.div(Tft,(Tft+0.01))
  
  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t];
    yinit[iters,t] = yt.clone().detach().numpy()
    #print(yt)
    #error = torch.tensor(reft[t]-yt,requires_grad=False)
    err = ref[t]-yt
    xcont = xcont+err
    if(t>0):
       #print(t,kpt,kit,kdt)
       #break;
       bd = torch.div(kdit,(Tft+0.01))
       D = ad*D-bd*(yt-yold);  
       u = (0.01*kiit*xcont+kpit*(ref[t]-yt)+D)
       u = torch.clamp(u,-1.0,1.0)
    uinit[iters,t] = u.clone().detach().numpy()
    x = torch.matmul(systA.float(),x)+systB.float()*u;
    cost = cost+(reft[t]-yt)**2
  costinit[iters] = cost.detach().numpy()

# %%
print(costinit)
plt.figure()
plt.plot(refs[16,:])
plt.plot(yinit[16,:])
# Out:
# [ 117.34791565  552.22052002  125.98283386  132.85415649  131.94830322
#   196.40657043  116.51049805 2720.95825195 4671.16796875  130.48298645
#  1178.52062988  119.8629837   127.49869537 3571.86303711 3589.92333984
#  3275.38378906 4580.91455078 1811.52587891 1082.65527344 2354.24780273
#  4907.73339844 1266.484375    138.09474182 1078.42614746 2586.77539062
#   163.80754089 2202.73706055 4029.84472656  137.50967407  113.25339508]

# %%
# Initialize network
Tft = torch.tensor(Tf,requires_grad=True)
kpit = torch.tensor(kp,requires_grad=False)
kiit = torch.tensor(ki,requires_grad=False)
kdit = torch.tensor(kd,requires_grad=False)
backit = torch.tensor(0.1,requires_grad=False)

kpt = torch.tensor(kp,requires_grad=True)
kit = torch.tensor(ki,requires_grad=True)
kdt = torch.tensor(kd,requires_grad=True)
backt = torch.tensor(0.1,requires_grad=True)

systA = torch.tensor(sysA,requires_grad=False)
systB = torch.tensor(sysB,requires_grad=False)
systC = torch.tensor(sysC,requires_grad=False)
systD = torch.tensor(sysD,requires_grad=False)

PIDparams = neuralPID()
#optimizer = torch.optim.Adam((PIDparams.parameters()), lr=0.1)
#for iters in range(1000):
#   kpt,kit,kdt = PIDparams(torch.randn(3,))
#   print(kpt,kit,kdt)
#   loss = (kpt-kpit)**2+(kit-kiit)**2+(kdt-kdit)**2
#   optimizer.zero_grad()
#   loss.backward()
#   optimizer.step()    
   #print(iters,loss)

# %%
ysat = np.zeros((T,))
uvalssat = np.zeros((T,))

optimizer = torch.optim.Adam((PIDparams.parameters()), lr=0.1, weight_decay=0.1)

smooth = 0.9
closs = 0
dtlossvals = []

for episodes in range(701):
  #cepisode = np.random.randint(20)  
  cepisode = episodes%20  
  if(cepisode==0):  
    episodeorder = np.random.choice(20, 20, replace=False)
  ref = refs[episodeorder[cepisode],:]
  reft = torch.tensor(ref)  
  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0],[0.0],[0.0],[0.0]],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  ucmd = torch.tensor([0.0],requires_grad=True)
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  D  = torch.tensor([0.0],requires_grad=False)
  ad = torch.div(Tft,(Tft+0.01))
  noise = 0.01*torch.randn(T,1)
  kpt = kpt.clone().detach()
  kit = kit.clone().detach()
  kdt = kdt.clone().detach()
  backt = backt.clone().detach()

  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t]
    saterr = u-ucmd
    err = reft[t]-yt
    ninput = torch.cat((err.detach(),saterr.detach()),0)
    kpdt,kidt,kddt,backdt = PIDparams(ninput)
    kpt = smooth*kpt+(1-smooth)*(kpit+kpdt)
    kit = smooth*kit+(1-smooth)*(kiit+kidt)
    kdt = smooth*kdt+(1-smooth)*(kdit+kddt)
    backt = smooth*backt+(1-smooth)*(backit+backdt)
    xcont = xcont+kit*err+backt*saterr.detach()
    if(t>0):
      bd = torch.div(kdt,(Tft+0.01))
      D = ad*D-bd*(yt-yold);  
      ucmd = (0.01*xcont+kpt*(reft[t]-yt)+D)
      u = torch.clamp(ucmd,-1.0,1.0)
    x = torch.matmul(systA.float(),x)+systB.float()*u;
    cost = cost+(reft[t]-yt)**2
  closs = closs+cost   
  if(episodes%120<20):
    print(episodes,cost)
    
  if(episodes%20==19):    
    dtlossvals.append(closs.clone().detach().numpy()[0]/20)
    closs = 0  
    
  optimizer.zero_grad()
  cost.backward()
  optimizer.step()
# Out:
# 0 tensor([109.7581], grad_fn=<AddBackward0>)
# 1 tensor([94.6338], grad_fn=<AddBackward0>)
# 2 tensor([99.7452], grad_fn=<AddBackward0>)
# 3 tensor([134.6832], grad_fn=<AddBackward0>)
# 4 tensor([1421.5074], grad_fn=<AddBackward0>)
# 5 tensor([1295940.8750], grad_fn=<AddBackward0>)
# 6 tensor([2488.2422], grad_fn=<AddBackward0>)
# 7 tensor([357.4035], grad_fn=<AddBackward0>)
# 8 tensor([697.4027], grad_fn=<AddBackward0>)
# 9 tensor([1306988.5000], grad_fn=<AddBackward0>)
# 10 tensor([318.9325], grad_fn=<AddBackward0>)
# 11 tensor([816.5289], grad_fn=<AddBackward0>)
# 12 tensor([1656.2382], grad_fn=<AddBackward0>)
# 13 tensor([15597.6357], grad_fn=<AddBackward0>)
# 14 tensor([114.9087], grad_fn=<AddBackward0>)
# 15 tensor([94.5803], grad_fn=<AddBackward0>)
# 16 tensor([1997.9246], grad_fn=<AddBackward0>)
# 17 tensor([98.2145], grad_fn=<AddBackward0>)
# 18 tensor([96.1504], grad_fn=<AddBackward0>)
# 19 tensor([1140.3910], grad_fn=<AddBackward0>)
# 120 tensor([2437.9573], grad_fn=<AddBackward0>)
# 121 tensor([732.4858], grad_fn=<AddBackward0>)
# 122 tensor([82.3993], grad_fn=<AddBackward0>)
# 123 tensor([669.1013], grad_fn=<AddBackward0>)
# 124 tensor([1589.3270], grad_fn=<AddBackward0>)
# 125 tensor([88.8585], grad_fn=<AddBackward0>)
# 126 tensor([89.3014], grad_fn=<AddBackward0>)
# 127 tensor([81.0298], grad_fn=<AddBackward0>)
# 128 tensor([126.8377], grad_fn=<AddBackward0>)
# 129 tensor([333.5592], grad_fn=<AddBackward0>)
# 130 tensor([1018.5502], grad_fn=<AddBackward0>)
# 131 tensor([89.5455], grad_fn=<AddBackward0>)
# 132 tensor([1925.4746], grad_fn=<AddBackward0>)
# 133 tensor([1961.9003], grad_fn=<AddBackward0>)
# 134 tensor([91.6124], grad_fn=<AddBackward0>)
# 135 tensor([92.0357], grad_fn=<AddBackward0>)
# 136 tensor([2566.0371], grad_fn=<AddBackward0>)
# 137 tensor([1743.2091], grad_fn=<AddBackward0>)
# 138 tensor([85.2825], grad_fn=<AddBackward0>)
# 139 tensor([1343.2131], grad_fn=<AddBackward0>)
# 240 tensor([91.4828], grad_fn=<AddBackward0>)
# 241 tensor([2582.9539], grad_fn=<AddBackward0>)
# 242 tensor([86.2989], grad_fn=<AddBackward0>)
# 243 tensor([1996.3901], grad_fn=<AddBackward0>)
# 244 tensor([1358.5116], grad_fn=<AddBackward0>)
# 245 tensor([340.0593], grad_fn=<AddBackward0>)
# 246 tensor([644.1794], grad_fn=<AddBackward0>)
# 247 tensor([699.1007], grad_fn=<AddBackward0>)
# 248 tensor([87.5248], grad_fn=<AddBackward0>)
# 249 tensor([1772.6185], grad_fn=<AddBackward0>)
# 250 tensor([84.3031], grad_fn=<AddBackward0>)
# 251 tensor([86.5896], grad_fn=<AddBackward0>)
# 252 tensor([77.3066], grad_fn=<AddBackward0>)
# 253 tensor([1579.0197], grad_fn=<AddBackward0>)
# 254 tensor([1953.6036], grad_fn=<AddBackward0>)
# 255 tensor([84.1442], grad_fn=<AddBackward0>)
# 256 tensor([86.4385], grad_fn=<AddBackward0>)
# 257 tensor([1026.3752], grad_fn=<AddBackward0>)
# 258 tensor([2376.1047], grad_fn=<AddBackward0>)
# 259 tensor([127.9827], grad_fn=<AddBackward0>)
# 360 tensor([87.2695], grad_fn=<AddBackward0>)
# 361 tensor([2584.9978], grad_fn=<AddBackward0>)
# 362 tensor([1982.0729], grad_fn=<AddBackward0>)
# 363 tensor([84.8949], grad_fn=<AddBackward0>)
# 364 tensor([88.9075], grad_fn=<AddBackward0>)
# 365 tensor([94.8400], grad_fn=<AddBackward0>)
# 366 tensor([1305.8495], grad_fn=<AddBackward0>)
# 367 tensor([337.9759], grad_fn=<AddBackward0>)
# 368 tensor([82.2394], grad_fn=<AddBackward0>)
# 369 tensor([598.9294], grad_fn=<AddBackward0>)
# 370 tensor([90.1789], grad_fn=<AddBackward0>)
# 371 tensor([718.9521], grad_fn=<AddBackward0>)
# 372 tensor([125.3562], grad_fn=<AddBackward0>)
# 373 tensor([955.3995], grad_fn=<AddBackward0>)
# 374 tensor([1865.0481], grad_fn=<AddBackward0>)
# 375 tensor([2267.8713], grad_fn=<AddBackward0>)
# 376 tensor([93.6957], grad_fn=<AddBackward0>)
# 377 tensor([1496.3793], grad_fn=<AddBackward0>)
# 378 tensor([1852.2928], grad_fn=<AddBackward0>)
# 379 tensor([88.9724], grad_fn=<AddBackward0>)
# 480 tensor([640.3811], grad_fn=<AddBackward0>)
# 481 tensor([92.1740], grad_fn=<AddBackward0>)
# 482 tensor([86.1821], grad_fn=<AddBackward0>)
# 483 tensor([2601.8589], grad_fn=<AddBackward0>)
# 484 tensor([1010.1143], grad_fn=<AddBackward0>)
# 485 tensor([86.6111], grad_fn=<AddBackward0>)
# 486 tensor([2265.4109], grad_fn=<AddBackward0>)
# 487 tensor([123.4365], grad_fn=<AddBackward0>)
# 488 tensor([702.3188], grad_fn=<AddBackward0>)
# 489 tensor([1527.6206], grad_fn=<AddBackward0>)
# 490 tensor([325.0036], grad_fn=<AddBackward0>)
# 491 tensor([93.3839], grad_fn=<AddBackward0>)
# 492 tensor([1938.5906], grad_fn=<AddBackward0>)
# 493 tensor([89.0456], grad_fn=<AddBackward0>)
# 494 tensor([2005.2389], grad_fn=<AddBackward0>)
# 495 tensor([1721.7550], grad_fn=<AddBackward0>)
# 496 tensor([92.3779], grad_fn=<AddBackward0>)
# 497 tensor([1271.3356], grad_fn=<AddBackward0>)
# 498 tensor([89.2924], grad_fn=<AddBackward0>)
# 499 tensor([88.5138], grad_fn=<AddBackward0>)
# 600 tensor([1554.6987], grad_fn=<AddBackward0>)
# 601 tensor([621.8278], grad_fn=<AddBackward0>)
# 602 tensor([88.7420], grad_fn=<AddBackward0>)
# 603 tensor([1031.6476], grad_fn=<AddBackward0>)
# 604 tensor([697.5591], grad_fn=<AddBackward0>)
# 605 tensor([2354.9399], grad_fn=<AddBackward0>)
# 606 tensor([1847.1659], grad_fn=<AddBackward0>)
# 607 tensor([78.7785], grad_fn=<AddBackward0>)
# 608 tensor([79.2860], grad_fn=<AddBackward0>)
# 609 tensor([85.7756], grad_fn=<AddBackward0>)
# 610 tensor([1941.4270], grad_fn=<AddBackward0>)
# 611 tensor([124.3668], grad_fn=<AddBackward0>)
# 612 tensor([2593.3838], grad_fn=<AddBackward0>)
# 613 tensor([1748.1737], grad_fn=<AddBackward0>)
# 614 tensor([348.5511], grad_fn=<AddBackward0>)
# 615 tensor([1328.8184], grad_fn=<AddBackward0>)
# 616 tensor([88.7893], grad_fn=<AddBackward0>)
# 617 tensor([94.5441], grad_fn=<AddBackward0>)
# 618 tensor([79.7114], grad_fn=<AddBackward0>)
# 619 tensor([86.9865], grad_fn=<AddBackward0>)

# %%
plt.figure()
plt.plot(dtlossvals)
torch.save(PIDparams.state_dict(), "4odgradientparams")

# %%
kpst = torch.tensor(kp,requires_grad=True)
kist = torch.tensor(ki,requires_grad=True)
kdst = torch.tensor(kd,requires_grad=True)
backst = torch.tensor(0.1,requires_grad=True)
Tft = torch.tensor(Tf,requires_grad=True)
optimizer = torch.optim.Adam((kpst,kist,kdst,backst), lr=0.1, weight_decay=0.5)

stlossvals = []
closs = 0
kptrain = []
kitrain = []
kdtrain = []
backtrain = []
for episodes in range(701):
  cepisode = episodes%20  
  if(cepisode==0):  
    episodeorder = np.random.choice(20, 20, replace=False)
  ref = refs[episodeorder[cepisode],:]
  reft = torch.tensor(ref)  
  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0],[0.0],[0.0],[0.0]],requires_grad=True)  
  ucmd = torch.tensor([0.0],requires_grad=True)
  u = torch.tensor([0.0],requires_grad=True)  
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  D  = torch.tensor([0.0],requires_grad=False)
  #torch.clamp(Tft,0.1,0.1)
  ad = torch.div(Tft,(Tft+0.01))
  bd = torch.div(kdst,(Tft+0.01))
  noise = 0.01*torch.randn(T,1)
  
  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t];
    #error = torch.tensor(reft[t]-yt,requires_grad=False)
    saterr = u-ucmd
    xcont = xcont+kist*(reft[t]-yt)+backst*saterr
    if(t>0):
       #deriv = torch.tensor(yt-yold,requires_grad=False) 
       D = ad*D-bd*(yt-yold);  
       ucmd = (0.01*xcont+kpst*(reft[t]-yt)+D)
    u = torch.clamp(ucmd,-1.0,1.0)
    uvalssat[i] = u;
    x = torch.matmul(systA.float(),x)+systB.float()*u;
    cost = cost+torch.clamp((reft[t]-yt)**2,0,50)
  closs = closs+cost  
  if(episodes%20==19):    
    stlossvals.append(closs.clone().detach().numpy()/20)
    closs = 0
  kptrain.append(kpst.clone().detach().numpy())
  kitrain.append(kist.clone().detach().numpy())
  kdtrain.append(kdst.clone().detach().numpy())
  backtrain.append(backst.clone().detach().numpy())  
  if(episodes%120<20):
    #print(kpt,kdt,kit,Tft)
    print(episodes,cost,backst) 
  optimizer.zero_grad()
  cost.backward()
  optimizer.step()

print(kpst,kist,kdst,backst)
# Out:
# 0 tensor([99.2214], grad_fn=<AddBackward0>) tensor(0.1000, requires_grad=True)
# 1 tensor([2013.9230], grad_fn=<AddBackward0>) tensor(0.2000, requires_grad=True)
# 2 tensor([1105.6694], grad_fn=<AddBackward0>) tensor(0.2765, requires_grad=True)
# 3 tensor([363.3252], grad_fn=<AddBackward0>) tensor(0.3509, requires_grad=True)
# 4 tensor([2386.1218], grad_fn=<AddBackward0>) tensor(0.4146, requires_grad=True)
# 5 tensor([127.6530], grad_fn=<AddBackward0>) tensor(0.4779, requires_grad=True)
# 6 tensor([93.3042], grad_fn=<AddBackward0>) tensor(0.5329, requires_grad=True)
# 7 tensor([99.0956], grad_fn=<AddBackward0>) tensor(0.5813, requires_grad=True)
# 8 tensor([1928.8451], grad_fn=<AddBackward0>) tensor(0.6240, requires_grad=True)
# 9 tensor([2570.4688], grad_fn=<AddBackward0>) tensor(0.6591, requires_grad=True)
# 10 tensor([87.9941], grad_fn=<AddBackward0>) tensor(0.6881, requires_grad=True)
# 11 tensor([96.4781], grad_fn=<AddBackward0>) tensor(0.7142, requires_grad=True)
# 12 tensor([2010.8680], grad_fn=<AddBackward0>) tensor(0.7374, requires_grad=True)
# 13 tensor([95.3108], grad_fn=<AddBackward0>) tensor(0.7537, requires_grad=True)
# 14 tensor([728.5001], grad_fn=<AddBackward0>) tensor(0.7683, requires_grad=True)
# 15 tensor([98.5687], grad_fn=<AddBackward0>) tensor(0.7803, requires_grad=True)
# 16 tensor([91.7853], grad_fn=<AddBackward0>) tensor(0.7910, requires_grad=True)
# 17 tensor([1546.3765], grad_fn=<AddBackward0>) tensor(0.8006, requires_grad=True)
# 18 tensor([1343.3855], grad_fn=<AddBackward0>) tensor(0.8068, requires_grad=True)
# 19 tensor([697.9280], grad_fn=<AddBackward0>) tensor(0.8106, requires_grad=True)
# 120 tensor([1308.2076], grad_fn=<AddBackward0>) tensor(0.7777, requires_grad=True)
# 121 tensor([1925.2656], grad_fn=<AddBackward0>) tensor(0.7813, requires_grad=True)
# 122 tensor([738.5932], grad_fn=<AddBackward0>) tensor(0.7822, requires_grad=True)
# 123 tensor([2580.9065], grad_fn=<AddBackward0>) tensor(0.7831, requires_grad=True)
# 124 tensor([129.6997], grad_fn=<AddBackward0>) tensor(0.7815, requires_grad=True)
# 125 tensor([88.1035], grad_fn=<AddBackward0>) tensor(0.7805, requires_grad=True)
# 126 tensor([81.7285], grad_fn=<AddBackward0>) tensor(0.7804, requires_grad=True)
# 127 tensor([1028.9733], grad_fn=<AddBackward0>) tensor(0.7807, requires_grad=True)
# 128 tensor([619.8101], grad_fn=<AddBackward0>) tensor(0.7810, requires_grad=True)
# 129 tensor([85.6419], grad_fn=<AddBackward0>) tensor(0.7819, requires_grad=True)
# 130 tensor([91.9162], grad_fn=<AddBackward0>) tensor(0.7834, requires_grad=True)
# 131 tensor([81.9958], grad_fn=<AddBackward0>) tensor(0.7853, requires_grad=True)
# 132 tensor([1922.9629], grad_fn=<AddBackward0>) tensor(0.7875, requires_grad=True)
# 133 tensor([1748.8472], grad_fn=<AddBackward0>) tensor(0.7872, requires_grad=True)
# 134 tensor([2368.5779], grad_fn=<AddBackward0>) tensor(0.7843, requires_grad=True)
# 135 tensor([1516.2102], grad_fn=<AddBackward0>) tensor(0.7790, requires_grad=True)
# 136 tensor([85.1420], grad_fn=<AddBackward0>) tensor(0.7734, requires_grad=True)
# 137 tensor([331.0819], grad_fn=<AddBackward0>) tensor(0.7689, requires_grad=True)
# 138 tensor([92.8878], grad_fn=<AddBackward0>) tensor(0.7654, requires_grad=True)
# 139 tensor([84.6281], grad_fn=<AddBackward0>) tensor(0.7627, requires_grad=True)
# 240 tensor([714.2815], grad_fn=<AddBackward0>) tensor(0.9259, requires_grad=True)
# 241 tensor([88.8325], grad_fn=<AddBackward0>) tensor(0.9289, requires_grad=True)
# 242 tensor([334.8586], grad_fn=<AddBackward0>) tensor(0.9328, requires_grad=True)
# 243 tensor([89.1276], grad_fn=<AddBackward0>) tensor(0.9375, requires_grad=True)
# 244 tensor([90.9244], grad_fn=<AddBackward0>) tensor(0.9424, requires_grad=True)
# 245 tensor([84.9489], grad_fn=<AddBackward0>) tensor(0.9475, requires_grad=True)
# 246 tensor([89.8153], grad_fn=<AddBackward0>) tensor(0.9530, requires_grad=True)
# 247 tensor([2376.6694], grad_fn=<AddBackward0>) tensor(0.9585, requires_grad=True)
# 248 tensor([1882.6927], grad_fn=<AddBackward0>) tensor(0.9591, requires_grad=True)
# 249 tensor([88.1177], grad_fn=<AddBackward0>) tensor(0.9565, requires_grad=True)
# 250 tensor([2594.9004], grad_fn=<AddBackward0>) tensor(0.9550, requires_grad=True)
# 251 tensor([1334.2223], grad_fn=<AddBackward0>) tensor(0.9496, requires_grad=True)
# 252 tensor([94.6076], grad_fn=<AddBackward0>) tensor(0.9447, requires_grad=True)
# 253 tensor([1529.1371], grad_fn=<AddBackward0>) tensor(0.9411, requires_grad=True)
# 254 tensor([659.0952], grad_fn=<AddBackward0>) tensor(0.9389, requires_grad=True)
# 255 tensor([1010.5703], grad_fn=<AddBackward0>) tensor(0.9387, requires_grad=True)
# 256 tensor([1720.9718], grad_fn=<AddBackward0>) tensor(0.9398, requires_grad=True)
# 257 tensor([127.1859], grad_fn=<AddBackward0>) tensor(0.9428, requires_grad=True)
# 258 tensor([1891.9922], grad_fn=<AddBackward0>) tensor(0.9467, requires_grad=True)
# 259 tensor([89.5622], grad_fn=<AddBackward0>) tensor(0.9501, requires_grad=True)
# 360 tensor([87.6338], grad_fn=<AddBackward0>) tensor(1.0537, requires_grad=True)
# 361 tensor([1746.4564], grad_fn=<AddBackward0>) tensor(1.0589, requires_grad=True)
# 362 tensor([2604.8540], grad_fn=<AddBackward0>) tensor(1.0602, requires_grad=True)
# 363 tensor([90.2358], grad_fn=<AddBackward0>) tensor(1.0548, requires_grad=True)
# 364 tensor([629.7510], grad_fn=<AddBackward0>) tensor(1.0504, requires_grad=True)
# 365 tensor([84.9977], grad_fn=<AddBackward0>) tensor(1.0464, requires_grad=True)
# 366 tensor([88.4932], grad_fn=<AddBackward0>) tensor(1.0436, requires_grad=True)
# 367 tensor([94.6570], grad_fn=<AddBackward0>) tensor(1.0417, requires_grad=True)
# 368 tensor([1519.5857], grad_fn=<AddBackward0>) tensor(1.0410, requires_grad=True)
# 369 tensor([712.7678], grad_fn=<AddBackward0>) tensor(1.0394, requires_grad=True)
# 370 tensor([334.0660], grad_fn=<AddBackward0>) tensor(1.0389, requires_grad=True)
# 371 tensor([89.4767], grad_fn=<AddBackward0>) tensor(1.0397, requires_grad=True)
# 372 tensor([130.1915], grad_fn=<AddBackward0>) tensor(1.0413, requires_grad=True)
# 373 tensor([1017.5869], grad_fn=<AddBackward0>) tensor(1.0435, requires_grad=True)
# 374 tensor([2403.2883], grad_fn=<AddBackward0>) tensor(1.0441, requires_grad=True)
# 375 tensor([90.9436], grad_fn=<AddBackward0>) tensor(1.0405, requires_grad=True)
# 376 tensor([88.4115], grad_fn=<AddBackward0>) tensor(1.0381, requires_grad=True)
# 377 tensor([1953.3743], grad_fn=<AddBackward0>) tensor(1.0369, requires_grad=True)
# 378 tensor([1301.5315], grad_fn=<AddBackward0>) tensor(1.0336, requires_grad=True)
# 379 tensor([1931.2395], grad_fn=<AddBackward0>) tensor(1.0301, requires_grad=True)
# 480 tensor([89.4217], grad_fn=<AddBackward0>) tensor(1.0308, requires_grad=True)
# 481 tensor([1928.9340], grad_fn=<AddBackward0>) tensor(1.0313, requires_grad=True)
# 482 tensor([90.2602], grad_fn=<AddBackward0>) tensor(1.0276, requires_grad=True)
# 483 tensor([338.8554], grad_fn=<AddBackward0>) tensor(1.0251, requires_grad=True)
# 484 tensor([632.7529], grad_fn=<AddBackward0>) tensor(1.0240, requires_grad=True)
# 485 tensor([1353.0198], grad_fn=<AddBackward0>) tensor(1.0242, requires_grad=True)
# 486 tensor([87.9147], grad_fn=<AddBackward0>) tensor(1.0242, requires_grad=True)
# 487 tensor([86.1093], grad_fn=<AddBackward0>) tensor(1.0250, requires_grad=True)
# 488 tensor([89.5161], grad_fn=<AddBackward0>) tensor(1.0265, requires_grad=True)
# 489 tensor([1013.3378], grad_fn=<AddBackward0>) tensor(1.0286, requires_grad=True)
# 490 tensor([2420.2397], grad_fn=<AddBackward0>) tensor(1.0282, requires_grad=True)
# 491 tensor([90.2749], grad_fn=<AddBackward0>) tensor(1.0207, requires_grad=True)
# 492 tensor([1928.2042], grad_fn=<AddBackward0>) tensor(1.0145, requires_grad=True)
# 493 tensor([1728.7344], grad_fn=<AddBackward0>) tensor(1.0051, requires_grad=True)
# 494 tensor([90.8756], grad_fn=<AddBackward0>) tensor(0.9939, requires_grad=True)
# 495 tensor([1537.1951], grad_fn=<AddBackward0>) tensor(0.9849, requires_grad=True)
# 496 tensor([91.7998], grad_fn=<AddBackward0>) tensor(0.9777, requires_grad=True)
# 497 tensor([719.2592], grad_fn=<AddBackward0>) tensor(0.9722, requires_grad=True)
# 498 tensor([129.5567], grad_fn=<AddBackward0>) tensor(0.9706, requires_grad=True)
# 499 tensor([2587.0361], grad_fn=<AddBackward0>) tensor(0.9707, requires_grad=True)
# 600 tensor([2379.5950], grad_fn=<AddBackward0>) tensor(0.9830, requires_grad=True)
# 601 tensor([645.8344], grad_fn=<AddBackward0>) tensor(0.9790, requires_grad=True)
# 602 tensor([89.0384], grad_fn=<AddBackward0>) tensor(0.9767, requires_grad=True)
# 603 tensor([1538.5409], grad_fn=<AddBackward0>) tensor(0.9760, requires_grad=True)
# 604 tensor([88.9811], grad_fn=<AddBackward0>) tensor(0.9726, requires_grad=True)
# 605 tensor([90.1916], grad_fn=<AddBackward0>) tensor(0.9707, requires_grad=True)
# 606 tensor([90.2965], grad_fn=<AddBackward0>) tensor(0.9703, requires_grad=True)
# 607 tensor([90.3260], grad_fn=<AddBackward0>) tensor(0.9713, requires_grad=True)
# 608 tensor([717.4007], grad_fn=<AddBackward0>) tensor(0.9734, requires_grad=True)
# 609 tensor([91.6130], grad_fn=<AddBackward0>) tensor(0.9763, requires_grad=True)
# 610 tensor([1007.5767], grad_fn=<AddBackward0>) tensor(0.9798, requires_grad=True)
# 611 tensor([323.8817], grad_fn=<AddBackward0>) tensor(0.9819, requires_grad=True)
# 612 tensor([1991.9906], grad_fn=<AddBackward0>) tensor(0.9849, requires_grad=True)
# 613 tensor([1759.2004], grad_fn=<AddBackward0>) tensor(0.9800, requires_grad=True)
# 614 tensor([131.2656], grad_fn=<AddBackward0>) tensor(0.9726, requires_grad=True)
# 615 tensor([95.8660], grad_fn=<AddBackward0>) tensor(0.9675, requires_grad=True)
# 616 tensor([2593.2188], grad_fn=<AddBackward0>) tensor(0.9640, requires_grad=True)
# 617 tensor([1325.4431], grad_fn=<AddBackward0>) tensor(0.9548, requires_grad=True)
# 618 tensor([96.2129], grad_fn=<AddBackward0>) tensor(0.9490, requires_grad=True)
# 619 tensor([1893.3353], grad_fn=<AddBackward0>) tensor(0.9450, requires_grad=True)
# tensor(3.5870, requires_grad=True) tensor(2.0020, requires_grad=True) tensor(1.0579, requires_grad=True) tensor(1.0242, requires_grad=True)

# %%
kpdft = torch.tensor(kp,requires_grad=True)
kidft = torch.tensor(ki,requires_grad=True)
kddft = torch.tensor(kd,requires_grad=True)

#backdft = torch.tensor(0.1,requires_grad=True)

backdft = torch.zeros(500,requires_grad=True)

optimizer = torch.optim.Adam([backdft], lr=0.1, weight_decay=0.1)

dftlossvals = []
closs = 0
for episodes in range(501):
  cepisode = episodes%20  
  if(cepisode==0):  
    episodeorder = np.random.choice(20, 20, replace=False)
    
  ref = refs[episodeorder[cepisode],:]
  reft = torch.tensor(ref)  
  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0],[0.0],[0.0],[0.0]],requires_grad=True)  
  ucmd = torch.tensor([0.0],requires_grad=True)   
  u = torch.tensor([0.0],requires_grad=True)  
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  D  = torch.tensor([0.0],requires_grad=False)
  ad = torch.div(Tft,(Tft+0.01))
  bd = torch.div(kddft,(Tft+0.01))

  noise = 0.01*torch.randn(T,1)
  satest = torch.zeros(500,requires_grad=False)
  #satestsum = torch.sum(satest)
  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t];
    #error = torch.tensor(reft[t]-yt,requires_grad=False)
    #satestc = satest.clone().detach()
    #satest[1:500] = satestc[0:499] 
    satest = torch.roll(satest,1)
    satest[0] = u-ucmd
    #print(satest)
    #satestsum = satestsum+satest[0]
    xcont = xcont+kidft*(reft[t]-yt)
    if(t>0):
       #deriv = torch.tensor(yt-yold,requires_grad=False) 
       D = ad*D-bd*(yt-yold);  
       ucmd = (0.01*xcont+kpdft*(reft[t]-yt)+D+0.01*torch.dot(backdft,satest.detach()))
    u = torch.clamp(ucmd,-1.0,1.0)
    x = torch.matmul(systA.float(),x)+systB.float()*u
    #u2 = u1
    #u1 = u
    cost = cost+torch.clamp((reft[t]-yt)**2,0,50)
  closs = closs+cost  
  if(episodes%20==19):    
    dftlossvals.append(closs.clone().detach().numpy()[0]/20)
    closs = 0 
  if(episodes%120<20):
    print(episodes,cost)
    
  optimizer.zero_grad()
  cost.backward()
  optimizer.step()
# Out:
# 0 tensor([116.2484], grad_fn=<AddBackward0>)
# 1 tensor([897.6294], grad_fn=<AddBackward0>)
# 2 tensor([1824.0211], grad_fn=<AddBackward0>)
# 3 tensor([104.2209], grad_fn=<AddBackward0>)
# 4 tensor([147.7334], grad_fn=<AddBackward0>)
# 5 tensor([106.9844], grad_fn=<AddBackward0>)
# 6 tensor([3739.4043], grad_fn=<AddBackward0>)
# 7 tensor([100.3412], grad_fn=<AddBackward0>)
# 8 tensor([2665.2815], grad_fn=<AddBackward0>)
# 9 tensor([2011.6920], grad_fn=<AddBackward0>)
# 10 tensor([393.4470], grad_fn=<AddBackward0>)
# 11 tensor([3148.3555], grad_fn=<AddBackward0>)
# 12 tensor([102.5034], grad_fn=<AddBackward0>)
# 13 tensor([908.8975], grad_fn=<AddBackward0>)
# 14 tensor([109.7121], grad_fn=<AddBackward0>)
# 15 tensor([105.0202], grad_fn=<AddBackward0>)
# 16 tensor([113.0611], grad_fn=<AddBackward0>)
# 17 tensor([1340.2224], grad_fn=<AddBackward0>)
# 18 tensor([2626.2021], grad_fn=<AddBackward0>)
# 19 tensor([2394.5020], grad_fn=<AddBackward0>)
# 120 tensor([101.9798], grad_fn=<AddBackward0>)
# 121 tensor([2396.6541], grad_fn=<AddBackward0>)
# 122 tensor([100.6903], grad_fn=<AddBackward0>)
# 123 tensor([3693.3398], grad_fn=<AddBackward0>)
# 124 tensor([106.1629], grad_fn=<AddBackward0>)
# 125 tensor([2025.9221], grad_fn=<AddBackward0>)
# 126 tensor([421.2364], grad_fn=<AddBackward0>)
# 127 tensor([2660.7808], grad_fn=<AddBackward0>)
# 128 tensor([154.0239], grad_fn=<AddBackward0>)
# 129 tensor([935.1507], grad_fn=<AddBackward0>)
# 130 tensor([2548.6797], grad_fn=<AddBackward0>)
# 131 tensor([110.1288], grad_fn=<AddBackward0>)
# 132 tensor([93.2768], grad_fn=<AddBackward0>)
# 133 tensor([1279.1125], grad_fn=<AddBackward0>)
# 134 tensor([3227.2046], grad_fn=<AddBackward0>)
# 135 tensor([1712.0535], grad_fn=<AddBackward0>)
# 136 tensor([98.1810], grad_fn=<AddBackward0>)
# 137 tensor([93.1356], grad_fn=<AddBackward0>)
# 138 tensor([772.5771], grad_fn=<AddBackward0>)
# 139 tensor([110.3014], grad_fn=<AddBackward0>)
# 240 tensor([2424.5334], grad_fn=<AddBackward0>)
# 241 tensor([2598.3308], grad_fn=<AddBackward0>)
# 242 tensor([118.5002], grad_fn=<AddBackward0>)
# 243 tensor([995.8161], grad_fn=<AddBackward0>)
# 244 tensor([1744.3182], grad_fn=<AddBackward0>)
# 245 tensor([108.0850], grad_fn=<AddBackward0>)
# 246 tensor([1385.3237], grad_fn=<AddBackward0>)
# 247 tensor([2012.3452], grad_fn=<AddBackward0>)
# 248 tensor([3634.5569], grad_fn=<AddBackward0>)
# 249 tensor([116.7827], grad_fn=<AddBackward0>)
# 250 tensor([169.1228], grad_fn=<AddBackward0>)
# 251 tensor([3212.6609], grad_fn=<AddBackward0>)
# 252 tensor([99.6631], grad_fn=<AddBackward0>)
# 253 tensor([105.9736], grad_fn=<AddBackward0>)
# 254 tensor([2449.0496], grad_fn=<AddBackward0>)
# 255 tensor([473.4326], grad_fn=<AddBackward0>)
# 256 tensor([105.7970], grad_fn=<AddBackward0>)
# 257 tensor([850.0459], grad_fn=<AddBackward0>)
# 258 tensor([108.3784], grad_fn=<AddBackward0>)
# 259 tensor([115.4198], grad_fn=<AddBackward0>)
# 360 tensor([2006.9066], grad_fn=<AddBackward0>)
# 361 tensor([1735.6078], grad_fn=<AddBackward0>)
# 362 tensor([448.9904], grad_fn=<AddBackward0>)
# 363 tensor([98.1097], grad_fn=<AddBackward0>)
# 364 tensor([107.3841], grad_fn=<AddBackward0>)
# 365 tensor([100.5512], grad_fn=<AddBackward0>)
# 366 tensor([3490.8108], grad_fn=<AddBackward0>)
# 367 tensor([114.0855], grad_fn=<AddBackward0>)
# 368 tensor([2210.0049], grad_fn=<AddBackward0>)
# 369 tensor([851.1333], grad_fn=<AddBackward0>)
# 370 tensor([1314.4058], grad_fn=<AddBackward0>)
# 371 tensor([97.6662], grad_fn=<AddBackward0>)
# 372 tensor([2377.6780], grad_fn=<AddBackward0>)
# 373 tensor([157.4465], grad_fn=<AddBackward0>)
# 374 tensor([107.7036], grad_fn=<AddBackward0>)
# 375 tensor([2581.8413], grad_fn=<AddBackward0>)
# 376 tensor([957.4119], grad_fn=<AddBackward0>)
# 377 tensor([96.7245], grad_fn=<AddBackward0>)
# 378 tensor([3125.6792], grad_fn=<AddBackward0>)
# 379 tensor([99.0615], grad_fn=<AddBackward0>)
# 480 tensor([2483.9556], grad_fn=<AddBackward0>)
# 481 tensor([1182.1481], grad_fn=<AddBackward0>)
# 482 tensor([139.6289], grad_fn=<AddBackward0>)
# 483 tensor([1964.7080], grad_fn=<AddBackward0>)
# 484 tensor([107.4934], grad_fn=<AddBackward0>)
# 485 tensor([2170.6372], grad_fn=<AddBackward0>)
# 486 tensor([756.0565], grad_fn=<AddBackward0>)
# 487 tensor([109.1660], grad_fn=<AddBackward0>)
# 488 tensor([1626.9702], grad_fn=<AddBackward0>)
# 489 tensor([104.2928], grad_fn=<AddBackward0>)
# 490 tensor([98.2344], grad_fn=<AddBackward0>)
# 491 tensor([104.7976], grad_fn=<AddBackward0>)
# 492 tensor([3351.1167], grad_fn=<AddBackward0>)
# 493 tensor([2998.4553], grad_fn=<AddBackward0>)
# 494 tensor([2449.1470], grad_fn=<AddBackward0>)
# 495 tensor([100.8874], grad_fn=<AddBackward0>)
# 496 tensor([888.4911], grad_fn=<AddBackward0>)
# 497 tensor([96.2256], grad_fn=<AddBackward0>)
# 498 tensor([110.1790], grad_fn=<AddBackward0>)
# 499 tensor([398.6152], grad_fn=<AddBackward0>)

# %%
kps = kpst.detach().numpy()
kis = kist.detach().numpy()
kds = kdst.detach().numpy()
backs = backst.detach().numpy()
print(kps,kis,kds,backs)

plt.figure()
plt.plot(np.arange(len(dtlossvals))*20,dtlossvals)
plt.xlabel("No. of episodes")
plt.ylabel("Loss")

plt.figure()
plt.plot(np.arange(len(dftlossvals))*20,dftlossvals)
plt.xlabel("No. of episodes")
plt.ylabel("Loss")

plt.figure()
plt.plot(np.arange(len(stlossvals))*20,stlossvals)
plt.xlabel("No. of episodes")
plt.ylabel("Loss")

plt.figure()
plt.plot(np.arange(len(kptrain)),kptrain)
plt.xlabel("No. of episodes")
plt.ylabel("kp")

plt.figure()
plt.plot(np.arange(len(kdtrain)),kdtrain)
plt.xlabel("No. of episodes")
plt.ylabel("kd")

plt.figure()
plt.plot(np.arange(len(kitrain)),kitrain)
plt.xlabel("No. of episodes")
plt.ylabel("ki")

plt.figure()
plt.plot(np.arange(len(backtrain)),backtrain)
plt.xlabel("No. of episodes")
plt.ylabel("Back-calculation constant")
# Out:
# 3.5870233 2.0020177 1.0578957 1.0241538
# Text(0, 0.5, 'Back-calculation constant')

# %%
costdgradient = np.zeros((10,))
costinit = np.zeros((10,))
costsgradient = np.zeros((10,))
costdfgradient = np.zeros((10,))

ydgradient = np.zeros((10,T))
udgradient = np.zeros((10,T))

ysgradient = np.zeros((10,T))
usgradient = np.zeros((10,T))

ydfgradient = np.zeros((10,T))
udfgradient = np.zeros((10,T))

kpdgradient = np.zeros((10,T))
kidgradient = np.zeros((10,T))
kddgradient = np.zeros((10,T))
backdgradient = np.zeros((10,T))
#PIDparams = neuralPID()
#PIDparams.load_state_dict(torch.load("dgradientparams"))

yinit = np.zeros((10,T))
uinit = np.zeros((10,T))
smooth = 0.9

for iters in range(0,10):
  ref = refs[20+iters,:]
  reft = torch.tensor(ref)
  noise = 0.01*torch.randn(T,1)  
  
  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0],[0.0],[0.0],[0.0]],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  ucmd = torch.tensor([0.0],requires_grad=True)
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  D  = torch.tensor([0.0],requires_grad=False)
  #torch.clamp(Tft,0.1,0.1)
  ad = torch.div(Tft,(Tft+0.01))
  
  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t];
    ydgradient[iters,t] = yt.clone().detach().numpy()
    #print(yt)
    #error = torch.tensor(reft[t]-yt,requires_grad=False)
    saterr = u-ucmd
    err = reft[t]-yt
    ninput = torch.cat((err.detach(),saterr.detach()),0)
    kpdt,kidt,kddt,backdt = PIDparams(ninput)
    kpt = smooth*kpt+(1-smooth)*(kpit+kpdt)
    kit = smooth*kit+(1-smooth)*(kiit+kidt)
    kdt = smooth*kdt+(1-smooth)*(kdit+kddt)
    backt = smooth*backt+(1-smooth)*(backit+backdt)
    xcont = xcont+kit*err+backt*saterr.detach()
    if(t>0):
      bd = torch.div(kdt,(Tft+0.01))
      D = ad*D-bd*(yt-yold);  
      ucmd = (0.01*xcont+kpt*(reft[t]-yt)+D)
      u = torch.clamp(ucmd,-1.0,1.0)
      udgradient[iters,t] = u.clone().detach().numpy()
      kpdgradient[iters,t] = kpt.clone().detach().numpy()
      kidgradient[iters,t] = kit.clone().detach().numpy()
      kddgradient[iters,t] = kdt.clone().detach().numpy()
      backdgradient[iters,t] = backt.clone().detach().numpy()  
    x = torch.matmul(systA.float(),x)+systB.float()*u;
    cost = cost+(reft[t]-yt)**2
    
  costdgradient[iters] = cost.detach().numpy()

  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0],[0.0],[0.0],[0.0]],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  D  = torch.tensor([0.0],requires_grad=False)
  #torch.clamp(Tft,0.1,0.1)
  ad = torch.div(Tft,(Tft+0.01))
  
  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t];
    yinit[iters,t] = yt.clone().detach().numpy()
    #print(yt)
    #error = torch.tensor(reft[t]-yt,requires_grad=False)
    err = ref[t]-yt
    xcont = xcont+err
    if(t>0):
       #print(t,kpt,kit,kdt)
       #break;
       bd = torch.div(kdit,(Tft+0.01))
       D = ad*D-bd*(yt-yold);  
       u = (0.01*kiit*xcont+kpit*(ref[t]-yt)+D)
       u = torch.clamp(u,-1.0,1.0)
    uinit[iters,t] = u.clone().detach().numpy()
    x = torch.matmul(systA.float(),x)+systB.float()*u;
    cost = cost+(reft[t]-yt)**2
  costinit[iters] = cost.detach().numpy()

  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0],[0.0],[0.0],[0.0]],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  D  = torch.tensor([0.0],requires_grad=False)
  #torch.clamp(Tft,0.1,0.1)
  ad = torch.div(Tft,(Tft+0.01))
  bd = torch.div(kdst,(Tft+0.01))

  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t];
    ysgradient[iters,t] = yt.clone().detach().numpy()
    #print(yt)
    #error = torch.tensor(reft[t]-yt,requires_grad=False)
    saterr = u-ucmd
    xcont = xcont+kist*(reft[t]-yt)+backst*saterr.detach()
    if(t>0):
       #deriv = torch.tensor(yt-yold,requires_grad=False) 
       D = ad*D-bd*(yt-yold);  
       ucmd = (0.01*xcont+kpst*(reft[t]-yt)+D)
    u = torch.clamp(ucmd,-1.0,1.0)
    usgradient[iters,t] = u.clone().detach().numpy()
    x = torch.matmul(systA.float(),x)+systB.float()*u;
    cost = cost+(reft[t]-yt)**2
  costsgradient[iters] = cost.detach().numpy() 

  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0],[0.0],[0.0],[0.0]],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  u2 = torch.tensor([0.0],requires_grad=True)
  u1 = torch.tensor([0.0],requires_grad=True)     
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  D  = torch.tensor([0.0],requires_grad=False)
  satest = torch.zeros(500,requires_grad=False)
  ad = torch.div(Tft,(Tft+0.01))
  bd = torch.div(kddft,(Tft+0.01))
    
  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t]
    ydfgradient[iters,t] = yt.clone().detach().numpy()
    satest = torch.roll(satest,1)
    satest[0] = u-ucmd
    xcont = xcont+kidft*(reft[t]-yt)
    if(t>0):
       D = ad*D-bd*(yt-yold);  
       ucmd = (0.01*xcont+kpdft*(reft[t]-yt)+D+0.01*torch.dot(backdft,satest.detach()))
    u = torch.clamp(ucmd,-1.0,1.0)
    x = torch.matmul(systA.float(),x)+systB.float()*u
    cost = cost+torch.clamp((reft[t]-yt)**2,0,50)
  costdfgradient[iters] = cost.detach().numpy()

# %%
print("Dgradient-dynamic",costdgradient)
print("Dgradient-static",costsgradient)
print("DF-CVX",costdfgradient)
print("Initial",costinit)

print("Dgradient-dynamic",np.mean(costdgradient),np.std(costdgradient))
print("DF-CVX",np.mean(costdfgradient),np.std(costdfgradient))
print("Dgradient-static",np.mean(costsgradient),np.std(costsgradient))
print("Initial",np.mean(costinit),np.std(costinit))
# Out:
# Dgradient-dynamic [2588.03271484  753.66400146   90.21466064  629.26525879 1421.51940918
#   123.48109436 1236.73425293 2099.4375       89.1911087    96.2537384 ]
# Dgradient-static [2573.63793945  772.65130615   98.11049652  658.99627686 1446.56542969
#   121.36502838 1201.45385742 2112.32617188   96.37775421   97.48383331]
# DF-CVX [3321.28417969  939.82263184  103.94159698  777.49420166 1794.14758301
#   151.68469238 1521.04797363 2682.44213867   98.33985901  106.52528381]
# Initial [4874.75097656 1250.40612793  121.93099976 1047.51721191 2496.53564453
#   179.65396118 2142.85644531 3937.7722168   129.75486755  139.24313354]
# Dgradient-dynamic 912.7793739318847 856.0787716389156
# DF-CVX 1149.6730140686036 1099.2766168198536
# Dgradient-static 917.896809387207 852.6807450355311
# Initial 1632.0421585083009 1618.7133933283499

# %%
plt.figure()
plt.plot(0.01*np.arange(0,T),refs[20,:])
plt.plot(0.01*np.arange(0,T),ydgradient[0,:])
plt.plot(0.01*np.arange(0,T),ysgradient[0,:])
plt.plot(0.01*np.arange(0,T),ydfgradient[0,:])
plt.plot(0.01*np.arange(0,T),yinit[0,:])
plt.xlabel("Time(s)")
plt.ylabel("Output")
plt.legend(["Reference","D-gradient (dynamic)","D-gradient (static)","DF-CVX","Initial"])

plt.figure()
plt.plot(0.01*np.arange(0,T),uinit[0,:])
plt.plot(0.01*np.arange(0,T),udgradient[0,:])
plt.plot(0.01*np.arange(0,T),usgradient[0,:])
plt.plot(0.01*np.arange(0,T),udfgradient[0,:])
plt.xlabel("Time(s)")
plt.ylabel("Input")
plt.legend(["Initial","D-gradient (dynamic)","D-gradient (static)","DF-CVX"])

plt.figure()
plt.plot(0.01*np.arange(1,T),kpdgradient[0,1:])
plt.xlabel("Time(s)")
plt.ylabel("Proportional gain")

plt.figure()
plt.plot(0.01*np.arange(1,T),kidgradient[0,1:])
plt.xlabel("Time(s)")
plt.ylabel("Integral gain")

plt.figure()
plt.plot(0.01*np.arange(1,T),kddgradient[0,1:])
plt.xlabel("Time(s)")
plt.ylabel("Derivative gain")

plt.figure()
plt.plot(0.01*np.arange(1,T),backdgradient[0,1:])
plt.xlabel("Time(s)")
plt.ylabel("Back-calculation gain")
# Out:
# Text(0, 0.5, 'Back-calculation gain')

# %%
# Save everything
np.save("4odddtlossvals",dtlossvals)
np.save("4oddstlossvals",stlossvals)
np.save("4odddftlossvals",dftlossvals)
np.save("4oddydgradient",ydgradient)
np.save("4oddydfgradient",ydfgradient)
np.save("4oddysgradient",ysgradient)
np.save("4oddyinit",yinit)
np.save("4oddudgradient",udgradient)
np.save("4oddudfgradient",udfgradient)
np.save("4oddusgradient",usgradient)
np.save("4odduinit",uinit)
np.save("4oddkpdgradient",kpdgradient)
np.save("4oddkidgradient",kidgradient)
np.save("4oddkddgradient",kddgradient)
np.save("4oddbackdgradient",backdgradient)
np.save("4oddkptrain",kptrain)
np.save("4oddkitrain",kitrain)
np.save("4oddkdtrain",kdtrain)
np.save("4oddbacktrain",backtrain)
np.save("4oddrefs",refs)
np.save("4oddcostdgradient",costdgradient)
np.save("4oddcostdfgradient",costdfgradient)
np.save("4oddcostsgradient",costsgradient)
np.save("4oddcostinit",costinit)

torch.save(backdft,"4oddbackdft")
torch.save(PIDparams.state_dict(), "4oddgradientparams")

# %%
kpit = torch.tensor(kp,requires_grad=False)
kiit = torch.tensor(ki,requires_grad=False)
kdit = torch.tensor(kd,requires_grad=False)
#PIDpg = neuralPID()
#optimizer = torch.optim.Adam((PIDpg.parameters()), lr=0.1)
#for iters in range(1000):
#   kpt,kit,kdt = PIDpg(torch.randn(3,))
#   print(kpt,kit,kdt)
#   loss = (kpt-kpit)**2+(kit-kiit)**2+(kdt-kdit)**2
#   optimizer.zero_grad()
#   loss.backward()
#   optimizer.step()

# %%
ysat = np.zeros((T,))
uvalssat = np.zeros((T,))

optimizer = torch.optim.Adam((PIDpg.parameters()), lr=0.1)

nupdates = 100
nepisodes = 120
for updates in range(nupdates):
  cost = np.zeros((nepisodes,T))
  ref = refs[updates%20,:]
  rcostsepisode = np.zeros((nepisodes*T,1))
  totalcost = np.zeros((nepisodes,))
  uvalsepisode = np.zeros((nepisodes*T,1))
  PIDinputsepisode = np.zeros((nepisodes*T,3))
  PIDstatesepisode = np.zeros((nepisodes*T,4))
  for episodes in range(nepisodes):
    xcont = 0
    x =[[0.0],[0.0]]  
    u = 0.0
    ucmd = 0.0
    
    ucmdvals = np.zeros((T,1))
    uvals =  np.zeros((T,1))
    PIDinputs = np.zeros((T,3))
    PIDstates = np.zeros((T,4))
    yt = 0.0
    D  = 0.0
    
    ad = Tf/(Tf+0.01)
    adt = torch.tensor(ad,requires_grad=False)
    adt = adt.float()
    noise = 0.01*np.random.randn(T,1)
    sigma = 0.5
    for t in range(T):
      yold = yt
      yt = np.clip(np.dot(sysC,x)+noise[t],-30.0,30.0)
      err = ref[t]-yt[0]
      xcont = xcont+err
      if(t>0):
         inp = np.array([err,u,ucmd])
         ninput = torch.tensor(inp,requires_grad=False)
         PIDinputs[t,:] = inp   
         kpdt,kidt,kddt = PIDpg(ninput.float())
         kpt = kpit+kpdt
         kit = kiit+kidt
         kdt = kdit+kddt
         kpn = kpt.detach().numpy()
         kin = kit.detach().numpy()
         kdn = kdt.detach().numpy()
         #print(kpn,kin,kdn)   
         bd = kdn[0]/(Tf+0.01)
         PIDstates[t,:] = [err,xcont,D,yt[0]-yold[0]] 
         D = ad*D-bd*(yt[0]-yold[0])
         ucmd = (0.01*kin[0]*xcont+kpn[0]*err+D)
      if(episodes==0):
        u = ucmd
      else:  
        u = ucmd+sigma*np.random.randn()
      uvals[t] = u
      u = np.clip(u,-35.0,35.0)
      x = np.dot(sysA,x)+sysB*u;
      cost[episodes,t] = (ref[t]-yt)**2
    #rcosts = np.flip(np.cumsum(np.flip(cost[episodes,:],[0]),0),[0])
    totalcost[episodes] = np.sum(cost[episodes,:])
    rcosts = np.repeat(totalcost[episodes],T,0)
    #if(episodes==0):
    #  print(updates,episodes,rcosts[0])
    rcostsepisode[episodes*T:(episodes+1)*T,0] = rcosts
    uvalsepisode[episodes*T:(episodes+1)*T,:] = uvals
    PIDinputsepisode[episodes*T:(episodes+1)*T,:] = PIDinputs
    PIDstatesepisode[episodes*T:(episodes+1)*T,:] = PIDstates
  print(updates,episodes,np.min(totalcost))
  PIDinputstorch = torch.tensor(PIDinputsepisode).float()
  PIDstatestorch = torch.tensor(PIDstatesepisode).float()
  uvalstorch = torch.tensor(uvalsepisode).float()
  rcoststorch = torch.tensor(rcostsepisode).float()
  costmean = torch.tensor(np.mean(totalcost)).float()
    
  kptvals,kitvals,kdtvals = PIDpg(PIDinputstorch)
  bdtvals = (kd+kdtvals)/(Tft+0.01)  
  Dvals = adt*PIDstatestorch[:,2]-bdtvals*PIDstatestorch[:,3]  
  ucmdvals = 0.01*torch.mul((ki+kitvals),PIDstatestorch[:,1])+torch.mul((kp+kptvals),PIDstatestorch[:,0])+Dvals
  
  updatecost = torch.mean(torch.mul((uvalstorch-ucmdvals)**2,rcoststorch-costmean))/(2*sigma)
  optimizer.zero_grad()
  updatecost.backward()
  optimizer.step()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-2b00b39fa3d9> in <module>
#       2 uvalssat = np.zeros((T,))
#       3
# ----> 4 optimizer = torch.optim.Adam((PIDpg.parameters()), lr=0.1)
#       5
#       6 nupdates = 100
#
# NameError: name 'PIDpg' is not defined
