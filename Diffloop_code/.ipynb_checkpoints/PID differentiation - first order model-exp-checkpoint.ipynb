# %%
import numpy as np
import scipy
import torch
from matplotlib import pyplot as plt
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable 
import control
from control import matlab
from matplotlib import cm

np.random.seed(0)
dev = "cpu"  
device = torch.device(dev)

# %%
sysA = np.array([1.01])
#sysA = 0.99
sysB = np.array([[0.125]])
sysC = np.array([0.1608])
sysD = 0
#print(np.linalg.eig(sysA))
kp = 4.0
ki = 10.0
kd = 0.0
Tf = 0.01

# %%
T = 1500
refs = np.zeros((30,T))

randval = 0

for i in range(30):
  refs[i,0:300] = 0
  randval = 8*np.random.rand()-4.0
  if randval>0 and randval<2:
    randval = 2
  if randval<0 and randval>-2:
    randval = -2
  refs[i,300:] = randval

# %%
ref = refs[8,:]
ysat = np.zeros((T,))
uvalssat = np.zeros((T,))
xcont = 0
u = 0
D = 0
ad = Tf/(Tf+0.01)
bd = kd/(Tf+0.01)
noise = 0.05*np.random.randn(T,1)

x0 = np.zeros((1,1))
x = x0
for i in range(T):
   ysat[i] = np.dot(sysC,x)+np.dot(sysD,u)+noise[i]
   xcont = xcont+(ref[i]-ysat[i])
   if(i>0):
     D = ad*D-bd*(ysat[i]-ysat[i-1])  
     u = 0.01*ki*xcont+kp*(ref[i]-ysat[i])+D
   if(u>3.3):
     u=3.3
   elif(u<-3.3):
     u=-3.3
   uvalssat[i] = u;
   x = np.dot(sysA,x)+np.dot(sysB,u);

ynosat = np.zeros((T,))
uvalsnosat = np.zeros((T,))
xcont = 0;
u = 0;
x = x0
D = 0

for i in range(T):
   ynosat[i] = np.dot(sysC,x)+np.dot(sysD,u)+noise[i]
   xcont = xcont+(ref[i]-ynosat[i])
   if(i>0):
     D = ad*D-bd*(ynosat[i]-ynosat[i-1])  
     u = 0.01*ki*xcont+kp*(ref[i]-ynosat[i])+D 
   uvalsnosat[i] = u;
   x = np.dot(sysA,x)+np.dot(sysB,u);

# %%
plt.figure
plt.plot(0.01*np.arange(T),ynosat)
plt.plot(0.01*np.arange(T),ysat)
plt.plot(0.01*np.arange(T),ref)
plt.xlabel("Time (s)")
plt.ylabel("Output")
plt.legend(["No saturation","Saturation","Reference"])
plt.show()

plt.figure
plt.plot(0.01*np.arange(T),uvalsnosat)
plt.plot(0.01*np.arange(T),uvalssat)
plt.xlabel("Time (s)")
plt.ylabel("Input")
plt.legend(["No saturation","Saturation"])
plt.show()

# %%
class neuralPID(torch.nn.Module):
   def __init__(self):
    super(neuralPID, self).__init__()
    torch.manual_seed(2)
    self.kplayer1 = torch.nn.Linear(2,2)
    self.kplayer2 = torch.nn.Linear(2,1)
    self.kilayer1 = torch.nn.Linear(2,2)
    self.kilayer2 = torch.nn.Linear(2,1)
    self.backlayer1 = torch.nn.Linear(2,2)
    self.backlayer2 = torch.nn.Linear(2,1)
  
   def forward(self,x):
    sigmoid = torch.nn.Tanh()
    kp = self.kplayer2(sigmoid(self.kplayer1(x)))
    ki = self.kilayer2(sigmoid(self.kilayer1(x)))
    back = self.backlayer2(sigmoid(self.backlayer1(x)))
    #kd = torch.clamp(kd,0,400)
    #kp = torch.clamp(kp,0,400)
    #ki = torch.clamp(ki,0,400)
    return kp,ki,back

# %%
Tft = torch.tensor(Tf,requires_grad=True)
kpit = torch.tensor(kp,requires_grad=False)
kiit = torch.tensor(ki,requires_grad=False)
#kdit = torch.tensor(kd,requires_grad=False)
backit = torch.tensor(0.1,requires_grad=False)

systA = torch.tensor(sysA,requires_grad=False)
systB = torch.tensor(sysB,requires_grad=False)
systC = torch.tensor(sysC,requires_grad=False)
systD = torch.tensor(sysD,requires_grad=False)

# %%
costinit = np.zeros((30,))

yinit = np.zeros((30,T))
uinit = np.zeros((30,T))
Tft = torch.tensor(Tf,requires_grad=True)
kpit = torch.tensor(kp,requires_grad=False)
kiit = torch.tensor(ki,requires_grad=False)
kdit = torch.tensor(kd,requires_grad=False)

systA = torch.tensor(sysA,requires_grad=False)
systB = torch.tensor(sysB,requires_grad=False)
systC = torch.tensor(sysC,requires_grad=False)
systD = torch.tensor(sysD,requires_grad=False)

for iters in range(0,30):
  ref = refs[iters,:]
  reft = torch.tensor(ref)
  noise = 0.05*torch.randn(T,1)

  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0]],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  D  = torch.tensor([0.0],requires_grad=False)
  #torch.clamp(Tft,0.1,0.1)
  ad = torch.div(Tft,(Tft+0.01))
  
  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t];
    yinit[iters,t] = yt.clone().detach().numpy()
    #print(yt)
    #error = torch.tensor(reft[t]-yt,requires_grad=False)
    err = ref[t]-yt
    xcont = xcont+err
    if(t>0):
       #print(t,kpt,kit,kdt)
       #break;
       bd = torch.div(kdit,(Tft+0.01))
       D = ad*D-bd*(yt-yold);  
       u = (0.01*kiit*xcont+kpit*(ref[t]-yt)+D)
       u = torch.clamp(u,-3.3,3.3)
    uinit[iters,t] = u.clone().detach().numpy()
    x = torch.matmul(systA.float(),x)+systB.float()*u;
    cost = cost+(reft[t]-yt)**2
  costinit[iters] = cost.detach().numpy()

# %%
###### print(costinit)
plt.figure()
plt.plot(refs[8,:])
plt.plot(yinit[8,:])
plt.plot(uinit[8,:])

# %%
# Initialize network
Tft = torch.tensor(Tf,requires_grad=True)
kpit = torch.tensor(kp,requires_grad=False)
kiit = torch.tensor(ki,requires_grad=False)
#kdit = torch.tensor(kd,requires_grad=False)
backit = torch.tensor(0.1,requires_grad=False)

kpt = torch.tensor(kp,requires_grad=True)
kit = torch.tensor(ki,requires_grad=True)
#kdit = torch.tensor(kd,requires_grad=False)
backt = torch.tensor(0.1,requires_grad=True)

systA = torch.tensor(sysA,requires_grad=False)
systB = torch.tensor(sysB,requires_grad=False)
systC = torch.tensor(sysC,requires_grad=False)
systD = torch.tensor(sysD,requires_grad=False)

PIDparams = neuralPID()
#optimizer = torch.optim.Adam((PIDparams.parameters()), lr=0.1)
#for iters in range(1000):
#   kpt,kit,kdt = PIDparams(torch.randn(3,))
#   print(kpt,kit,kdt)
#   loss = (kpt-kpit)**2+(kit-kiit)**2+(kdt-kdit)**2
#   optimizer.zero_grad()
#   loss.backward()
#   optimizer.step()    
   #print(iters,loss)

# %%
ysat = np.zeros((T,))
uvalssat = np.zeros((T,))

optimizer = torch.optim.Adam((PIDparams.parameters()), lr=0.1, weight_decay=0.1)
smooth = 0.9
for episodes in range(1001):
  #cepisode = np.random.randint(20)  
  cepisode = episodes%20
  ref = refs[cepisode,:]
  reft = torch.tensor(ref)  
  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0]],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  ucmd = torch.tensor([0.0],requires_grad=True)
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  #D  = torch.tensor([0.0],requires_grad=False)
  #ad = torch.div(Tft,(Tft+0.01))
  noise = 0.01*torch.randn(T,1)
  kpt = kpt.clone().detach()
  kit = kit.clone().detach()
  backt = backt.clone().detach()
  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t]
    saterr = u-ucmd
    err = reft[t]-yt
    ninput = torch.cat((err,saterr),0)
    kpdt,kidt,backdt = PIDparams(ninput)
    kpt = smooth*kpt+(1-smooth)*(kpit+kpdt)
    kit = smooth*kit+(1-smooth)*(kiit+kidt)
    backt = smooth*backt+(1-smooth)*(backit+backdt)
    xcont = xcont+kit*err+backt*saterr.detach()
    if(t>0):
      #bd = torch.div(kdt,(Tft+0.01))
      #D = ad*D-bd*(yt-yold);  
      ucmd = (0.01*xcont+kpt*(reft[t]-yt))
      u = torch.clamp(ucmd,-3.3,3.3)
    x = torch.matmul(systA.float(),x)+systB.float()*u;
    cost = cost+(reft[t]-yt)**2  
  if(episodes%120<20):
    print(episodes,cost)
  optimizer.zero_grad()
  cost.backward()
  optimizer.step()
# Out:
# 0 tensor([58.7995], grad_fn=<AddBackward0>)
# 1 tensor([56.2188], grad_fn=<AddBackward0>)
# 2 tensor([53.3500], grad_fn=<AddBackward0>)
# 3 tensor([50.1808], grad_fn=<AddBackward0>)
# 4 tensor([56.4114], grad_fn=<AddBackward0>)
# 5 tensor([46.5903], grad_fn=<AddBackward0>)
# 6 tensor([52.6793], grad_fn=<AddBackward0>)
# 7 tensor([150.8672], grad_fn=<AddBackward0>)
# 8 tensor([237.2937], grad_fn=<AddBackward0>)
# 9 tensor([46.8675], grad_fn=<AddBackward0>)
# 10 tensor([62.8654], grad_fn=<AddBackward0>)
# 11 tensor([40.6827], grad_fn=<AddBackward0>)
# 12 tensor([39.9954], grad_fn=<AddBackward0>)
# 13 tensor([190.2167], grad_fn=<AddBackward0>)
# 14 tensor([192.3780], grad_fn=<AddBackward0>)
# 15 tensor([170.5181], grad_fn=<AddBackward0>)
# 16 tensor([262.0353], grad_fn=<AddBackward0>)
# 17 tensor([93.3582], grad_fn=<AddBackward0>)
# 18 tensor([54.8927], grad_fn=<AddBackward0>)
# 19 tensor([123.8182], grad_fn=<AddBackward0>)
# 120 tensor([40.0440], grad_fn=<AddBackward0>)
# 121 tensor([40.2300], grad_fn=<AddBackward0>)
# 122 tensor([40.0657], grad_fn=<AddBackward0>)
# 123 tensor([40.3957], grad_fn=<AddBackward0>)
# 124 tensor([40.1128], grad_fn=<AddBackward0>)
# 125 tensor([40.8196], grad_fn=<AddBackward0>)
# 126 tensor([39.7671], grad_fn=<AddBackward0>)
# 127 tensor([146.1521], grad_fn=<AddBackward0>)
# 128 tensor([237.1853], grad_fn=<AddBackward0>)
# 129 tensor([40.0642], grad_fn=<AddBackward0>)
# 130 tensor([62.3834], grad_fn=<AddBackward0>)
# 131 tensor([39.5294], grad_fn=<AddBackward0>)
# 132 tensor([39.9875], grad_fn=<AddBackward0>)
# 133 tensor([183.5623], grad_fn=<AddBackward0>)
# 134 tensor([192.5036], grad_fn=<AddBackward0>)
# 135 tensor([173.9126], grad_fn=<AddBackward0>)
# 136 tensor([268.6917], grad_fn=<AddBackward0>)
# 137 tensor([90.9936], grad_fn=<AddBackward0>)
# 138 tensor([54.8807], grad_fn=<AddBackward0>)
# 139 tensor([127.1292], grad_fn=<AddBackward0>)
# 240 tensor([40.5894], grad_fn=<AddBackward0>)
# 241 tensor([40.6583], grad_fn=<AddBackward0>)
# 242 tensor([40.5892], grad_fn=<AddBackward0>)
# 243 tensor([40.9271], grad_fn=<AddBackward0>)
# 244 tensor([40.2853], grad_fn=<AddBackward0>)
# 245 tensor([40.6892], grad_fn=<AddBackward0>)
# 246 tensor([40.1144], grad_fn=<AddBackward0>)
# 247 tensor([146.1510], grad_fn=<AddBackward0>)
# 248 tensor([236.6024], grad_fn=<AddBackward0>)
# 249 tensor([40.0914], grad_fn=<AddBackward0>)
# 250 tensor([62.9155], grad_fn=<AddBackward0>)
# 251 tensor([40.4706], grad_fn=<AddBackward0>)
# 252 tensor([41.0379], grad_fn=<AddBackward0>)
# 253 tensor([185.2034], grad_fn=<AddBackward0>)
# 254 tensor([191.4629], grad_fn=<AddBackward0>)
# 255 tensor([171.9592], grad_fn=<AddBackward0>)
# 256 tensor([260.9474], grad_fn=<AddBackward0>)
# 257 tensor([90.9204], grad_fn=<AddBackward0>)
# 258 tensor([54.6907], grad_fn=<AddBackward0>)
# 259 tensor([123.6018], grad_fn=<AddBackward0>)
# 360 tensor([40.5522], grad_fn=<AddBackward0>)
# 361 tensor([40.4024], grad_fn=<AddBackward0>)
# 362 tensor([40.7307], grad_fn=<AddBackward0>)
# 363 tensor([40.2285], grad_fn=<AddBackward0>)
# 364 tensor([39.8817], grad_fn=<AddBackward0>)
# 365 tensor([40.5051], grad_fn=<AddBackward0>)
# 366 tensor([40.0893], grad_fn=<AddBackward0>)
# 367 tensor([146.1200], grad_fn=<AddBackward0>)
# 368 tensor([236.7262], grad_fn=<AddBackward0>)
# 369 tensor([40.4123], grad_fn=<AddBackward0>)
# 370 tensor([62.4806], grad_fn=<AddBackward0>)
# 371 tensor([40.0329], grad_fn=<AddBackward0>)
# 372 tensor([40.3989], grad_fn=<AddBackward0>)
# 373 tensor([185.3549], grad_fn=<AddBackward0>)
# 374 tensor([189.1192], grad_fn=<AddBackward0>)
# 375 tensor([169.1419], grad_fn=<AddBackward0>)
# 376 tensor([261.2151], grad_fn=<AddBackward0>)
# 377 tensor([91.0927], grad_fn=<AddBackward0>)
# 378 tensor([54.9974], grad_fn=<AddBackward0>)
# 379 tensor([123.8234], grad_fn=<AddBackward0>)
# 480 tensor([41.0739], grad_fn=<AddBackward0>)
# 481 tensor([40.7877], grad_fn=<AddBackward0>)
# 482 tensor([40.6225], grad_fn=<AddBackward0>)
# 483 tensor([40.3461], grad_fn=<AddBackward0>)
# 484 tensor([41.8562], grad_fn=<AddBackward0>)
# 485 tensor([40.2505], grad_fn=<AddBackward0>)
# 486 tensor([42.5450], grad_fn=<AddBackward0>)
# 487 tensor([146.5455], grad_fn=<AddBackward0>)
# 488 tensor([238.2411], grad_fn=<AddBackward0>)
# 489 tensor([42.3157], grad_fn=<AddBackward0>)
# 490 tensor([62.6083], grad_fn=<AddBackward0>)
# 491 tensor([39.9783], grad_fn=<AddBackward0>)
# 492 tensor([40.3876], grad_fn=<AddBackward0>)
# 493 tensor([185.5802], grad_fn=<AddBackward0>)
# 494 tensor([211.6903], grad_fn=<AddBackward0>)
# 495 tensor([186.9753], grad_fn=<AddBackward0>)
# 496 tensor([290.6574], grad_fn=<AddBackward0>)
# 497 tensor([90.5826], grad_fn=<AddBackward0>)
# 498 tensor([55.3565], grad_fn=<AddBackward0>)
# 499 tensor([124.7975], grad_fn=<AddBackward0>)
# 600 tensor([40.6439], grad_fn=<AddBackward0>)
# 601 tensor([40.5061], grad_fn=<AddBackward0>)
# 602 tensor([40.7356], grad_fn=<AddBackward0>)
# 603 tensor([40.8289], grad_fn=<AddBackward0>)
# 604 tensor([41.1680], grad_fn=<AddBackward0>)
# 605 tensor([40.7955], grad_fn=<AddBackward0>)
# 606 tensor([41.7410], grad_fn=<AddBackward0>)
# 607 tensor([152.2981], grad_fn=<AddBackward0>)
# 608 tensor([246.2855], grad_fn=<AddBackward0>)
# 609 tensor([41.8228], grad_fn=<AddBackward0>)
# 610 tensor([63.2835], grad_fn=<AddBackward0>)
# 611 tensor([40.3394], grad_fn=<AddBackward0>)
# 612 tensor([40.4628], grad_fn=<AddBackward0>)
# 613 tensor([186.1050], grad_fn=<AddBackward0>)
# 614 tensor([199.5747], grad_fn=<AddBackward0>)
# 615 tensor([177.7011], grad_fn=<AddBackward0>)
# 616 tensor([275.0170], grad_fn=<AddBackward0>)
# 617 tensor([91.4854], grad_fn=<AddBackward0>)
# 618 tensor([54.9649], grad_fn=<AddBackward0>)
# 619 tensor([122.5512], grad_fn=<AddBackward0>)
# 720 tensor([41.1776], grad_fn=<AddBackward0>)
# 721 tensor([41.3324], grad_fn=<AddBackward0>)
# 722 tensor([41.1128], grad_fn=<AddBackward0>)
# 723 tensor([41.6065], grad_fn=<AddBackward0>)
# 724 tensor([40.1080], grad_fn=<AddBackward0>)
# 725 tensor([40.7035], grad_fn=<AddBackward0>)
# 726 tensor([40.2676], grad_fn=<AddBackward0>)
# 727 tensor([149.9317], grad_fn=<AddBackward0>)
# 728 tensor([242.8058], grad_fn=<AddBackward0>)
# 729 tensor([40.5813], grad_fn=<AddBackward0>)
# 730 tensor([61.8252], grad_fn=<AddBackward0>)
# 731 tensor([39.5998], grad_fn=<AddBackward0>)
# 732 tensor([40.4804], grad_fn=<AddBackward0>)
# 733 tensor([185.5920], grad_fn=<AddBackward0>)
# 734 tensor([191.9050], grad_fn=<AddBackward0>)
# 735 tensor([172.0342], grad_fn=<AddBackward0>)
# 736 tensor([263.9316], grad_fn=<AddBackward0>)
# 737 tensor([93.0072], grad_fn=<AddBackward0>)
# 738 tensor([54.9655], grad_fn=<AddBackward0>)
# 739 tensor([126.1738], grad_fn=<AddBackward0>)
# 840 tensor([40.2628], grad_fn=<AddBackward0>)
# 841 tensor([40.0165], grad_fn=<AddBackward0>)
# 842 tensor([39.9100], grad_fn=<AddBackward0>)
# 843 tensor([40.1537], grad_fn=<AddBackward0>)
# 844 tensor([40.9790], grad_fn=<AddBackward0>)
# 845 tensor([40.4122], grad_fn=<AddBackward0>)
# 846 tensor([40.4354], grad_fn=<AddBackward0>)
# 847 tensor([146.0851], grad_fn=<AddBackward0>)
# 848 tensor([237.7765], grad_fn=<AddBackward0>)
# 849 tensor([40.4790], grad_fn=<AddBackward0>)
# 850 tensor([62.8178], grad_fn=<AddBackward0>)
# 851 tensor([39.8116], grad_fn=<AddBackward0>)
# 852 tensor([40.2065], grad_fn=<AddBackward0>)
# 853 tensor([184.6762], grad_fn=<AddBackward0>)
# 854 tensor([188.8177], grad_fn=<AddBackward0>)
# 855 tensor([169.6848], grad_fn=<AddBackward0>)
# 856 tensor([260.1021], grad_fn=<AddBackward0>)
# 857 tensor([90.2754], grad_fn=<AddBackward0>)
# 858 tensor([54.4435], grad_fn=<AddBackward0>)
# 859 tensor([124.0573], grad_fn=<AddBackward0>)
# 960 tensor([41.5546], grad_fn=<AddBackward0>)
# 961 tensor([41.1666], grad_fn=<AddBackward0>)
# 962 tensor([40.8402], grad_fn=<AddBackward0>)
# 963 tensor([41.3752], grad_fn=<AddBackward0>)
# 964 tensor([40.8345], grad_fn=<AddBackward0>)
# 965 tensor([40.5425], grad_fn=<AddBackward0>)
# 966 tensor([40.1028], grad_fn=<AddBackward0>)
# 967 tensor([148.5812], grad_fn=<AddBackward0>)
# 968 tensor([239.8763], grad_fn=<AddBackward0>)
# 969 tensor([39.9991], grad_fn=<AddBackward0>)
# 970 tensor([64.0954], grad_fn=<AddBackward0>)
# 971 tensor([40.4025], grad_fn=<AddBackward0>)
# 972 tensor([40.4666], grad_fn=<AddBackward0>)
# 973 tensor([186.4167], grad_fn=<AddBackward0>)
# 974 tensor([190.2711], grad_fn=<AddBackward0>)
# 975 tensor([171.3693], grad_fn=<AddBackward0>)
# 976 tensor([261.9564], grad_fn=<AddBackward0>)
# 977 tensor([91.6143], grad_fn=<AddBackward0>)
# 978 tensor([54.8861], grad_fn=<AddBackward0>)
# 979 tensor([123.6162], grad_fn=<AddBackward0>)

# %%
#plt.figure()
#plt.plot(ref)
torch.save(PIDparams.state_dict(), "fodgradientparams")

# %%
kpst = torch.tensor(kp,requires_grad=True)
kist = torch.tensor(ki,requires_grad=True)
#kdst = torch.tensor(kd,requires_grad=True)
backst = torch.tensor(0.1,requires_grad=True)
#Tft = torch.tensor(Tf,requires_grad=True)
optimizer = torch.optim.Adam((kpst,kist,backst), lr=0.1, weight_decay=0.1)

stlossvals = []
closs = 0
kptrain = []
kitrain = []
kdtrain = []
backtrain = []
for episodes in range(1001):
  cepisode = episodes%20
  ref = refs[cepisode,:]
  reft = torch.tensor(ref)  
  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0]],requires_grad=True)  
  ucmd = torch.tensor([0.0],requires_grad=True)
  u = torch.tensor([0.0],requires_grad=True)  
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  D  = torch.tensor([0.0],requires_grad=False)
  #torch.clamp(Tft,0.1,0.1)
  #ad = torch.div(Tft,(Tft+0.01))
  #bd = torch.div(kdst,(Tft+0.01))
  noise = 0.01*torch.randn(T,1)
  
  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t];
    #error = torch.tensor(reft[t]-yt,requires_grad=False)
    saterr = u-ucmd
    xcont = xcont+kist*(reft[t]-yt)+backst*saterr
    if(t>0):
       #deriv = torch.tensor(yt-yold,requires_grad=False) 
       #D = ad*D-bd*(yt-yold);  
       ucmd = (0.01*xcont+kpst*(reft[t]-yt))
    u = torch.clamp(ucmd,-3.3,3.3)
    uvalssat[i] = u;
    x = torch.matmul(systA.float(),x)+systB.float()*u;
    cost = cost+torch.clamp((reft[t]-yt)**2,0,50)
  closs = closs+cost  
  if(episodes%20==19):    
    stlossvals.append(closs.clone().detach().numpy()/20)
    closs = 0
  kptrain.append(kpst.clone().detach().numpy())
  kitrain.append(kist.clone().detach().numpy())
  #kdtrain.append(kdst.clone().detach().numpy())
  backtrain.append(backst.clone().detach().numpy())  
  if(episodes%120<20):
    #print(kpt,kdt,kit,Tft)
    print(episodes,cost,backst) 
  optimizer.zero_grad()
  cost.backward()
  optimizer.step()

print(kpst,kist,backst)
# Out:
# 0 tensor([60.2904], grad_fn=<AddBackward0>) tensor(0.1000, requires_grad=True)
# 1 tensor([59.2130], grad_fn=<AddBackward0>) tensor(0.2000, requires_grad=True)
# 2 tensor([56.9503], grad_fn=<AddBackward0>) tensor(0.2999, requires_grad=True)
# 3 tensor([55.9406], grad_fn=<AddBackward0>) tensor(0.3994, requires_grad=True)
# 4 tensor([54.6603], grad_fn=<AddBackward0>) tensor(0.4985, requires_grad=True)
# 5 tensor([53.5551], grad_fn=<AddBackward0>) tensor(0.5971, requires_grad=True)
# 6 tensor([52.4434], grad_fn=<AddBackward0>) tensor(0.6951, requires_grad=True)
# 7 tensor([183.3102], grad_fn=<AddBackward0>) tensor(0.7923, requires_grad=True)
# 8 tensor([287.1890], grad_fn=<AddBackward0>) tensor(0.8777, requires_grad=True)
# 9 tensor([49.2562], grad_fn=<AddBackward0>) tensor(0.9612, requires_grad=True)
# 10 tensor([75.2158], grad_fn=<AddBackward0>) tensor(1.0393, requires_grad=True)
# 11 tensor([47.9997], grad_fn=<AddBackward0>) tensor(1.1150, requires_grad=True)
# 12 tensor([47.3060], grad_fn=<AddBackward0>) tensor(1.1861, requires_grad=True)
# 13 tensor([206.0774], grad_fn=<AddBackward0>) tensor(1.2533, requires_grad=True)
# 14 tensor([206.6506], grad_fn=<AddBackward0>) tensor(1.3270, requires_grad=True)
# 15 tensor([184.5339], grad_fn=<AddBackward0>) tensor(1.4056, requires_grad=True)
# 16 tensor([275.4460], grad_fn=<AddBackward0>) tensor(1.4866, requires_grad=True)
# 17 tensor([97.7495], grad_fn=<AddBackward0>) tensor(1.5715, requires_grad=True)
# 18 tensor([59.0130], grad_fn=<AddBackward0>) tensor(1.6531, requires_grad=True)
# 19 tensor([128.9476], grad_fn=<AddBackward0>) tensor(1.7297, requires_grad=True)
# 120 tensor([41.2668], grad_fn=<AddBackward0>) tensor(2.0030, requires_grad=True)
# 121 tensor([41.1252], grad_fn=<AddBackward0>) tensor(1.9936, requires_grad=True)
# 122 tensor([41.3560], grad_fn=<AddBackward0>) tensor(1.9867, requires_grad=True)
# 123 tensor([41.1309], grad_fn=<AddBackward0>) tensor(1.9823, requires_grad=True)
# 124 tensor([41.4315], grad_fn=<AddBackward0>) tensor(1.9800, requires_grad=True)
# 125 tensor([41.0412], grad_fn=<AddBackward0>) tensor(1.9797, requires_grad=True)
# 126 tensor([41.1476], grad_fn=<AddBackward0>) tensor(1.9812, requires_grad=True)
# 127 tensor([145.7895], grad_fn=<AddBackward0>) tensor(1.9842, requires_grad=True)
# 128 tensor([235.9835], grad_fn=<AddBackward0>) tensor(1.9855, requires_grad=True)
# 129 tensor([41.1794], grad_fn=<AddBackward0>) tensor(1.9788, requires_grad=True)
# 130 tensor([62.9972], grad_fn=<AddBackward0>) tensor(1.9744, requires_grad=True)
# 131 tensor([40.9716], grad_fn=<AddBackward0>) tensor(1.9722, requires_grad=True)
# 132 tensor([40.8524], grad_fn=<AddBackward0>) tensor(1.9719, requires_grad=True)
# 133 tensor([185.6436], grad_fn=<AddBackward0>) tensor(1.9733, requires_grad=True)
# 134 tensor([190.5651], grad_fn=<AddBackward0>) tensor(1.9694, requires_grad=True)
# 135 tensor([169.9808], grad_fn=<AddBackward0>) tensor(1.9600, requires_grad=True)
# 136 tensor([261.6176], grad_fn=<AddBackward0>) tensor(1.9474, requires_grad=True)
# 137 tensor([91.1534], grad_fn=<AddBackward0>) tensor(1.9251, requires_grad=True)
# 138 tensor([55.3270], grad_fn=<AddBackward0>) tensor(1.9063, requires_grad=True)
# 139 tensor([123.8087], grad_fn=<AddBackward0>) tensor(1.8915, requires_grad=True)
# 240 tensor([41.7917], grad_fn=<AddBackward0>) tensor(1.3873, requires_grad=True)
# 241 tensor([42.0749], grad_fn=<AddBackward0>) tensor(1.3777, requires_grad=True)
# 242 tensor([41.9458], grad_fn=<AddBackward0>) tensor(1.3736, requires_grad=True)
# 243 tensor([41.8209], grad_fn=<AddBackward0>) tensor(1.3744, requires_grad=True)
# 244 tensor([41.9916], grad_fn=<AddBackward0>) tensor(1.3797, requires_grad=True)
# 245 tensor([41.3414], grad_fn=<AddBackward0>) tensor(1.3889, requires_grad=True)
# 246 tensor([41.4339], grad_fn=<AddBackward0>) tensor(1.4015, requires_grad=True)
# 247 tensor([145.6312], grad_fn=<AddBackward0>) tensor(1.4172, requires_grad=True)
# 248 tensor([236.3212], grad_fn=<AddBackward0>) tensor(1.4307, requires_grad=True)
# 249 tensor([41.2905], grad_fn=<AddBackward0>) tensor(1.4283, requires_grad=True)
# 250 tensor([63.5358], grad_fn=<AddBackward0>) tensor(1.4301, requires_grad=True)
# 251 tensor([41.2642], grad_fn=<AddBackward0>) tensor(1.4359, requires_grad=True)
# 252 tensor([41.2296], grad_fn=<AddBackward0>) tensor(1.4450, requires_grad=True)
# 253 tensor([185.9130], grad_fn=<AddBackward0>) tensor(1.4570, requires_grad=True)
# 254 tensor([188.4588], grad_fn=<AddBackward0>) tensor(1.4578, requires_grad=True)
# 255 tensor([168.5056], grad_fn=<AddBackward0>) tensor(1.4478, requires_grad=True)
# 256 tensor([263.0958], grad_fn=<AddBackward0>) tensor(1.4319, requires_grad=True)
# 257 tensor([91.7949], grad_fn=<AddBackward0>) tensor(1.3949, requires_grad=True)
# 258 tensor([55.8655], grad_fn=<AddBackward0>) tensor(1.3652, requires_grad=True)
# 259 tensor([123.7815], grad_fn=<AddBackward0>) tensor(1.3435, requires_grad=True)
# 360 tensor([42.0442], grad_fn=<AddBackward0>) tensor(1.2022, requires_grad=True)
# 361 tensor([41.8915], grad_fn=<AddBackward0>) tensor(1.1935, requires_grad=True)
# 362 tensor([41.5787], grad_fn=<AddBackward0>) tensor(1.1915, requires_grad=True)
# 363 tensor([41.6161], grad_fn=<AddBackward0>) tensor(1.1955, requires_grad=True)
# 364 tensor([41.9414], grad_fn=<AddBackward0>) tensor(1.2049, requires_grad=True)
# 365 tensor([41.8171], grad_fn=<AddBackward0>) tensor(1.2192, requires_grad=True)
# 366 tensor([41.8562], grad_fn=<AddBackward0>) tensor(1.2376, requires_grad=True)
# 367 tensor([146.7447], grad_fn=<AddBackward0>) tensor(1.2597, requires_grad=True)
# 368 tensor([238.2912], grad_fn=<AddBackward0>) tensor(1.2803, requires_grad=True)
# 369 tensor([41.4198], grad_fn=<AddBackward0>) tensor(1.2831, requires_grad=True)
# 370 tensor([63.8415], grad_fn=<AddBackward0>) tensor(1.2905, requires_grad=True)
# 371 tensor([41.7826], grad_fn=<AddBackward0>) tensor(1.3023, requires_grad=True)
# 372 tensor([40.8148], grad_fn=<AddBackward0>) tensor(1.3176, requires_grad=True)
# 373 tensor([185.5299], grad_fn=<AddBackward0>) tensor(1.3359, requires_grad=True)
# 374 tensor([190.4219], grad_fn=<AddBackward0>) tensor(1.3401, requires_grad=True)
# 375 tensor([169.5954], grad_fn=<AddBackward0>) tensor(1.3300, requires_grad=True)
# 376 tensor([262.3506], grad_fn=<AddBackward0>) tensor(1.3121, requires_grad=True)
# 377 tensor([91.5493], grad_fn=<AddBackward0>) tensor(1.2709, requires_grad=True)
# 378 tensor([55.6074], grad_fn=<AddBackward0>) tensor(1.2386, requires_grad=True)
# 379 tensor([123.7342], grad_fn=<AddBackward0>) tensor(1.2157, requires_grad=True)
# 480 tensor([42.0534], grad_fn=<AddBackward0>) tensor(1.1807, requires_grad=True)
# 481 tensor([42.2644], grad_fn=<AddBackward0>) tensor(1.1719, requires_grad=True)
# 482 tensor([41.5875], grad_fn=<AddBackward0>) tensor(1.1700, requires_grad=True)
# 483 tensor([41.7508], grad_fn=<AddBackward0>) tensor(1.1744, requires_grad=True)
# 484 tensor([41.9468], grad_fn=<AddBackward0>) tensor(1.1844, requires_grad=True)
# 485 tensor([41.5342], grad_fn=<AddBackward0>) tensor(1.1994, requires_grad=True)
# 486 tensor([41.5224], grad_fn=<AddBackward0>) tensor(1.2187, requires_grad=True)
# 487 tensor([145.6590], grad_fn=<AddBackward0>) tensor(1.2417, requires_grad=True)
# 488 tensor([236.5291], grad_fn=<AddBackward0>) tensor(1.2635, requires_grad=True)
# 489 tensor([41.6655], grad_fn=<AddBackward0>) tensor(1.2675, requires_grad=True)
# 490 tensor([63.4213], grad_fn=<AddBackward0>) tensor(1.2761, requires_grad=True)
# 491 tensor([41.1091], grad_fn=<AddBackward0>) tensor(1.2891, requires_grad=True)
# 492 tensor([41.3128], grad_fn=<AddBackward0>) tensor(1.3055, requires_grad=True)
# 493 tensor([185.9506], grad_fn=<AddBackward0>) tensor(1.3248, requires_grad=True)
# 494 tensor([191.1175], grad_fn=<AddBackward0>) tensor(1.3289, requires_grad=True)
# 495 tensor([169.4871], grad_fn=<AddBackward0>) tensor(1.3175, requires_grad=True)
# 496 tensor([261.8796], grad_fn=<AddBackward0>) tensor(1.2978, requires_grad=True)
# 497 tensor([91.3993], grad_fn=<AddBackward0>) tensor(1.2542, requires_grad=True)
# 498 tensor([55.8688], grad_fn=<AddBackward0>) tensor(1.2199, requires_grad=True)
# 499 tensor([123.8841], grad_fn=<AddBackward0>) tensor(1.1953, requires_grad=True)
# 600 tensor([41.5138], grad_fn=<AddBackward0>) tensor(1.1714, requires_grad=True)
# 601 tensor([41.7701], grad_fn=<AddBackward0>) tensor(1.1632, requires_grad=True)
# 602 tensor([41.9288], grad_fn=<AddBackward0>) tensor(1.1619, requires_grad=True)
# 603 tensor([41.7318], grad_fn=<AddBackward0>) tensor(1.1670, requires_grad=True)
# 604 tensor([41.8745], grad_fn=<AddBackward0>) tensor(1.1776, requires_grad=True)
# 605 tensor([41.7375], grad_fn=<AddBackward0>) tensor(1.1933, requires_grad=True)
# 606 tensor([41.7533], grad_fn=<AddBackward0>) tensor(1.2132, requires_grad=True)
# 607 tensor([146.5708], grad_fn=<AddBackward0>) tensor(1.2366, requires_grad=True)
# 608 tensor([237.4946], grad_fn=<AddBackward0>) tensor(1.2584, requires_grad=True)
# 609 tensor([41.3127], grad_fn=<AddBackward0>) tensor(1.2614, requires_grad=True)
# 610 tensor([63.4771], grad_fn=<AddBackward0>) tensor(1.2691, requires_grad=True)
# 611 tensor([41.2586], grad_fn=<AddBackward0>) tensor(1.2813, requires_grad=True)
# 612 tensor([41.4837], grad_fn=<AddBackward0>) tensor(1.2971, requires_grad=True)
# 613 tensor([185.2456], grad_fn=<AddBackward0>) tensor(1.3158, requires_grad=True)
# 614 tensor([189.6958], grad_fn=<AddBackward0>) tensor(1.3196, requires_grad=True)
# 615 tensor([170.1647], grad_fn=<AddBackward0>) tensor(1.3084, requires_grad=True)
# 616 tensor([260.3998], grad_fn=<AddBackward0>) tensor(1.2887, requires_grad=True)
# 617 tensor([92.0188], grad_fn=<AddBackward0>) tensor(1.2455, requires_grad=True)
# 618 tensor([56.1865], grad_fn=<AddBackward0>) tensor(1.2117, requires_grad=True)
# 619 tensor([124.4332], grad_fn=<AddBackward0>) tensor(1.1877, requires_grad=True)
# 720 tensor([41.9188], grad_fn=<AddBackward0>) tensor(1.1737, requires_grad=True)
# 721 tensor([41.8355], grad_fn=<AddBackward0>) tensor(1.1649, requires_grad=True)
# 722 tensor([41.7655], grad_fn=<AddBackward0>) tensor(1.1633, requires_grad=True)
# 723 tensor([41.9740], grad_fn=<AddBackward0>) tensor(1.1680, requires_grad=True)
# 724 tensor([41.8201], grad_fn=<AddBackward0>) tensor(1.1784, requires_grad=True)
# 725 tensor([41.7072], grad_fn=<AddBackward0>) tensor(1.1938, requires_grad=True)
# 726 tensor([41.5841], grad_fn=<AddBackward0>) tensor(1.2136, requires_grad=True)
# 727 tensor([146.1630], grad_fn=<AddBackward0>) tensor(1.2370, requires_grad=True)
# 728 tensor([236.6395], grad_fn=<AddBackward0>) tensor(1.2590, requires_grad=True)
# 729 tensor([41.2016], grad_fn=<AddBackward0>) tensor(1.2627, requires_grad=True)
# 730 tensor([63.5542], grad_fn=<AddBackward0>) tensor(1.2710, requires_grad=True)
# 731 tensor([41.4169], grad_fn=<AddBackward0>) tensor(1.2839, requires_grad=True)
# 732 tensor([41.2797], grad_fn=<AddBackward0>) tensor(1.3003, requires_grad=True)
# 733 tensor([185.2539], grad_fn=<AddBackward0>) tensor(1.3196, requires_grad=True)
# 734 tensor([190.6609], grad_fn=<AddBackward0>) tensor(1.3236, requires_grad=True)
# 735 tensor([169.8489], grad_fn=<AddBackward0>) tensor(1.3119, requires_grad=True)
# 736 tensor([261.2585], grad_fn=<AddBackward0>) tensor(1.2917, requires_grad=True)
# 737 tensor([91.5554], grad_fn=<AddBackward0>) tensor(1.2461, requires_grad=True)
# 738 tensor([55.9493], grad_fn=<AddBackward0>) tensor(1.2101, requires_grad=True)
# 739 tensor([124.5196], grad_fn=<AddBackward0>) tensor(1.1842, requires_grad=True)
# 840 tensor([42.2511], grad_fn=<AddBackward0>) tensor(1.1740, requires_grad=True)
# 841 tensor([41.9678], grad_fn=<AddBackward0>) tensor(1.1655, requires_grad=True)
# 842 tensor([41.8069], grad_fn=<AddBackward0>) tensor(1.1640, requires_grad=True)
# 843 tensor([41.6929], grad_fn=<AddBackward0>) tensor(1.1690, requires_grad=True)
# 844 tensor([41.8585], grad_fn=<AddBackward0>) tensor(1.1797, requires_grad=True)
# 845 tensor([41.7198], grad_fn=<AddBackward0>) tensor(1.1954, requires_grad=True)
# 846 tensor([41.5657], grad_fn=<AddBackward0>) tensor(1.2155, requires_grad=True)
# 847 tensor([145.7642], grad_fn=<AddBackward0>) tensor(1.2393, requires_grad=True)
# 848 tensor([236.8447], grad_fn=<AddBackward0>) tensor(1.2622, requires_grad=True)
# 849 tensor([41.5456], grad_fn=<AddBackward0>) tensor(1.2671, requires_grad=True)
# 850 tensor([62.8580], grad_fn=<AddBackward0>) tensor(1.2766, requires_grad=True)
# 851 tensor([41.4677], grad_fn=<AddBackward0>) tensor(1.2907, requires_grad=True)
# 852 tensor([40.9937], grad_fn=<AddBackward0>) tensor(1.3082, requires_grad=True)
# 853 tensor([185.8979], grad_fn=<AddBackward0>) tensor(1.3285, requires_grad=True)
# 854 tensor([190.0308], grad_fn=<AddBackward0>) tensor(1.3331, requires_grad=True)
# 855 tensor([169.1506], grad_fn=<AddBackward0>) tensor(1.3220, requires_grad=True)
# 856 tensor([260.6960], grad_fn=<AddBackward0>) tensor(1.3025, requires_grad=True)
# 857 tensor([91.4296], grad_fn=<AddBackward0>) tensor(1.2586, requires_grad=True)
# 858 tensor([55.7844], grad_fn=<AddBackward0>) tensor(1.2241, requires_grad=True)
# 859 tensor([123.9127], grad_fn=<AddBackward0>) tensor(1.1994, requires_grad=True)
# 960 tensor([42.2019], grad_fn=<AddBackward0>) tensor(1.1792, requires_grad=True)
# 961 tensor([41.8214], grad_fn=<AddBackward0>) tensor(1.1712, requires_grad=True)
# 962 tensor([41.7592], grad_fn=<AddBackward0>) tensor(1.1702, requires_grad=True)
# 963 tensor([41.9961], grad_fn=<AddBackward0>) tensor(1.1756, requires_grad=True)
# 964 tensor([41.9382], grad_fn=<AddBackward0>) tensor(1.1866, requires_grad=True)
# 965 tensor([41.7804], grad_fn=<AddBackward0>) tensor(1.2026, requires_grad=True)
# 966 tensor([41.5272], grad_fn=<AddBackward0>) tensor(1.2228, requires_grad=True)
# 967 tensor([146.1272], grad_fn=<AddBackward0>) tensor(1.2466, requires_grad=True)
# 968 tensor([236.2848], grad_fn=<AddBackward0>) tensor(1.2687, requires_grad=True)
# 969 tensor([41.4601], grad_fn=<AddBackward0>) tensor(1.2719, requires_grad=True)
# 970 tensor([63.3491], grad_fn=<AddBackward0>) tensor(1.2799, requires_grad=True)
# 971 tensor([41.4683], grad_fn=<AddBackward0>) tensor(1.2924, requires_grad=True)
# 972 tensor([41.1311], grad_fn=<AddBackward0>) tensor(1.3083, requires_grad=True)
# 973 tensor([187.1736], grad_fn=<AddBackward0>) tensor(1.3272, requires_grad=True)
# 974 tensor([190.3483], grad_fn=<AddBackward0>) tensor(1.3298, requires_grad=True)
# 975 tensor([169.5719], grad_fn=<AddBackward0>) tensor(1.3170, requires_grad=True)
# 976 tensor([261.6239], grad_fn=<AddBackward0>) tensor(1.2962, requires_grad=True)
# 977 tensor([91.5037], grad_fn=<AddBackward0>) tensor(1.2512, requires_grad=True)
# 978 tensor([55.8617], grad_fn=<AddBackward0>) tensor(1.2158, requires_grad=True)
# 979 tensor([123.4545], grad_fn=<AddBackward0>) tensor(1.1905, requires_grad=True)
# tensor(6.0300, requires_grad=True) tensor(2.5801, requires_grad=True) tensor(1.1685, requires_grad=True)

# %%
kps = kpst.detach().numpy()
kis = kist.detach().numpy()
#kds = kdst.detach().numpy()
backs = backst.detach().numpy()
print(kps,kis,backs)

plt.figure()
plt.plot(np.arange(len(stlossvals))*20,stlossvals)
plt.xlabel("No. of episodes")
plt.ylabel("Loss")

plt.figure()
plt.plot(np.arange(len(kptrain)),kptrain)
plt.xlabel("No. of episodes")
plt.ylabel("kp")

#plt.figure()
#plt.plot(np.arange(len(kdtrain)),kdtrain)
#plt.xlabel("No. of episodes")
#plt.ylabel("kd")

plt.figure()
plt.plot(np.arange(len(kitrain)),kitrain)
plt.xlabel("No. of episodes")
plt.ylabel("ki")

plt.figure()
plt.plot(np.arange(len(backtrain)),backtrain)
plt.xlabel("No. of episodes")
plt.ylabel("Back-calculation constant")
# Out:
# 6.029956 2.5800996 1.1684914
# Text(0, 0.5, 'Back-calculation constant')

# %%
costdgradient = np.zeros((10,))
costinit = np.zeros((10,))
costsgradient = np.zeros((10,))
kpt = torch.tensor(kp,requires_grad=True)
kit = torch.tensor(ki,requires_grad=True)
#kdit = torch.tensor(kd,requires_grad=False)
backt = torch.tensor(0.1,requires_grad=True)

ydgradient = np.zeros((10,T))
udgradient = np.zeros((10,T))

ysgradient = np.zeros((10,T))
usgradient = np.zeros((10,T))
smooth = 0.9

kpdgradient = np.zeros((10,T))
kidgradient = np.zeros((10,T))
#kddgradient = np.zeros((10,T))
backdgradient = np.zeros((10,T))
#PIDparams = neuralPID()
#PIDparams.load_state_dict(torch.load("dgradientparams"))

#yinit = np.zeros((10,T))
#uinit = np.zeros((10,T))

for iters in range(0,10):
  ref = refs[20+iters,:]
  reft = torch.tensor(ref)
  noise = 0.01*torch.randn(T,1)  
  
  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0]],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  ucmd = torch.tensor([0.0],requires_grad=True)
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
#  D  = torch.tensor([0.0],requires_grad=False)
  #torch.clamp(Tft,0.1,0.1)
#  ad = torch.div(Tft,(Tft+0.01))
  
  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t];
    ydgradient[iters,t] = yt.clone().detach().numpy()
    #print(yt)
    #error = torch.tensor(reft[t]-yt,requires_grad=False)
    saterr = u-ucmd
    err = reft[t]-yt
    ninput = torch.cat((err.detach(),saterr.detach()),0)
    kpdt,kidt,backdt = PIDparams(ninput)
    kpt = smooth*kpt+(1-smooth)*(kpit+kpdt)
    kit = smooth*kit+(1-smooth)*(kiit+kidt)
    backt = smooth*backt+(1-smooth)*(backit+backdt)
    xcont = xcont+kit*err+backt*saterr.detach()
    if(t>0):
#      bd = torch.div(kdt,(Tft+0.01))
#      D = ad*D-bd*(yt-yold);  
      ucmd = (0.01*xcont+kpt*(reft[t]-yt))
      u = torch.clamp(ucmd,-3.3,3.3)
      udgradient[iters,t] = u.clone().detach().numpy()
      kpdgradient[iters,t] = kpt.clone().detach().numpy()
      kidgradient[iters,t] = kit.clone().detach().numpy()
#      kddgradient[iters,t] = kdt.clone().detach().numpy()
      backdgradient[iters,t] = backt.clone().detach().numpy()  
    x = torch.matmul(systA.float(),x)+systB.float()*u;
    cost = cost+(reft[t]-yt)**2
    
  costdgradient[iters] = cost.detach().numpy()

  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0]],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  #D  = torch.tensor([0.0],requires_grad=False)
  #torch.clamp(Tft,0.1,0.1)
  #ad = torch.div(Tft,(Tft+0.01))
  
  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t];
    yinit[iters,t] = yt.clone().detach().numpy()
    #print(yt)
    #error = torch.tensor(reft[t]-yt,requires_grad=False)
    err = ref[t]-yt
    xcont = xcont+err
    if(t>0):
       #print(t,kpt,kit,kdt)
       #break;
       #bd = torch.div(kdit,(Tft+0.01))
       #D = ad*D-bd*(yt-yold);  
       u = (0.01*kiit*xcont+kpit*(ref[t]-yt))
       u = torch.clamp(u,-3.3,3.3)
    uinit[iters,t] = u.clone().detach().numpy()
    x = torch.matmul(systA.float(),x)+systB.float()*u;
    cost = cost+(reft[t]-yt)**2
  costinit[iters] = cost.detach().numpy()

  xcont = torch.tensor([0.0],requires_grad=True)
  x = torch.tensor([[0.0]],requires_grad=True)  
  u = torch.tensor([0.0],requires_grad=True)
  cost = torch.tensor([0.0],requires_grad=True)
  yt = torch.tensor([0.0],requires_grad=True)
  D  = torch.tensor([0.0],requires_grad=False)
  #torch.clamp(Tft,0.1,0.1)
  #ad = torch.div(Tft,(Tft+0.01))
  #bd = torch.div(kdst,(Tft+0.01))

  for t in range(T):
    yold = yt
    yt = torch.matmul(systC.float(),x)+noise[t];
    ysgradient[iters,t] = yt.clone().detach().numpy()
    #print(yt)
    #error = torch.tensor(reft[t]-yt,requires_grad=False)
    saterr = u-ucmd
    xcont = xcont+kist*(reft[t]-yt)+backst*saterr.detach()
    if(t>0):
       #deriv = torch.tensor(yt-yold,requires_grad=False) 
       #D = ad*D-bd*(yt-yold);  
       ucmd = (0.01*xcont+kpst*(reft[t]-yt))
    u = torch.clamp(ucmd,-3.3,3.3)
    usgradient[iters,t] = u.clone().detach().numpy()
    x = torch.matmul(systA.float(),x)+systB.float()*u;
    cost = cost+(reft[t]-yt)**2
  costsgradient[iters] = cost.detach().numpy()

# %%
print("Dgradient-dynamic",costdgradient)
print("Dgradient-static",costsgradient)
print("Initial",costinit)
# Out:
# Dgradient-dynamic [262.44454956  67.55183411  40.75533676  55.99765396 135.28314209
#   39.91223526 111.23078918 212.90907288  39.96796417  39.89403534]
# Dgradient-static [259.11569214  68.77529144  42.38205338  57.45540237 135.7542572
#   41.65450668 111.94981384 210.09933472  41.76825333  41.71579742]
# Initial [862.5960083  106.02617645  61.85018539  86.93269348 224.16003418
#   60.78626251 180.28944397 455.92980957  61.11427689  60.92399216]

# %%
plt.figure()
plt.plot(0.01*np.arange(0,T),refs[20,:])
plt.plot(0.01*np.arange(0,T),ydgradient[0,:])
plt.plot(0.01*np.arange(0,T),ysgradient[0,:])
plt.plot(0.01*np.arange(0,T),yinit[0,:])
plt.xlabel("Time(s)")
plt.ylabel("Output")
plt.legend(["Reference","D-gradient (dynamic)","D-gradient (static)","Initial"])

plt.figure()
plt.plot(0.01*np.arange(0,T),uinit[0,:])
plt.plot(0.01*np.arange(0,T),udgradient[0,:])
plt.plot(0.01*np.arange(0,T),usgradient[0,:])
plt.xlabel("Time(s)")
plt.ylabel("Input")
plt.legend(["Initial","D-gradient (dynamic)","D-gradient (static)"])

plt.figure()
plt.plot(0.01*np.arange(1,T),kpdgradient[0,1:])
plt.xlabel("Time(s)")
plt.ylabel("Proportional gain")

plt.figure()
plt.plot(0.01*np.arange(1,T),kidgradient[0,1:])
plt.xlabel("Time(s)")
plt.ylabel("Integral gain")

#plt.figure()
#plt.plot(0.01*np.arange(1,T),kddgradient[2,1:])
#plt.xlabel("Time(s)")
#plt.ylabel("Derivative gain")

plt.figure()
plt.plot(0.01*np.arange(1,T),backdgradient[0,1:])
plt.xlabel("Time(s)")
plt.ylabel("Back-calculation gain")
# Out:
# Text(0, 0.5, 'Back-calculation gain')

# %%
print(kpdgradient[6,0:300])
print(kidgradient[6,0:300])
# Out:
# [ 0.         22.03262711 23.01442719 23.01442719 22.0326252  22.0326252
#  22.0326252  22.03258896 22.0326252  22.03260803 23.01442719 23.01442719
#  23.01442719 23.01442719 22.0326252  23.01442719 22.0326252  23.01442719
#  23.0144062  22.0326252  23.01442719 23.01442719 23.00859451 22.68816376
#  22.0326252  22.03262329 22.03262329 22.0326252  22.0326252  22.0326252
#  21.79889297 23.01442719 23.01442719 23.01442719 22.0326252  22.0326252
#  22.0326252  23.01442719 23.01305008 22.0326252  22.0326252  23.01442719
#  23.01414108 22.0326252  21.03497314 23.01442719 23.01442719 23.01442719
#  22.0326252  22.03347969 23.01442719 22.0326252  22.58296967 22.0326252
#  22.0326252  23.01442719 22.0326252  23.01442719 22.04034042 22.04950333
#  22.0326252  22.00075912 23.01442719 23.01442719 23.01402092 22.0326252
#  23.01442719 23.01442719 22.03262138 23.01442719 22.0326252  22.0326252
#  22.0326786  23.01442719 23.01442719 22.0326252  23.01442719 23.01442719
#  22.0326252  22.03262329 20.96812057 23.01442719 23.01442719 22.0326252
#  22.0326252  23.01442719 22.0326252  22.0326252  23.01442719 23.01442719
#  23.01442719 22.03262329 23.01442719 23.01442719 22.0326252  22.03262329
#  22.0326252  22.0326252  23.01442719 22.0326252  23.01428223 22.03273392
#  22.0326252  23.01442719 23.01442719 23.01442719 22.0326252  23.01442719
#  22.0326252  22.0326252  23.01442719 22.0326252  22.0326252  23.01442719
#  23.01442719 22.04998398 23.01442719 22.98893929 22.0326252  23.01442719
#  22.0326252  22.98773575 22.0326252  21.33955383 22.0326252  22.0326252
#  23.01442719 23.01435089 23.01442719 23.01442719 23.0138588  22.0326252
#  22.0326252  23.01442719 22.0326252  23.01442719 23.01442719 22.51196289
#  22.0326252  22.03276062 23.01442719 22.0326252  22.0800209  22.0326252
#  22.0326252  23.01442719 23.01442719 22.03262329 23.01442719 22.0326252
#  23.01442719 22.0326252  22.0326252  22.03266525 23.01437569 22.0326252
#  22.03133583 23.01442719 22.0326252  22.0326252  23.01442719 23.01442719
#  23.01430702 22.0326252  22.0326252  23.01407242 23.01442719 23.00900841
#  23.01442719 22.03261948 22.0326252  22.0326252  23.01442719 23.01442719
#  22.03261948 23.01442719 23.01442719 22.03238297 23.01442719 23.01442719
#  23.01442719 22.0326252  23.01442719 22.0326252  23.01442719 22.0326252
#  22.0326252  22.0326252  22.0326252  22.03261948 22.0326252  20.96756554
#  22.0326252  22.0326252  23.01442719 23.01442719 22.0326252  23.01442719
#  22.0326252  22.95749664 22.03262711 22.03220367 23.01440048 22.03278732
#  22.0326252  22.0326252  23.01442719 23.01442719 22.0326252  22.0326252
#  22.0326252  23.01442719 22.0326252  23.01442719 23.01234436 23.01442719
#  23.01442719 22.0326252  23.01442719 23.01442719 22.0326252  22.0326252
#  23.01442719 22.0326252  23.01442719 23.01442719 22.0326252  23.01442719
#  22.0326252  23.01442719 22.0326252  22.58460617 22.0326252  22.0326252
#  22.90697861 22.0326252  23.01442719 22.0326252  22.0326252  23.01442719
#  22.0326252  23.01442719 22.0326252  22.03262329 23.01442719 22.0326252
#  23.01442719 22.0326252  23.01442719 23.01440048 23.01442719 22.03262329
#  22.0326252  22.03366852 22.0326252  20.96759987 22.0326252  22.03260422
#  22.0326252  22.0326252  23.01442719 22.03263474 23.01442719 22.0326252
#  23.01442719 22.03283691 22.0326252  23.01442719 22.13273621 22.0326252
#  23.01442719 22.0326252  23.01442719 22.0326252  22.03257751 23.01442719
#  23.01438332 22.03262329 23.01442719 22.0326252  22.0326252  22.0326252
#  23.01442719 22.0326252  23.01442719 23.01442719 22.0326252  22.0326252
#  22.00731659 23.01442719 23.01442719 22.0326252  22.0326252  22.0326252
#  22.0326252  22.0326252  23.01442719 23.01442719 22.0326252  21.99996185]
# [ 0.         10.57468987 12.07868385 12.07868385  6.95504332  6.96021605
#   6.95504332  6.95504332  7.18937874  6.95504332 12.07868385 12.07868385
#  12.07868385 12.07868385  6.95504332 12.07868385  6.95504379 12.07868385
#  12.07868385  6.95504332 12.07868385 12.07868385 12.0786829  12.07867146
#   6.97321367  6.95504332  6.95504332  6.95504332  6.95504332  6.95504332
#   6.95504332 12.07868385 12.07868385 12.07868385  6.95504332  6.95504332
#   6.97747993 12.07868385 12.0786829   6.95512438  6.95504332 12.07868385
#  12.07868385  6.95504332  6.95504332 12.07868385 12.07868385 12.07868385
#   6.95504332 12.07320881 12.07868385  7.44240856 12.07866764  6.95504332
#   6.95504332 12.07868385  6.95504332 12.07868385 12.07782745 12.07824135
#   6.95504332  6.95504332 12.07868385 12.07868385 12.07868385  6.95504332
#  12.07868385 12.07868385  6.95504332 12.07868385  8.09255981  6.95504332
#  12.01682281 12.07868385 12.07868385  6.95504332 12.07868385 12.07868385
#   6.95504332  6.95504332  6.95504332 12.07868385 12.07868385  6.95504332
#   6.95504332 12.07868385  6.95504332  6.95504332 12.07868385 12.07868385
#  12.07868385  6.95504332 12.07868385 12.07868385  6.95504332  6.95504332
#   6.95504332  6.95504379 12.07868385  6.95504332 12.07868385 12.05041122
#   6.95504332 12.07868385 12.07868385 12.07868385  6.95504379 12.07868385
#   6.95504379  6.95708179 12.07868385  6.95504332  6.95504332 12.07868385
#  12.07868385 12.07825184 12.07868385 12.07868195  6.95504332 12.07868385
#   6.97458267 12.07868195  6.95504379  6.95504332  6.95504332  6.95504332
#  12.07868385 12.07868385 12.07868385 12.07868385 12.0786829   6.95504332
#   6.95504332 12.07868385  6.95504332 12.07868385 12.07868385 12.07866383
#   6.95504332 12.05186939 12.07868385  6.95504379 12.07849503  6.95504332
#   6.95504332 12.07868385 12.07868385  6.95504332 12.07868385  6.95907116
#  12.07868385  6.95504332  6.95504332 12.00186729 12.07868385  6.95541143
#   6.95504332 12.07868385  6.95504332  6.95627117 12.07868385 12.07868385
#  12.07868385  6.95504332  6.95504332 12.07868385 12.07868385 12.0786829
#  12.07868385  6.95504332  6.95504332  6.9550457  12.07868385 12.07868385
#   6.95504332 12.07868385 12.07868385  6.95504332 12.07868385 12.07868385
#  12.07868385  6.95504332 12.07868385  6.9567194  12.07868385  6.95504332
#   6.95504332  6.95504332  8.49625111  6.95504332  6.95504332  6.95504332
#   6.95504332  6.95504332 12.07868385 12.07868385  6.95504332 12.07868385
#   7.54717922 12.07868099 11.09764099  6.95504332 12.07868385 12.05862617
#   6.95504332  6.95504332 12.07868385 12.07868385  6.97336197  6.95504332
#   6.95504332 12.07868385  6.95517826 12.07868385 12.0786829  12.07868385
#  12.07868385  6.95504332 12.07868385 12.07868385  6.95504332  6.95504856
#  12.07868385  6.95504332 12.07868385 12.07868385  6.95504332 12.07868385
#   6.95504332 12.07868385  6.95802021 12.07866859  6.95504332  6.95686769
#  12.07868004  6.95558643 12.07868385  6.95504332  6.95526028 12.07868385
#   6.95504332 12.07868385  6.95504332  6.95504332 12.07868385  6.95504332
#  12.07868385  6.95504332 12.07868385 12.07868385 12.07868385  6.95504332
#   6.95504332 12.07471085  6.95504332  6.95504332  6.95504332  6.95504332
#   6.95504332  6.95504332 12.07868385 11.77339935 12.07868385  7.00216818
#  12.07868385 12.06336403  6.95504332 12.07868385 12.07858658  6.95504332
#  12.07868385  6.95504332 12.07868385  8.83378792  6.95504332 12.07868385
#  12.07868385  6.95504332 12.07868385  6.95504332  6.95504951  6.95504332
#  12.07868385  6.95504379 12.07868385 12.07868385  6.95516682  6.95504332
#   6.95504332 12.07868385 12.07868385  6.95504332  6.95504332  6.95504332
#   6.98158979  6.95504761 12.07868385 12.07868385  6.95504332  6.95504332]

# %%
kpit = torch.tensor(kp,requires_grad=False)
kiit = torch.tensor(ki,requires_grad=False)
kdit = torch.tensor(kd,requires_grad=False)
PIDpg = neuralPID()
#optimizer = torch.optim.Adam((PIDpg.parameters()), lr=0.1)
#for iters in range(1000):
#   kpt,kit,kdt = PIDpg(torch.randn(3,))
#   print(kpt,kit,kdt)
#   loss = (kpt-kpit)**2+(kit-kiit)**2+(kdt-kdit)**2
#   optimizer.zero_grad()
#   loss.backward()
#   optimizer.step()

# %%
ysat = np.zeros((T,))
uvalssat = np.zeros((T,))

optimizer = torch.optim.Adam((PIDpg.parameters()), lr=0.1)

nupdates = 100
nepisodes = 120
for updates in range(nupdates):
  cost = np.zeros((nepisodes,T))
  ref = refs[updates%20,:]
  rcostsepisode = np.zeros((nepisodes*T,1))
  totalcost = np.zeros((nepisodes,))
  uvalsepisode = np.zeros((nepisodes*T,1))
  PIDinputsepisode = np.zeros((nepisodes*T,3))
  PIDstatesepisode = np.zeros((nepisodes*T,4))
  for episodes in range(nepisodes):
    xcont = 0
    x =[[0.0],[0.0]]  
    u = 0.0
    ucmd = 0.0
    
    ucmdvals = np.zeros((T,1))
    uvals =  np.zeros((T,1))
    PIDinputs = np.zeros((T,3))
    PIDstates = np.zeros((T,4))
    yt = 0.0
    D  = 0.0
    
    ad = Tf/(Tf+0.01)
    adt = torch.tensor(ad,requires_grad=False)
    adt = adt.float()
    noise = 0.01*np.random.randn(T,1)
    sigma = 0.5
    for t in range(T):
      yold = yt
      yt = np.clip(np.dot(sysC,x)+noise[t],-30.0,30.0)
      err = ref[t]-yt[0]
      xcont = xcont+err
      if(t>0):
         inp = np.array([err,u,ucmd])
         ninput = torch.tensor(inp,requires_grad=False)
         PIDinputs[t,:] = inp   
         kpdt,kidt,kddt = PIDpg(ninput.float())
         kpt = kpit+kpdt
         kit = kiit+kidt
         kdt = kdit+kddt
         kpn = kpt.detach().numpy()
         kin = kit.detach().numpy()
         kdn = kdt.detach().numpy()
         #print(kpn,kin,kdn)   
         bd = kdn[0]/(Tf+0.01)
         PIDstates[t,:] = [err,xcont,D,yt[0]-yold[0]] 
         D = ad*D-bd*(yt[0]-yold[0])
         ucmd = (0.01*kin[0]*xcont+kpn[0]*err+D)
      if(episodes==0):
        u = ucmd
      else:  
        u = ucmd+sigma*np.random.randn()
      uvals[t] = u
      u = np.clip(u,-35.0,35.0)
      x = np.dot(sysA,x)+sysB*u;
      cost[episodes,t] = (ref[t]-yt)**2
    #rcosts = np.flip(np.cumsum(np.flip(cost[episodes,:],[0]),0),[0])
    totalcost[episodes] = np.sum(cost[episodes,:])
    rcosts = np.repeat(totalcost[episodes],T,0)
    #if(episodes==0):
    #  print(updates,episodes,rcosts[0])
    rcostsepisode[episodes*T:(episodes+1)*T,0] = rcosts
    uvalsepisode[episodes*T:(episodes+1)*T,:] = uvals
    PIDinputsepisode[episodes*T:(episodes+1)*T,:] = PIDinputs
    PIDstatesepisode[episodes*T:(episodes+1)*T,:] = PIDstates
  print(updates,episodes,np.min(totalcost))
  PIDinputstorch = torch.tensor(PIDinputsepisode).float()
  PIDstatestorch = torch.tensor(PIDstatesepisode).float()
  uvalstorch = torch.tensor(uvalsepisode).float()
  rcoststorch = torch.tensor(rcostsepisode).float()
  costmean = torch.tensor(np.mean(totalcost)).float()
    
  kptvals,kitvals,kdtvals = PIDpg(PIDinputstorch)
  bdtvals = (kd+kdtvals)/(Tft+0.01)  
  Dvals = adt*PIDstatestorch[:,2]-bdtvals*PIDstatestorch[:,3]  
  ucmdvals = 0.01*torch.mul((ki+kitvals),PIDstatestorch[:,1])+torch.mul((kp+kptvals),PIDstatestorch[:,0])+Dvals
  
  updatecost = torch.mean(torch.mul((uvalstorch-ucmdvals)**2,rcoststorch-costmean))/(2*sigma)
  optimizer.zero_grad()
  updatecost.backward()
  optimizer.step()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-2b00b39fa3d9> in <module>
#      38       xcont = xcont+err
#      39       if(t>0):
# ---> 40          inp = np.array([err,u,ucmd])
#      41          ninput = torch.tensor(inp,requires_grad=False)
#      42          PIDinputs[t,:] = inp
#
# KeyboardInterrupt:
